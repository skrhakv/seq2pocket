# %%
import torch
from transformers import AutoTokenizer, EsmModel
import torch.nn as nn
import numpy as np

sys.path.append('/home/skrhakv/cryptic-nn/src')
import finetuning_utils

# some constants
MODEL_NAME = "facebook/esm2_t33_650M_UR50D"
MAX_LENGTH = 1024
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
OUTPUT_SIZE = 1
DROPOUT = 0.25

# UPDATE THIS!
MODEL_PATH = "/home/skrhakv/cryptic-nn/final-data/trained-models/multitask-finetuned-model-with-ligysis.pt"

# define the model - if we do not define the model then the loading of the model will fail
class FinetuneESM(nn.Module):
    def __init__(self, esm_model: str) -> None:
        super().__init__()
        self.llm = EsmModel.from_pretrained(esm_model)
        self.dropout = nn.Dropout(DROPOUT)
        self.classifier = nn.Linear(self.llm.config.hidden_size, OUTPUT_SIZE)
        self.plDDT_regressor = nn.Linear(self.llm.config.hidden_size, OUTPUT_SIZE)
        self.distance_regressor = nn.Linear(self.llm.config.hidden_size, OUTPUT_SIZE)

    def forward(self, batch: dict[str, np.ndarray]) -> torch.Tensor:
        input_ids, attention_mask = batch["input_ids"], batch["attention_mask"]
        token_embeddings = self.llm(
            input_ids=input_ids, attention_mask=attention_mask
        ).last_hidden_state
        
        return self.classifier(token_embeddings), self.plDDT_regressor(token_embeddings), self.distance_regressor(token_embeddings)

# load the model
model = torch.load(MODEL_PATH, weights_only=False)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model.eval()

with open('/home/skrhakv/cryptoshow-analysis/src/E-regular-binding-site-predictor/evaluation/creatine-kinase/3b6rB.txt', 'r') as f:
    sequence = f.readline()

# %%
import sys
sys.path.append('/home/skrhakv/cryptoshow-analysis/src/B-evaluate-cryptoshow')
import eval_utils

DECISION_THRESHOLD = 0.8
DROPOUT = 0.3
LAYER_WIDTH = 256
ESM2_DIM  = 1280 * 2

class CryptoBenchClassifier(nn.Module):
    def __init__(self, input_dim=ESM2_DIM):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=input_dim, out_features=LAYER_WIDTH)
        self.dropout1 = nn.Dropout(DROPOUT)

        self.layer_2 = nn.Linear(in_features=LAYER_WIDTH, out_features=LAYER_WIDTH)
        self.dropout2 = nn.Dropout(DROPOUT)

        self.layer_3 = nn.Linear(in_features=LAYER_WIDTH, out_features=1)

        self.relu = nn.ReLU()

    def forward(self, x):
        # Intersperse the ReLU activation function between layers
        return self.layer_3(self.dropout2(self.relu(self.layer_2(self.dropout1(self.relu(self.layer_1(x)))))))
    

HIGH_SCORE_THRESHOLD = 0.7  # Threshold to consider a point as high score
SMOOTHENED_THRESHOLD = 0.7 # this is defined by the training data - best F1 score was achieved with this threshold 
SMOOTHING_MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/C-optimize-smoother/smoother.pt'
smoothing_model = torch.load(SMOOTHING_MODEL_PATH, weights_only=False)

# %%
OUTPUT_PATH = '/home/skrhakv/cryptoshow-analysis/src/E-regular-binding-site-predictor/evaluation/creatine-kinase'
pdb_id = '3b6r'
chain_id = 'B'

embedding_path = f'{OUTPUT_PATH}/{pdb_id}{chain_id}_embedding-3B.npy'
coordinates_path = f'{OUTPUT_PATH}/{pdb_id}{chain_id}.npy'

prediction = eval_utils.compute_prediction(
    sequence,
    embedding_path,
    model,
    tokenizer
)

coordinates = np.load(coordinates_path)
clusters = eval_utils.compute_clusters(
        coordinates,
        prediction,
        decision_threshold=DECISION_THRESHOLD,
        method='dbscan',
        eps=3,
        min_samples=1
    )


distance_matrix = eval_utils.compute_distance_matrix(coordinates)

# enhance predicted pockets using the smoothing model
predicted_binding_sites = []
for cluster_label in np.unique(clusters):
    if cluster_label == -1:
        continue
    cluster_residue_indices = np.where(clusters == cluster_label)[0]
    embeddings, indices = eval_utils.process_single_sequence(pdb_id, chain_id, cluster_residue_indices, '/home/skrhakv/cryptoshow-analysis/src/E-regular-binding-site-predictor/evaluation/creatine-kinase/3b6rB-nonfinetuned-embedding.npy', distance_matrix) 
    
    prediction = eval_utils.predict_single_sequence(embeddings, indices, smoothing_model)

    enhanced_residue_indices = np.concatenate((indices[prediction['predictions'] > SMOOTHENED_THRESHOLD], cluster_residue_indices))
    predicted_binding_sites.append(enhanced_residue_indices)

import pickle
with open(f'{OUTPUT_PATH}/{pdb_id}{chain_id}.pkl', 'wb') as f:
    pickle.dump(predicted_binding_sites, f)

predicted_binding_sites
# Out:
# [array([53]),
#  array([54]),
#  array([57]),
#  array([63]),
#  array([64]),
#  array([277, 278, 279,  53,  65]),
#  array([66]),
#  array([67]),
#  array([278,  68]),
#  array([277,  69]),
#  array([335,  90]),
#  array([122]),
#  array([286, 126, 124]),
#  array([286, 126]),
#  array([234, 185]),
#  array([199]),
#  array([280, 277]),
#  array([284, 278]),
#  array([279]),
#  array([277, 286, 280]),
#  array([126, 286]),
#  array([288]),
#  array([329, 288, 314, 124, 290]),
#  array([314]),
#  array([316]),
#  array([317]),
#  array([315, 318]),
#  array([319]),
#  array([329]),
#  array([329, 286, 290, 314, 124, 331])]

# %%
[array([ 67, 195, 198, 199,  53,  54,  55,  57,  56]),
 array([ 65,  67,  68,  69, 195,  22,  23, 277, 278, 279,  53,  54,  63,
         66]),
 array([286, 126, 124]),
 array([286, 230, 124, 126]),
 array([195, 197, 198, 199, 200, 201, 202, 203, 225,  53, 196]),
 array([276,  53,  54,  56,  67,  68, 195, 196, 198, 225, 199, 200, 201]),
 array([230, 222]),
 array([222, 225, 126, 230]),
 array([286,  66,  67, 199, 201, 276, 277, 278, 279, 280]),
 array([280, 124, 126, 286]),
 array([320, 321, 318, 319, 315, 316, 317, 314]),
 array([320, 321, 329, 290, 185, 314, 315,  63, 316, 317, 318, 319])]

# %% [markdown]
# ## Try-out clustering

# %%
CLUSTERING_MODEL_STATE_DICT_PATH = '/home/skrhakv/cryptoshow-analysis/data/F-clustering/clustering.pt'
clustering_model = torch.load(CLUSTERING_MODEL_STATE_DICT_PATH, weights_only=False)
CLUSTERING_DECISION_THRESHOLD = 0.9

# %% [markdown]
# ### Greedy approach
# If the subpocket is predicted as positive with any other subpocket, then add it into the mix

# %%
def get_index_in_final_clustering(index, final_clustering):
    for cluster_index, cluster in enumerate(final_clustering):
        if index in cluster:
            return True, cluster_index
    return False, -1

def merge_indices_in_final_clustering(index_1, index_2, final_clustering):
    is_index_1_in_final, index_1_in_final = get_index_in_final_clustering(index_1, final_clustering)
    is_index_2_in_final, index_2_in_final = get_index_in_final_clustering(index_2, final_clustering)
    
    if is_index_1_in_final and is_index_2_in_final:
        if index_1_in_final != index_2_in_final:
            final_clustering[index_1_in_final].extend(final_clustering[index_2_in_final])
            del final_clustering[index_2_in_final]
    elif is_index_1_in_final:
        final_clustering[index_1_in_final].append(index_2)
    elif is_index_2_in_final:
        final_clustering[index_2_in_final].append(index_1)
    else:
        final_clustering.append([index_1, index_2])

    return final_clustering

def get_embedding(embeddings, predicted_binding_site_i, predicted_binding_site_ii):
    embeddings_i = embeddings[predicted_binding_site_i]
    embeddings_ii = embeddings[predicted_binding_site_ii]

    mean_embedding_i = np.mean(embeddings_i, axis=0)
    mean_embedding_ii = np.mean(embeddings_ii, axis=0)

    combined_embedding1 = np.concatenate((mean_embedding_i, mean_embedding_ii), axis=0)
    combined_embedding1 = torch.tensor(combined_embedding1, dtype=torch.float32)

    combined_embedding2 = np.concatenate((mean_embedding_ii, mean_embedding_i), axis=0)
    combined_embedding2 = torch.tensor(combined_embedding2, dtype=torch.float32)

    return (combined_embedding1, combined_embedding2)

def predict(embedding, model):
    combined_embedding1, combined_embedding2 = embedding

    probability1 = torch.sigmoid(model(combined_embedding1.to(DEVICE)))
    probability2 = torch.sigmoid(model(combined_embedding2.to(DEVICE)))

    prediction1 = (probability1 > CLUSTERING_DECISION_THRESHOLD).float()
    prediction2 = (probability2 > CLUSTERING_DECISION_THRESHOLD).float()

    print(probability1.detach().cpu().numpy(), probability2.detach().cpu().numpy())

    # this fails sometimes, but it is a close call, so we will ignore it
    # assert prediction1 == prediction2, "Inconsistent clustering predictions! {}, {}".format(prediction1, prediction2)

    return (prediction1 == 1.0) and (prediction2 == 1.0)

embedding_path = f'/home/skrhakv/cryptoshow-analysis/src/E-regular-binding-site-predictor/evaluation/creatine-kinase/3b6rB-nonfinetuned-embedding.npy'
embeddings = np.load(embedding_path)

final_clustering = []

for i, predicted_binding_site_i in enumerate(predicted_binding_sites):
    was_added = False
    for ii, predicted_binding_site_ii in enumerate(predicted_binding_sites):
        if ii <= i:
            continue

        combined_embedding = get_embedding(embeddings, predicted_binding_site_i, predicted_binding_site_ii)

        should_cluster_together = predict(combined_embedding, clustering_model)
        if should_cluster_together:
            final_clustering = merge_indices_in_final_clustering(i, ii, final_clustering)
            was_added = True
            
    if not was_added:
        final_clustering.append([i])

print('Final clustering:', final_clustering)
final_predicted_binding_sites = []
for cluster in final_clustering:
    this_final_binding_site = []
    for binding_site_index in cluster:
        this_final_binding_site.extend(predicted_binding_sites[binding_site_index])
    final_predicted_binding_sites.append(this_final_binding_site)

final_predicted_binding_sites
# Out:
# [0.73246205] [0.72424614]
# [0.9998828] [0.99975115]
# [0.9987476] [0.9977325]
# [0.82559454] [0.88224685]
# [0.9685042] [0.9410501]
# [0.9702105] [0.96801555]
# [0.42557165] [0.21715511]
# [0.9170285] [0.923472]
# [0.9931484] [0.9885749]
# [0.99744284] [0.99628735]
# [0.8916586] [0.9513483]
# [0.9979038] [0.9972186]
# [0.99803215] [0.99770516]
# [0.91990185] [0.889909]
# [0.00350576] [0.00565635]
# [0.95828855] [0.9394036]
# [0.40025485] [0.16760966]
# [0.63469607] [0.31079873]
# [0.99502796] [0.99186945]
# [0.99803215] [0.99770516]
# [0.3548842] [0.23747057]
# [0.9943773] [0.9891289]
# [0.97693765] [0.95589286]
# [0.55231136] [0.6516763]
# [0.48167482] [0.55293876]
# [0.23479061] [0.16633058]
# [0.9977977] [0.99440825]
# [0.95203006] [0.90067524]
# [0.99448293] [0.9913897]
# [0.99983394] [0.999708]
# [0.99765944] [0.99353576]
# [0.5259135] [0.6433668]
# [0.96922964] [0.9219403]
# [0.9737176] [0.96466863]
# [0.30592206] [0.13826908]
# [0.93118924] [0.8730327]
# [0.9947713] [0.98940337]
# [0.9972946] [0.99683446]
# [0.93268824] [0.9296092]
# [0.99878544] [0.99836475]
# [0.9987521] [0.99900407]
# [0.94727296] [0.9036824]
# [0.00426422] [0.00179777]
# [0.9732122] [0.9574585]
# [0.39635006] [0.1829007]
# [0.6313702] [0.24952734]
# [0.99649906] [0.9947966]
# [0.9987521] [0.99900407]
# [0.36637804] [0.22158015]
# [0.9960459] [0.9931764]
# [0.9863955] [0.97657347]
# [0.41311604] [0.4895813]
# [0.21065639] [0.22497562]
# [0.23689136] [0.18221669]
# [0.99890983] [0.99566615]
# [0.9704359] [0.9220309]
# [0.9966487] [0.99528426]
# [0.99998915] [0.9999747]
# [0.99919146] [0.99964046]
# [0.99998355] [0.99998045]
# [0.999907] [0.99989736]
# [0.9993931] [0.9988159]
# [0.99995244] [0.9999392]
# [0.99999475] [0.99999297]
# [0.99999726] [0.99999714]
# [0.9999466] [0.9999683]
# [0.9999987] [0.9999988]
# [0.9999988] [0.9999989]
# [0.99997723] [0.99997246]
# [0.9210362] [0.9658334]
# [0.99997675] [0.999982]
# [0.9994711] [0.9993082]
# [0.9997733] [0.9995208]
# [0.9999963] [0.999997]
# [0.9999988] [0.9999989]
# [0.99904615] [0.9994617]
# [0.9999975] [0.99999774]
# [0.9999907] [0.99998784]
# [0.9989606] [0.99939215]
# [0.99923694] [0.99963605]
# [0.9993156] [0.9991917]
# [0.99999523] [0.9999882]
# [0.9999819] [0.99998045]
# [0.99999785] [0.99999785]
# [0.9892413] [0.994337]
# [0.99952567] [0.9995467]
# [0.9989054] [0.9993795]
# [0.9860583] [0.97192365]
# [0.99835074] [0.9990606]
# [0.9997322] [0.99982613]
# [0.99991596] [0.99996376]
# [0.9971814] [0.9995881]
# [0.9998878] [0.9999651]
# [0.999887] [0.99996686]
# [0.9949869] [0.9977475]
# [0.20400724] [0.45215338]
# [0.9975268] [0.99897206]
# [0.96930426] [0.96761996]
# [0.99177974] [0.9878307]
# [0.9996767] [0.99984205]
# [0.999887] [0.99996686]
# [0.9403059] [0.9794545]
# [0.9997509] [0.9998615]
# [0.99907553] [0.99953055]
# [0.9893798] [0.996485]
# [0.9870106] [0.9963174]
# [0.9665705] [0.9770544]
# [0.999892] [0.9999219]
# [0.99794406] [0.99801755]
# [0.99976057] [0.9998816]
# [0.97342795] [0.90453124]
# [0.84873307] [0.8485162]
# [0.3031475] [0.06609726]
# [0.87807715] [0.8131708]
# [0.98530257] [0.9618537]
# [0.99668247] [0.9927153]
# [0.8577236] [0.90068704]
# [0.9963547] [0.9924975]
# [0.9962435] [0.9934068]
# [0.7616482] [0.58985335]
# [0.00423518] [0.00314742]
# [0.9081273] [0.8405058]
# [0.30389675] [0.06699707]
# [0.5814653] [0.22829308]
# [0.9880469] [0.9745386]
# [0.9962435] [0.9934068]
# [0.1866305] [0.06368249]
# [0.9889148] [0.9639523]
# [0.9503715] [0.8928416]
# [0.5882163] [0.5928735]
# [0.60747445] [0.4430066]
# [0.23322459] [0.07214089]
# [0.9922437] [0.9806147]
# [0.8896993] [0.6427633]
# [0.98963964] [0.97286725]
# [0.994865] [0.99640405]
# [0.8198469] [0.74028486]
# [0.98410946] [0.9919497]
# [0.9994111] [0.9994456]
# [0.9997404] [0.9997397]
# [0.9793742] [0.9952866]
# [0.99975175] [0.9998419]
# [0.99976677] [0.9998715]
# [0.990348] [0.99399227]
# [0.01272514] [0.03944893]
# [0.9951121] [0.9969182]
# [0.7558829] [0.7093178]
# [0.8932304] [0.7777626]
# [0.99950016] [0.9996283]
# [0.99976677] [0.9998715]
# [0.7453402] [0.7352974]
# [0.99940157] [0.9995376]
# [0.99784267] [0.9973348]
# [0.75877446] [0.9379751]
# [0.7040466] [0.86143273]
# [0.631263] [0.66758037]
# [0.9996712] [0.99945897]
# [0.9923685] [0.9937046]
# [0.9994011] [0.9996275]
# [0.9390405] [0.8039242]
# [0.9891054] [0.98854816]
# [0.99841666] [0.99857545]
# [0.9998155] [0.9997676]
# [0.98918414] [0.99725974]
# [0.9997603] [0.9998404]
# [0.99975985] [0.9998579]
# [0.9684921] [0.9794026]
# [0.02848182] [0.04524619]
# [0.9907803] [0.9933068]
# [0.8705113] [0.76393455]
# [0.96970046] [0.89098036]
# [0.9988595] [0.9991315]
# [0.99975985] [0.9998579]
# [0.89592314] [0.87849164]
# [0.9991479] [0.9993061]
# [0.9976412] [0.9973254]
# [0.88320494] [0.9390997]
# [0.924891] [0.9446358]
# [0.89804494] [0.8298506]
# [0.9995208] [0.9992624]
# [0.9949254] [0.99158746]
# [0.999161] [0.99943465]
# [0.53732675] [0.7467485]
# [0.9414625] [0.9799605]
# [0.9810523] [0.98703206]
# [0.58463585] [0.8315075]
# [0.98787016] [0.9944026]
# [0.98948544] [0.9965932]
# [0.5787625] [0.6936055]
# [0.00036729] [0.00066702]
# [0.7521539] [0.8948784]
# [0.05004019] [0.07741144]
# [0.15623936] [0.13955429]
# [0.96261495] [0.9866173]
# [0.98948544] [0.9965932]
# [0.05358499] [0.0905972]
# [0.96070534] [0.9748284]
# [0.86898935] [0.9208069]
# [0.05663579] [0.26795262]
# [0.02681497] [0.09132293]
# [0.03023013] [0.05794767]
# [0.9902444] [0.9935284]
# [0.74031574] [0.7737694]
# [0.967882] [0.9806076]
# [0.99777395] [0.9978484]
# [0.999331] [0.9993075]
# [0.9700247] [0.98739606]
# [0.9994331] [0.9995447]
# [0.9994686] [0.99961805]
# [0.9469119] [0.97050834]
# [0.00677265] [0.01473674]
# [0.98224187] [0.9876332]
# [0.6324295] [0.39923874]
# [0.83776534] [0.5221439]
# [0.99833965] [0.99847203]
# [0.9994686] [0.99961805]
# [0.5984053] [0.56635445]
# [0.99849784] [0.99836355]
# [0.99379396] [0.9919775]
# [0.71073395] [0.8152752]
# [0.6298971] [0.72874695]
# [0.48529482] [0.47249073]
# [0.9992945] [0.99861455]
# [0.97998446] [0.9743921]
# [0.99855703] [0.9985625]
# [0.99997115] [0.999972]
# [0.99841654] [0.99933213]
# [0.99997973] [0.9999877]
# [0.9999765] [0.9999896]
# [0.99873775] [0.9991948]
# [0.10999274] [0.20521197]
# [0.99928075] [0.9995951]
# [0.96902496] [0.95684016]
# [0.9912196] [0.97804135]
# [0.9999229] [0.99995637]
# [0.9999765] [0.9999896]
# [0.9712425] [0.9715892]
# [0.9999521] [0.99996066]
# [0.9997849] [0.9997967]
# [0.9620698] [0.9834637]
# [0.95646083] [0.96554494]
# [0.9648454] [0.9480427]
# [0.9999325] [0.9998584]
# [0.9994361] [0.99927837]
# [0.9999521] [0.99997056]
# [0.9993135] [0.9997111]
# [0.99998593] [0.99999106]
# [0.99998677] [0.9999918]
# [0.9995989] [0.9996916]
# [0.3455401] [0.4846331]
# [0.9997454] [0.99982125]
# [0.9857202] [0.97694016]
# [0.9939406] [0.98903555]
# [0.9999672] [0.99997723]
# [0.99998677] [0.9999918]
# [0.97600627] [0.98459744]
# [0.9999665] [0.99997616]
# [0.99985635] [0.99986064]
# [0.98579514] [0.99494886]
# [0.9763949] [0.9829055]
# [0.9737857] [0.96817285]
# [0.99997807] [0.9999484]
# [0.9997056] [0.9996586]
# [0.9999696] [0.9999825]
# [0.9997162] [0.9996431]
# [0.9997031] [0.9997247]
# [0.989935] [0.9700715]
# [0.01350359] [0.0093383]
# [0.9948508] [0.98988885]
# [0.7848189] [0.5416081]
# [0.8975469] [0.50095356]
# [0.9992932] [0.9987627]
# [0.9997031] [0.9997247]
# [0.6787456] [0.58922917]
# [0.99933714] [0.9986217]
# [0.99702424] [0.99529934]
# [0.86052644] [0.75394595]
# [0.6980633] [0.63596]
# [0.7128152] [0.49113998]
# [0.99971694] [0.9985476]
# [0.99503016] [0.9823622]
# [0.9992981] [0.99878484]
# [0.9999933] [0.9999938]
# [0.99984324] [0.9996823]
# [0.41349995] [0.4936839]
# [0.9999089] [0.999864]
# [0.9930854] [0.98471886]
# [0.9969789] [0.9897194]
# [0.9999864] [0.9999815]
# [0.9999933] [0.9999938]
# [0.9927395] [0.9904389]
# [0.9999865] [0.9999832]
# [0.9999424] [0.99989593]
# [0.9905496] [0.9947567]
# [0.9859971] [0.9882272]
# [0.989369] [0.98482275]
# [0.9999876] [0.9999356]
# [0.99988174] [0.99985456]
# [0.99998796] [0.99998665]
# [0.99987674] [0.9996728]
# [0.5072965] [0.5130844]
# [0.99993] [0.9998683]
# [0.9950311] [0.9860854]
# [0.99788755] [0.9908035]
# [0.9999888] [0.9999814]
# [0.9999939] [0.9999939]
# [0.9951899] [0.9918417]
# [0.9999894] [0.9999827]
# [0.99995446] [0.99990094]
# [0.9917434] [0.99477273]
# [0.9903887] [0.98947436]
# [0.99307066] [0.9855517]
# [0.99998856] [0.99993396]
# [0.99990976] [0.99987185]
# [0.99998987] [0.99998665]
# [0.00860384] [0.01366017]
# [0.99586785] [0.99541473]
# [0.6238859] [0.48821926]
# [0.8921559] [0.7134988]
# [0.9994276] [0.9996006]
# [0.9996728] [0.99987674]
# [0.64397836] [0.7166303]
# [0.9992495] [0.9993327]
# [0.9955238] [0.99588037]
# [0.7454998] [0.7779182]
# [0.5825718] [0.7042088]
# [0.59349114] [0.50590336]
# [0.999268] [0.99707496]
# [0.9921185] [0.98741096]
# [0.9993118] [0.9995022]
# [0.04175685] [0.03728127]
# [0.00058651] [0.00025381]
# [0.00388329] [0.0003415]
# [0.24426155] [0.2171284]
# [0.5130844] [0.5072965]
# [0.00070494] [0.00052029]
# [0.21780509] [0.16595279]
# [0.06700683] [0.04686594]
# [0.00118448] [0.00162096]
# [0.00099569] [0.00113042]
# [0.0003754] [0.00033643]
# [0.60610473] [0.17344427]
# [0.04705265] [0.03084103]
# [0.21398298] [0.17784607]
# [0.85216737] [0.8068309]
# [0.95790106] [0.89802486]
# [0.9997131] [0.9997615]
# [0.9998683] [0.99993]
# [0.89476424] [0.8825489]
# [0.99979943] [0.99974614]
# [0.99901104] [0.99850404]
# [0.78681886] [0.9097846]
# [0.80858666] [0.8125214]
# [0.8468504] [0.78796643]
# [0.99967706] [0.99906224]
# [0.99771345] [0.99745136]
# [0.9997701] [0.99978226]
# [0.16116057] [0.07739741]
# [0.968731] [0.9781742]
# [0.9860854] [0.9950311]
# [0.09903711] [0.09242096]
# [0.9660886] [0.97591114]
# [0.87473243] [0.904337]
# [0.05355796] [0.26777717]
# [0.03954635] [0.10245431]
# [0.03955219] [0.04735801]
# [0.9888876] [0.98282456]
# [0.7814083] [0.7989886]
# [0.96361184] [0.97713405]
# [0.9815332] [0.9934823]
# [0.9908035] [0.99788755]
# [0.14058782] [0.24007988]
# [0.97417647] [0.9887953]
# [0.9179477] [0.9629971]
# [0.1065925] [0.57054967]
# [0.09496636] [0.34098]
# [0.07847717] [0.12670146]
# [0.99338657] [0.9955058]
# [0.90161705] [0.9508068]
# [0.9725743] [0.9905075]
# [0.9999814] [0.9999888]
# [0.9831476] [0.9808363]
# [0.99997294] [0.9999685]
# [0.9998779] [0.9997917]
# [0.96508205] [0.9862279]
# [0.97118336] [0.970523]
# [0.97667706] [0.9662646]
# [0.9999535] [0.999826]
# [0.99970895] [0.9996618]
# [0.9999721] [0.99997437]
# [0.9951899] [0.9918417]
# [0.9999894] [0.9999827]
# [0.99995446] [0.99990094]
# [0.9917434] [0.99477273]
# [0.9903887] [0.98947436]
# [0.99307066] [0.9855517]
# [0.99998856] [0.99993396]
# [0.99990976] [0.99987185]
# [0.99998987] [0.99998665]
# [0.97654426] [0.97028714]
# [0.9313773] [0.9241979]
# [0.08301046] [0.27147353]
# [0.04549506] [0.07536932]
# [0.06790747] [0.06994739]
# [0.9935411] [0.98712975]
# [0.90084654] [0.87496215]
# [0.9789122] [0.97542727]
# [0.9998449] [0.99978846]
# [0.9689118] [0.98454905]
# [0.9443637] [0.9691563]
# [0.95610183] [0.96180606]
# [0.99995923] [0.9998809]
# [0.99963796] [0.99959093]
# [0.9999716] [0.9999734]
# [0.8909492] [0.93407696]
# [0.84080297] [0.885169]
# [0.868754] [0.85503274]
# [0.99980885] [0.9995703]
# [0.9980519] [0.9986999]
# [0.99980384] [0.9998809]
# [0.36482468] [0.2500807]
# [0.13908577] [0.05465474]
# [0.9951696] [0.98804176]
# [0.87497] [0.86079973]
# [0.9818619] [0.9765555]
# [0.04689017] [0.02767359]
# [0.99593216] [0.9849798]
# [0.8143883] [0.7236555]
# [0.97475976] [0.95943403]
# [0.990906] [0.9877336]
# [0.80633086] [0.7965752]
# [0.9640427] [0.9694583]
# [0.99927324] [0.99958795]
# [0.9998516] [0.9999635]
# [0.9996772] [0.99971217]
# Final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29, 1, 11, 14, 4, 7, 15, 17, 18, 21, 24, 25, 26], [15], [29]]
# [[53,
#   57,
#   63,
#   277,
#   278,
#   279,
#   53,
#   65,
#   66,
#   278,
#   68,
#   277,
#   69,
#   335,
#   90,
#   286,
#   126,
#   124,
#   286,
#   126,
#   280,
#   277,
#   277,
#   286,
#   280,
#   126,
#   286,
#   329,
#   288,
#   314,
#   124,
#   290,
#   314,
#   319,
#   329,
#   329,
#   286,
#   290,
#   314,
#   124,
#   331,
#   54,
#   122,
#   234,
#   185,
#   64,
#   67,
#   199,
#   284,
#   278,
#   279,
#   288,
#   316,
#   317,
#   315,
#   318],
#  [199],
#  [329, 286, 290, 314, 124, 331]]

# %% [markdown]
# ### Unified-vote approach
# Every subpocket has to agree with adding another subpocket.

# %%
embedding_path = f'/home/skrhakv/cryptoshow-analysis/src/E-regular-binding-site-predictor/evaluation/creatine-kinase/3b6rB-nonfinetuned-embedding.npy'
embeddings = np.load(embedding_path)

decisions = {}

VERBOSE = True
final_clustering = []

# this is similar as before
for i, predicted_binding_site_i in enumerate(predicted_binding_sites):
    for ii, predicted_binding_site_ii in enumerate(predicted_binding_sites):
        if ii <= i:
            continue
        if VERBOSE:
            print('Considering merging', i, f'({predicted_binding_site_i})', ii, f'({predicted_binding_site_ii})')
        combined_embedding = get_embedding(embeddings, predicted_binding_site_i, predicted_binding_site_ii)
        should_cluster_together = predict(combined_embedding, clustering_model)
        
        if (i, ii) not in decisions:
            decisions[(i, ii)] = should_cluster_together
            decisions[(ii, i)] = should_cluster_together
        else:
            if decisions[(i, ii)] != should_cluster_together:
                if VERBOSE:
                    print('Inconsistent decision for', i, ii, 'existing:', decisions[(i, ii)], 'new:', should_cluster_together)

        if not should_cluster_together:
            if VERBOSE:
                print('Not merging', i, f'({predicted_binding_site_i})' , ii, f'({predicted_binding_site_ii})', 'based on initial prediction')
        merge = True if should_cluster_together else False # potential merging candidate if the clusters agree
        # here, if we want to merge, we need to check that all subpockets agree:
        if should_cluster_together:
            if VERBOSE:
                print('Initial agreement for merging', i, f'({predicted_binding_site_i})', ii, f'({predicted_binding_site_ii})' f'; check for all members of {i}th cluster')
            # first check if i-th cluster is OK with merging the ii-th subpocket
            is_index_in_final_clustering_i, index_in_final_i = get_index_in_final_clustering(i, final_clustering)
            if VERBOSE:
                print('is_index_in_final_clustering_i:', is_index_in_final_clustering_i, 'index_in_final_i:', index_in_final_i)
            if is_index_in_final_clustering_i: # is the i-th subpocket actually a part of some cluster? Because if not, then we already collected that one vote (and it was positive)
                i_th_cluster = final_clustering[index_in_final_i]
                for subpocket_index in i_th_cluster:
                    if VERBOSE:
                        print('\tChecking member', subpocket_index, 'of cluster', i_th_cluster)
                    if subpocket_index == i:
                        continue
                    # check if all members agree with merging ii-th subpocket
                    member_subpocket = predicted_binding_sites[subpocket_index] # get the residues of the member subpocket
                    print('\tmember_subpocket:', member_subpocket, 'predicted_binding_site_ii:', predicted_binding_site_ii)

                    combined_embedding = get_embedding(embeddings, member_subpocket, predicted_binding_site_ii)
                    should_cluster_together_member = predict(combined_embedding, clustering_model)

                    if VERBOSE:
                        print('\tMember', subpocket_index, 'predicts merging with', ii, ':', should_cluster_together_member)

                    if (subpocket_index, ii) not in decisions:
                        decisions[(subpocket_index, ii)] = should_cluster_together_member
                        decisions[(ii, subpocket_index)] = should_cluster_together_member
                    else:
                        if decisions[(subpocket_index, ii)] != should_cluster_together_member:
                            if VERBOSE: 
                                print('\tInconsistent decision for', subpocket_index, ii, 'existing:', decisions[(subpocket_index, ii)], 'new:', should_cluster_together_member)

                    if not should_cluster_together_member:
                        if VERBOSE:
                            print('\tNot merging', i, ii, 'because of member', subpocket_index, ' in cluster', i_th_cluster)
                        merge = False
                        break
            
            is_index_in_final_clustering_ii, index_in_final_ii = get_index_in_final_clustering(ii, final_clustering)

            if VERBOSE:
                print('check second candidate; check for all members of', ii, 'th cluster')
                print('is_index_in_final_clustering_ii:', is_index_in_final_clustering_ii, 'index_in_final_ii:', index_in_final_ii)

            if is_index_in_final_clustering_ii: # is the ii-th subpocket actually a part of some cluster? Because if not, then we already collected that one vote (and it was positive)
                ii_th_cluster = final_clustering[index_in_final_ii]
                for subpocket_index in ii_th_cluster:
                    if VERBOSE:
                        print('Checking member', subpocket_index, 'of cluster', ii_th_cluster)
                    if subpocket_index == ii:
                        continue
                    # check if all members agree with merging ii-th subpocket

                    member_subpocket = predicted_binding_sites[subpocket_index] # get the residues of the member subpocket
                    print('\tmember_subpocket:', member_subpocket, 'predicted_binding_site_i:', predicted_binding_site_i)

                    combined_embedding = get_embedding(embeddings, member_subpocket, predicted_binding_site_i)
                    should_cluster_together_member = predict(combined_embedding, clustering_model)

                    if VERBOSE:
                        print('\tMember', subpocket_index, 'predicts merging with', i, ':', should_cluster_together_member)

                    if (subpocket_index, i) not in decisions:
                        decisions[(subpocket_index, i)] = should_cluster_together_member
                        decisions[(i, subpocket_index)] = should_cluster_together_member
                    else:
                        if decisions[(subpocket_index, i)] != should_cluster_together_member:
                            if VERBOSE:
                                print('\tInconsistent decision for', subpocket_index, i, 'existing:', decisions[(subpocket_index, i)], 'new:', should_cluster_together_member)

                    if not should_cluster_together_member:
                        if VERBOSE:
                            print('\tNot merging', i, ii, 'because of member', subpocket_index)
                        merge = False
                        break
            if VERBOSE:
                print('All members agree for merging', i, ii, '; final clustering:', final_clustering)
            
        if merge:
            final_clustering = merge_indices_in_final_clustering(i, ii, final_clustering)
            print('Merging', i, ii, final_clustering)

print('Final clustering:', final_clustering)
final_predicted_binding_sites = []
for cluster in final_clustering:
    this_final_binding_site = []
    for binding_site_index in cluster:
        this_final_binding_site.extend(predicted_binding_sites[binding_site_index])
    final_predicted_binding_sites.append(this_final_binding_site)

final_predicted_binding_sites
# Out:
# Considering merging 0 ([53]) 1 ([54])
# [0.73246205] [0.72424614]
# Not merging 0 ([53]) 1 ([54]) based on initial prediction
# Considering merging 0 ([53]) 2 ([57])
# [0.9998828] [0.99975115]
# Initial agreement for merging 0 ([53]) 2 ([57]); check for all members of 0th cluster
# is_index_in_final_clustering_i: False index_in_final_i: -1
# check second candidate; check for all members of 2 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 2 ; final clustering: []
# Merging 0 2 [[0, 2]]
# Considering merging 0 ([53]) 3 ([63])
# [0.9987476] [0.9977325]
# Initial agreement for merging 0 ([53]) 3 ([63]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2]
# 	Checking member 2 of cluster [0, 2]
# 	member_subpocket: [57] predicted_binding_site_ii: [63]
# [0.99998915] [0.9999747]
# 	Member 2 predicts merging with 3 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 3 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 3 ; final clustering: [[0, 2]]
# Merging 0 3 [[0, 2, 3]]
# Considering merging 0 ([53]) 4 ([64])
# [0.82559454] [0.88224685]
# Not merging 0 ([53]) 4 ([64]) based on initial prediction
# Considering merging 0 ([53]) 5 ([277 278 279  53  65])
# [0.9685042] [0.9410501]
# Initial agreement for merging 0 ([53]) 5 ([277 278 279  53  65]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3]
# 	Checking member 2 of cluster [0, 2, 3]
# 	member_subpocket: [57] predicted_binding_site_ii: [277 278 279  53  65]
# [0.99998355] [0.99998045]
# 	Member 2 predicts merging with 5 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3]
# 	member_subpocket: [63] predicted_binding_site_ii: [277 278 279  53  65]
# [0.99952567] [0.9995467]
# 	Member 3 predicts merging with 5 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 5 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 5 ; final clustering: [[0, 2, 3]]
# Merging 0 5 [[0, 2, 3, 5]]
# Considering merging 0 ([53]) 6 ([66])
# [0.9702105] [0.96801555]
# Initial agreement for merging 0 ([53]) 6 ([66]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5]
# 	Checking member 2 of cluster [0, 2, 3, 5]
# 	member_subpocket: [57] predicted_binding_site_ii: [66]
# [0.999907] [0.99989736]
# 	Member 2 predicts merging with 6 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5]
# 	member_subpocket: [63] predicted_binding_site_ii: [66]
# [0.9989054] [0.9993795]
# 	Member 3 predicts merging with 6 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [66]
# [0.994865] [0.99640405]
# 	Member 5 predicts merging with 6 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 6 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 6 ; final clustering: [[0, 2, 3, 5]]
# Merging 0 6 [[0, 2, 3, 5, 6]]
# Considering merging 0 ([53]) 7 ([67])
# [0.42557165] [0.21715511]
# Not merging 0 ([53]) 7 ([67]) based on initial prediction
# Considering merging 0 ([53]) 8 ([278  68])
# [0.9170285] [0.923472]
# Initial agreement for merging 0 ([53]) 8 ([278  68]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6]
# 	member_subpocket: [57] predicted_binding_site_ii: [278  68]
# [0.99995244] [0.9999392]
# 	Member 2 predicts merging with 8 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6]
# 	member_subpocket: [63] predicted_binding_site_ii: [278  68]
# [0.99835074] [0.9990606]
# 	Member 3 predicts merging with 8 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [278  68]
# [0.98410946] [0.9919497]
# 	Member 5 predicts merging with 8 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6]
# 	member_subpocket: [66] predicted_binding_site_ii: [278  68]
# [0.9891054] [0.98854816]
# 	Member 6 predicts merging with 8 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 8 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 8 ; final clustering: [[0, 2, 3, 5, 6]]
# Merging 0 8 [[0, 2, 3, 5, 6, 8]]
# Considering merging 0 ([53]) 9 ([277  69])
# [0.9931484] [0.9885749]
# Initial agreement for merging 0 ([53]) 9 ([277  69]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8]
# 	member_subpocket: [57] predicted_binding_site_ii: [277  69]
# [0.99999475] [0.99999297]
# 	Member 2 predicts merging with 9 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8]
# 	member_subpocket: [63] predicted_binding_site_ii: [277  69]
# [0.9997322] [0.99982613]
# 	Member 3 predicts merging with 9 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [277  69]
# [0.9994111] [0.9994456]
# 	Member 5 predicts merging with 9 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8]
# 	member_subpocket: [66] predicted_binding_site_ii: [277  69]
# [0.99841666] [0.99857545]
# 	Member 6 predicts merging with 9 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [277  69]
# [0.99777395] [0.9978484]
# 	Member 8 predicts merging with 9 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 9 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 9 ; final clustering: [[0, 2, 3, 5, 6, 8]]
# Merging 0 9 [[0, 2, 3, 5, 6, 8, 9]]
# Considering merging 0 ([53]) 10 ([335  90])
# [0.99744284] [0.99628735]
# Initial agreement for merging 0 ([53]) 10 ([335  90]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9]
# 	member_subpocket: [57] predicted_binding_site_ii: [335  90]
# [0.99999726] [0.99999714]
# 	Member 2 predicts merging with 10 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9]
# 	member_subpocket: [63] predicted_binding_site_ii: [335  90]
# [0.99991596] [0.99996376]
# 	Member 3 predicts merging with 10 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [335  90]
# [0.9997404] [0.9997397]
# 	Member 5 predicts merging with 10 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9]
# 	member_subpocket: [66] predicted_binding_site_ii: [335  90]
# [0.9998155] [0.9997676]
# 	Member 6 predicts merging with 10 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [335  90]
# [0.999331] [0.9993075]
# 	Member 8 predicts merging with 10 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [335  90]
# [0.99997115] [0.999972]
# 	Member 9 predicts merging with 10 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 10 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 10 ; final clustering: [[0, 2, 3, 5, 6, 8, 9]]
# Merging 0 10 [[0, 2, 3, 5, 6, 8, 9, 10]]
# Considering merging 0 ([53]) 11 ([122])
# [0.8916586] [0.9513483]
# Not merging 0 ([53]) 11 ([122]) based on initial prediction
# Considering merging 0 ([53]) 12 ([286 126 124])
# [0.9979038] [0.9972186]
# Initial agreement for merging 0 ([53]) 12 ([286 126 124]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10]
# 	member_subpocket: [57] predicted_binding_site_ii: [286 126 124]
# [0.9999987] [0.9999988]
# 	Member 2 predicts merging with 12 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10]
# 	member_subpocket: [63] predicted_binding_site_ii: [286 126 124]
# [0.9998878] [0.9999651]
# 	Member 3 predicts merging with 12 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [286 126 124]
# [0.99975175] [0.9998419]
# 	Member 5 predicts merging with 12 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10]
# 	member_subpocket: [66] predicted_binding_site_ii: [286 126 124]
# [0.9997603] [0.9998404]
# 	Member 6 predicts merging with 12 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [286 126 124]
# [0.9994331] [0.9995447]
# 	Member 8 predicts merging with 12 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [286 126 124]
# [0.99997973] [0.9999877]
# 	Member 9 predicts merging with 12 : tensor([True], device='cuda:0')
# 	Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10]
# 	member_subpocket: [335  90] predicted_binding_site_ii: [286 126 124]
# [0.99998593] [0.99999106]
# 	Member 10 predicts merging with 12 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 12 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 12 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10]]
# Merging 0 12 [[0, 2, 3, 5, 6, 8, 9, 10, 12]]
# Considering merging 0 ([53]) 13 ([286 126])
# [0.99803215] [0.99770516]
# Initial agreement for merging 0 ([53]) 13 ([286 126]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12]
# 	member_subpocket: [57] predicted_binding_site_ii: [286 126]
# [0.9999988] [0.9999989]
# 	Member 2 predicts merging with 13 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12]
# 	member_subpocket: [63] predicted_binding_site_ii: [286 126]
# [0.999887] [0.99996686]
# 	Member 3 predicts merging with 13 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [286 126]
# [0.99976677] [0.9998715]
# 	Member 5 predicts merging with 13 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12]
# 	member_subpocket: [66] predicted_binding_site_ii: [286 126]
# [0.99975985] [0.9998579]
# 	Member 6 predicts merging with 13 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [286 126]
# [0.9994686] [0.99961805]
# 	Member 8 predicts merging with 13 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [286 126]
# [0.9999765] [0.9999896]
# 	Member 9 predicts merging with 13 : tensor([True], device='cuda:0')
# 	Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12]
# 	member_subpocket: [335  90] predicted_binding_site_ii: [286 126]
# [0.99998677] [0.9999918]
# 	Member 10 predicts merging with 13 : tensor([True], device='cuda:0')
# 	Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12]
# 	member_subpocket: [286 126 124] predicted_binding_site_ii: [286 126]
# [0.9999933] [0.9999938]
# 	Member 12 predicts merging with 13 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 13 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 13 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12]]
# Merging 0 13 [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13]]
# Considering merging 0 ([53]) 14 ([234 185])
# [0.91990185] [0.889909]
# Not merging 0 ([53]) 14 ([234 185]) based on initial prediction
# Considering merging 0 ([53]) 15 ([199])
# [0.00350576] [0.00565635]
# Not merging 0 ([53]) 15 ([199]) based on initial prediction
# Considering merging 0 ([53]) 16 ([280 277])
# [0.95828855] [0.9394036]
# Initial agreement for merging 0 ([53]) 16 ([280 277]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13]
# 	member_subpocket: [57] predicted_binding_site_ii: [280 277]
# [0.99997675] [0.999982]
# 	Member 2 predicts merging with 16 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13]
# 	member_subpocket: [63] predicted_binding_site_ii: [280 277]
# [0.9975268] [0.99897206]
# 	Member 3 predicts merging with 16 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [280 277]
# [0.9951121] [0.9969182]
# 	Member 5 predicts merging with 16 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13]
# 	member_subpocket: [66] predicted_binding_site_ii: [280 277]
# [0.9907803] [0.9933068]
# 	Member 6 predicts merging with 16 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [280 277]
# [0.98224187] [0.9876332]
# 	Member 8 predicts merging with 16 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [280 277]
# [0.99928075] [0.9995951]
# 	Member 9 predicts merging with 16 : tensor([True], device='cuda:0')
# 	Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13]
# 	member_subpocket: [335  90] predicted_binding_site_ii: [280 277]
# [0.9997454] [0.99982125]
# 	Member 10 predicts merging with 16 : tensor([True], device='cuda:0')
# 	Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13]
# 	member_subpocket: [286 126 124] predicted_binding_site_ii: [280 277]
# [0.9999089] [0.999864]
# 	Member 12 predicts merging with 16 : tensor([True], device='cuda:0')
# 	Checking member 13 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13]
# 	member_subpocket: [286 126] predicted_binding_site_ii: [280 277]
# [0.99993] [0.9998683]
# 	Member 13 predicts merging with 16 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 16 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 16 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13]]
# Merging 0 16 [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]]
# Considering merging 0 ([53]) 17 ([284 278])
# [0.40025485] [0.16760966]
# Not merging 0 ([53]) 17 ([284 278]) based on initial prediction
# Considering merging 0 ([53]) 18 ([279])
# [0.63469607] [0.31079873]
# Not merging 0 ([53]) 18 ([279]) based on initial prediction
# Considering merging 0 ([53]) 19 ([277 286 280])
# [0.99502796] [0.99186945]
# Initial agreement for merging 0 ([53]) 19 ([277 286 280]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]
# 	member_subpocket: [57] predicted_binding_site_ii: [277 286 280]
# [0.9999963] [0.999997]
# 	Member 2 predicts merging with 19 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]
# 	member_subpocket: [63] predicted_binding_site_ii: [277 286 280]
# [0.9996767] [0.99984205]
# 	Member 3 predicts merging with 19 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [277 286 280]
# [0.99950016] [0.9996283]
# 	Member 5 predicts merging with 19 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]
# 	member_subpocket: [66] predicted_binding_site_ii: [277 286 280]
# [0.9988595] [0.9991315]
# 	Member 6 predicts merging with 19 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [277 286 280]
# [0.99833965] [0.99847203]
# 	Member 8 predicts merging with 19 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [277 286 280]
# [0.9999229] [0.99995637]
# 	Member 9 predicts merging with 19 : tensor([True], device='cuda:0')
# 	Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]
# 	member_subpocket: [335  90] predicted_binding_site_ii: [277 286 280]
# [0.9999672] [0.99997723]
# 	Member 10 predicts merging with 19 : tensor([True], device='cuda:0')
# 	Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]
# 	member_subpocket: [286 126 124] predicted_binding_site_ii: [277 286 280]
# [0.9999864] [0.9999815]
# 	Member 12 predicts merging with 19 : tensor([True], device='cuda:0')
# 	Checking member 13 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]
# 	member_subpocket: [286 126] predicted_binding_site_ii: [277 286 280]
# [0.9999888] [0.9999814]
# 	Member 13 predicts merging with 19 : tensor([True], device='cuda:0')
# 	Checking member 16 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]
# 	member_subpocket: [280 277] predicted_binding_site_ii: [277 286 280]
# [0.9997131] [0.9997615]
# 	Member 16 predicts merging with 19 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 19 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 19 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16]]
# Merging 0 19 [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]]
# Considering merging 0 ([53]) 20 ([126 286])
# [0.99803215] [0.99770516]
# Initial agreement for merging 0 ([53]) 20 ([126 286]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	member_subpocket: [57] predicted_binding_site_ii: [126 286]
# [0.9999988] [0.9999989]
# 	Member 2 predicts merging with 20 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	member_subpocket: [63] predicted_binding_site_ii: [126 286]
# [0.999887] [0.99996686]
# 	Member 3 predicts merging with 20 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [126 286]
# [0.99976677] [0.9998715]
# 	Member 5 predicts merging with 20 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	member_subpocket: [66] predicted_binding_site_ii: [126 286]
# [0.99975985] [0.9998579]
# 	Member 6 predicts merging with 20 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [126 286]
# [0.9994686] [0.99961805]
# 	Member 8 predicts merging with 20 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [126 286]
# [0.9999765] [0.9999896]
# 	Member 9 predicts merging with 20 : tensor([True], device='cuda:0')
# 	Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	member_subpocket: [335  90] predicted_binding_site_ii: [126 286]
# [0.99998677] [0.9999918]
# 	Member 10 predicts merging with 20 : tensor([True], device='cuda:0')
# 	Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	member_subpocket: [286 126 124] predicted_binding_site_ii: [126 286]
# [0.9999933] [0.9999938]
# 	Member 12 predicts merging with 20 : tensor([True], device='cuda:0')
# 	Checking member 13 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	member_subpocket: [286 126] predicted_binding_site_ii: [126 286]
# [0.9999939] [0.9999939]
# 	Member 13 predicts merging with 20 : tensor([True], device='cuda:0')
# 	Checking member 16 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	member_subpocket: [280 277] predicted_binding_site_ii: [126 286]
# [0.9998683] [0.99993]
# 	Member 16 predicts merging with 20 : tensor([True], device='cuda:0')
# 	Checking member 19 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]
# 	member_subpocket: [277 286 280] predicted_binding_site_ii: [126 286]
# [0.9999814] [0.9999888]
# 	Member 19 predicts merging with 20 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 20 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 20 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19]]
# Merging 0 20 [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]]
# Considering merging 0 ([53]) 21 ([288])
# [0.3548842] [0.23747057]
# Not merging 0 ([53]) 21 ([288]) based on initial prediction
# Considering merging 0 ([53]) 22 ([329 288 314 124 290])
# [0.9943773] [0.9891289]
# Initial agreement for merging 0 ([53]) 22 ([329 288 314 124 290]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [57] predicted_binding_site_ii: [329 288 314 124 290]
# [0.9999975] [0.99999774]
# 	Member 2 predicts merging with 22 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [63] predicted_binding_site_ii: [329 288 314 124 290]
# [0.9997509] [0.9998615]
# 	Member 3 predicts merging with 22 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [329 288 314 124 290]
# [0.99940157] [0.9995376]
# 	Member 5 predicts merging with 22 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [66] predicted_binding_site_ii: [329 288 314 124 290]
# [0.9991479] [0.9993061]
# 	Member 6 predicts merging with 22 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [329 288 314 124 290]
# [0.99849784] [0.99836355]
# 	Member 8 predicts merging with 22 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [329 288 314 124 290]
# [0.9999521] [0.99996066]
# 	Member 9 predicts merging with 22 : tensor([True], device='cuda:0')
# 	Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [335  90] predicted_binding_site_ii: [329 288 314 124 290]
# [0.9999665] [0.99997616]
# 	Member 10 predicts merging with 22 : tensor([True], device='cuda:0')
# 	Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [286 126 124] predicted_binding_site_ii: [329 288 314 124 290]
# [0.9999865] [0.9999832]
# 	Member 12 predicts merging with 22 : tensor([True], device='cuda:0')
# 	Checking member 13 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [286 126] predicted_binding_site_ii: [329 288 314 124 290]
# [0.9999894] [0.9999827]
# 	Member 13 predicts merging with 22 : tensor([True], device='cuda:0')
# 	Checking member 16 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [280 277] predicted_binding_site_ii: [329 288 314 124 290]
# [0.99979943] [0.99974614]
# 	Member 16 predicts merging with 22 : tensor([True], device='cuda:0')
# 	Checking member 19 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [277 286 280] predicted_binding_site_ii: [329 288 314 124 290]
# [0.99997294] [0.9999685]
# 	Member 19 predicts merging with 22 : tensor([True], device='cuda:0')
# 	Checking member 20 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]
# 	member_subpocket: [126 286] predicted_binding_site_ii: [329 288 314 124 290]
# [0.9999894] [0.9999827]
# 	Member 20 predicts merging with 22 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 22 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 22 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20]]
# Merging 0 22 [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]]
# Considering merging 0 ([53]) 23 ([314])
# [0.97693765] [0.95589286]
# Initial agreement for merging 0 ([53]) 23 ([314]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [57] predicted_binding_site_ii: [314]
# [0.9999907] [0.99998784]
# 	Member 2 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [63] predicted_binding_site_ii: [314]
# [0.99907553] [0.99953055]
# 	Member 3 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [314]
# [0.99784267] [0.9973348]
# 	Member 5 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [66] predicted_binding_site_ii: [314]
# [0.9976412] [0.9973254]
# 	Member 6 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [314]
# [0.99379396] [0.9919775]
# 	Member 8 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [314]
# [0.9997849] [0.9997967]
# 	Member 9 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [335  90] predicted_binding_site_ii: [314]
# [0.99985635] [0.99986064]
# 	Member 10 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [286 126 124] predicted_binding_site_ii: [314]
# [0.9999424] [0.99989593]
# 	Member 12 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 13 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [286 126] predicted_binding_site_ii: [314]
# [0.99995446] [0.99990094]
# 	Member 13 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 16 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [280 277] predicted_binding_site_ii: [314]
# [0.99901104] [0.99850404]
# 	Member 16 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 19 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [277 286 280] predicted_binding_site_ii: [314]
# [0.9998779] [0.9997917]
# 	Member 19 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 20 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [126 286] predicted_binding_site_ii: [314]
# [0.99995446] [0.99990094]
# 	Member 20 predicts merging with 23 : tensor([True], device='cuda:0')
# 	Checking member 22 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]
# 	member_subpocket: [329 288 314 124 290] predicted_binding_site_ii: [314]
# [0.9998449] [0.99978846]
# 	Member 22 predicts merging with 23 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 23 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 23 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22]]
# Merging 0 23 [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]]
# Considering merging 0 ([53]) 24 ([316])
# [0.55231136] [0.6516763]
# Not merging 0 ([53]) 24 ([316]) based on initial prediction
# Considering merging 0 ([53]) 25 ([317])
# [0.48167482] [0.55293876]
# Not merging 0 ([53]) 25 ([317]) based on initial prediction
# Considering merging 0 ([53]) 26 ([315 318])
# [0.23479061] [0.16633058]
# Not merging 0 ([53]) 26 ([315 318]) based on initial prediction
# Considering merging 0 ([53]) 27 ([319])
# [0.9977977] [0.99440825]
# Initial agreement for merging 0 ([53]) 27 ([319]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [57] predicted_binding_site_ii: [319]
# [0.99999523] [0.9999882]
# 	Member 2 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [63] predicted_binding_site_ii: [319]
# [0.999892] [0.9999219]
# 	Member 3 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [319]
# [0.9996712] [0.99945897]
# 	Member 5 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [66] predicted_binding_site_ii: [319]
# [0.9995208] [0.9992624]
# 	Member 6 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [319]
# [0.9992945] [0.99861455]
# 	Member 8 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [319]
# [0.9999325] [0.9998584]
# 	Member 9 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [335  90] predicted_binding_site_ii: [319]
# [0.99997807] [0.9999484]
# 	Member 10 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [286 126 124] predicted_binding_site_ii: [319]
# [0.9999876] [0.9999356]
# 	Member 12 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 13 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [286 126] predicted_binding_site_ii: [319]
# [0.99998856] [0.99993396]
# 	Member 13 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 16 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [280 277] predicted_binding_site_ii: [319]
# [0.99967706] [0.99906224]
# 	Member 16 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 19 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [277 286 280] predicted_binding_site_ii: [319]
# [0.9999535] [0.999826]
# 	Member 19 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 20 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [126 286] predicted_binding_site_ii: [319]
# [0.99998856] [0.99993396]
# 	Member 20 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 22 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [329 288 314 124 290] predicted_binding_site_ii: [319]
# [0.99995923] [0.9998809]
# 	Member 22 predicts merging with 27 : tensor([True], device='cuda:0')
# 	Checking member 23 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]
# 	member_subpocket: [314] predicted_binding_site_ii: [319]
# [0.99980885] [0.9995703]
# 	Member 23 predicts merging with 27 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 27 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 27 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23]]
# Merging 0 27 [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]]
# Considering merging 0 ([53]) 28 ([329])
# [0.95203006] [0.90067524]
# Initial agreement for merging 0 ([53]) 28 ([329]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [57] predicted_binding_site_ii: [329]
# [0.9999819] [0.99998045]
# 	Member 2 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [63] predicted_binding_site_ii: [329]
# [0.99794406] [0.99801755]
# 	Member 3 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [329]
# [0.9923685] [0.9937046]
# 	Member 5 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [66] predicted_binding_site_ii: [329]
# [0.9949254] [0.99158746]
# 	Member 6 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [329]
# [0.97998446] [0.9743921]
# 	Member 8 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [329]
# [0.9994361] [0.99927837]
# 	Member 9 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [335  90] predicted_binding_site_ii: [329]
# [0.9997056] [0.9996586]
# 	Member 10 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [286 126 124] predicted_binding_site_ii: [329]
# [0.99988174] [0.99985456]
# 	Member 12 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 13 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [286 126] predicted_binding_site_ii: [329]
# [0.99990976] [0.99987185]
# 	Member 13 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 16 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [280 277] predicted_binding_site_ii: [329]
# [0.99771345] [0.99745136]
# 	Member 16 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 19 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [277 286 280] predicted_binding_site_ii: [329]
# [0.99970895] [0.9996618]
# 	Member 19 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 20 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [126 286] predicted_binding_site_ii: [329]
# [0.99990976] [0.99987185]
# 	Member 20 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 22 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [329 288 314 124 290] predicted_binding_site_ii: [329]
# [0.99963796] [0.99959093]
# 	Member 22 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 23 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [314] predicted_binding_site_ii: [329]
# [0.9980519] [0.9986999]
# 	Member 23 predicts merging with 28 : tensor([True], device='cuda:0')
# 	Checking member 27 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]
# 	member_subpocket: [319] predicted_binding_site_ii: [329]
# [0.99927324] [0.99958795]
# 	Member 27 predicts merging with 28 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 28 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 28 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27]]
# Merging 0 28 [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]]
# Considering merging 0 ([53]) 29 ([329 286 290 314 124 331])
# [0.99448293] [0.9913897]
# Initial agreement for merging 0 ([53]) 29 ([329 286 290 314 124 331]); check for all members of 0th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [57] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99999785] [0.99999785]
# 	Member 2 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [63] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99976057] [0.9998816]
# 	Member 3 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9994011] [0.9996275]
# 	Member 5 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [66] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.999161] [0.99943465]
# 	Member 6 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99855703] [0.9985625]
# 	Member 8 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9999521] [0.99997056]
# 	Member 9 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [335  90] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9999696] [0.9999825]
# 	Member 10 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [286 126 124] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99998796] [0.99998665]
# 	Member 12 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 13 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [286 126] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99998987] [0.99998665]
# 	Member 13 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 16 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [280 277] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9997701] [0.99978226]
# 	Member 16 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 19 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [277 286 280] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9999721] [0.99997437]
# 	Member 19 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 20 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [126 286] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99998987] [0.99998665]
# 	Member 20 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 22 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [329 288 314 124 290] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9999716] [0.9999734]
# 	Member 22 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 23 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [314] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99980384] [0.9998809]
# 	Member 23 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 27 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [319] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9998516] [0.9999635]
# 	Member 27 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 28 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]
# 	member_subpocket: [329] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9996772] [0.99971217]
# 	Member 28 predicts merging with 29 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 29 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 0 29 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28]]
# Merging 0 29 [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]]
# Considering merging 1 ([54]) 2 ([57])
# [0.99983394] [0.999708]
# Initial agreement for merging 1 ([54]) 2 ([57]); check for all members of 1th cluster
# is_index_in_final_clustering_i: False index_in_final_i: -1
# check second candidate; check for all members of 2 th cluster
# is_index_in_final_clustering_ii: True index_in_final_ii: 0
# Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [53] predicted_binding_site_i: [54]
# [0.73246205] [0.72424614]
# 	Member 0 predicts merging with 1 : tensor([False], device='cuda:0')
# 	Not merging 1 2 because of member 0
# All members agree for merging 1 2 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]]
# Considering merging 1 ([54]) 3 ([63])
# [0.99765944] [0.99353576]
# Initial agreement for merging 1 ([54]) 3 ([63]); check for all members of 1th cluster
# is_index_in_final_clustering_i: False index_in_final_i: -1
# check second candidate; check for all members of 3 th cluster
# is_index_in_final_clustering_ii: True index_in_final_ii: 0
# Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [53] predicted_binding_site_i: [54]
# [0.73246205] [0.72424614]
# 	Member 0 predicts merging with 1 : tensor([False], device='cuda:0')
# 	Not merging 1 3 because of member 0
# All members agree for merging 1 3 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]]
# Considering merging 1 ([54]) 4 ([64])
# [0.5259135] [0.6433668]
# Not merging 1 ([54]) 4 ([64]) based on initial prediction
# Considering merging 1 ([54]) 5 ([277 278 279  53  65])
# [0.96922964] [0.9219403]
# Initial agreement for merging 1 ([54]) 5 ([277 278 279  53  65]); check for all members of 1th cluster
# is_index_in_final_clustering_i: False index_in_final_i: -1
# check second candidate; check for all members of 5 th cluster
# is_index_in_final_clustering_ii: True index_in_final_ii: 0
# Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [53] predicted_binding_site_i: [54]
# [0.73246205] [0.72424614]
# 	Member 0 predicts merging with 1 : tensor([False], device='cuda:0')
# 	Not merging 1 5 because of member 0
# All members agree for merging 1 5 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]]
# Considering merging 1 ([54]) 6 ([66])
# [0.9737176] [0.96466863]
# Initial agreement for merging 1 ([54]) 6 ([66]); check for all members of 1th cluster
# is_index_in_final_clustering_i: False index_in_final_i: -1
# check second candidate; check for all members of 6 th cluster
# is_index_in_final_clustering_ii: True index_in_final_ii: 0
# Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [53] predicted_binding_site_i: [54]
# [0.73246205] [0.72424614]
# 	Member 0 predicts merging with 1 : tensor([False], device='cuda:0')
# 	Not merging 1 6 because of member 0
# All members agree for merging 1 6 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]]
# Considering merging 1 ([54]) 7 ([67])
# [0.30592206] [0.13826908]
# Not merging 1 ([54]) 7 ([67]) based on initial prediction
# Considering merging 1 ([54]) 8 ([278  68])
# [0.93118924] [0.8730327]
# Not merging 1 ([54]) 8 ([278  68]) based on initial prediction
# Considering merging 1 ([54]) 9 ([277  69])
# [0.9947713] [0.98940337]
# Initial agreement for merging 1 ([54]) 9 ([277  69]); check for all members of 1th cluster
# is_index_in_final_clustering_i: False index_in_final_i: -1
# check second candidate; check for all members of 9 th cluster
# is_index_in_final_clustering_ii: True index_in_final_ii: 0
# Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [53] predicted_binding_site_i: [54]
# [0.73246205] [0.72424614]
# 	Member 0 predicts merging with 1 : tensor([False], device='cuda:0')
# 	Not merging 1 9 because of member 0
# All members agree for merging 1 9 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]]
# Considering merging 1 ([54]) 10 ([335  90])
# [0.9972946] [0.99683446]
# Initial agreement for merging 1 ([54]) 10 ([335  90]); check for all members of 1th cluster
# is_index_in_final_clustering_i: False index_in_final_i: -1
# check second candidate; check for all members of 10 th cluster
# is_index_in_final_clustering_ii: True index_in_final_ii: 0
# Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [53] predicted_binding_site_i: [54]
# [0.73246205] [0.72424614]
# 	Member 0 predicts merging with 1 : tensor([False], device='cuda:0')
# 	Not merging 1 10 because of member 0
# All members agree for merging 1 10 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]]
# Considering merging 1 ([54]) 11 ([122])
# [0.93268824] [0.9296092]
# Initial agreement for merging 1 ([54]) 11 ([122]); check for all members of 1th cluster
# is_index_in_final_clustering_i: False index_in_final_i: -1
# check second candidate; check for all members of 11 th cluster
# is_index_in_final_clustering_ii: False index_in_final_ii: -1
# All members agree for merging 1 11 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]]
# ...
# 	member_subpocket: [329 288 314 124 290] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9999716] [0.9999734]
# 	Member 22 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 23 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [314] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99980384] [0.9998809]
# 	Member 23 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 27 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	Checking member 28 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [329] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9996772] [0.99971217]
# 	Member 28 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 29 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [329 286 290 314 124 331] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9999758] [0.9999758]
# 	Member 29 predicts merging with 29 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 29 th cluster
# is_index_in_final_clustering_ii: True index_in_final_ii: 0
# Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [53] predicted_binding_site_i: [319]
# [0.9977977] [0.99440825]
# 	Member 0 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [57] predicted_binding_site_i: [319]
# [0.99999523] [0.9999882]
# 	Member 2 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [63] predicted_binding_site_i: [319]
# [0.999892] [0.9999219]
# 	Member 3 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_i: [319]
# [0.9996712] [0.99945897]
# 	Member 5 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [66] predicted_binding_site_i: [319]
# [0.9995208] [0.9992624]
# 	Member 6 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [278  68] predicted_binding_site_i: [319]
# [0.9992945] [0.99861455]
# 	Member 8 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [277  69] predicted_binding_site_i: [319]
# [0.9999325] [0.9998584]
# 	Member 9 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [335  90] predicted_binding_site_i: [319]
# [0.99997807] [0.9999484]
# 	Member 10 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [286 126 124] predicted_binding_site_i: [319]
# [0.9999876] [0.9999356]
# 	Member 12 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 13 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [286 126] predicted_binding_site_i: [319]
# [0.99998856] [0.99993396]
# 	Member 13 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 16 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [280 277] predicted_binding_site_i: [319]
# [0.99967706] [0.99906224]
# 	Member 16 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 19 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [277 286 280] predicted_binding_site_i: [319]
# [0.9999535] [0.999826]
# 	Member 19 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 20 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [126 286] predicted_binding_site_i: [319]
# [0.99998856] [0.99993396]
# 	Member 20 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 22 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [329 288 314 124 290] predicted_binding_site_i: [319]
# [0.99995923] [0.9998809]
# 	Member 22 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 23 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [314] predicted_binding_site_i: [319]
# [0.99980885] [0.9995703]
# 	Member 23 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 27 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [319] predicted_binding_site_i: [319]
# [0.99993443] [0.99993443]
# 	Member 27 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 28 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [329] predicted_binding_site_i: [319]
# [0.99958795] [0.99927324]
# 	Member 28 predicts merging with 27 : tensor([True], device='cuda:0')
# Checking member 29 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# All members agree for merging 27 29 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29], [1, 11, 14]]
# Merging 27 29 [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29], [1, 11, 14]]
# Considering merging 28 ([329]) 29 ([329 286 290 314 124 331])
# [0.9996772] [0.99971217]
# Initial agreement for merging 28 ([329]) 29 ([329 286 290 314 124 331]); check for all members of 28th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [53] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99448293] [0.9913897]
# 	Member 0 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [57] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99999785] [0.99999785]
# 	Member 2 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [63] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99976057] [0.9998816]
# 	Member 3 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9994011] [0.9996275]
# 	Member 5 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [66] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.999161] [0.99943465]
# 	Member 6 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [278  68] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99855703] [0.9985625]
# 	Member 8 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [277  69] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9999521] [0.99997056]
# 	Member 9 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [335  90] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9999696] [0.9999825]
# 	Member 10 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [286 126 124] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99998796] [0.99998665]
# 	Member 12 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 13 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [286 126] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99998987] [0.99998665]
# 	Member 13 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 16 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [280 277] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9997701] [0.99978226]
# 	Member 16 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 19 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [277 286 280] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9999721] [0.99997437]
# 	Member 19 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 20 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [126 286] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99998987] [0.99998665]
# 	Member 20 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 22 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [329 288 314 124 290] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9999716] [0.9999734]
# 	Member 22 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 23 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [314] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.99980384] [0.9998809]
# 	Member 23 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 27 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [319] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9998516] [0.9999635]
# 	Member 27 predicts merging with 29 : tensor([True], device='cuda:0')
# 	Checking member 28 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	Checking member 29 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [329 286 290 314 124 331] predicted_binding_site_ii: [329 286 290 314 124 331]
# [0.9999758] [0.9999758]
# 	Member 29 predicts merging with 29 : tensor([True], device='cuda:0')
# check second candidate; check for all members of 29 th cluster
# is_index_in_final_clustering_ii: True index_in_final_ii: 0
# Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [53] predicted_binding_site_i: [329]
# [0.95203006] [0.90067524]
# 	Member 0 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 2 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [57] predicted_binding_site_i: [329]
# [0.9999819] [0.99998045]
# 	Member 2 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 3 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [63] predicted_binding_site_i: [329]
# [0.99794406] [0.99801755]
# 	Member 3 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 5 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [277 278 279  53  65] predicted_binding_site_i: [329]
# [0.9923685] [0.9937046]
# 	Member 5 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 6 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [66] predicted_binding_site_i: [329]
# [0.9949254] [0.99158746]
# 	Member 6 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 8 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [278  68] predicted_binding_site_i: [329]
# [0.97998446] [0.9743921]
# 	Member 8 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 9 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [277  69] predicted_binding_site_i: [329]
# [0.9994361] [0.99927837]
# 	Member 9 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 10 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [335  90] predicted_binding_site_i: [329]
# [0.9997056] [0.9996586]
# 	Member 10 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 12 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [286 126 124] predicted_binding_site_i: [329]
# [0.99988174] [0.99985456]
# 	Member 12 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 13 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [286 126] predicted_binding_site_i: [329]
# [0.99990976] [0.99987185]
# 	Member 13 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 16 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [280 277] predicted_binding_site_i: [329]
# [0.99771345] [0.99745136]
# 	Member 16 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 19 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [277 286 280] predicted_binding_site_i: [329]
# [0.99970895] [0.9996618]
# 	Member 19 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 20 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [126 286] predicted_binding_site_i: [329]
# [0.99990976] [0.99987185]
# 	Member 20 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 22 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [329 288 314 124 290] predicted_binding_site_i: [329]
# [0.99963796] [0.99959093]
# 	Member 22 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 23 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [314] predicted_binding_site_i: [329]
# [0.9980519] [0.9986999]
# 	Member 23 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 27 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [319] predicted_binding_site_i: [329]
# [0.99927324] [0.99958795]
# 	Member 27 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 28 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# 	member_subpocket: [329] predicted_binding_site_i: [329]
# [0.9976799] [0.9976799]
# 	Member 28 predicts merging with 28 : tensor([True], device='cuda:0')
# Checking member 29 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29]
# All members agree for merging 28 29 ; final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29], [1, 11, 14]]
# Merging 28 29 [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29], [1, 11, 14]]
# Final clustering: [[0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29], [1, 11, 14]]
# [[53,
#   57,
#   63,
#   277,
#   278,
#   279,
#   53,
#   65,
#   66,
#   278,
#   68,
#   277,
#   69,
#   335,
#   90,
#   286,
#   126,
#   124,
#   286,
#   126,
#   280,
#   277,
#   277,
#   286,
#   280,
#   126,
#   286,
#   329,
#   288,
#   314,
#   124,
#   290,
#   314,
#   319,
#   329,
#   329,
#   286,
#   290,
#   314,
#   124,
#   331],
#  [54, 122, 234, 185]]

# %% [markdown]
# ## Try to cluster embeddings
# Take the predicted binding residues, and use their embeddings to cluster them.

# %%
embedding_path = f'/home/skrhakv/cryptoshow-analysis/src/E-regular-binding-site-predictor/evaluation/creatine-kinase/3b6rB-nonfinetuned-embedding.npy'
embeddings = np.load(embedding_path)

predicted_binding_sites_merged = np.concatenate(predicted_binding_sites)
binding_site_embeddings = embeddings[predicted_binding_sites_merged]

from sklearn.cluster import KMeans
clustering = KMeans(n_clusters=len(predicted_binding_sites_merged) // 15)
labels = clustering.fit_predict(binding_site_embeddings)

final_predicted_binding_sites = [[] for _ in range(np.max(labels) + 1)]
for residue_index, cluster_label in zip(predicted_binding_sites_merged, labels):
    final_predicted_binding_sites[cluster_label].append(residue_index)
final_predicted_binding_sites
# Out:
# [[53,
#   54,
#   57,
#   63,
#   64,
#   53,
#   65,
#   66,
#   67,
#   68,
#   69,
#   90,
#   122,
#   126,
#   124,
#   126,
#   234,
#   185,
#   126,
#   329,
#   124,
#   317,
#   315,
#   318,
#   319,
#   329,
#   329,
#   124,
#   331],
#  [277, 278, 279, 278, 277, 277, 278, 279, 277, 316],
#  [335,
#   286,
#   286,
#   199,
#   280,
#   284,
#   286,
#   280,
#   286,
#   288,
#   288,
#   314,
#   290,
#   314,
#   286,
#   290,
#   314]]

# %% [markdown]
# ### PCA
# First reduce the dimensionality of the embedding, then do clustering.
#
# #### Note
# This was a bit better I guess, but still there was one cluster that had residues all over the place, and it didn't make sense spatially.

# %%
embedding_path = f'/home/skrhakv/cryptoshow-analysis/src/E-regular-binding-site-predictor/evaluation/creatine-kinase/3b6rB-nonfinetuned-embedding.npy'
embeddings = np.load(embedding_path)

predicted_binding_sites_merged = np.concatenate(predicted_binding_sites)
binding_site_embeddings = embeddings[predicted_binding_sites_merged]

from sklearn.decomposition import PCA

pca = PCA(n_components=15, random_state=42)
projections = pca.fit_transform(binding_site_embeddings)

from sklearn.cluster import KMeans
clustering = KMeans(n_clusters=len(predicted_binding_sites_merged) // 15)
labels = clustering.fit_predict(projections)

final_predicted_binding_sites = [[] for _ in range(np.max(labels) + 1)]
for residue_index, cluster_label in zip(predicted_binding_sites_merged, labels):
    final_predicted_binding_sites[cluster_label].append(residue_index)
final_predicted_binding_sites
# Out:
# [[277,
#   278,
#   279,
#   278,
#   277,
#   234,
#   199,
#   277,
#   278,
#   279,
#   277,
#   329,
#   316,
#   317,
#   315,
#   318,
#   319,
#   329,
#   329,
#   331],
#  [53,
#   54,
#   57,
#   63,
#   64,
#   53,
#   65,
#   66,
#   67,
#   68,
#   69,
#   335,
#   90,
#   122,
#   126,
#   124,
#   126,
#   185,
#   126,
#   314,
#   124,
#   314,
#   314,
#   124],
#  [286, 286, 280, 284, 286, 280, 286, 288, 288, 290, 286, 290]]

# %% [markdown]
# ### PCAed embeddings + distances
# Do the same as before (use PCA on embedding), but merge it with the distances and after then run the clustering.

# %%
embedding_path = f'/home/skrhakv/cryptoshow-analysis/src/E-regular-binding-site-predictor/evaluation/creatine-kinase/3b6rB-nonfinetuned-embedding.npy'
coordinates_path = f'{OUTPUT_PATH}/{pdb_id}{chain_id}.npy'
embeddings = np.load(embedding_path)
coordinates = np.load(coordinates_path)

predicted_binding_sites_merged = np.concatenate(predicted_binding_sites)

binding_site_embeddings = embeddings[predicted_binding_sites_merged]
binding_site_coordinates = coordinates[predicted_binding_sites_merged]

from sklearn.decomposition import PCA

pca = PCA(n_components=10, random_state=42)
projections = pca.fit_transform(binding_site_embeddings)

concatenated_features = np.concatenate((projections, binding_site_coordinates), axis=1)


from sklearn.cluster import KMeans
clustering = KMeans(n_clusters=len(predicted_binding_sites_merged) // 15)
labels = clustering.fit_predict(concatenated_features)

final_predicted_binding_sites = [[] for _ in range(np.max(labels) + 1)]
for residue_index, cluster_label in zip(predicted_binding_sites_merged, labels):
    final_predicted_binding_sites[cluster_label].append(residue_index)
final_predicted_binding_sites
# Out:
# (56, 13)

# %% [markdown]
# ## Sanity check
# Do the same on coordinates, compare the results visually
#
# ### Note
# Visually, this makes much more sense than clustering the embeddings.

# %%
coordinates_path = f'{OUTPUT_PATH}/{pdb_id}{chain_id}.npy'
coordinates = np.load(coordinates_path)

predicted_binding_sites_merged = np.concatenate(predicted_binding_sites)
binding_site_coordinates = coordinates[predicted_binding_sites_merged]

from sklearn.cluster import KMeans
clustering = KMeans(n_clusters=len(predicted_binding_sites_merged) // 15)
labels = clustering.fit_predict(binding_site_coordinates)

final_predicted_binding_sites = [[] for _ in range(np.max(labels) + 1)]
for residue_index, cluster_label in zip(predicted_binding_sites_merged, labels):
    final_predicted_binding_sites[cluster_label].append(residue_index)
final_predicted_binding_sites
# Out:
# [[122,
#   286,
#   126,
#   124,
#   286,
#   126,
#   234,
#   185,
#   286,
#   126,
#   286,
#   288,
#   329,
#   288,
#   314,
#   124,
#   290,
#   314,
#   316,
#   317,
#   315,
#   318,
#   319,
#   329,
#   329,
#   286,
#   290,
#   314,
#   124,
#   331],
#  [277, 278, 279, 278, 277, 335, 90, 280, 277, 284, 278, 279, 277, 280],
#  [53, 54, 57, 63, 64, 53, 65, 66, 67, 68, 69, 199]]

# %% [markdown]
# # Things to try:
# 1. change clustering decision threshold (0.9)
# 2. design train data in reverse (now I stack them (v1, v2), do (v2, v1) as well) to do data augmenting

# %%
# Considering merging 0 ([53]) 1 ([54])
# [0.73246205] [0.72424614]
# Not merging 0 ([53]) 1 ([54]) based on initial prediction


# Initial agreement for merging 1 ([54]) 3 ([63]); check for all members of 1th cluster
# is_index_in_final_clustering_i: True index_in_final_i: 0
# 	Checking member 0 of cluster [0, 2, 3, 5, 6, 8, 9, 10, 12, 13, 16, 19, 20, 22, 23, 27, 28, 29, 1]
# 	member_subpocket: [53] predicted_binding_site_ii: [63]
# [0.9987476] [0.9977325]


# Considering merging 0 ([53]) 1 ([54])
# [0.73246205] [0.72424614]
# TODO: why not merging when next to each other?
