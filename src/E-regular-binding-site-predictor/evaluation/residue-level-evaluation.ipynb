# %% [markdown]
# # Intro
# Code copied from the `cryptic-finetuning` repository history to replicate the results that were calculated previously.

# %%
import torch
from transformers import AutoTokenizer, EsmModel
import numpy as np
import torch.nn as nn
import sklearn.metrics as metrics
import functools
import sys
sys.path.append('/home/skrhakv/cryptic-nn/src')
import finetuning_utils
import baseline_utils

torch.manual_seed(420)
MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/model-enhanced-scPDB.pt'
ESM_MODEL_NAME = 'facebook/esm2_t36_3B_UR50D'
MAX_LENGTH = 1024
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DECISION_THRESHOLD = 0.5
loaded_model = torch.load(MODEL_PATH, weights_only=False).to(DEVICE)
tokenizer = AutoTokenizer.from_pretrained(ESM_MODEL_NAME)
partial_collate_fn = functools.partial(finetuning_utils.collate_fn, tokenizer=tokenizer)

# %%
import csv
RESIDUE_LEVEL_ANNOTATIONS = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis_for_residue_level_evaluation.csv'
sequences = {}
annotations = {}
with open('/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis_for_pocket_level_evaluation.csv', 'r') as f:
    reader = csv.reader(f, delimiter=';')
    for row in reader:
        sequences[row[0]] = row[4]
        if row[0] not in annotations:
            annotations[row[0]] = row[3]
        else:
            annotations[row[0]] += ' ' + row[3]
with open(RESIDUE_LEVEL_ANNOTATIONS, 'w') as f:
    for protein_id in sequences:
        f.write(f"{protein_id[:4]};{protein_id[4:]};UNKNOWN;{annotations[protein_id]};{sequences[protein_id]}\n")
val_dataset = finetuning_utils.process_sequence_dataset(
    RESIDUE_LEVEL_ANNOTATIONS, 
    tokenizer,
    load_ids=True,
    )

# %%
SMOOTHING_MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/C-optimize-smoother/smoother.pt'

SMOOTHING_DECISION_THRESHOLD = 0.4 # see src/C-optimize-smoother/classifier-for-cryptoshow.ipynb
DROPOUT = 0.5
LAYER_WIDTH = 2048
ESM2_DIM = 2560
INPUT_DIM  = ESM2_DIM * 2

class CryptoBenchClassifier(nn.Module):
    def __init__(self, dim=LAYER_WIDTH, dropout=DROPOUT):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=INPUT_DIM, out_features=dim)
        self.dropout1 = nn.Dropout(dropout)

        self.layer_2 = nn.Linear(in_features=dim, out_features=dim)
        self.dropout2 = nn.Dropout(dropout)

        self.layer_3 = nn.Linear(in_features=dim, out_features=1)

        self.relu = nn.ReLU()

    def forward(self, x):
      # Intersperse the ReLU activation function between layers
       return self.layer_3(self.dropout2(self.relu(self.layer_2(self.dropout1(self.relu(self.layer_1(x)))))))


smoothing_model = torch.load(SMOOTHING_MODEL_PATH, weights_only=False).to(DEVICE)
smoothing_model.eval()
# Out:
# CryptoBenchClassifier(
#   (layer_1): Linear(in_features=5120, out_features=2048, bias=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (layer_2): Linear(in_features=2048, out_features=2048, bias=True)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (layer_3): Linear(in_features=2048, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %% [markdown]
# ## Run model with smoothing

# %%
sys.path.append('/home/skrhakv/cryptoshow-analysis/src/B-evaluate-cryptoshow')
sys.path.append('/home/skrhakv/cryptic-nn/src')
import eval_utils

ESM_EMBEDDINGS_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/embeddings-enhanced-scPDB'
COORDINATES_DIR = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis-coordinates'
POSITIVE_DISTANCE_THRESHOLD = 15

with torch.no_grad():
    all_test_logits = []
    all_test_pred = []
    all_y_test = []
    this_test_losses = []

    for batch in val_dataset:
        
        protein_id = batch['ids'][0]
        del batch['ids']
        batch = finetuning_utils.collate_fn([batch], tokenizer=tokenizer)
        output1 = loaded_model(batch)

        labels = batch['labels'].to(DEVICE)
        flattened_labels = labels.flatten()
        y_test = flattened_labels[flattened_labels != -100]
        logits = output1.flatten()[flattened_labels != -100]

        test_pred = (torch.sigmoid(logits)>DECISION_THRESHOLD).float()
        test_pred_copy = test_pred.clone().detach().cpu().numpy()

        # let's use the smoothing model here:
        # first, get the distance matrix
        coordinates = np.load(f'{COORDINATES_DIR}/{protein_id}.npy')
        distance_matrix = eval_utils.compute_distance_matrix(coordinates)

        assert distance_matrix.shape[0] == distance_matrix.shape[1]
        assert distance_matrix.shape[0] == test_pred_copy.shape[0]
        
        X_test = np.load(f'{ESM_EMBEDDINGS_PATH}/{protein_id}.npy')
        assert X_test.shape[0] == distance_matrix.shape[0]

        # loop over the residues that are not binding and are potential candidates for smoothing
        for residue_idx in torch.where(test_pred == 0.0)[0]:
            # get the embedding of the residue
            current_residue_embedding = X_test[residue_idx]

            # get the close binding residues
            close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
            close_binding_residues_indices = np.intersect1d(close_residues_indices, torch.where(test_pred == 1.0)[0].cpu().numpy())

            # create embedding 
            if len(close_binding_residues_indices) == 0:
                # no close binding residues - skip this residue
                continue
            elif len(close_binding_residues_indices) == 1:
                surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
            else:
                # get the mean of the close binding residues
                surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

            concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(DEVICE)
            
            # get the prediction
            test_logits = smoothing_model(concatenated_embedding).squeeze()
            result = (torch.sigmoid(test_logits)>SMOOTHING_DECISION_THRESHOLD).float()
            if result == 1:
                # set the residue as binding
                print(f"Smoothing changed residue {residue_idx} in protein {protein_id} to binding")
                test_pred_copy[residue_idx] = 1
        
        all_test_logits.append(logits.cpu().detach().numpy())
        all_y_test.append(y_test.cpu().detach().numpy())
        all_test_pred.append(test_pred_copy)
        assert len(y_test) == len(test_pred_copy)        
    test_logits = torch.tensor(np.concatenate(all_test_logits, axis=0), dtype=torch.float32).to(DEVICE)
    test_pred = torch.tensor(np.concatenate(all_test_pred, axis=0), dtype=torch.float32).to(DEVICE)
    y_test = torch.tensor(np.concatenate(all_y_test, axis=0), dtype=torch.float32).to(DEVICE)

    test_acc = baseline_utils.accuracy_fn(y_true=y_test,
                            y_pred=test_pred)

    mcc = metrics.matthews_corrcoef(y_test.cpu().numpy(), test_pred.cpu().numpy())

    f1 = metrics.f1_score(y_test.cpu().numpy(), test_pred.cpu().numpy(), average='weighted')

print(f"Accuracy: {test_acc:.2f}% |  MCC: {mcc:.4f}, F1: {f1:.4f}")
# Out:
# Smoothing changed residue 24 in protein 1a52A to binding
# Smoothing changed residue 25 in protein 1a52A to binding
# Smoothing changed residue 26 in protein 1a52A to binding
# Smoothing changed residue 27 in protein 1a52A to binding
# Smoothing changed residue 29 in protein 1a52A to binding
# Smoothing changed residue 30 in protein 1a52A to binding
# Smoothing changed residue 31 in protein 1a52A to binding
# Smoothing changed residue 101 in protein 1a52A to binding
# Smoothing changed residue 102 in protein 1a52A to binding
# Smoothing changed residue 104 in protein 1a52A to binding
# Smoothing changed residue 108 in protein 1a52A to binding
# Smoothing changed residue 224 in protein 1a52A to binding
# Smoothing changed residue 225 in protein 1a52A to binding
# Smoothing changed residue 156 in protein 1b55B to binding
# Smoothing changed residue 107 in protein 1bldA to binding
# Smoothing changed residue 116 in protein 1bp5A to binding
# Smoothing changed residue 74 in protein 1buvM to binding
# Smoothing changed residue 76 in protein 1buvM to binding
# Smoothing changed residue 79 in protein 1buvM to binding
# Smoothing changed residue 81 in protein 1buvM to binding
# Smoothing changed residue 94 in protein 1buvM to binding
# Smoothing changed residue 98 in protein 1buvM to binding
# Smoothing changed residue 100 in protein 1buvM to binding
# Smoothing changed residue 102 in protein 1buvM to binding
# Smoothing changed residue 68 in protein 1bzsA to binding
# Smoothing changed residue 70 in protein 1bzsA to binding
# Smoothing changed residue 72 in protein 1bzsA to binding
# Smoothing changed residue 75 in protein 1bzsA to binding
# Smoothing changed residue 76 in protein 1bzsA to binding
# Smoothing changed residue 77 in protein 1bzsA to binding
# Smoothing changed residue 94 in protein 1bzsA to binding
# Smoothing changed residue 96 in protein 1bzsA to binding
# Smoothing changed residue 98 in protein 1bzsA to binding
# Smoothing changed residue 19 in protein 1c07A to binding
# Smoothing changed residue 26 in protein 1c07A to binding
# Smoothing changed residue 53 in protein 1c07A to binding
# Smoothing changed residue 60 in protein 1c07A to binding
# Smoothing changed residue 322 in protein 1c4zA to binding
# Smoothing changed residue 116 in protein 1cb6A to binding
# Smoothing changed residue 250 in protein 1cb6A to binding
# Smoothing changed residue 251 in protein 1cb6A to binding
# Smoothing changed residue 594 in protein 1cb6A to binding
# Smoothing changed residue 595 in protein 1cb6A to binding
# Smoothing changed residue 139 in protein 1czaN to binding
# Smoothing changed residue 157 in protein 1czaN to binding
# Smoothing changed residue 217 in protein 1czaN to binding
# Smoothing changed residue 219 in protein 1czaN to binding
# Smoothing changed residue 665 in protein 1czaN to binding
# Smoothing changed residue 96 in protein 1d1sA to binding
# Smoothing changed residue 97 in protein 1d1sA to binding
# Smoothing changed residue 99 in protein 1d1sA to binding
# Smoothing changed residue 102 in protein 1d1sA to binding
# Smoothing changed residue 146 in protein 2j2pC to binding
# Smoothing changed residue 147 in protein 2j2pC to binding
# Smoothing changed residue 148 in protein 2j2pC to binding
# Smoothing changed residue 149 in protein 2j2pC to binding
# Smoothing changed residue 86 in protein 2joxA to binding
# Smoothing changed residue 63 in protein 2jsdA to binding
# Smoothing changed residue 65 in protein 2jsdA to binding
# Smoothing changed residue 67 in protein 2jsdA to binding
# Smoothing changed residue 70 in protein 2jsdA to binding
# Smoothing changed residue 71 in protein 2jsdA to binding
# Smoothing changed residue 72 in protein 2jsdA to binding
# Smoothing changed residue 89 in protein 2jsdA to binding
# Smoothing changed residue 91 in protein 2jsdA to binding
# Smoothing changed residue 93 in protein 2jsdA to binding
# Smoothing changed residue 39 in protein 2k2cA to binding
# Smoothing changed residue 20 in protein 2k7dA to binding
# Smoothing changed residue 22 in protein 2k7dA to binding
# Smoothing changed residue 57 in protein 2k7dA to binding
# Smoothing changed residue 27 in protein 2kjeA to binding
# Smoothing changed residue 53 in protein 2kjeA to binding
# Smoothing changed residue 67 in protein 2kjeA to binding
# Smoothing changed residue 75 in protein 2kjeA to binding
# Smoothing changed residue 19 in protein 2kkrA to binding
# Smoothing changed residue 28 in protein 2kkrA to binding
# Smoothing changed residue 69 in protein 2l51B to binding
# Smoothing changed residue 71 in protein 2l51B to binding
# Smoothing changed residue 72 in protein 2l51B to binding
# Smoothing changed residue 106 in protein 2l7wA to binding
# Smoothing changed residue 107 in protein 2l7wA to binding
# Smoothing changed residue 110 in protein 2l7wA to binding
# Smoothing changed residue 111 in protein 2l7wA to binding
# Smoothing changed residue 1 in protein 2lcpA to binding
# Smoothing changed residue 76 in protein 2lcpA to binding
# Smoothing changed residue 108 in protein 2lcpA to binding
# Smoothing changed residue 110 in protein 2lcpA to binding
# Smoothing changed residue 112 in protein 2lcpA to binding
# Smoothing changed residue 160 in protein 2lcpA to binding
# Smoothing changed residue 47 in protein 2lgrA to binding
# Smoothing changed residue 23 in protein 2lnkA to binding
# Smoothing changed residue 24 in protein 2lnkA to binding
# Smoothing changed residue 66 in protein 2lnkA to binding
# Smoothing changed residue 68 in protein 2lnkA to binding
# Smoothing changed residue 69 in protein 2lnkA to binding
# Smoothing changed residue 70 in protein 2lnkA to binding
# Smoothing changed residue 34 in protein 2lzuA to binding
# Smoothing changed residue 58 in protein 2lzuA to binding
# Smoothing changed residue 15 in protein 2m9wA to binding
# Smoothing changed residue 64 in protein 2miuA to binding
# Smoothing changed residue 19 in protein 2mkdA to binding
# Smoothing changed residue 143 in protein 2mziA to binding
# Smoothing changed residue 145 in protein 2mziA to binding
# Smoothing changed residue 147 in protein 2mziA to binding
# Smoothing changed residue 150 in protein 2mziA to binding
# Smoothing changed residue 151 in protein 2mziA to binding
# Smoothing changed residue 152 in protein 2mziA to binding
# Smoothing changed residue 165 in protein 2mziA to binding
# Smoothing changed residue 166 in protein 2mziA to binding
# Smoothing changed residue 169 in protein 2mziA to binding
# Smoothing changed residue 171 in protein 2mziA to binding
# Smoothing changed residue 71 in protein 2uvlA to binding
# Smoothing changed residue 77 in protein 2uvlA to binding
# Smoothing changed residue 58 in protein 2vm5A to binding
# Smoothing changed residue 76 in protein 2vm5A to binding
# Smoothing changed residue 77 in protein 2vm5A to binding
# Smoothing changed residue 82 in protein 2vm5A to binding
# Smoothing changed residue 5 in protein 2vrdA to binding
# Smoothing changed residue 29 in protein 2vrdA to binding
# Smoothing changed residue 331 in protein 2vxoA to binding
# Smoothing changed residue 390 in protein 2vxoA to binding
# Smoothing changed residue 595 in protein 2vxoA to binding
# Smoothing changed residue 163 in protein 2w2iA to binding
# Smoothing changed residue 65 in protein 2wceA to binding
# Smoothing changed residue 67 in protein 2wceA to binding
# Smoothing changed residue 68 in protein 2wceA to binding
# Smoothing changed residue 186 in protein 2wk6B to binding
# Smoothing changed residue 411 in protein 2wwyB to binding
# Smoothing changed residue 32 in protein 2wyaC to binding
# Smoothing changed residue 69 in protein 2x7hB to binding
# Smoothing changed residue 47 in protein 2yqmA to binding
# Smoothing changed residue 45 in protein 2z5fB to binding
# Smoothing changed residue 49 in protein 2z5fB to binding
# Smoothing changed residue 127 in protein 2z5fB to binding
# Smoothing changed residue 190 in protein 2z5fB to binding
# Smoothing changed residue 225 in protein 2z5fB to binding
# Smoothing changed residue 226 in protein 2z5fB to binding
# Smoothing changed residue 252 in protein 2z5fB to binding
# Smoothing changed residue 253 in protein 2z5fB to binding
# Smoothing changed residue 254 in protein 2z5fB to binding
# Smoothing changed residue 255 in protein 2z5fB to binding
# Smoothing changed residue 256 in protein 2z5fB to binding
# Smoothing changed residue 17 in protein 2zrtG to binding
# Smoothing changed residue 77 in protein 2zrtG to binding
# Smoothing changed residue 79 in protein 2zrtG to binding
# Smoothing changed residue 81 in protein 2zrtG to binding
# Smoothing changed residue 84 in protein 2zrtG to binding
# Smoothing changed residue 145 in protein 2zrtG to binding
# Smoothing changed residue 150 in protein 2zrtG to binding
# Smoothing changed residue 330 in protein 3b6rB to binding
# Smoothing changed residue 204 in protein 3b6uA to binding
# Smoothing changed residue 206 in protein 3b6uA to binding
# Smoothing changed residue 221 in protein 3b6vA to binding
# Smoothing changed residue 108 in protein 3bceA to binding
# Smoothing changed residue 109 in protein 3bceA to binding
# Smoothing changed residue 110 in protein 3bceA to binding
# Smoothing changed residue 42 in protein 3bfxA to binding
# Smoothing changed residue 213 in protein 3bfxA to binding
# Smoothing changed residue 214 in protein 3bfxA to binding
# Smoothing changed residue 259 in protein 3bo5A to binding
# Smoothing changed residue 263 in protein 3bo5A to binding
# Smoothing changed residue 22 in protein 3cbbB to binding
# Smoothing changed residue 67 in protein 3cbbB to binding
# Smoothing changed residue 97 in protein 3cosC to binding
# Smoothing changed residue 98 in protein 3cosC to binding
# Smoothing changed residue 103 in protein 3cosC to binding
# Smoothing changed residue 111 in protein 3cosC to binding
# Smoothing changed residue 135 in protein 3d5oB to binding
# Smoothing changed residue 137 in protein 3d5oB to binding
# Smoothing changed residue 139 in protein 3d5oB to binding
# Smoothing changed residue 72 in protein 4fvlA to binding
# Smoothing changed residue 75 in protein 4fvlA to binding
# Smoothing changed residue 76 in protein 4fvlA to binding
# Smoothing changed residue 77 in protein 4fvlA to binding
# Smoothing changed residue 94 in protein 4fvlA to binding
# Smoothing changed residue 96 in protein 4fvlA to binding
# Smoothing changed residue 98 in protein 4fvlA to binding
# Smoothing changed residue 369 in protein 4gqqA to binding
# Smoothing changed residue 8 in protein 4hc7A to binding
# Smoothing changed residue 29 in protein 4hc7A to binding
# Smoothing changed residue 62 in protein 4hc7A to binding
# Smoothing changed residue 83 in protein 4hc7A to binding
# Smoothing changed residue 124 in protein 4honA to binding
# Smoothing changed residue 167 in protein 4honA to binding
# Smoothing changed residue 233 in protein 4honA to binding
# Smoothing changed residue 298 in protein 4honA to binding
# Smoothing changed residue 186 in protein 4i5jA to binding
# Smoothing changed residue 188 in protein 4i5jA to binding
# Smoothing changed residue 190 in protein 4i5jA to binding
# Smoothing changed residue 193 in protein 4i5jA to binding
# Smoothing changed residue 251 in protein 4j14A to binding
# Smoothing changed residue 373 in protein 4j14A to binding
# Smoothing changed residue 374 in protein 4j14A to binding
# Smoothing changed residue 375 in protein 4j14A to binding
# Smoothing changed residue 379 in protein 4j14A to binding
# Smoothing changed residue 382 in protein 4j14A to binding
# Smoothing changed residue 45 in protein 4jvnA to binding
# Smoothing changed residue 49 in protein 4jvnA to binding
# Smoothing changed residue 126 in protein 4jvnA to binding
# Smoothing changed residue 224 in protein 4jvnA to binding
# Smoothing changed residue 225 in protein 4jvnA to binding
# Smoothing changed residue 251 in protein 4jvnA to binding
# Smoothing changed residue 252 in protein 4jvnA to binding
# Smoothing changed residue 253 in protein 4jvnA to binding
# Smoothing changed residue 254 in protein 4jvnA to binding
# Smoothing changed residue 255 in protein 4jvnA to binding
# Smoothing changed residue 45 in protein 4kfzB to binding
# Smoothing changed residue 266 in protein 4kq8A to binding
# Smoothing changed residue 269 in protein 4kq8A to binding
# Smoothing changed residue 330 in protein 4kq8A to binding
# Smoothing changed residue 384 in protein 4kq8A to binding
# Smoothing changed residue 385 in protein 4kq8A to binding
# Smoothing changed residue 386 in protein 4kq8A to binding
# Smoothing changed residue 390 in protein 4kq8A to binding
# Smoothing changed residue 392 in protein 4kq8A to binding
# Smoothing changed residue 393 in protein 4kq8A to binding
# Smoothing changed residue 394 in protein 4kq8A to binding
# Smoothing changed residue 203 in protein 4l7nA to binding
# Smoothing changed residue 418 in protein 4l9mA to binding
# Smoothing changed residue 193 in protein 4mewA to binding
# Smoothing changed residue 197 in protein 4mewA to binding
# Smoothing changed residue 267 in protein 4mewA to binding
# Smoothing changed residue 269 in protein 4mewA to binding
# Smoothing changed residue 271 in protein 4mewA to binding
# Smoothing changed residue 127 in protein 4mspA to binding
# Smoothing changed residue 131 in protein 4mspA to binding
# Smoothing changed residue 134 in protein 4mspA to binding
# Smoothing changed residue 178 in protein 4mspA to binding
# Smoothing changed residue 79 in protein 4nn2B to binding
# Smoothing changed residue 205 in protein 4nqaI to binding
# Smoothing changed residue 230 in protein 4nqaI to binding
# Smoothing changed residue 268 in protein 4nqaI to binding
# Smoothing changed residue 269 in protein 4nqaI to binding
# Smoothing changed residue 339 in protein 4oavB to binding
# Smoothing changed residue 87 in protein 4or9A to binding
# Smoothing changed residue 59 in protein 4p5wA to binding
# Smoothing changed residue 62 in protein 4p5wA to binding
# Smoothing changed residue 8 in protein 4p60A to binding
# Smoothing changed residue 12 in protein 4p60A to binding
# Smoothing changed residue 15 in protein 4p60A to binding
# Smoothing changed residue 259 in protein 4pcuA to binding
# Smoothing changed residue 67 in protein 4pcwB to binding
# Smoothing changed residue 10 in protein 4pziA to binding
# ...
# Smoothing changed residue 69 in protein 6udmB to binding
# Smoothing changed residue 351 in protein 6udmB to binding
# Smoothing changed residue 412 in protein 6udmB to binding
# Smoothing changed residue 413 in protein 6udmB to binding
# Smoothing changed residue 414 in protein 6udmB to binding
# Smoothing changed residue 418 in protein 6udmB to binding
# Smoothing changed residue 420 in protein 6udmB to binding
# Smoothing changed residue 421 in protein 6udmB to binding
# Smoothing changed residue 42 in protein 6w7zB to binding
# Smoothing changed residue 38 in protein 6w9nA to binding
# Smoothing changed residue 111 in protein 6wu5A to binding
# Smoothing changed residue 115 in protein 6wu5A to binding
# Smoothing changed residue 118 in protein 6wu5A to binding
# Smoothing changed residue 122 in protein 6wu5A to binding
# Smoothing changed residue 159 in protein 6wu5A to binding
# Smoothing changed residue 65 in protein 6ww0C to binding
# Smoothing changed residue 269 in protein 6ww0C to binding
# Smoothing changed residue 323 in protein 6ww0C to binding
# Smoothing changed residue 335 in protein 6ww0C to binding
# Smoothing changed residue 396 in protein 6ww0C to binding
# Smoothing changed residue 397 in protein 6ww0C to binding
# Smoothing changed residue 398 in protein 6ww0C to binding
# Smoothing changed residue 402 in protein 6ww0C to binding
# Smoothing changed residue 404 in protein 6ww0C to binding
# Smoothing changed residue 405 in protein 6ww0C to binding
# Smoothing changed residue 406 in protein 6ww0C to binding
# Smoothing changed residue 317 in protein 6x0lP to binding
# Smoothing changed residue 326 in protein 6x0lP to binding
# Smoothing changed residue 333 in protein 6x0lP to binding
# Smoothing changed residue 118 in protein 6x5hB to binding
# Smoothing changed residue 127 in protein 6xjxQ to binding
# Smoothing changed residue 131 in protein 6xjxQ to binding
# Smoothing changed residue 134 in protein 6xjxQ to binding
# Smoothing changed residue 317 in protein 6xjxQ to binding
# Smoothing changed residue 319 in protein 6xjxQ to binding
# Smoothing changed residue 104 in protein 6xmxH to binding
# Smoothing changed residue 101 in protein 6xqnJ to binding
# Smoothing changed residue 268 in protein 6xqnJ to binding
# Smoothing changed residue 111 in protein 6xr0M to binding
# Smoothing changed residue 254 in protein 6xr0M to binding
# Smoothing changed residue 255 in protein 6xr0M to binding
# Smoothing changed residue 256 in protein 6xr0M to binding
# Smoothing changed residue 257 in protein 6xr0M to binding
# Smoothing changed residue 9 in protein 6xreJ to binding
# Smoothing changed residue 23 in protein 6xreL to binding
# Smoothing changed residue 26 in protein 6xreL to binding
# Smoothing changed residue 147 in protein 6y41L to binding
# Smoothing changed residue 151 in protein 6y43A to binding
# Smoothing changed residue 126 in protein 6yb8B to binding
# Smoothing changed residue 53 in protein 6yihA to binding
# Smoothing changed residue 56 in protein 6yihA to binding
# Smoothing changed residue 75 in protein 6yihA to binding
# Smoothing changed residue 76 in protein 6yihA to binding
# Smoothing changed residue 80 in protein 6yihA to binding
# Smoothing changed residue 133 in protein 6ypeB to binding
# Smoothing changed residue 141 in protein 6ypeB to binding
# Smoothing changed residue 145 in protein 6ypeB to binding
# Smoothing changed residue 20 in protein 6zbzD to binding
# Smoothing changed residue 100 in protein 6zioA to binding
# Smoothing changed residue 103 in protein 6zioA to binding
# Smoothing changed residue 109 in protein 6zmnB to binding
# Smoothing changed residue 190 in protein 6zphB to binding
# Smoothing changed residue 192 in protein 6zphB to binding
# Smoothing changed residue 152 in protein 6zqxB to binding
# Smoothing changed residue 156 in protein 6zqxB to binding
# Smoothing changed residue 134 in protein 6ztrJ to binding
# Smoothing changed residue 21 in protein 7ai1DDD to binding
# Smoothing changed residue 33 in protein 7ai1DDD to binding
# Smoothing changed residue 47 in protein 7ai1DDD to binding
# Smoothing changed residue 422 in protein 7audD to binding
# Smoothing changed residue 4 in protein 7bk2A to binding
# Smoothing changed residue 28 in protein 7bk2A to binding
# Smoothing changed residue 72 in protein 7bk2A to binding
# Smoothing changed residue 195 in protein 7bk2A to binding
# Smoothing changed residue 157 in protein 7breE to binding
# Smoothing changed residue 182 in protein 7bw1A to binding
# Smoothing changed residue 286 in protein 7cebA to binding
# Smoothing changed residue 403 in protein 7cebA to binding
# Smoothing changed residue 211 in protein 7croI to binding
# Smoothing changed residue 214 in protein 7crpI to binding
# Smoothing changed residue 30 in protein 7d2tB to binding
# Smoothing changed residue 382 in protein 7e21A to binding
# Smoothing changed residue 402 in protein 7e21A to binding
# Smoothing changed residue 403 in protein 7e21A to binding
# Smoothing changed residue 405 in protein 7e21A to binding
# Smoothing changed residue 463 in protein 7e21A to binding
# Smoothing changed residue 502 in protein 7e21A to binding
# Smoothing changed residue 233 in protein 7ea8L to binding
# Smoothing changed residue 355 in protein 7fhaA to binding
# Smoothing changed residue 356 in protein 7fhaA to binding
# Smoothing changed residue 51 in protein 7jl5A to binding
# Smoothing changed residue 73 in protein 7jl5A to binding
# Smoothing changed residue 81 in protein 7jl5A to binding
# Smoothing changed residue 77 in protein 7jr8A to binding
# Smoothing changed residue 78 in protein 7jr8A to binding
# Smoothing changed residue 196 in protein 7kbuA to binding
# Smoothing changed residue 80 in protein 7kprA to binding
# Smoothing changed residue 69 in protein 7lpzA to binding
# Smoothing changed residue 388 in protein 7lyxA to binding
# Smoothing changed residue 389 in protein 7lyxA to binding
# Smoothing changed residue 390 in protein 7lyxA to binding
# Smoothing changed residue 394 in protein 7lyxA to binding
# Smoothing changed residue 397 in protein 7lyxA to binding
# Smoothing changed residue 398 in protein 7lyxA to binding
# Smoothing changed residue 156 in protein 7tz2A to binding
# Smoothing changed residue 36 in protein 7ujnC to binding
# Smoothing changed residue 37 in protein 7ujnC to binding
# Smoothing changed residue 44 in protein 7ujnC to binding
# Smoothing changed residue 45 in protein 7ujnC to binding
# Smoothing changed residue 341 in protein 7ujnC to binding
# Smoothing changed residue 10 in protein 7ungMG to binding
# Smoothing changed residue 11 in protein 7ungMG to binding
# Smoothing changed residue 91 in protein 7ungMG to binding
# Smoothing changed residue 138 in protein 7ungMG to binding
# Smoothing changed residue 218 in protein 7ungMG to binding
# Smoothing changed residue 65 in protein 7w6sC to binding
# Smoothing changed residue 97 in protein 7w6sC to binding
# Smoothing changed residue 101 in protein 7w6sC to binding
# Smoothing changed residue 104 in protein 7w6sC to binding
# Smoothing changed residue 145 in protein 7w6sC to binding
# Smoothing changed residue 149 in protein 7w6sC to binding
# Smoothing changed residue 152 in protein 7w6sC to binding
# Smoothing changed residue 156 in protein 7w6sC to binding
# Smoothing changed residue 231 in protein 7wgrB to binding
# Smoothing changed residue 112 in protein 7x2uC to binding
# Smoothing changed residue 116 in protein 7x2uC to binding
# Smoothing changed residue 119 in protein 7x2uC to binding
# Smoothing changed residue 256 in protein 7x73B to binding
# Smoothing changed residue 22 in protein 7xnkH to binding
# Smoothing changed residue 58 in protein 7xnkH to binding
# Smoothing changed residue 60 in protein 7xv6A to binding
# Smoothing changed residue 64 in protein 7xv6A to binding
# Smoothing changed residue 69 in protein 7xv6A to binding
# Smoothing changed residue 28 in protein 7yq8B to binding
# Smoothing changed residue 179 in protein 7yq8B to binding
# Smoothing changed residue 180 in protein 7yq8B to binding
# Smoothing changed residue 420 in protein 7yq8B to binding
# Smoothing changed residue 17 in protein 7z71A to binding
# Smoothing changed residue 28 in protein 7z71A to binding
# Smoothing changed residue 128 in protein 7z71A to binding
# Smoothing changed residue 24 in protein 7z9fA to binding
# Smoothing changed residue 10 in protein 7zcwG to binding
# Smoothing changed residue 11 in protein 7zcwG to binding
# Smoothing changed residue 14 in protein 7zcwG to binding
# Smoothing changed residue 138 in protein 7zcwG to binding
# Smoothing changed residue 144 in protein 7zcwG to binding
# Smoothing changed residue 168 in protein 7zcwG to binding
# Smoothing changed residue 224 in protein 7zcwG to binding
# Smoothing changed residue 225 in protein 7zcwG to binding
# Smoothing changed residue 210 in protein 7zi9A to binding
# Smoothing changed residue 400 in protein 7zmvD to binding
# Smoothing changed residue 419 in protein 7zmvD to binding
# Smoothing changed residue 21 in protein 8a38C to binding
# Smoothing changed residue 23 in protein 8a38C to binding
# Smoothing changed residue 65 in protein 8a40U to binding
# Smoothing changed residue 131 in protein 8a40U to binding
# Smoothing changed residue 2 in protein 8a8mA to binding
# Smoothing changed residue 55 in protein 8a8mA to binding
# Smoothing changed residue 317 in protein 8a8mA to binding
# Smoothing changed residue 0 in protein 8ca0B to binding
# Smoothing changed residue 100 in protein 8ca0B to binding
# Smoothing changed residue 104 in protein 8ca0B to binding
# Smoothing changed residue 366 in protein 8d3vA to binding
# Smoothing changed residue 387 in protein 8d3vA to binding
# Smoothing changed residue 389 in protein 8d3vA to binding
# Smoothing changed residue 447 in protein 8d3vA to binding
# Smoothing changed residue 486 in protein 8d3vA to binding
# Smoothing changed residue 252 in protein 8dydA to binding
# Smoothing changed residue 580 in protein 8dylB to binding
# Smoothing changed residue 583 in protein 8dylB to binding
# Smoothing changed residue 228 in protein 8e1aA to binding
# Smoothing changed residue 233 in protein 8eyoA to binding
# Smoothing changed residue 234 in protein 8eyoA to binding
# Smoothing changed residue 400 in protein 8eyoA to binding
# Smoothing changed residue 58 in protein 8ffvA to binding
# Smoothing changed residue 59 in protein 8ffvA to binding
# Smoothing changed residue 72 in protein 8ffvA to binding
# Smoothing changed residue 28 in protein 8fmuB to binding
# Smoothing changed residue 106 in protein 8fmuB to binding
# Smoothing changed residue 494 in protein 8g7nA to binding
# Smoothing changed residue 25 in protein 8g9pD to binding
# Smoothing changed residue 29 in protein 8g9pD to binding
# Smoothing changed residue 30 in protein 8g9pD to binding
# Smoothing changed residue 85 in protein 8g9pD to binding
# Smoothing changed residue 86 in protein 8g9pD to binding
# Smoothing changed residue 89 in protein 8g9pD to binding
# Smoothing changed residue 90 in protein 8g9pD to binding
# Smoothing changed residue 262 in protein 8gk3H to binding
# Smoothing changed residue 324 in protein 8gk3H to binding
# Smoothing changed residue 335 in protein 8gk3H to binding
# Smoothing changed residue 395 in protein 8gk3H to binding
# Smoothing changed residue 396 in protein 8gk3H to binding
# Smoothing changed residue 400 in protein 8gk3H to binding
# Smoothing changed residue 401 in protein 8gk3H to binding
# Smoothing changed residue 8 in protein 8hdpR to binding
# Smoothing changed residue 280 in protein 8hy5B to binding
# Smoothing changed residue 454 in protein 8i9uJ to binding
# Smoothing changed residue 68 in protein 8ifoA to binding
# Smoothing changed residue 468 in protein 8iwuA to binding
# Smoothing changed residue 501 in protein 8odoA to binding
# Smoothing changed residue 101 in protein 8oi8A to binding
# Smoothing changed residue 262 in protein 8oi8A to binding
# Smoothing changed residue 263 in protein 8oi8A to binding
# Smoothing changed residue 279 in protein 8oi8A to binding
# Smoothing changed residue 339 in protein 8oi8A to binding
# Smoothing changed residue 84 in protein 8omrA to binding
# Smoothing changed residue 90 in protein 8omrA to binding
# Smoothing changed residue 284 in protein 8omrA to binding
# Smoothing changed residue 334 in protein 8omrA to binding
# Smoothing changed residue 80 in protein 8p94A to binding
# Smoothing changed residue 92 in protein 8sg5H to binding
# Smoothing changed residue 331 in protein 8sg5H to binding
# Smoothing changed residue 384 in protein 8sg5H to binding
# Smoothing changed residue 388 in protein 8sg5H to binding
# Smoothing changed residue 391 in protein 8sg5H to binding
# Smoothing changed residue 222 in protein 8t9hK to binding
# Smoothing changed residue 119 in protein 8tzoC to binding
# Accuracy: 89.26% |  MCC: 0.4278, F1: 0.8951

# %% [markdown]
# ## Model with smoothing without ions
# Run the model that was trained on the original scPDB without enhancement.

# %%
MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/model-non-enhanced-scPDB.pt'

loaded_model = torch.load(MODEL_PATH, weights_only=False).to(DEVICE)

with torch.no_grad():
    all_test_logits = []
    all_test_pred = []
    all_y_test = []
    this_test_losses = []

    for batch in val_dataset:
        
        protein_id = batch['ids'][0]
        del batch['ids']
        batch = finetuning_utils.collate_fn([batch], tokenizer=tokenizer)
        output1 = loaded_model(batch)

        labels = batch['labels'].to(DEVICE)
        flattened_labels = labels.flatten()
        y_test = flattened_labels[flattened_labels != -100]
        logits = output1.flatten()[flattened_labels != -100]

        test_pred = (torch.sigmoid(logits)>DECISION_THRESHOLD).float()
        test_pred_copy = test_pred.clone().detach().cpu().numpy()

        # let's use the smoothing model here:
        # first, get the distance matrix
        coordinates = np.load(f'{COORDINATES_DIR}/{protein_id}.npy')
        distance_matrix = eval_utils.compute_distance_matrix(coordinates)

        assert distance_matrix.shape[0] == distance_matrix.shape[1]
        assert distance_matrix.shape[0] == test_pred_copy.shape[0]
        
        X_test = np.load(f'{ESM_EMBEDDINGS_PATH}/{protein_id}.npy')
        assert X_test.shape[0] == distance_matrix.shape[0]

        # loop over the residues that are not binding and are potential candidates for smoothing
        for residue_idx in torch.where(test_pred == 0.0)[0]:
            # get the embedding of the residue
            current_residue_embedding = X_test[residue_idx]

            # get the close binding residues
            close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
            close_binding_residues_indices = np.intersect1d(close_residues_indices, torch.where(test_pred == 1.0)[0].cpu().numpy())

            # create embedding 
            if len(close_binding_residues_indices) == 0:
                # no close binding residues - skip this residue
                continue
            elif len(close_binding_residues_indices) == 1:
                surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
            else:
                # get the mean of the close binding residues
                surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

            concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(DEVICE)
            
            # get the prediction
            test_logits = smoothing_model(concatenated_embedding).squeeze()
            result = (torch.sigmoid(test_logits)>SMOOTHING_DECISION_THRESHOLD).float()
            if result == 1:
                # set the residue as binding
                test_pred_copy[residue_idx] = 1
        
        all_test_logits.append(logits.cpu().detach().numpy())
        all_y_test.append(y_test.cpu().detach().numpy())
        all_test_pred.append(test_pred_copy)
        assert len(y_test) == len(test_pred_copy)        
    test_logits = torch.tensor(np.concatenate(all_test_logits, axis=0), dtype=torch.float32).to(DEVICE)
    test_pred = torch.tensor(np.concatenate(all_test_pred, axis=0), dtype=torch.float32).to(DEVICE)
    y_test = torch.tensor(np.concatenate(all_y_test, axis=0), dtype=torch.float32).to(DEVICE)

    test_acc = baseline_utils.accuracy_fn(y_true=y_test,
                            y_pred=test_pred)

    mcc = metrics.matthews_corrcoef(y_test.cpu().numpy(), test_pred.cpu().numpy())

    f1 = metrics.f1_score(y_test.cpu().numpy(), test_pred.cpu().numpy(), average='weighted')
    
    fpr, tpr, thresholds = metrics.roc_curve(y_test.cpu().float().numpy(), torch.sigmoid(test_logits).cpu().float().numpy())
    roc_auc = metrics.auc(fpr, tpr)
    precision, recall, thresholds = metrics.precision_recall_curve(y_test.cpu().float().numpy(), torch.sigmoid(test_logits).cpu().float().numpy())
    auprc = metrics.auc(recall, precision)

print(f"Accuracy: {test_acc:.2f}% | AUC: {roc_auc:.4f}, MCC: {mcc:.4f}, F1: {f1:.4f}, AUPRC: {auprc:.4f}")
# Out:
# Accuracy: 89.26% | AUC: 0.8217, MCC: 0.4278, F1: 0.8951, AUPRC: 0.4958

# %% [markdown]
# ## Compare it with model without smoothing

# %%
from torch.utils.data import DataLoader
MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/model-enhanced-scPDB.pt'

loaded_model = torch.load(MODEL_PATH, weights_only=False).to(DEVICE)

partial_collate_fn = functools.partial(finetuning_utils.collate_fn, tokenizer=tokenizer)
val_dataset = finetuning_utils.process_sequence_dataset(RESIDUE_LEVEL_ANNOTATIONS, tokenizer)
val_dataloader = DataLoader(val_dataset, batch_size=val_dataset.num_rows // 20, collate_fn=partial_collate_fn)

all_test_logits = []
all_test_pred = []
all_y_test = []

with torch.no_grad():
    for batch in val_dataloader:
        output1 = loaded_model(batch)

        labels = batch['labels'].to(DEVICE)

        flattened_labels = labels.flatten()

        logits = output1.flatten()[flattened_labels != -100]
        valid_flattened_labels = labels.flatten()[flattened_labels != -100]

        predictions = (torch.sigmoid(logits)>DECISION_THRESHOLD).float()

        all_test_logits.append(logits.cpu().detach().numpy())
        all_y_test.append(valid_flattened_labels.cpu().detach().numpy())
        all_test_pred.append(predictions.cpu().detach().numpy())
        assert len(valid_flattened_labels) == len(predictions)        
    
    cbs_logits = torch.tensor(np.concatenate(all_test_logits, axis=0), dtype=torch.float32).to(DEVICE)
    predictions = torch.tensor(np.concatenate(all_test_pred, axis=0), dtype=torch.float32).to(DEVICE)
    valid_flattened_labels = torch.tensor(np.concatenate(all_y_test, axis=0), dtype=torch.float32).to(DEVICE)

    # compute metrics on test dataset
    test_acc = baseline_utils.accuracy_fn(y_true=valid_flattened_labels,
                            y_pred=predictions)
    fpr, tpr, thresholds = metrics.roc_curve(valid_flattened_labels.cpu().float().numpy(), torch.sigmoid(cbs_logits).cpu().float().numpy())
    roc_auc = metrics.auc(fpr, tpr)

    mcc = metrics.matthews_corrcoef(valid_flattened_labels.cpu().float().numpy(), predictions.cpu().float().numpy())

    f1 = metrics.f1_score(valid_flattened_labels.cpu().float().numpy(), predictions.cpu().float().numpy(), average='weighted')

    precision, recall, thresholds = metrics.precision_recall_curve(valid_flattened_labels.cpu().float().numpy(), torch.sigmoid(cbs_logits).cpu().float().numpy())
    auprc = metrics.auc(recall, precision)

print(f"Accuracy: {test_acc:.2f}% | AUC: {roc_auc:.4f}, MCC: {mcc:.4f}, F1: {f1:.4f}, AUPRC: {auprc:.4f}")
# Out:
# Accuracy: 89.05% | AUC: 0.8732, MCC: 0.4893, F1: 0.8985, AUPRC: 0.5949
