# %%
import csv

with open('/home/vit/Projects/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis_without_unobserved.csv', 'r') as f:
    with open('/home/vit/Projects/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis.fasta', 'w') as out_f:
        reader = csv.reader(f, delimiter=';')
        next(reader)  # Skip header
        for row in reader:
            protein_id = row[0]
            sequence = row[4]
            out_f.write(f">{protein_id}\n{sequence}\n")
