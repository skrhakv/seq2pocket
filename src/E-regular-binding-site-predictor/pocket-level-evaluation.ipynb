# %% [markdown]
# ### venv location:
# activate the following: `~/cryptic-nn/src/fine-tuning/esmc-venv/bin/activate`

# %%
from transformers import AutoTokenizer
import torch
import numpy as np
import functools
from sklearn import metrics
from torch.utils.data import DataLoader
import sys

sys.path.append('/home/skrhakv/cryptoshow-analysis/src/B-evaluate-cryptoshow')
sys.path.append('/home/skrhakv/cryptic-nn/src')
import finetuning_utils
from finetuning_utils import FinetunedEsmModel
import eval_utils
from eval_utils import CryptoBenchClassifier

MODEL_NAME = 'facebook/esm2_t36_3B_UR50D'
device = 'cuda' if torch.cuda.is_available() else 'cpu'

MODEL_PATH = f'/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/model.pt'
# model = torch.load(MODEL_PATH, weights_only=False)
# tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
SMOOTHING_MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/C-optimize-smoother/smoother.pt'
smoothing_model = torch.load(SMOOTHING_MODEL_PATH, weights_only=False) #, map_location=torch.device('cpu'))

# %%
PRECALCULATED = True
PREDICTIONS_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/predictions'
PRECALCULATED_PATH = F'{PREDICTIONS_PATH}/finetuning-without-smoothing'
COORDINATES_DIR = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis-coordinates'
EMBEDDINGS_DIR = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/embeddings'
LIGYSIS_ANNOTATION_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis_for_pocket_level_evaluation.csv'
DECISION_THRESHOLD = 0.8

binding_residues, sequences = eval_utils.read_test_binding_residues(data_path=LIGYSIS_ANNOTATION_PATH, pocket_types=['NON_CRYPTIC'])

predicted_binding_sites = {}
prediction_scores = {}
for protein_id in sequences.keys():
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    embeddings_path = f'{EMBEDDINGS_DIR}/{pdb_id}{chain_id}.npy'
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'

    if not PRECALCULATED:
        # finetuned prediction
        prediction = eval_utils.compute_prediction(
            sequence,
            embeddings_path,
            model,
            tokenizer
        )
    else:
        # load precalculated prediction
        prediction = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')
    
    prediction_scores[protein_id] = prediction
    
    # cluster predicted pockets
    coordinates = np.load(coordinates_path)
    clusters = eval_utils.compute_clusters(
        coordinates,
        prediction,
        decision_threshold=DECISION_THRESHOLD,
    )

    assert coordinates.shape[0] == prediction.shape[0], "Number of coordinates must match number of prediction scores."
    # load distance matrix
    distance_matrix = eval_utils.compute_distance_matrix(coordinates)
    print(protein_id, 'number of clusters:', len(np.unique(clusters)) - (1 if -1 in clusters else 0))
    # enhance predicted pockets using the smoothing model
    predicted_binding_sites[protein_id] = []
    for cluster_label in np.unique(clusters):
        if cluster_label == -1:
            continue
        cluster_residue_indices = np.where(clusters == cluster_label)[0]
        embeddings, indices = eval_utils.process_single_sequence(pdb_id, chain_id, cluster_residue_indices, embeddings_path, distance_matrix) 

        # # TODO: This is weird, fix later
        # if embeddings.shape[0] == 0:
        #     predicted_binding_sites[protein_id].append((cluster_residue_indices, 'finetuned model with smoothing'))
        #     continue

        prediction = eval_utils.predict_single_sequence(embeddings, indices, smoothing_model)

        # # TODO: This is weird, fix later
        # if indices[prediction['predictions'] > eval_utils.SMOOTHING_DECISION_THRESHOLD].shape[0] == 0:
        #     predicted_binding_sites[protein_id].append((cluster_residue_indices, 'finetuned model with smoothing'))
        #     continue
        
        enhanced_residue_indices = np.concatenate((indices[prediction['predictions'] > eval_utils.SMOOTHING_DECISION_THRESHOLD], cluster_residue_indices))
        predicted_binding_sites[protein_id].append((enhanced_residue_indices, 'finetuned model with smoothing'))

# import numpy as np
# for protein_id in prediction_scores.keys():
#     np.save(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy', prediction_scores[protein_id])
# Out:
# 1a52_A number of clusters: 4
# 1a5h_D number of clusters: 1
# 1a9w_B number of clusters: 0
# 1ags_B number of clusters: 3
# 1aii_A number of clusters: 0
# 1au1_A number of clusters: 0
# 1aue_B number of clusters: 1
# 1aye_A number of clusters: 2
# 1b1c_A number of clusters: 1
# 1b50_B number of clusters: 0
# 1b55_B number of clusters: 0
# 1b6c_F number of clusters: 2
# 1b9o_A number of clusters: 2
# 1bbo_A number of clusters: 0
# 1bci_A number of clusters: 0
# 1bf9_A number of clusters: 0
# 1bhi_A number of clusters: 0
# 1bhx_C number of clusters: 1
# 1bld_A number of clusters: 3
# 1blx_A number of clusters: 2
# 1bmo_A number of clusters: 0
# 1bnl_A number of clusters: 0
# 1boy_A number of clusters: 0
# 1bp5_A number of clusters: 2
# 1buv_A number of clusters: 3
# 1byg_A number of clusters: 2
# 1bzs_A number of clusters: 3
# 1c07_A number of clusters: 4
# 1c4z_A number of clusters: 0
# 1c5n_A number of clusters: 0
# 1c9y_A number of clusters: 3
# 1cb6_A number of clusters: 2
# 1cjy_B number of clusters: 2
# 1cm8_A number of clusters: 1
# 1cr8_A number of clusters: 0
# 1cws_A number of clusters: 1
# 1cx8_C number of clusters: 0
# 1cza_A number of clusters: 6
# 1czv_A number of clusters: 0
# 1d1s_A number of clusters: 3
# 1d2l_A number of clusters: 0
# 1d4u_A number of clusters: 0
# 1d5g_A number of clusters: 2
# 1drf_A number of clusters: 5
# 1ds6_A number of clusters: 3
# 1dsz_C number of clusters: 0
# 1dtw_B number of clusters: 0
# 1dxt_D number of clusters: 0
# 1e0o_D number of clusters: 0
# 1e17_A number of clusters: 0
# 1e9t_A number of clusters: 0
# 1eh2_A number of clusters: 0
# 1ek3_A number of clusters: 0
# 1ek6_A number of clusters: 7
# 1emn_A number of clusters: 0
# 1equ_A number of clusters: 3
# 1eub_A number of clusters: 3
# 1evt_C number of clusters: 0
# 1eyb_A number of clusters: 0
# 1f13_B number of clusters: 0
# 1f5y_A number of clusters: 0
# 1f62_A number of clusters: 0
# 1f6w_A number of clusters: 1
# 1f8z_A number of clusters: 0
# 1fa9_A number of clusters: 2
# 1fao_A number of clusters: 1
# 1faq_A number of clusters: 0
# 1fcg_A number of clusters: 0
# 1fd3_C number of clusters: 0
# 1fdh_D number of clusters: 0
# 1fe8_G number of clusters: 0
# 1fht_A number of clusters: 0
# 1fkt_A number of clusters: 4
# 1flh_A number of clusters: 4
# 1fp0_A number of clusters: 0
# 1fq3_A number of clusters: 2
# 1fsu_A number of clusters: 0
# 1fuj_C number of clusters: 1
# 1fvr_B number of clusters: 2
# 1fw1_A number of clusters: 2
# 1fy1_A number of clusters: 2
# 1fzd_G number of clusters: 0
# 1g1q_C number of clusters: 0
# 1g25_A number of clusters: 0
# 1g3f_A number of clusters: 0
# 1g47_A number of clusters: 0
# 1g55_A number of clusters: 3
# 1g5v_A number of clusters: 0
# 1g5w_A number of clusters: 2
# 1ga5_G number of clusters: 0
# 1ggl_A number of clusters: 4
# 1ggz_A number of clusters: 6
# 1gh7_A number of clusters: 0
# 1gnh_D number of clusters: 0
# 1gpz_B number of clusters: 1
# 1gqf_B number of clusters: 2
# 1gr3_A number of clusters: 0
# 1gvl_A number of clusters: 2
# 1gwb_B number of clusters: 0
# 1gxd_A number of clusters: 1
# 1gxr_A number of clusters: 0
# 1gzq_A number of clusters: 4
# 1h30_A number of clusters: 0
# 1h6h_A number of clusters: 1
# 1h6p_B number of clusters: 0
# 1hcp_A number of clusters: 0
# 1hdo_A number of clusters: 3
# 1hdr_A number of clusters: 2
# 1hgu_A number of clusters: 0
# 1hh4_C number of clusters: 0
# 1hnc_A number of clusters: 6
# 1hnf_A number of clusters: 0
# 1hp7_A number of clusters: 0
# 1hra_A number of clusters: 0
# 1ht0_A number of clusters: 3
# 1htn_A number of clusters: 0
# 1hup_A number of clusters: 1
# 1i1n_A number of clusters: 2
# 1i3e_A number of clusters: 1
# 1i3o_F number of clusters: 0
# 1i71_A number of clusters: 2
# 1ihk_A number of clusters: 4
# 1ijt_A number of clusters: 2
# 1ilg_A number of clusters: 5
# 1iq3_A number of clusters: 0
# 1isi_A number of clusters: 4
# 1itu_A number of clusters: 0
# 1ivh_D number of clusters: 6
# 1ivy_A number of clusters: 1
# 1j2x_A number of clusters: 0
# 1j78_B number of clusters: 0
# 1j8e_A number of clusters: 0
# 1j8f_A number of clusters: 4
# 1j8h_D number of clusters: 0
# 1jdn_A number of clusters: 1
# 1jiz_B number of clusters: 3
# 1jm7_B number of clusters: 0
# 1joc_B number of clusters: 0
# 1jxs_A number of clusters: 0
# 1k3b_A number of clusters: 1
# 1k6m_B number of clusters: 5
# 1k94_B number of clusters: 0
# 1k9i_H number of clusters: 1
# 1kb2_D number of clusters: 0
# 1kcg_C number of clusters: 2
# 1kcw_A number of clusters: 0
# 1kfu_B number of clusters: 3
# 1kkq_D number of clusters: 5
# 1klv_A number of clusters: 3
# 1kq6_A number of clusters: 0
# 1kqn_D number of clusters: 2
# 1krn_A number of clusters: 1
# 1kvi_A number of clusters: 2
# 1kwm_A number of clusters: 2
# 1kyn_B number of clusters: 1
# 1l1o_F number of clusters: 0
# 1l6j_A number of clusters: 1
# 1l9l_A number of clusters: 0
# 1ldr_A number of clusters: 0
# 1lgp_A number of clusters: 1
# 1lhu_A number of clusters: 1
# 1lj5_A number of clusters: 0
# 1ljr_B number of clusters: 2
# 1lmj_A number of clusters: 0
# 1lo1_C number of clusters: 0
# 1lpb_B number of clusters: 1
# 1lpj_A number of clusters: 5
# 1lpq_C number of clusters: 0
# 1ls6_A number of clusters: 3
# 1lt8_B number of clusters: 1
# 1lv2_A number of clusters: 4
# 1lw3_A number of clusters: 1
# 1lyw_A number of clusters: 3
# 1lyw_F number of clusters: 3
# 1lyy_A number of clusters: 5
# 1m36_A number of clusters: 0
# 1m4r_B number of clusters: 0
# 1m6d_B number of clusters: 2
# 1m76_A number of clusters: 5
# 1m9i_A number of clusters: 0
# 1mf8_A number of clusters: 0
# 1mj4_A number of clusters: 1
# 1mkk_B number of clusters: 0
# 1mm2_A number of clusters: 0
# 1mq0_B number of clusters: 2
# 1mr1_D number of clusters: 0
# 1msz_A number of clusters: 0
# 1n0z_A number of clusters: 0
# 1n7d_A number of clusters: 0
# 1nav_A number of clusters: 6
# 1nd6_C number of clusters: 1
# 1ne7_A number of clusters: 1
# 1nko_A number of clusters: 0
# 1nn8_C number of clusters: 0
# 1nnl_B number of clusters: 2
# 1now_B number of clusters: 1
# 1nq1_A number of clusters: 4
# 1nsi_C number of clusters: 2
# 1nst_A number of clusters: 3
# 1nuh_A number of clusters: 2
# 1nuu_B number of clusters: 2
# 1nyp_A number of clusters: 0
# 1o6u_B number of clusters: 0
# 1ohc_A number of clusters: 2
# 1oj6_D number of clusters: 0
# 1op8_D number of clusters: 1
# 1opl_A number of clusters: 3
# 1oqj_B number of clusters: 0
# 1ozo_A number of clusters: 3
# 1ozs_A number of clusters: 2
# 1p32_A number of clusters: 0
# 1p4o_A number of clusters: 1
# 1p4q_B number of clusters: 0
# 1p97_A number of clusters: 4
# 1pb5_A number of clusters: 1
# 1pfl_A number of clusters: 0
# 1pkx_B number of clusters: 3
# 1pl8_C number of clusters: 3
# 1plo_A number of clusters: 0
# 1psr_B number of clusters: 1
# 1pt6_B number of clusters: 0
# 1q0p_A number of clusters: 0
# 1q1u_A number of clusters: 5
# 1q22_A number of clusters: 2
# 1q33_A number of clusters: 1
# 1q3a_A number of clusters: 3
# 1q7l_C number of clusters: 3
# 1q7l_D number of clusters: 1
# 1q8l_A number of clusters: 1
# 1q8x_A number of clusters: 0
# 1q9s_A number of clusters: 2
# 1qh5_B number of clusters: 3
# 1qib_A number of clusters: 3
# 1qnm_A number of clusters: 0
# 1qzq_A number of clusters: 0
# 1qzu_B number of clusters: 4
# 1r3y_A number of clusters: 2
# 1r54_A number of clusters: 3
# 1r79_A number of clusters: 0
# 1r8q_B number of clusters: 2
# 1rgo_B number of clusters: 0
# 1riw_B number of clusters: 1
# 1rjv_A number of clusters: 3
# 1rkb_A number of clusters: 4
# 1rm8_A number of clusters: 3
# 1rnf_B number of clusters: 1
# 1ro4_A number of clusters: 0
# 1rtg_A number of clusters: 0
# 1rx0_D number of clusters: 5
# 1rxr_A number of clusters: 0
# 1s18_A number of clusters: 1
# 1s1e_A number of clusters: 2
# 1s4b_A number of clusters: 2
# 1s4y_B number of clusters: 0
# 1s5o_A number of clusters: 3
# 1s9i_A number of clusters: 3
# 1sg4_B number of clusters: 1
# 1shr_D number of clusters: 0
# 1siq_A number of clusters: 5
# 1sl6_E number of clusters: 1
# 1smo_B number of clusters: 0
# 1so0_B number of clusters: 0
# 1soj_I number of clusters: 4
# 1sp2_A number of clusters: 0
# 1spj_A number of clusters: 1
# 1st0_B number of clusters: 1
# 1su3_A number of clusters: 3
# 1szb_B number of clusters: 0
# 1t3n_D number of clusters: 0
# 1t6b_B number of clusters: 1
# 1t8c_A number of clusters: 0
# 1t8t_B number of clusters: 2
# 1tff_A number of clusters: 0
# 1tfi_A number of clusters: 1
# 1tg6_C number of clusters: 1
# 1tjj_A number of clusters: 0
# 1toz_A number of clusters: 0
# 1tpk_C number of clusters: 0
# 1ttx_A number of clusters: 3
# 1tu4_C number of clusters: 3
# 1tvx_D number of clusters: 0
# 1u31_A number of clusters: 1
# 1u3t_A number of clusters: 4
# 1u59_A number of clusters: 2
# 1u7f_B number of clusters: 0
# 1u7t_D number of clusters: 2
# 1ubd_C number of clusters: 0
# 1ul1_C number of clusters: 2
# 1umk_A number of clusters: 2
# 1unq_A number of clusters: 2
# 1upr_A number of clusters: 1
# 1ur6_B number of clusters: 0
# 1uv0_A number of clusters: 0
# 1uvq_B number of clusters: 1
# 1uw5_A number of clusters: 0
# 1uwy_A number of clusters: 1
# 1ux6_A number of clusters: 0
# 1uzj_B number of clusters: 0
# 1v5h_A number of clusters: 1
# 1v6g_A number of clusters: 0
# 1v84_A number of clusters: 5
# 1v88_A number of clusters: 0
# 1va1_A number of clusters: 0
# 1vd4_A number of clusters: 0
# 1vhr_A number of clusters: 2
# 1vtn_C number of clusters: 0
# 1w0s_C number of clusters: 0
# 1w1h_C number of clusters: 1
# 1w45_B number of clusters: 0
# 1w4r_A number of clusters: 4
# 1w4u_A number of clusters: 1
# 1w6j_A number of clusters: 3
# 1war_A number of clusters: 0
# 1wch_A number of clusters: 1
# 1wd2_A number of clusters: 0
# 1wig_A number of clusters: 0
# 1wjp_A number of clusters: 0
# 1wl4_A number of clusters: 3
# 1wlj_A number of clusters: 1
# 1woj_A number of clusters: 2
# 1wq1_B number of clusters: 0
# 1wsr_A number of clusters: 3
# 1wyh_A number of clusters: 0
# 1x03_A number of clusters: 0
# 1x05_A number of clusters: 1
# 1x3c_A number of clusters: 0
# 1x3h_A number of clusters: 0
# 1x3s_A number of clusters: 1
# 1x4k_A number of clusters: 0
# 1x4l_A number of clusters: 1
# 1x4s_A number of clusters: 0
# 1x4u_A number of clusters: 0
# 1x4v_A number of clusters: 0
# 1x4w_A number of clusters: 0
# 1x5w_A number of clusters: 0
# 1x61_A number of clusters: 0
# 1x62_A number of clusters: 0
# 1x63_A number of clusters: 0
# 1x68_A number of clusters: 0
# 1x6a_A number of clusters: 0
# 1x6e_A number of clusters: 0
# 1x6f_A number of clusters: 0
# 1x9d_A number of clusters: 0
# 1xa6_A number of clusters: 0
# 1xc5_A number of clusters: 0
# 1xcr_A number of clusters: 1
# 1xd3_A number of clusters: 2
# 1xd4_A number of clusters: 0
# 1xgd_A number of clusters: 9
# 1xpw_A number of clusters: 0
# 1xrj_A number of clusters: 2
# 1xsb_A number of clusters: 3
# 1xvp_B number of clusters: 5
# 1xw6_D number of clusters: 6
# 1xwi_A number of clusters: 4
# 1y02_A number of clusters: 1
# 1y3j_A number of clusters: 1
# 1y4j_B number of clusters: 0
# 1yb1_B number of clusters: 4
# 1yb5_A number of clusters: 4
# 1yfh_G number of clusters: 0
# 1yjt_A number of clusters: 1
# 1yjx_H number of clusters: 2
# 1yuo_A number of clusters: 2
# 1yvj_A number of clusters: 2
# 1yw7_A number of clusters: 0
# 1yxm_A number of clusters: 3
# 1yzg_A number of clusters: 4
# 1yzx_A number of clusters: 2
# 1z0a_C number of clusters: 3
# 1z29_A number of clusters: 1
# 1z60_A number of clusters: 0
# 1z6c_A number of clusters: 0
# 1z6t_D number of clusters: 2
# 1z6u_A number of clusters: 0
# 1z6x_B number of clusters: 3
# 1z7x_B number of clusters: 1
# 1z8d_A number of clusters: 2
# 1z8l_A number of clusters: 4
# 1z9q_A number of clusters: 0
# 1zbj_A number of clusters: 0
# 1zbq_B number of clusters: 3
# 1zbu_B number of clusters: 0
# 1zd9_A number of clusters: 3
# 1zkl_A number of clusters: 4
# 1zr9_A number of clusters: 0
# 1zrh_A number of clusters: 2
# 1zs6_A number of clusters: 3
# 1zs9_A number of clusters: 3
# 1zt4_C number of clusters: 0
# 1zv4_A number of clusters: 0
# 2a07_J number of clusters: 0
# 2a0z_A number of clusters: 0
# 2a14_A number of clusters: 2
# 2a1u_A number of clusters: 1
# 2a1u_B number of clusters: 2
# 2a1x_A number of clusters: 0
# 2a2a_A number of clusters: 4
# 2a2c_A number of clusters: 2
# 2a3r_A number of clusters: 2
# 2a5j_A number of clusters: 4
# 2a66_C number of clusters: 0
# 2a8l_B number of clusters: 2
# 2a98_A number of clusters: 2
# 2ac3_A number of clusters: 2
# 2ag5_B number of clusters: 2
# 2al7_A number of clusters: 2
# 2aou_B number of clusters: 1
# 2atv_A number of clusters: 4
# 2atx_B number of clusters: 2
# 2avd_A number of clusters: 2
# 2b0o_B number of clusters: 0
# 2b25_A number of clusters: 2
# 2b3y_A number of clusters: 3
# 2b48_A number of clusters: 5
# 2b6h_A number of clusters: 3
# 2b9e_A number of clusters: 3
# 2bbw_A number of clusters: 7
# 2bei_A number of clusters: 5
# 2bex_C number of clusters: 0
# 2biv_A number of clusters: 0
# 2bka_A number of clusters: 5
# 2ble_A number of clusters: 5
# 2bme_B number of clusters: 2
# 2bo2_B number of clusters: 0
# 2bov_A number of clusters: 3
# 2bp1_D number of clusters: 5
# 2bw0_A number of clusters: 4
# 2bwj_E number of clusters: 6
# 2bzg_A number of clusters: 2
# 2bzm_A number of clusters: 0
# 2c30_A number of clusters: 3
# 2c3q_C number of clusters: 3
# 2c43_A number of clusters: 5
# 2c47_C number of clusters: 3
# 2c6a_A number of clusters: 0
# 2c7n_K number of clusters: 0
# 2c9y_A number of clusters: 6
# 2cg5_B number of clusters: 1
# 2ch5_B number of clusters: 2
# 2ch9_A number of clusters: 0
# 2cjw_A number of clusters: 4
# 2clp_K number of clusters: 5
# 2cmw_A number of clusters: 3
# 2cn5_A number of clusters: 3
# 2co8_A number of clusters: 0
# 2cor_A number of clusters: 0
# 2cot_A number of clusters: 0
# 2cq9_A number of clusters: 2
# 2cqe_A number of clusters: 0
# 2cr8_A number of clusters: 0
# 2crc_A number of clusters: 1
# 2crr_A number of clusters: 0
# 2crw_A number of clusters: 0
# 2cs3_A number of clusters: 0
# 2cs8_A number of clusters: 0
# 2csh_A number of clusters: 0
# 2csv_A number of clusters: 0
# 2csy_A number of clusters: 0
# 2ct0_A number of clusters: 0
# 2ct5_A number of clusters: 0
# 2ct7_A number of clusters: 0
# 2ctd_A number of clusters: 0
# 2ctt_A number of clusters: 1
# 2ctu_A number of clusters: 0
# 2cu8_A number of clusters: 1
# 2cuq_A number of clusters: 0
# 2cur_A number of clusters: 0
# 2cw9_A number of clusters: 0
# 2cxy_A number of clusters: 0
# 2czh_B number of clusters: 0
# 2d07_A number of clusters: 3
# 2d7i_A number of clusters: 3
# 2d8r_A number of clusters: 0
# 2d8s_A number of clusters: 0
# 2d8t_A number of clusters: 0
# 2d8u_A number of clusters: 0
# 2d8x_A number of clusters: 0
# 2d8y_A number of clusters: 0
# 2d8z_A number of clusters: 0
# 2d9g_A number of clusters: 0
# 2d9k_A number of clusters: 0
# 2d9l_A number of clusters: 0
# 2d9m_A number of clusters: 0
# 2dan_A number of clusters: 0
# 2dar_A number of clusters: 0
# 2das_A number of clusters: 0
# 2db6_A number of clusters: 0
# 2dho_A number of clusters: 1
# 2dif_A number of clusters: 0
# 2dip_A number of clusters: 0
# 2dj7_A number of clusters: 0
# 2dja_A number of clusters: 0
# 2djb_A number of clusters: 0
# 2djr_A number of clusters: 0
# 2dko_B number of clusters: 1
# 2dlk_A number of clusters: 0
# 2dlo_A number of clusters: 0
# 2dmd_A number of clusters: 0
# 2dmi_A number of clusters: 0
# 2dmj_A number of clusters: 0
# 2dq7_A number of clusters: 2
# 2dud_B number of clusters: 0
# 2e2x_B number of clusters: 0
# 2e59_A number of clusters: 0
# 2e5r_A number of clusters: 0
# 2e5s_A number of clusters: 0
# 2e61_A number of clusters: 0
# 2e6i_A number of clusters: 0
# 2e6r_A number of clusters: 0
# 2e6s_A number of clusters: 0
# 2e6w_A number of clusters: 1
# 2e72_A number of clusters: 0
# 2e73_A number of clusters: 0
# 2e9s_A number of clusters: 2
# 2ea5_A number of clusters: 0
# 2eav_A number of clusters: 3
# 2eb1_B number of clusters: 2
# 2ebl_A number of clusters: 0
# 2ebq_A number of clusters: 0
# 2ebr_A number of clusters: 0
# 2ebt_A number of clusters: 0
# 2ebv_A number of clusters: 0
# 2ecj_A number of clusters: 0
# 2ecn_A number of clusters: 0
# 2ecv_A number of clusters: 0
# 2ecy_A number of clusters: 0
# 2egm_A number of clusters: 0
# 2egp_A number of clusters: 0
# 2ehe_A number of clusters: 0
# 2el4_A number of clusters: 0
# 2el5_A number of clusters: 0
# 2el6_A number of clusters: 0
# 2eli_A number of clusters: 0
# 2eln_A number of clusters: 0
# 2elr_A number of clusters: 0
# 2ely_A number of clusters: 0
# 2em1_A number of clusters: 0
# 2em2_A number of clusters: 0
# 2em3_A number of clusters: 0
# 2em4_A number of clusters: 0
# 2em6_A number of clusters: 0
# 2em7_A number of clusters: 0
# 2em9_A number of clusters: 0
# 2ema_A number of clusters: 0
# 2emb_A number of clusters: 0
# 2emc_A number of clusters: 0
# 2emf_A number of clusters: 0
# 2emg_A number of clusters: 0
# 2emh_A number of clusters: 0
# 2emi_A number of clusters: 0
# 2emj_A number of clusters: 0
# 2emk_A number of clusters: 0
# 2eml_A number of clusters: 0
# 2emp_A number of clusters: 0
# 2emv_A number of clusters: 0
# 2emw_A number of clusters: 0
# 2emx_A number of clusters: 0
# 2emy_A number of clusters: 0
# 2en0_A number of clusters: 0
# 2en2_A number of clusters: 0
# 2en4_A number of clusters: 0
# 2en6_A number of clusters: 0
# 2en7_A number of clusters: 0
# 2en8_A number of clusters: 0
# 2en9_A number of clusters: 0
# 2ena_A number of clusters: 0
# 2enc_A number of clusters: 0
# 2enf_A number of clusters: 0
# 2enh_A number of clusters: 0
# 2enn_A number of clusters: 0
# 2ent_A number of clusters: 0
# 2env_A number of clusters: 0
# 2enz_A number of clusters: 0
# 2eod_A number of clusters: 0
# 2eoe_A number of clusters: 0
# 2eof_A number of clusters: 0
# 2eog_A number of clusters: 0
# 2eoh_A number of clusters: 0
# 2eoi_A number of clusters: 0
# 2eoj_A number of clusters: 0
# 2eok_A number of clusters: 0
# 2eol_A number of clusters: 0
# 2eop_A number of clusters: 0
# 2eoq_A number of clusters: 0
# 2eor_A number of clusters: 0
# 2eos_A number of clusters: 0
# 2eou_A number of clusters: 0
# 2eov_A number of clusters: 0
# 2eow_A number of clusters: 0
# 2eox_A number of clusters: 0
# 2eoy_A number of clusters: 0
# 2ep0_A number of clusters: 0
# 2ep1_A number of clusters: 0
# 2ep2_A number of clusters: 0
# 2ep3_A number of clusters: 0
# 2ep4_A number of clusters: 0
# 2epa_A number of clusters: 0
# 2epc_A number of clusters: 0
# 2epp_A number of clusters: 0
# 2epr_A number of clusters: 0
# 2eps_A number of clusters: 0
# 2ept_A number of clusters: 0
# 2epu_A number of clusters: 0
# 2epv_A number of clusters: 0
# 2epw_A number of clusters: 0
# 2epx_A number of clusters: 0
# 2epy_A number of clusters: 0
# 2epz_A number of clusters: 0
# 2eq0_A number of clusters: 0
# 2eq1_A number of clusters: 0
# 2eqg_A number of clusters: 0
# 2eqw_A number of clusters: 0
# 2erf_A number of clusters: 0
# 2erx_A number of clusters: 3
# 2ery_B number of clusters: 3
# 2esl_F number of clusters: 1
# 2eva_A number of clusters: 2
# 2ew1_A number of clusters: 1
# 2f0y_B number of clusters: 3
# 2f27_A number of clusters: 2
# 2f57_B number of clusters: 2
# 2f7k_B number of clusters: 4
# 2f7s_A number of clusters: 2
# 2f9n_A number of clusters: 2
# 2fby_A number of clusters: 0
# 2fc6_A number of clusters: 0
# 2fcw_B number of clusters: 0
# 2fdv_D number of clusters: 3
# 2ffu_A number of clusters: 4
# 2ffw_A number of clusters: 0
# 2fg5_A number of clusters: 1
# 2fh1_B number of clusters: 0
# 2fim_B number of clusters: 1
# 2fj9_A number of clusters: 1
# 2fju_B number of clusters: 3
# 2fqq_B number of clusters: 1
# 2frw_A number of clusters: 0
# 2fsz_A number of clusters: 4
# 2fu5_B number of clusters: 0
# 2fuu_A number of clusters: 0
# 2fvl_A number of clusters: 7
# 2fyl_B number of clusters: 0
# 2g2k_A number of clusters: 0
# 2g43_A number of clusters: 0
# 2g4a_A number of clusters: 3
# 2g6b_A number of clusters: 1
# 2g9o_A number of clusters: 1
# 2gao_B number of clusters: 3
# 2gco_A number of clusters: 2
# 2ger_B number of clusters: 3
# 2gf0_B number of clusters: 2
# 2gf2_A number of clusters: 4
# 2gf9_A number of clusters: 3
# 2ggm_A number of clusters: 5
# 2ggz_B number of clusters: 3
# 2ghf_A number of clusters: 0
# 2gjx_H number of clusters: 1
# 2gk1_N number of clusters: 0
# 2gli_C number of clusters: 0
# 2gmv_A number of clusters: 3
# 2gp5_A number of clusters: 2
# 2gpq_A number of clusters: 2
# 2gqj_A number of clusters: 0
# 2gql_A number of clusters: 1
# 2gwh_A number of clusters: 2
# 2gz5_A number of clusters: 2
# 2gzv_A number of clusters: 2
# 2h16_D number of clusters: 4
# 2h57_B number of clusters: 2
# 2h63_D number of clusters: 1
# 2h6h_A number of clusters: 0
# 2h8h_A number of clusters: 2
# 2h8k_B number of clusters: 2
# 2h9e_B number of clusters: 0
# 2ha8_A number of clusters: 4
# 2hd5_A number of clusters: 3
# 2hei_B number of clusters: 3
# 2hgs_A number of clusters: 0
# 2hhl_A number of clusters: 2
# 2hhn_A number of clusters: 2
# 2hi4_A number of clusters: 4
# 2hrb_A number of clusters: 3
# 2hup_A number of clusters: 3
# 2hw5_A number of clusters: 3
# 2hw6_A number of clusters: 2
# 2hzq_A number of clusters: 2
# 2i0e_A number of clusters: 4
# 2i0y_A number of clusters: 2
# 2i3c_B number of clusters: 1
# 2i50_A number of clusters: 0
# 2i5d_A number of clusters: 3
# 2i6a_A number of clusters: 4
# 2i6s_A number of clusters: 1
# 2i7a_A number of clusters: 0
# 2i7n_B number of clusters: 2
# 2i8n_A number of clusters: 3
# 2i96_A number of clusters: 1
# 2i99_B number of clusters: 3
# 2i9a_D number of clusters: 0
# 2ibn_A number of clusters: 0
# 2iby_A number of clusters: 3
# 2ic4_A number of clusters: 0
# 2iim_A number of clusters: 0
# 2il1_A number of clusters: 1
# 2ipp_A number of clusters: 2
# 2iqj_B number of clusters: 0
# 2it4_B number of clusters: 3
# 2iuw_A number of clusters: 3
# 2iwy_A number of clusters: 3
# 2iyk_B number of clusters: 0
# 2j2p_C number of clusters: 0
# 2j2s_A number of clusters: 0
# 2j3s_A number of clusters: 0
# 2j4o_A number of clusters: 0
# 2j5z_B number of clusters: 0
# 2j8z_A number of clusters: 4
# 2j9l_F number of clusters: 2
# 2jai_A number of clusters: 1
# 2jam_B number of clusters: 3
# 2jbh_B number of clusters: 2
# 2jdw_A number of clusters: 1
# 2jed_A number of clusters: 4
# 2jeo_A number of clusters: 3
# 2jg9_F number of clusters: 0
# 2jif_D number of clusters: 4
# 2jis_B number of clusters: 4
# 2jld_B number of clusters: 2
# 2jlp_C number of clusters: 0
# 2jm1_A number of clusters: 0
# 2jm4_A number of clusters: 0
# 2jmo_A number of clusters: 0
# 2jox_A number of clusters: 0
# 2jr7_A number of clusters: 0
# 2jrj_A number of clusters: 0
# 2jrs_A number of clusters: 1
# 2jsd_A number of clusters: 3
# 2jtf_A number of clusters: 2
# 2jtg_A number of clusters: 0
# 2jyo_A number of clusters: 0
# 2k01_B number of clusters: 0
# 2k1b_A number of clusters: 2
# 2k1j_A number of clusters: 0
# 2k2c_A number of clusters: 0
# 2k2d_A number of clusters: 0
# 2k42_A number of clusters: 1
# 2k60_A number of clusters: 0
# 2k7d_A number of clusters: 4
# 2kc3_A number of clusters: 0
# 2kdp_A number of clusters: 0
# 2ke1_A number of clusters: 0
# 2kfh_A number of clusters: 0
# 2khn_A number of clusters: 0
# 2kht_A number of clusters: 1
# 2ki6_F number of clusters: 0
# 2kje_A number of clusters: 0
# 2kkr_A number of clusters: 0
# 2kkt_A number of clusters: 0
# 2kld_A number of clusters: 1
# 2kmx_A number of clusters: 4
# 2knt_A number of clusters: 1
# 2knx_A number of clusters: 0
# 2ksg_A number of clusters: 0
# 2ku3_A number of clusters: 0
# 2kul_A number of clusters: 3
# 2kuo_A number of clusters: 0
# 2kwi_A number of clusters: 4
# 2kwn_B number of clusters: 0
# 2l0b_A number of clusters: 0
# 2l4s_A number of clusters: 2
# 2l51_B number of clusters: 1
# 2l5u_A number of clusters: 0
# 2l5y_A number of clusters: 0
# 2l60_A number of clusters: 1
# 2l6l_A number of clusters: 0
# 2l70_A number of clusters: 0
# 2l7w_A number of clusters: 0
# 2l80_A number of clusters: 0
# 2l8e_A number of clusters: 0
# 2l9z_A number of clusters: 0
# 2lau_A number of clusters: 0
# 2lce_A number of clusters: 0
# 2lcp_A number of clusters: 4
# 2ldr_A number of clusters: 0
# 2lgk_A number of clusters: 0
# 2lgp_A number of clusters: 0
# 2lgq_A number of clusters: 0
# 2lgr_A number of clusters: 3
# 2lko_A number of clusters: 0
# 2ln0_A number of clusters: 0
# 2lnk_B number of clusters: 2
# 2lob_A number of clusters: 2
# 2lq6_A number of clusters: 0
# 2lri_A number of clusters: 0
# 2lto_A number of clusters: 1
# 2lul_A number of clusters: 1
# 2lv2_A number of clusters: 0
# 2lv7_A number of clusters: 2
# 2lvz_A number of clusters: 0
# 2lxp_C number of clusters: 0
# 2lxw_A number of clusters: 0
# 2lzu_A number of clusters: 1
# 2m0p_A number of clusters: 0
# 2m13_A number of clusters: 0
# 2m2d_A number of clusters: 0
# 2m3h_A number of clusters: 0
# 2m5h_A number of clusters: 1
# 2m68_A number of clusters: 0
# 2m6n_A number of clusters: 0
# 2m8j_A number of clusters: 0
# 2m96_A number of clusters: 0
# 2m9a_A number of clusters: 0
# 2m9w_A number of clusters: 1
# 2ma5_A number of clusters: 0
# 2ma6_A number of clusters: 0
# 2ma7_A number of clusters: 0
# 2md8_A number of clusters: 0
# 2mdg_A number of clusters: 0
# 2mhs_A number of clusters: 3
# 2miu_A number of clusters: 0
# 2mji_A number of clusters: 5
# 2mkd_A number of clusters: 0
# 2mkv_A number of clusters: 0
# 2mm3_A number of clusters: 4
# 2mmz_A number of clusters: 2
# 2mnz_A number of clusters: 0
# 2mpf_A number of clusters: 4
# 2mph_A number of clusters: 3
# 2mse_D number of clusters: 0
# 2msv_A number of clusters: 0
# 2muq_A number of clusters: 0
# 2mwx_A number of clusters: 0
# 2mxc_A number of clusters: 1
# 2mxv_A number of clusters: 0
# 2mzi_A number of clusters: 3
# 2n14_A number of clusters: 3
# 2n1a_A number of clusters: 1
# 2n1a_B number of clusters: 0
# 2n1u_A number of clusters: 0
# 2n26_A number of clusters: 0
# 2n42_A number of clusters: 3
# 2n64_A number of clusters: 0
# 2n8a_A number of clusters: 0
# 2n8z_A number of clusters: 7
# 2n9p_A number of clusters: 0
# 2nbq_A number of clusters: 1
# 2nll_D number of clusters: 0
# 2nna_A number of clusters: 0
# 2nvu_B number of clusters: 2
# 2nxp_F number of clusters: 0
# 2nyt_C number of clusters: 2
# 2nz0_B number of clusters: 0
# 2nz2_A number of clusters: 2
# 2nzj_C number of clusters: 4
# 2nzt_B number of clusters: 6
# 2o06_A number of clusters: 1
# 2o10_A number of clusters: 1
# 2o13_A number of clusters: 1
# 2o2f_A number of clusters: 5
# 2o52_B number of clusters: 2
# 2o6g_C number of clusters: 0
# 2o8f_D number of clusters: 1
# 2obd_A number of clusters: 0
# 2obv_A number of clusters: 2
# 2ocb_A number of clusters: 1
# 2ocg_A number of clusters: 1
# 2ocp_C number of clusters: 4
# 2od1_A number of clusters: 0
# 2ohf_A number of clusters: 4
# 2oil_A number of clusters: 4
# 2okv_C number of clusters: 4
# 2oo4_B number of clusters: 0
# 2opw_A number of clusters: 0
# 2oq5_A number of clusters: 1
# 2ox8_D number of clusters: 2
# 2oxc_A number of clusters: 3
# 2p0a_A number of clusters: 3
# 2p0d_A number of clusters: 0
# 2p0r_B number of clusters: 1
# 2p0w_A number of clusters: 2
# 2p1f_A number of clusters: 2
# 2p57_A number of clusters: 0
# 2p5s_B number of clusters: 3
# 2p8e_B number of clusters: 0
# 2p8u_A number of clusters: 4
# 2pfr_A number of clusters: 3
# 2pg5_D number of clusters: 3
# 2pid_A number of clusters: 3
# 2pl0_A number of clusters: 3
# 2pl3_A number of clusters: 2
# 2pla_A number of clusters: 4
# 2pmy_A number of clusters: 2
# 2pny_A number of clusters: 1
# 2ppl_A number of clusters: 1
# 2pqf_D number of clusters: 2
# 2pru_B number of clusters: 3
# 2psn_D number of clusters: 2
# 2puy_A number of clusters: 0
# 2pvs_A number of clusters: 1
# 2pxx_A number of clusters: 1
# 2q3f_B number of clusters: 2
# 2q3h_A number of clusters: 2
# 2q3z_A number of clusters: 0
# 2q5e_D number of clusters: 2
# 2q7r_F number of clusters: 0
# 2q8f_A number of clusters: 1
# 2q98_A number of clusters: 0
# 2qic_A number of clusters: 0
# 2qk4_B number of clusters: 3
# 2qkk_W number of clusters: 0
# 2qlu_A number of clusters: 2
# 2qnk_A number of clusters: 2
# 2qpp_B number of clusters: 1
# 2qra_B number of clusters: 0
# 2qst_B number of clusters: 0
# 2qt0_A number of clusters: 4
# 2qt7_B number of clusters: 2
# 2qtz_A number of clusters: 2
# 2qyk_B number of clusters: 4
# 2qym_A number of clusters: 2
# 2qz4_A number of clusters: 2
# 2r3a_A number of clusters: 4
# 2r5g_A number of clusters: 2
# 2r83_A number of clusters: 0
# 2r8u_A number of clusters: 0
# 2ra4_B number of clusters: 0
# 2raj_A number of clusters: 1
# 2rb3_C number of clusters: 0
# 2rb4_B number of clusters: 1
# 2rc4_A number of clusters: 3
# 2rhp_A number of clusters: 0
# 2rje_B number of clusters: 0
# 2rjp_B number of clusters: 2
# 2rjq_A number of clusters: 2
# 2rkb_C number of clusters: 3
# 2rli_A number of clusters: 1
# 2rmk_A number of clusters: 4
# 2rpc_A number of clusters: 0
# 2rpp_A number of clusters: 0
# 2rpr_A number of clusters: 0
# 2rqb_A number of clusters: 0
# 2rsg_A number of clusters: 2
# 2rsq_A number of clusters: 1
# 2ruu_A number of clusters: 0
# 2ruw_A number of clusters: 0
# 2rux_A number of clusters: 0
# 2ruy_A number of clusters: 0
# 2rv0_A number of clusters: 0
# 2rv1_A number of clusters: 1
# 2rv2_A number of clusters: 0
# 2uuh_A number of clusters: 2
# 2uur_A number of clusters: 0
# 2uvl_A number of clusters: 0
# 2uyy_D number of clusters: 2
# 2uzg_A number of clusters: 0
# 2uzp_B number of clusters: 0
# 2v0r_B number of clusters: 0
# 2v40_A number of clusters: 2
# 2v55_B number of clusters: 2
# 2v7o_A number of clusters: 3
# 2v9k_A number of clusters: 0
# 2vac_A number of clusters: 0
# 2vcv_J number of clusters: 4
# 2vd5_B number of clusters: 3
# 2vdy_A number of clusters: 0
# 2vhf_A number of clusters: 4
# 2vkq_A number of clusters: 4
# 2vm5_A number of clusters: 0
# 2vn0_A number of clusters: 2
# 2vn8_A number of clusters: 6
# 2vn9_A number of clusters: 3
# 2vpd_C number of clusters: 0
# 2vq3_A number of clusters: 3
# 2vr2_A number of clusters: 0
# 2vrd_A number of clusters: 0
# 2vrg_A number of clusters: 3
# 2vsc_C number of clusters: 0
# 2vwi_D number of clusters: 2
# 2vxo_A number of clusters: 2
# 2vy5_A number of clusters: 0
# 2w0t_A number of clusters: 0
# 2w2i_A number of clusters: 0
# 2w3o_B number of clusters: 1
# 2w4l_E number of clusters: 1
# 2w4m_A number of clusters: 2
# 2w4o_A number of clusters: 3
# 2w4r_D number of clusters: 0
# 2w5a_A number of clusters: 2
# 2w86_A number of clusters: 0
# 2w8p_A number of clusters: 2
# 2wbi_B number of clusters: 6
# 2wce_A number of clusters: 2
# 2wef_A number of clusters: 2
# 2wh5_E number of clusters: 2
# 2wjy_A number of clusters: 1
# 2wk6_B number of clusters: 0
# 2wno_A number of clusters: 0
# 2wns_B number of clusters: 2
# 2wtk_E number of clusters: 2
# 2wtk_F number of clusters: 2
# 2wwy_B number of clusters: 3
# 2wwz_C number of clusters: 0
# 2wya_C number of clusters: 4
# 2wzb_A number of clusters: 2
# 2x10_A number of clusters: 0
# 2x11_B number of clusters: 0
# 2x4d_A number of clusters: 1
# 2x4f_B number of clusters: 3
# 2x4w_A number of clusters: 0
# 2x7g_A number of clusters: 3
# 2x7h_B number of clusters: 5
# 2xik_A number of clusters: 2
# 2xmr_C number of clusters: 0
# 2xn3_B number of clusters: 0
# 2xph_A number of clusters: 0
# 2xrc_D number of clusters: 3
# 2xsx_A number of clusters: 2
# 2xtp_A number of clusters: 3
# 2xzg_A number of clusters: 0
# 2y05_B number of clusters: 4
# 2y1h_A number of clusters: 0
# 2y1l_D number of clusters: 1
# 2y23_A number of clusters: 0
# 2y43_B number of clusters: 0
# 2y7j_D number of clusters: 2
# 2yan_A number of clusters: 2
# 2yd8_A number of clusters: 0
# 2ydx_D number of clusters: 4
# 2ygq_A number of clusters: 0
# 2yh0_A number of clusters: 1
# 2yho_C number of clusters: 0
# 2yqm_A number of clusters: 0
# 2yqp_A number of clusters: 0
# 2yqq_A number of clusters: 0
# 2yrc_A number of clusters: 0
# 2yre_A number of clusters: 0
# 2yrg_A number of clusters: 0
# 2yrm_A number of clusters: 0
# 2yrt_A number of clusters: 0
# 2ys2_A number of clusters: 0
# 2ysa_A number of clusters: 1
# 2ysl_A number of clusters: 0
# 2ysm_A number of clusters: 0
# 2yt9_A number of clusters: 0
# 2yta_A number of clusters: 0
# 2ytb_A number of clusters: 0
# 2ytd_A number of clusters: 0
# 2yte_A number of clusters: 0
# 2ytf_A number of clusters: 0
# 2yti_A number of clusters: 0
# 2ytj_A number of clusters: 0
# 2ytk_A number of clusters: 0
# 2ytm_A number of clusters: 0
# 2yto_A number of clusters: 0
# 2ytp_A number of clusters: 0
# 2ytq_A number of clusters: 0
# 2yts_A number of clusters: 0
# 2ytt_A number of clusters: 0
# 2yu2_A number of clusters: 1
# 2yu4_A number of clusters: 0
# 2yu5_A number of clusters: 0
# 2yuc_A number of clusters: 0
# 2yul_A number of clusters: 0
# 2yur_A number of clusters: 0
# 2yuu_A number of clusters: 0
# 2yvr_A number of clusters: 0
# 2z0u_B number of clusters: 0
# 2z15_C number of clusters: 0
# 2z4e_E number of clusters: 0
# 2z5f_B number of clusters: 3
# 2z7x_B number of clusters: 0
# 2zch_A number of clusters: 1
# 2zfu_B number of clusters: 2
# 2zg1_A number of clusters: 0
# 2znv_D number of clusters: 0
# 2zoc_A number of clusters: 0
# 2zoq_A number of clusters: 1
# 2zox_A number of clusters: 3
# 2zrt_G number of clusters: 1
# 2zv6_B number of clusters: 0
# 3a2a_B number of clusters: 0
# 3a4s_A number of clusters: 1
# 3a4u_A number of clusters: 0
# 3aad_A number of clusters: 4
# 3aco_A number of clusters: 0
# 3ahq_A number of clusters: 2
# 3aih_A number of clusters: 0
# 3aj4_A number of clusters: 0
# 3alq_G number of clusters: 0
# 3ap3_A number of clusters: 2
# 3b2d_A number of clusters: 0
# 3b2d_D number of clusters: 3
# 3b3l_A number of clusters: 2
# 3b6h_B number of clusters: 2
# 3b6r_B number of clusters: 2
# 3b6u_A number of clusters: 3
# 3b6v_A number of clusters: 1
# 3b7y_A number of clusters: 0
# 3bce_A number of clusters: 3
# 3bd9_A number of clusters: 4
# 3ber_A number of clusters: 3
# 3bfx_A number of clusters: 2
# 3bh7_B number of clusters: 0
# 3bhh_A number of clusters: 3
# 3bhm_A number of clusters: 3
# 3bhy_A number of clusters: 4
# 3bi6_A number of clusters: 2
# 3bjc_A number of clusters: 4
# 3bm4_B number of clusters: 2
# 3bo5_A number of clusters: 2
# 3bpt_A number of clusters: 1
# 3bpu_A number of clusters: 2
# 3brh_A number of clusters: 1
# 3bsu_J number of clusters: 0
# 3bvo_B number of clusters: 0
# 3c5c_D number of clusters: 3
# 3c5e_A number of clusters: 4
# 3c5h_A number of clusters: 3
# 3c6k_A number of clusters: 1
# 3c6w_C number of clusters: 0
# 3cbb_D number of clusters: 0
# 3cbk_A number of clusters: 3
# 3cbq_A number of clusters: 3
# 3cfw_A number of clusters: 0
# 3cos_C number of clusters: 4
# 3ctr_A number of clusters: 0
# 3ctz_A number of clusters: 3
# 3cxp_A number of clusters: 4
# 3czh_A number of clusters: 2
# 3d0e_B number of clusters: 4
# 3d24_C number of clusters: 3
# 3d2f_D number of clusters: 3
# 3d34_B number of clusters: 0
# 3d3l_B number of clusters: 0
# 3d3w_B number of clusters: 2
# 3d5o_B number of clusters: 0
# 3d87_B number of clusters: 0
# 3d8b_A number of clusters: 3
# 3d8e_C number of clusters: 1
# 3d9s_D number of clusters: 0
# 3ddu_A number of clusters: 1
# 3dem_B number of clusters: 0
# 3dh1_D number of clusters: 1
# 3dk9_A number of clusters: 2
# 3dko_A number of clusters: 3
# 3dkp_A number of clusters: 2
# 3dlj_B number of clusters: 2
# 3dls_C number of clusters: 2
# 3doe_A number of clusters: 1
# 3dwb_A number of clusters: 1
# 3dyd_B number of clusters: 5
# 3dz4_A number of clusters: 0
# 3e04_D number of clusters: 1
# 3e1y_B number of clusters: 0
# 3e3r_B number of clusters: 2
# 3e4c_B number of clusters: 2
# 3e5h_A number of clusters: 1
# 3e6i_B number of clusters: 3
# 3eb5_A number of clusters: 0
# 3ecs_A number of clusters: 2
# 3edi_A number of clusters: 1
# 3edy_A number of clusters: 2
# 3eh1_A number of clusters: 0
# 3eh2_B number of clusters: 0
# 3elb_A number of clusters: 6
# 3epy_B number of clusters: 1
# 3epz_A number of clusters: 0
# 3eta_A number of clusters: 1
# 3eue_A number of clusters: 3
# 3exi_B number of clusters: 0
# 3eyh_A number of clusters: 2
# 3f1r_B number of clusters: 3
# 3f3s_A number of clusters: 2
# 3f3y_A number of clusters: 3
# 3f5o_E number of clusters: 3
# 3f6u_A number of clusters: 1
# 3f70_B number of clusters: 0
# 3f7u_C number of clusters: 3
# 3f9p_A number of clusters: 0
# 3fby_B number of clusters: 0
# 3fcx_B number of clusters: 1
# 3fd6_B number of clusters: 4
# 3fe1_B number of clusters: 3
# 3fe2_B number of clusters: 2
# 3fe3_A number of clusters: 1
# 3fe4_A number of clusters: 2
# 3fec_A number of clusters: 3
# 3ff6_D number of clusters: 1
# 3ffk_A number of clusters: 0
# 3fg6_E number of clusters: 0
# 3fl2_A number of clusters: 0
# 3flv_B number of clusters: 2
# 3fvf_A number of clusters: 1
# 3fvy_A number of clusters: 0
# 3fy1_A number of clusters: 2
# 3g4h_B number of clusters: 2
# 3g5k_D number of clusters: 4
# 3g73_A number of clusters: 0
# 3g9y_A number of clusters: 0
# 3gbj_A number of clusters: 2
# 3gc9_B number of clusters: 1
# 3gdh_B number of clusters: 3
# 3gdq_A number of clusters: 3
# 3gep_B number of clusters: 2
# 3ggf_B number of clusters: 2
# 3ghg_C number of clusters: 0
# 3gis_I number of clusters: 0
# 3gjx_D number of clusters: 0
# 3gkh_A number of clusters: 1
# 3gpd_B number of clusters: 5
# 3gqc_D number of clusters: 0
# 3gta_A number of clusters: 0
# 3gvp_B number of clusters: 1
# 3gxb_A number of clusters: 0
# 3gzd_A number of clusters: 3
# 3h1d_A number of clusters: 0
# 3h2u_B number of clusters: 0
# 3h53_B number of clusters: 1
# 3h9e_B number of clusters: 3
# 3hco_B number of clusters: 5
# 3hf1_A number of clusters: 0
# 3hhd_B number of clusters: 2
# 3hm8_A number of clusters: 3
# 3hmh_A number of clusters: 2
# 3hn3_B number of clusters: 1
# 3ho4_A number of clusters: 0
# 3hr4_G number of clusters: 1
# 3hud_B number of clusters: 4
# 3hxt_A number of clusters: 3
# 3hy8_A number of clusters: 4
# 3ia8_A number of clusters: 2
# 3iar_A number of clusters: 1
# 3ici_B number of clusters: 1
# 3idv_A number of clusters: 2
# 3iei_H number of clusters: 4
# 3ihj_A number of clusters: 3
# 3ihp_B number of clusters: 1
# 3ik7_B number of clusters: 3
# 3ikm_A number of clusters: 2
# 3io2_A number of clusters: 0
# 3isq_A number of clusters: 2
# 3iu6_A number of clusters: 0
# 3iuf_A number of clusters: 0
# 3iuy_A number of clusters: 3
# 3iwl_A number of clusters: 2
# 3ixe_B number of clusters: 0
# 3ixs_K number of clusters: 1
# 3j0a_A number of clusters: 0
# 3j2s_A number of clusters: 0
# 3jrx_A number of clusters: 2
# 3jub_A number of clusters: 2
# 3jue_A number of clusters: 0
# 3jyh_A number of clusters: 1
# 3k2o_B number of clusters: 0
# 3k2s_B number of clusters: 0
# 3k51_B number of clusters: 0
# 3k5t_A number of clusters: 0
# 3k7v_A number of clusters: 0
# 3k9j_A number of clusters: 0
# 3k9o_A number of clusters: 1
# 3kcg_C number of clusters: 0
# 3khu_C number of clusters: 4
# 3kn1_A number of clusters: 0
# 3knv_A number of clusters: 0
# 3kq0_A number of clusters: 2
# 3kq4_B number of clusters: 0
# 3kqg_A number of clusters: 1
# 3kuc_A number of clusters: 3
# 3kv5_B number of clusters: 1
# 3kvo_A number of clusters: 3
# 3kyd_A number of clusters: 2
# 3kze_A number of clusters: 2
# 3l43_B number of clusters: 4
# 3l4v_A number of clusters: 1
# 3l95_C number of clusters: 0
# 3lea_B number of clusters: 3
# 3lf5_B number of clusters: 0
# 3lgd_B number of clusters: 1
# 3ljw_A number of clusters: 2
# 3lkj_C number of clusters: 0
# 3llk_A number of clusters: 5
# 3lqc_A number of clusters: 0
# 3lqh_A number of clusters: 0
# 3lrq_C number of clusters: 0
# 3lru_B number of clusters: 0
# 3ltl_B number of clusters: 2
# 3luc_A number of clusters: 0
# 3lxj_A number of clusters: 1
# 3lxx_A number of clusters: 4
# 3ly5_A number of clusters: 3
# 3lyr_A number of clusters: 0
# 3m1d_B number of clusters: 0
# 3m52_A number of clusters: 2
# 3mao_A number of clusters: 1
# 3mb3_A number of clusters: 3
# 3mb4_B number of clusters: 2
# 3mbg_C number of clusters: 3
# 3mdi_A number of clusters: 0
# 3mdy_B number of clusters: 3
# 3mdz_A number of clusters: 4
# 3mgm_A number of clusters: 2
# 3mjh_B number of clusters: 0
# 3mp5_B number of clusters: 3
# 3mq7_L number of clusters: 0
# 3mqi_C number of clusters: 0
# 3mtg_B number of clusters: 1
# 3mtl_A number of clusters: 3
# 3mtn_A number of clusters: 3
# 3my0_J number of clusters: 1
# 3mzg_B number of clusters: 0
# 3n1g_C number of clusters: 3
# 3n1m_A number of clusters: 1
# 3n2n_F number of clusters: 1
# 3n5n_B number of clusters: 3
# 3n7o_A number of clusters: 1
# 3na1_A number of clusters: 2
# 3ncu_A number of clusters: 0
# 3ner_B number of clusters: 0
# 3nks_A number of clusters: 4
# 3nmq_A number of clusters: 3
# 3nmz_B number of clusters: 0
# 3noi_A number of clusters: 0
# 3nv1_A number of clusters: 1
# 3nvq_B number of clusters: 0
# 3nwn_A number of clusters: 2
# 3nxb_A number of clusters: 4
# 3nyn_B number of clusters: 4
# 3o0g_A number of clusters: 2
# 3o2g_A number of clusters: 1
# 3o4r_B number of clusters: 2
# 3o4s_A number of clusters: 1
# 3o7a_A number of clusters: 0
# 3oag_A number of clusters: 3
# 3oes_A number of clusters: 1
# 3oj3_J number of clusters: 2
# 3ojy_B number of clusters: 0
# 3olh_A number of clusters: 1
# 3orh_B number of clusters: 1
# 3otc_B number of clusters: 2
# 3ovp_B number of clusters: 3
# 3ox6_A number of clusters: 0
# 3p0f_A number of clusters: 2
# 3p1m_B number of clusters: 0
# 3p57_A number of clusters: 0
# 3pb4_A number of clusters: 1
# 3pe0_A number of clusters: 0
# 3pja_K number of clusters: 1
# 3pls_A number of clusters: 2
# 3pm0_A number of clusters: 3
# 3poo_A number of clusters: 4
# 3pse_B number of clusters: 1
# 3q13_A number of clusters: 0
# 3q19_A number of clusters: 3
# 3q1d_A number of clusters: 0
# 3q2g_B number of clusters: 3
# 3q2u_A number of clusters: 1
# 3q3j_B number of clusters: 2
# 3q4t_B number of clusters: 2
# 3q6z_A number of clusters: 4
# 3qcj_A number of clusters: 3
# 3qfb_B number of clusters: 2
# 3qj4_A number of clusters: 5
# 3qj5_B number of clusters: 3
# 3qmh_A number of clusters: 0
# 3qni_A number of clusters: 0
# 3qpu_A number of clusters: 5
# 3qrf_B number of clusters: 0
# 3qxm_B number of clusters: 4
# 3qxy_C number of clusters: 3
# 3r6b_A number of clusters: 0
# 3rap_B number of clusters: 1
# 3ray_A number of clusters: 2
# 3rbl_B number of clusters: 2
# 3rc3_A number of clusters: 2
# 3rfe_A number of clusters: 0
# 3rgk_A number of clusters: 0
# 3rk2_G number of clusters: 0
# 3rmu_A number of clusters: 0
# 3rnj_A number of clusters: 0
# 3rq4_A number of clusters: 4
# 3rz3_C number of clusters: 1
# 3rzv_A number of clusters: 0
# 3s4y_A number of clusters: 4
# 3sag_B number of clusters: 0
# 3sbz_A number of clusters: 0
# 3sh5_A number of clusters: 1
# 3sjv_F number of clusters: 1
# 3sn5_B number of clusters: 2
# 3szb_B number of clusters: 3
# 3t6a_A number of clusters: 0
# 3t6p_A number of clusters: 0
# 3t7l_A number of clusters: 0
# 3t9i_A number of clusters: 3
# 3tac_A number of clusters: 3
# 3thd_D number of clusters: 0
# 3tht_D number of clusters: 3
# 3tkl_A number of clusters: 1
# 3top_A number of clusters: 1
# 3tvl_A number of clusters: 1
# 3twj_B number of clusters: 2
# 3u5n_A number of clusters: 0
# 3u8u_A number of clusters: 0
# 3ua8_A number of clusters: 4
# 3ucw_A number of clusters: 2
# 3uh4_B number of clusters: 3
# 3uk3_C number of clusters: 0
# 3ukm_C number of clusters: 1
# 3uyq_A number of clusters: 3
# 3uzx_B number of clusters: 6
# 3v2b_A number of clusters: 3
# 3v3l_A number of clusters: 0
# 3v4v_B number of clusters: 0
# 3v4v_E number of clusters: 0
# 3v70_A number of clusters: 4
# 3v7t_A number of clusters: 2
# 3v8x_B number of clusters: 3
# 3vcm_B number of clusters: 5
# 3vd2_E number of clusters: 0
# 3vf0_A number of clusters: 0
# 3vfq_A number of clusters: 8
# 3vi3_A number of clusters: 0
# 3vjc_A number of clusters: 2
# 3vjm_A number of clusters: 1
# 3vm8_A number of clusters: 1
# 3vp6_B number of clusters: 4
# 3vpp_B number of clusters: 0
# 3vrn_A number of clusters: 0
# 3vuy_B number of clusters: 1
# 3vw9_B number of clusters: 3
# 3vwd_A number of clusters: 2
# 3vzb_A number of clusters: 3
# 3w4u_E number of clusters: 2
# 3w58_D number of clusters: 2
# 3w5k_B number of clusters: 0
# 3w8i_A number of clusters: 0
# 3we2_B number of clusters: 0
# 3wh2_A number of clusters: 1
# 3whd_A number of clusters: 1
# 3wsr_B number of clusters: 0
# 3wup_A number of clusters: 0
# 3wv6_A number of clusters: 2
# 3wzf_A number of clusters: 2
# 3x1u_J number of clusters: 0
# 3zdu_A number of clusters: 3
# 3zjc_F number of clusters: 3
# 3zli_A number of clusters: 1
# 3zmz_A number of clusters: 5
# 3znr_B number of clusters: 1
# 3zwf_A number of clusters: 1
# 3zyg_A number of clusters: 0
# 3zyj_D number of clusters: 0
# 3zyq_A number of clusters: 0
# 4a24_A number of clusters: 0
# 4a35_A number of clusters: 4
# 4a49_A number of clusters: 0
# 4a4f_A number of clusters: 1
# 4a69_A number of clusters: 4
# 4a6d_A number of clusters: 3
# 4a94_B number of clusters: 2
# 4a9o_A number of clusters: 2
# 4ad9_A number of clusters: 2
# 4af3_A number of clusters: 2
# 4afx_A number of clusters: 0
# 4ag4_A number of clusters: 0
# 4agc_A number of clusters: 1
# 4agu_C number of clusters: 2
# 4aoh_A number of clusters: 0
# 4ap6_C number of clusters: 3
# 4apc_B number of clusters: 2
# 4aqi_A number of clusters: 2
# 4at3_A number of clusters: 2
# 4auq_E number of clusters: 0
# 4awl_C number of clusters: 0
# 4awn_A number of clusters: 0
# 4az3_B number of clusters: 0
# 4azm_A number of clusters: 5
# 4b4o_G number of clusters: 3
# 4b6d_C number of clusters: 0
# 4b6l_A number of clusters: 2
# 4b91_B number of clusters: 0
# 4bb2_B number of clusters: 0
# 4bbq_B number of clusters: 0
# 4bc3_C number of clusters: 3
# 4bcx_A number of clusters: 0
# 4bgq_A number of clusters: 2
# 4bj3_B number of clusters: 0
# 4bk4_B number of clusters: 0
# 4bmj_D number of clusters: 0
# 4bsm_A number of clusters: 0
# 4bur_B number of clusters: 4
# 4bv3_A number of clusters: 4
# 4bvd_A number of clusters: 1
# 4bvv_A number of clusters: 1
# 4bw5_C number of clusters: 1
# 4bxf_B number of clusters: 1
# 4bxo_A number of clusters: 0
# 4bxo_B number of clusters: 0
# 4byf_C number of clusters: 4
# 4bzy_B number of clusters: 0
# 4c02_B number of clusters: 4
# 4c0o_B number of clusters: 0
# 4c2j_B number of clusters: 4
# 4c2x_A number of clusters: 4
# 4c3z_A number of clusters: 3
# 4c6m_A number of clusters: 1
# 4c9z_B number of clusters: 0
# 4cbo_A number of clusters: 1
# 4cc0_A number of clusters: 0
# 4ccg_C number of clusters: 0
# 4ccz_A number of clusters: 4
# 4cfr_C number of clusters: 0
# 4cg4_D number of clusters: 0
# 4chl_B number of clusters: 2
# 4cj6_A number of clusters: 0
# 4cmn_A number of clusters: 1
# 4cns_B number of clusters: 0
# 4cql_G number of clusters: 3
# 4cql_P number of clusters: 1
# 4crs_A number of clusters: 4
# 4ct4_D number of clusters: 2
# 4cvh_A number of clusters: 4
# 4cvo_A number of clusters: 0
# 4cyy_A number of clusters: 1
# 4cz2_B number of clusters: 2
# 4d08_D number of clusters: 3
# 4d0g_A number of clusters: 2
# 4d1p_B number of clusters: 2
# 4d2n_D number of clusters: 0
# 4d50_A number of clusters: 2
# 4d8k_A number of clusters: 0
# 4d90_B number of clusters: 0
# 4da1_A number of clusters: 0
# 4dd8_D number of clusters: 2
# 4dg4_C number of clusters: 1
# 4dg6_A number of clusters: 0
# 4dgl_A number of clusters: 0
# 4dgl_C number of clusters: 3
# 4din_B number of clusters: 3
# 4diq_A number of clusters: 1
# 4dir_A number of clusters: 2
# 4drb_F number of clusters: 0
# 4duq_B number of clusters: 3
# 4dur_A number of clusters: 1
# 4dxa_B number of clusters: 0
# 4dy7_C number of clusters: 0
# 4dyo_A number of clusters: 0
# 4e3c_D number of clusters: 2
# 4e4m_B number of clusters: 2
# 4e93_A number of clusters: 1
# 4e9e_A number of clusters: 0
# 4egc_B number of clusters: 2
# 4epu_A number of clusters: 0
# 4erc_A number of clusters: 2
# 4ezf_A number of clusters: 0
# 4f0e_A number of clusters: 2
# 4f14_A number of clusters: 1
# 4f5b_A number of clusters: 0
# 4f7n_B number of clusters: 0
# 4f80_A number of clusters: 0
# 4f9c_B number of clusters: 0
# 4fao_B number of clusters: 0
# 4fc7_C number of clusters: 2
# 4fdi_A number of clusters: 0
# 4fgb_A number of clusters: 2
# 4fgu_B number of clusters: 1
# 4fl6_B number of clusters: 0
# 4fmw_B number of clusters: 2
# 4fo0_A number of clusters: 2
# 4fo9_A number of clusters: 0
# 4fom_A number of clusters: 0
# 4fqf_A number of clusters: 3
# 4fr4_F number of clusters: 2
# 4fu4_C number of clusters: 1
# 4fvl_A number of clusters: 3
# 4fwj_A number of clusters: 4
# 4g8a_B number of clusters: 0
# 4gei_A number of clusters: 0
# 4gk0_F number of clusters: 1
# 4gl2_A number of clusters: 3
# 4gmj_B number of clusters: 1
# 4gnf_A number of clusters: 0
# 4gnk_D number of clusters: 2
# 4gos_A number of clusters: 0
# 4gqq_A number of clusters: 0
# 4gqs_D number of clusters: 3
# 4gup_C number of clusters: 1
# 4h2d_B number of clusters: 1
# 4h5r_B number of clusters: 2
# 4h7w_A number of clusters: 0
# 4hai_A number of clusters: 2
# 4haz_A number of clusters: 2
# 4hc7_A number of clusters: 2
# 4hlq_A number of clusters: 1
# 4hnd_A number of clusters: 4
# 4hni_B number of clusters: 3
# 4hon_A number of clusters: 0
# 4hvy_A number of clusters: 3
# 4i5j_A number of clusters: 2
# 4i6b_A number of clusters: 3
# 4i91_A number of clusters: 2
# 4ic2_A number of clusters: 0
# 4ic7_B number of clusters: 2
# 4iej_A number of clusters: 0
# 4ig8_A number of clusters: 4
# 4ii1_B number of clusters: 0
# 4iqm_A number of clusters: 2
# 4iqy_B number of clusters: 4
# 4iy0_A number of clusters: 2
# 4j14_A number of clusters: 2
# 4j1y_B number of clusters: 1
# 4j4p_B number of clusters: 0
# 4jfp_D number of clusters: 0
# 4jvn_A number of clusters: 2
# 4jxf_A number of clusters: 1
# 4jze_A number of clusters: 2
# 4jzj_A number of clusters: 0
# 4k30_B number of clusters: 4
# 4k7i_C number of clusters: 1
# 4k85_C number of clusters: 0
# 4kfz_B number of clusters: 0
# 4ki5_E number of clusters: 0
# 4kki_A number of clusters: 0
# 4klz_A number of clusters: 2
# 4kmy_A number of clusters: 2
# 4kq8_A number of clusters: 2
# 4kxc_A number of clusters: 2
# 4kyi_H number of clusters: 2
# 4l1j_B number of clusters: 1
# 4l58_A number of clusters: 0
# 4l7n_A number of clusters: 3
# 4l9m_A number of clusters: 0
# 4lay_A number of clusters: 6
# 4lec_B number of clusters: 2
# 4lhx_B number of clusters: 3
# 4liq_A number of clusters: 0
# 4lot_A number of clusters: 0
# 4lqy_A number of clusters: 1
# 4lt6_A number of clusters: 4
# 4m62_A number of clusters: 0
# 4m6r_D number of clusters: 2
# 4mew_A number of clusters: 0
# 4mf3_A number of clusters: 5
# 4mg2_A number of clusters: 3
# 4mhv_B number of clusters: 0
# 4miv_C number of clusters: 0
# 4mqw_C number of clusters: 0
# 4msp_A number of clusters: 3
# 4mum_A number of clusters: 3
# 4mvt_C number of clusters: 0
# 4mwi_A number of clusters: 1
# 4myg_A number of clusters: 1
# 4mzv_A number of clusters: 0
# 4n2c_A number of clusters: 1
# 4n4a_A number of clusters: 6
# 4neh_A number of clusters: 0
# ...
# 7fya_B number of clusters: 3
# 7g20_A number of clusters: 4
# 7jl5_A number of clusters: 0
# 7jl8_A number of clusters: 0
# 7jpo_D number of clusters: 3
# 7jr8_A number of clusters: 3
# 7jsj_B number of clusters: 3
# 7juu_A number of clusters: 3
# 7juy_A number of clusters: 1
# 7jxg_A number of clusters: 1
# 7k0m_H number of clusters: 2
# 7k36_I number of clusters: 0
# 7k7t_A number of clusters: 2
# 7kbu_A number of clusters: 0
# 7kc4_A number of clusters: 0
# 7kg8_A number of clusters: 4
# 7khm_B number of clusters: 0
# 7kiu_C number of clusters: 0
# 7kjo_B number of clusters: 1
# 7klo_A number of clusters: 0
# 7knu_C number of clusters: 0
# 7knv_A number of clusters: 0
# 7knx_C number of clusters: 0
# 7kpr_A number of clusters: 0
# 7kpu_A number of clusters: 4
# 7kql_C number of clusters: 0
# 7krb_A number of clusters: 0
# 7ktp_C number of clusters: 0
# 7ktr_A number of clusters: 0
# 7kuy_A number of clusters: 2
# 7kxi_A number of clusters: 0
# 7kzp_H number of clusters: 0
# 7kzt_F number of clusters: 0
# 7l50_D number of clusters: 1
# 7l65_A number of clusters: 1
# 7l6w_A number of clusters: 0
# 7la5_A number of clusters: 0
# 7laf_A number of clusters: 0
# 7lel_C number of clusters: 3
# 7lh2_B number of clusters: 1
# 7lht_B number of clusters: 5
# 7lj1_E number of clusters: 1
# 7lj1_Z number of clusters: 1
# 7lms_B number of clusters: 3
# 7ln4_E number of clusters: 5
# 7lpz_A number of clusters: 1
# 7lqd_A number of clusters: 2
# 7lrc_C number of clusters: 4
# 7lus_A number of clusters: 0
# 7lv3_A number of clusters: 5
# 7lw1_A number of clusters: 3
# 7lw9_A number of clusters: 2
# 7lyb_I number of clusters: 0
# 7lyx_A number of clusters: 2
# 7m10_A number of clusters: 0
# 7m20_G number of clusters: 1
# 7m6j_B number of clusters: 3
# 7m8h_D number of clusters: 3
# 7m8v_E number of clusters: 2
# 7m98_A number of clusters: 1
# 7meq_A number of clusters: 1
# 7mgj_C number of clusters: 2
# 7mii_D number of clusters: 3
# 7mix_A number of clusters: 0
# 7mjd_A number of clusters: 3
# 7mnp_B number of clusters: 0
# 7mnr_B number of clusters: 0
# 7mns_B number of clusters: 0
# 7mnt_D number of clusters: 0
# 7mnu_B number of clusters: 0
# 7mnv_B number of clusters: 0
# 7mob_B number of clusters: 0
# 7mon_B number of clusters: 2
# 7msr_B number of clusters: 0
# 7mto_A number of clusters: 0
# 7mu5_B number of clusters: 1
# 7mxx_A number of clusters: 2
# 7mzw_A number of clusters: 0
# 7n1r_B number of clusters: 3
# 7n6r_C number of clusters: 0
# 7n7n_A number of clusters: 2
# 7n86_C number of clusters: 0
# 7n8v_B number of clusters: 0
# 7ndg_F number of clusters: 0
# 7ne6_A number of clusters: 0
# 7nfx_AB number of clusters: 3
# 7ngp_E number of clusters: 5
# 7niw_A number of clusters: 7
# 7nk0_A number of clusters: 0
# 7nnj_A number of clusters: 3
# 7noz_E number of clusters: 2
# 7nrb_A number of clusters: 2
# 7nsr_A number of clusters: 4
# 7nut_B number of clusters: 1
# 7nvl_J number of clusters: 2
# 7nwa_B number of clusters: 3
# 7nxd_B number of clusters: 0
# 7o45_C number of clusters: 0
# 7o4p_A number of clusters: 0
# 7o5z_A number of clusters: 3
# 7o6c_A number of clusters: 0
# 7o7j_A number of clusters: 3
# 7o7k_A number of clusters: 2
# 7o7l_B number of clusters: 0
# 7o9m_BB number of clusters: 2
# 7oat_C number of clusters: 3
# 7obb_A number of clusters: 0
# 7od1_B number of clusters: 0
# 7oix_A number of clusters: 0
# 7ojo_D number of clusters: 0
# 7ok6_B number of clusters: 3
# 7okv_A number of clusters: 0
# 7ol3_B number of clusters: 3
# 7ole_A number of clusters: 2
# 7oni_C number of clusters: 0
# 7onu_E number of clusters: 1
# 7onu_F number of clusters: 4
# 7oob_M number of clusters: 1
# 7orc_B number of clusters: 4
# 7oub_A number of clusters: 1
# 7oxx_C number of clusters: 4
# 7oy0_A number of clusters: 3
# 7p0p_D number of clusters: 0
# 7p1p_C number of clusters: 1
# 7p2d_A number of clusters: 0
# 7p6s_A number of clusters: 0
# 7p8w_B number of clusters: 0
# 7pay_A number of clusters: 2
# 7pd3_GB number of clusters: 2
# 7pgt_A number of clusters: 0
# 7phl_D number of clusters: 0
# 7piv_A number of clusters: 1
# 7plp_B number of clusters: 0
# 7pls_A number of clusters: 2
# 7pq0_B number of clusters: 2
# 7pqg_B number of clusters: 0
# 7pw9_B number of clusters: 3
# 7py4_A number of clusters: 1
# 7pzp_B number of clusters: 1
# 7q13_G number of clusters: 2
# 7q15_A number of clusters: 1
# 7q3z_A number of clusters: 0
# 7q4p_D number of clusters: 0
# 7qaa_B number of clusters: 6
# 7qb0_A number of clusters: 0
# 7qbe_D number of clusters: 0
# 7qbo_B number of clusters: 0
# 7qcr_B number of clusters: 2
# 7qdp_B number of clusters: 0
# 7qei_A number of clusters: 6
# 7qfo_A number of clusters: 4
# 7qgj_B number of clusters: 0
# 7qhg_B number of clusters: 2
# 7qhw_A number of clusters: 1
# 7qi2_A number of clusters: 0
# 7qid_A number of clusters: 0
# 7qie_D number of clusters: 2
# 7qk7_B number of clusters: 5
# 7qm2_B number of clusters: 0
# 7qn7_A number of clusters: 3
# 7qne_A number of clusters: 2
# 7qne_B number of clusters: 2
# 7qns_A number of clusters: 1
# 7qo1_A number of clusters: 0
# 7qqd_B number of clusters: 0
# 7qqh_D number of clusters: 1
# 7qtt_H number of clusters: 0
# 7qtt_I number of clusters: 0
# 7qu4_C number of clusters: 1
# 7qu6_F number of clusters: 0
# 7qwk_H number of clusters: 1
# 7qwq_E number of clusters: 0
# 7r2e_A number of clusters: 0
# 7r89_A number of clusters: 5
# 7r8e_B number of clusters: 2
# 7ra0_A number of clusters: 2
# 7rb3_B number of clusters: 4
# 7rds_A number of clusters: 2
# 7rei_A number of clusters: 0
# 7rfg_B number of clusters: 7
# 7rh9_A number of clusters: 3
# 7rhi_B number of clusters: 3
# 7rhq_C number of clusters: 0
# 7rik_A number of clusters: 1
# 7rkf_A number of clusters: 5
# 7rm9_A number of clusters: 3
# 7rpm_A number of clusters: 0
# 7rsj_A number of clusters: 4
# 7rx0_A number of clusters: 3
# 7rx6_B number of clusters: 3
# 7rzf_B number of clusters: 0
# 7s05_B number of clusters: 4
# 7s0z_D number of clusters: 2
# 7s1o_A number of clusters: 0
# 7s4e_A number of clusters: 2
# 7s5h_A number of clusters: 1
# 7s6h_D number of clusters: 2
# 7s7g_A number of clusters: 4
# 7sa5_A number of clusters: 4
# 7sch_A number of clusters: 3
# 7se8_B number of clusters: 1
# 7sfz_D number of clusters: 0
# 7sgl_D number of clusters: 0
# 7sk6_A number of clusters: 4
# 7ske_A number of clusters: 3
# 7sl9_A number of clusters: 0
# 7slq_A number of clusters: 3
# 7sqh_C number of clusters: 0
# 7sqm_A number of clusters: 2
# 7sr6_F number of clusters: 0
# 7sr8_E number of clusters: 5
# 7srs_C number of clusters: 5
# 7sud_A number of clusters: 4
# 7sx4_A number of clusters: 0
# 7syd_A number of clusters: 0
# 7sz7_D number of clusters: 0
# 7sz8_A number of clusters: 0
# 7t6b_E number of clusters: 3
# 7t6u_F number of clusters: 5
# 7tai_A number of clusters: 2
# 7td5_A number of clusters: 2
# 7tgq_A number of clusters: 0
# 7thi_A number of clusters: 2
# 7tj8_A number of clusters: 2
# 7tn4_A number of clusters: 3
# 7to7_B number of clusters: 2
# 7ts0_A number of clusters: 0
# 7ttl_C number of clusters: 0
# 7ttr_E number of clusters: 2
# 7tuz_A number of clusters: 6
# 7tvb_A number of clusters: 0
# 7txc_C number of clusters: 0
# 7tyf_C number of clusters: 0
# 7tyx_A number of clusters: 0
# 7tz2_A number of clusters: 0
# 7tzb_B number of clusters: 3
# 7u8g_B number of clusters: 0
# 7u9d_A number of clusters: 1
# 7ugk_B number of clusters: 3
# 7uhg_B number of clusters: 0
# 7uhg_C number of clusters: 0
# 7uhy_B number of clusters: 0
# 7uhy_C number of clusters: 0
# 7uhy_D number of clusters: 0
# 7ujn_C number of clusters: 3
# 7ujr_A number of clusters: 3
# 7um7_A number of clusters: 3
# 7umv_A number of clusters: 1
# 7unf_D number of clusters: 2
# 7unf_H number of clusters: 0
# 7ung_PI number of clusters: 2
# 7up5_B number of clusters: 2
# 7upi_A number of clusters: 3
# 7upr_F number of clusters: 2
# 7ure_A number of clusters: 0
# 7uw7_A number of clusters: 0
# 7uy0_A number of clusters: 3
# 7uz3_A number of clusters: 2
# 7uze_B number of clusters: 0
# 7uzq_B number of clusters: 0
# 7v62_B number of clusters: 0
# 7v6p_A number of clusters: 0
# 7v8g_D number of clusters: 0
# 7vbb_B number of clusters: 0
# 7vdv_J number of clusters: 1
# 7vgf_B number of clusters: 4
# 7vh0_A number of clusters: 4
# 7vif_D number of clusters: 2
# 7vjv_A number of clusters: 2
# 7vkt_A number of clusters: 5
# 7vl8_D number of clusters: 1
# 7vnr_D number of clusters: 0
# 7vox_H number of clusters: 0
# 7vsl_A number of clusters: 3
# 7w1y_J number of clusters: 3
# 7w2z_B number of clusters: 3
# 7w3k_GA number of clusters: 1
# 7w3u_C number of clusters: 2
# 7w5d_B number of clusters: 0
# 7w68_E number of clusters: 2
# 7w6s_C number of clusters: 2
# 7w72_B number of clusters: 0
# 7w72_C number of clusters: 0
# 7w77_C number of clusters: 0
# 7wc5_A number of clusters: 5
# 7wcn_E number of clusters: 5
# 7we4_A number of clusters: 0
# 7wgr_B number of clusters: 2
# 7wld_B number of clusters: 1
# 7wld_E number of clusters: 0
# 7wlk_A number of clusters: 0
# 7wpq_F number of clusters: 0
# 7wqx_A number of clusters: 1
# 7wsm_A number of clusters: 2
# 7wu7_N number of clusters: 2
# 7wu7_Q number of clusters: 3
# 7wu7_T number of clusters: 2
# 7wv9_D number of clusters: 2
# 7wwb_A number of clusters: 0
# 7wxu_E number of clusters: 0
# 7x2u_A number of clusters: 0
# 7x2u_C number of clusters: 3
# 7x6c_C number of clusters: 0
# 7x6i_H number of clusters: 4
# 7x73_B number of clusters: 5
# 7x8p_D number of clusters: 0
# 7xbw_D number of clusters: 4
# 7xho_N number of clusters: 0
# 7xjk_F number of clusters: 4
# 7xms_A number of clusters: 4
# 7xnk_H number of clusters: 6
# 7xnn_E number of clusters: 0
# 7xpz_A number of clusters: 0
# 7xqj_E number of clusters: 0
# 7xr6_B number of clusters: 2
# 7xt2_B number of clusters: 0
# 7xtq_E number of clusters: 4
# 7xv0_A number of clusters: 0
# 7xv3_A number of clusters: 3
# 7xv6_C number of clusters: 0
# 7xw7_B number of clusters: 2
# 7y0b_C number of clusters: 5
# 7y0i_A number of clusters: 0
# 7y24_F number of clusters: 4
# 7y3l_A number of clusters: 0
# 7y3m_I number of clusters: 0
# 7y4a_G number of clusters: 3
# 7y5t_B number of clusters: 2
# 7y7z_A number of clusters: 3
# 7yb9_A number of clusters: 0
# 7yea_B number of clusters: 4
# 7yk7_C number of clusters: 6
# 7yni_A number of clusters: 1
# 7yox_F number of clusters: 0
# 7yq8_B number of clusters: 0
# 7ys6_A number of clusters: 5
# 7yu8_A number of clusters: 1
# 7yui_A number of clusters: 5
# 7z5h_A number of clusters: 3
# 7z6h_D number of clusters: 4
# 7z6h_E number of clusters: 3
# 7z6h_F number of clusters: 3
# 7z6h_G number of clusters: 4
# 7z71_A number of clusters: 0
# 7z9f_B number of clusters: 0
# 7zan_C number of clusters: 0
# 7zcw_G number of clusters: 1
# 7zee_A number of clusters: 2
# 7zel_A number of clusters: 2
# 7zh3_B number of clusters: 2
# 7zha_A number of clusters: 0
# 7zi9_A number of clusters: 6
# 7zjv_A number of clusters: 1
# 7zlx_J number of clusters: 0
# 7zmk_X number of clusters: 0
# 7zmv_D number of clusters: 3
# 7zmx_A number of clusters: 0
# 7zr0_A number of clusters: 2
# 7zr6_E number of clusters: 1
# 7zrr_A number of clusters: 1
# 7zsc_C number of clusters: 0
# 7zxs_C number of clusters: 1
# 7zyg_A number of clusters: 0
# 7zyh_J number of clusters: 0
# 7zyu_A number of clusters: 0
# 7zzp_A number of clusters: 5
# 8a0v_A number of clusters: 0
# 8a38_C number of clusters: 0
# 8a40_P number of clusters: 0
# 8a4c_D number of clusters: 2
# 8a4k_B number of clusters: 2
# 8a6l_B number of clusters: 1
# 8a8m_A number of clusters: 2
# 8ajo_A number of clusters: 0
# 8ari_W number of clusters: 5
# 8as4_B number of clusters: 0
# 8ayf_A number of clusters: 4
# 8aza_B number of clusters: 2
# 8b0a_A number of clusters: 1
# 8b0f_C number of clusters: 0
# 8b0f_F number of clusters: 0
# 8b0g_H number of clusters: 0
# 8b0h_D number of clusters: 0
# 8b10_A number of clusters: 0
# 8b5r_H number of clusters: 2
# 8b6l_L number of clusters: 1
# 8b6l_N number of clusters: 0
# 8b6l_O number of clusters: 0
# 8b9e_A number of clusters: 1
# 8bah_B number of clusters: 0
# 8bbg_C number of clusters: 0
# 8bbs_B number of clusters: 6
# 8bc9_B number of clusters: 0
# 8blp_C number of clusters: 0
# 8bot_U number of clusters: 0
# 8bot_X number of clusters: 0
# 8bub_B number of clusters: 2
# 8bya_B number of clusters: 0
# 8byl_B number of clusters: 0
# 8bzy_A number of clusters: 0
# 8c3u_A number of clusters: 4
# 8c6j_E number of clusters: 3
# 8ca0_B number of clusters: 1
# 8ch6_FB number of clusters: 2
# 8cqb_A number of clusters: 2
# 8cr1_C number of clusters: 3
# 8css_G number of clusters: 1
# 8cua_C number of clusters: 1
# 8cuc_F number of clusters: 0
# 8cv5_A number of clusters: 4
# 8cx0_A number of clusters: 3
# 8czk_A number of clusters: 1
# 8d1e_A number of clusters: 0
# 8d1l_B number of clusters: 0
# 8d30_A number of clusters: 0
# 8d3c_E number of clusters: 0
# 8d3v_A number of clusters: 3
# 8d6e_B number of clusters: 1
# 8d7z_C number of clusters: 0
# 8d8i_A number of clusters: 4
# 8daf_A number of clusters: 4
# 8dbk_B number of clusters: 3
# 8dey_F number of clusters: 0
# 8dgo_A number of clusters: 0
# 8dgp_A number of clusters: 4
# 8dkm_C number of clusters: 0
# 8dmk_C number of clusters: 0
# 8dnu_D number of clusters: 2
# 8dph_A number of clusters: 5
# 8dvl_A number of clusters: 0
# 8dyd_A number of clusters: 3
# 8dyl_A number of clusters: 2
# 8e0c_A number of clusters: 3
# 8e0f_B number of clusters: 1
# 8e1a_A number of clusters: 6
# 8e3y_F number of clusters: 0
# 8e4y_A number of clusters: 0
# 8e8v_A number of clusters: 1
# 8e93_B number of clusters: 2
# 8e98_C number of clusters: 1
# 8e9z_A number of clusters: 3
# 8ede_B number of clusters: 3
# 8ef7_A number of clusters: 4
# 8efg_A number of clusters: 1
# 8efq_E number of clusters: 3
# 8eg3_A number of clusters: 0
# 8egx_B number of clusters: 0
# 8egx_A number of clusters: 0
# 8eih_A number of clusters: 3
# 8eiq_A number of clusters: 5
# 8ejm_A number of clusters: 4
# 8emr_B number of clusters: 0
# 8enp_A number of clusters: 0
# 8eok_A number of clusters: 0
# 8eop_A number of clusters: 5
# 8eor_B number of clusters: 1
# 8epl_A number of clusters: 0
# 8esv_A number of clusters: 3
# 8eyk_B number of clusters: 11
# 8eyo_A number of clusters: 2
# 8f16_A number of clusters: 0
# 8f7s_A number of clusters: 4
# 8fb2_B number of clusters: 5
# 8fc7_F number of clusters: 0
# 8ffv_A number of clusters: 3
# 8ffw_D number of clusters: 6
# 8fgw_C number of clusters: 0
# 8fjx_A number of clusters: 2
# 8fmu_B number of clusters: 0
# 8fnb_B number of clusters: 0
# 8foa_A number of clusters: 0
# 8fp1_A number of clusters: 4
# 8fw5_B number of clusters: 0
# 8fyh_H number of clusters: 1
# 8g0l_A number of clusters: 5
# 8g46_B number of clusters: 0
# 8g7n_A number of clusters: 2
# 8g9p_D number of clusters: 1
# 8gju_A number of clusters: 1
# 8gk3_H number of clusters: 2
# 8gnn_A number of clusters: 2
# 8gt5_A number of clusters: 5
# 8gui_K number of clusters: 0
# 8gx3_A number of clusters: 2
# 8gye_A number of clusters: 0
# 8gyx_A number of clusters: 1
# 8gz2_B number of clusters: 0
# 8h65_A number of clusters: 3
# 8h8j_C number of clusters: 3
# 8hbe_B number of clusters: 6
# 8hdp_E number of clusters: 7
# 8hy5_B number of clusters: 1
# 8i1o_A number of clusters: 5
# 8i5y_A number of clusters: 0
# 8i5y_B number of clusters: 0
# 8i9u_J number of clusters: 3
# 8i9u_O number of clusters: 3
# 8ifo_A number of clusters: 0
# 8il3_C number of clusters: 3
# 8iqn_A number of clusters: 6
# 8irr_E number of clusters: 5
# 8iuh_B number of clusters: 0
# 8iwu_A number of clusters: 4
# 8iys_E number of clusters: 3
# 8jbn_B number of clusters: 2
# 8jdl_YB number of clusters: 0
# 8jhf_B number of clusters: 0
# 8jii_E number of clusters: 4
# 8jjo_A number of clusters: 4
# 8jyg_B number of clusters: 1
# 8kb5_G number of clusters: 0
# 8odo_A number of clusters: 2
# 8oew_Q number of clusters: 1
# 8oi8_B number of clusters: 4
# 8oma_C number of clusters: 1
# 8omr_A number of clusters: 6
# 8oxy_A number of clusters: 0
# 8p50_B number of clusters: 1
# 8p8x_A number of clusters: 2
# 8p94_A number of clusters: 2
# 8pp8_B number of clusters: 4
# 8pqh_A number of clusters: 2
# 8q7n_G number of clusters: 0
# 8qk3_D number of clusters: 0
# 8qy4_C number of clusters: 0
# 8rbx_X number of clusters: 0
# 8sg5_H number of clusters: 1
# 8sgo_C number of clusters: 2
# 8syp_C number of clusters: 0
# 8szp_A number of clusters: 2
# 8t6j_B number of clusters: 2
# 8t9h_K number of clusters: 4
# 8tar_L number of clusters: 0
# 8tgd_A number of clusters: 3
# 8tnq_B number of clusters: 0
# 8tzo_C number of clusters: 1
# 8tzs_A number of clusters: 0
# 8u26_E number of clusters: 2
# 8u37_A number of clusters: 4
# 8ucd_C number of clusters: 0
# 8uhd_U number of clusters: 0
# 8v4y_K number of clusters: 1
# 8v8u_B number of clusters: 0
# 8wej_B number of clusters: 4
# 8x15_W number of clusters: 0
# 8x72_A number of clusters: 3
# 8xov_A number of clusters: 2
# 8xpn_A number of clusters: 2
# 8y14_A number of clusters: 0
# 8y6b_E number of clusters: 0
# 8y6o_H number of clusters: 0

# %%
import pickle

for protein_id in sequences.keys():
    filename = protein_id.replace('_','')
    
    with open(f'{PREDICTIONS_PATH}/finetuning-with-smoothing/{filename}.pkl', 'wb') as f:
        pickle.dump(predicted_binding_sites[protein_id], f)

# %%
VERBOSE_OUTPUT = False
MODEL = 'Finetuned model'
DCCs, coverages, dice_coefficients, binding_prediction_scores, number_of_pockets = eval_utils.compute_pocket_level_metrics(binding_residues, predicted_binding_sites, prediction_scores, COORDINATES_DIR, VERBOSE_OUTPUT)
print(np.sum(np.array(DCCs) < 4) / number_of_pockets, np.sum(np.array(DCCs) < 12) / number_of_pockets)
eval_utils.print_plots(DCCs, coverages, dice_coefficients, binding_prediction_scores, number_of_pockets, MODEL, dcc_threshold=12.0)
# scPDB-smoother (SMOOTHING_DECISION_THRESHOLD=0.4, eps=4, minsamples=1): 0.08103845687249787 0.44498362246754825
# scPDB-smoother (SMOOTHING_DECISION_THRESHOLD=0.8, eps=4, minsamples=1): 
# smoother.pt (SMOOTHING_DECISION_THRESHOLD=0.4, eps=4, minsamples=1): 0.1733592138784423 0.41356302317117555
# smoother.pt (SMOOTHING_DECISION_THRESHOLD=0.4, eps=4, minsamples=1): 0.1733592138784423 0.41356302317117555
# smoother.pt (SMOOTHING_DECISION_THRESHOLD=0.8, eps=5, minsamples=3): 0.12167900036394516 0.3161470338469004
# smoother.pt (SMOOTHING_DECISION_THRESHOLD=0.4, eps=5, minsamples=3): 0.12483319179910227 0.31578308868130534


# without smoothing, eps=4, minsamples=1: 0.08273686764527478 0.46560718185126776

# scPDB-smoother (SMOOTHING_DECISION_THRESHOLD=0.8, eps=5, minsamples=3): 0.06769380080067937 0.3214848962756278
# without smoothing, eps=5, minsamples=3: 0.06975615673905132 0.34113793521776054
# Out:
# 0.12483319179910227 0.31578308868130534

# %%
import sys
from sklearn.cluster import DBSCAN

no_smoothing_predicted_binding_sites = {}
no_smoothing_prediction_scores = {}
for protein_id in sequences.keys():
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    embeddings_path = f'{EMBEDDINGS_DIR}/{pdb_id}{chain_id}.npy'
    
    if not PRECALCULATED or protein_id not in prediction_scores:
        # finetuned prediction
        prediction = eval_utils.compute_prediction(
        sequence,
        embeddings_path
        )
    elif protein_id in prediction_scores:
        # load precalculated prediction
        prediction = prediction_scores[protein_id]
    elif PRECALCULATED:
        # load precalculated prediction
        prediction = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')

    predicted_indices = np.where(prediction > DECISION_THRESHOLD)[0]

    # compute clusters without smoothing
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'
    coordinates = np.load(coordinates_path)

    high_score_points = coordinates[predicted_indices]  # Extract only (x, y, z) coordinates

    EPS = 5  # Max distance for neighbors
    MIN_SAMPLES = 3  # Min points to form a cluster

    # No pockets can be formed if there are not enough high score points.
    if len(high_score_points) < MIN_SAMPLES:
        no_smoothing_predicted_binding_sites[protein_id] = []
        no_smoothing_predicted_binding_sites[protein_id].append((predicted_indices, 'finetuned model without smoothing'))
        no_smoothing_prediction_scores[protein_id] = prediction
        continue
    
    dbscan = DBSCAN(eps=EPS, min_samples=MIN_SAMPLES)
    labels = dbscan.fit_predict(high_score_points)

    # Initialize all labels to -1
    clusters = -1 * np.ones(len(prediction), dtype=int)
    # Assign cluster labels to high score points
    clusters[predicted_indices] = labels
    clusters_indices = []
    for cluster_label in np.unique(clusters):
        if cluster_label == -1:
            continue
        cluster_indices = np.where(clusters == cluster_label)[0]
        clusters_indices.append(cluster_indices)

    no_smoothing_prediction_scores[protein_id] = prediction
    no_smoothing_predicted_binding_sites[protein_id] = [(i, 'finetuned model without smoothing') for i in clusters_indices]

# %%
VERBOSE_OUTPUT = False
MODEL = 'Finetuned model without smoothing'

DCCs, coverages, dice_coefficients, binding_prediction_scores, number_of_pockets = eval_utils.compute_pocket_level_metrics(binding_residues, no_smoothing_predicted_binding_sites, no_smoothing_prediction_scores, COORDINATES_DIR, VERBOSE_OUTPUT)
print(np.sum(np.array(DCCs) < 4) / number_of_pockets, np.sum(np.array(DCCs) < 12) / number_of_pockets, number_of_pockets)
eval_utils.print_plots(DCCs, coverages, dice_coefficients, binding_prediction_scores, number_of_pockets, MODEL, dcc_threshold=4.0)

# min sapmples = 1, eps=1.7: 0.15528327065388814 0.4827126046342351 8243
# min sapmples = 1, eps=1.7: 0.15528327065388814 0.4827126046342351 8243
# Out:
# 0.06975615673905132 0.34113793521776054 8243
