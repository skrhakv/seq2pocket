# %% [markdown]
# # Replicate pocket-level-evaluation.ipynb
# We need to create a plot where we will compare DCC and cluster fragmentation.
#
# Especially, we need to run the atom-level clustering and subsequently the smoothing.
#
# Let's run it on LIGYSIS, as the flexible nature of CBSs might be problematic.

# %%
from transformers import AutoTokenizer
import torch
import numpy as np
import functools
from sklearn import metrics
from torch.utils.data import DataLoader
import sys

sys.path.append('/home/skrhakv/cryptoshow-analysis/src/B-evaluate-cryptoshow')
sys.path.append('/home/skrhakv/cryptic-nn/src')
import finetuning_utils
from finetuning_utils import FinetunedEsmModel
import eval_utils
from eval_utils import CryptoBenchClassifier
import cryptoshow_utils

MODEL_NAME = 'facebook/esm2_t36_3B_UR50D'
device = 'cuda' if torch.cuda.is_available() else 'cpu'

MODEL_PATH = "/home/skrhakv/cryptic-nn/final-data/trained-models/multitask-finetuned-model-with-ligysis.pt"

SMOOTHING_MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/C-optimize-smoother/smoother.pt'
smoothing_model = torch.load(SMOOTHING_MODEL_PATH, weights_only=False) #, map_location=torch.device('cpu'))

# %%
import sys
import numpy as np
from Bio.PDB import MMCIFParser
from Bio.PDB.SASA import ShrakeRupley
from sklearn.cluster import MeanShift, AgglomerativeClustering, DBSCAN, AffinityPropagation
from sklearn.mixture import BayesianGaussianMixture
from collections import Counter

CIF_FILES = '/home/skrhakv/cryptoshow-analysis/data/F-clustering/cif_files'
EPS = 10
POINTS_DENSITY_PER_ATOM = 50
# VDW radius of Carbon + water probe radius
PROBE_RADIUS = 1.6

def execute_atom_clustering(pdb_id, chain_id, predictions, probabilities, eps=EPS):
    """
    Execute atom-level clustering based on predicted binding residues.
    Args:
        pdb_id: PDB identifier of the protein.
        chain_id: Chain identifier of the protein.
        predictions: List of predicted binding residue IDs (mmCIF numbering).
        probabilities: List of probabilities/scores for the predicted binding residues.
    Returns:
        clusters: Dict {cluster_id: [atom_id, ...], ...}
        cluster_residues: List of Lists [[residue_id, ...], ...] for each cluster. The ordering corresponds to cluster IDs.
        cluster_scores: List of average scores for each cluster. List has size of N, where N is number of clusters, and the ordering corresponds to cluster IDs.
        atom_coords: Dict {atom_id: np.array([x,y,z])}
    """
    # 1. Map mmCIF numbering to auth numbering
    auth_predictions, scores = cryptoshow_utils.map_mmcif_numbering_to_auth(pdb_id, chain_id, predictions, binding_scores=probabilities)

    # 2. Get surface points and their mapping to atoms, atom coordinates, and atom to residue mapping
    all_points, map_point_to_atom, map_atoms_to_residue_id, atom_coords, residue_coords = get_protein_surface_points(pdb_id, chain_id, auth_predictions)

    if all_points.shape[0] == 0:
        return None, None, None, None, None

    # 3. Cluster surface points and propagate labels to atoms    
    atom_labels = cluster_atoms_by_surface(
        all_points, map_point_to_atom, eps=eps)
    
    # get cluster dictionary {cluster_id: [atom_id, ...], ...}
    clusters = {}
    for atom_index, cluster_label in atom_labels.items():
        if cluster_label not in clusters:
            clusters[cluster_label] = []
        clusters[cluster_label].append(atom_index)

    # 4. Voting: the residue gets the label of the majority of its atoms
    cluster_scores = [[] for _ in range(max(clusters) + 1)]
    cluster_residues = [[] for _ in range(max(clusters) + 1)]
    auth_predictions = np.array(auth_predictions)
    
    # 4.1 For each atom in each cluster, get its residue and score
    for atom_id, cluster_label in atom_labels.items():
        residue_id = map_atoms_to_residue_id[atom_id] # this is auth residue id
        score = scores[np.where(auth_predictions == int(residue_id))[0][0]]
        cluster_scores[cluster_label].append(score)
        cluster_residues[cluster_label].append(residue_id)
    
    # 4.2 Vote
    residue_voting = {residue: [0 for _ in range(len(cluster_residues))] for residue in auth_predictions}
    for i, labels in enumerate(cluster_residues):
        counts = Counter(labels)
        for residue, number_of_occurences in counts.items():
            residue_voting[residue][i] = number_of_occurences
    
    residue_clusters = {i: [] for i in range(len(cluster_residues))}
    # 4.3 get residue cluster assignment based on voting
    for residue, votes in residue_voting.items():
        cluster = np.argmax(votes)
        residue_clusters[cluster].append(residue)

    # 5. Compute average cluster scores
    final_cluster_scores = []
    for scores in cluster_scores:
        if len(scores) == 0:
            final_cluster_scores.append(0.0)
        else:
            final_cluster_scores.append(np.mean(scores))
    cluster_scores = final_cluster_scores

    return clusters, residue_clusters, cluster_scores, atom_coords, residue_coords


def cluster_atoms_by_surface(all_points, point_to_atom_map, eps=1.5, gmm=False):
    """
    Clusters surface points and propagates labels to atoms via majority vote.
    
    Args:
        surface_points_dict: Dict {atom_id: np.array([[x,y,z], ...])}
        eps: DBSCAN maximum distance between two samples (in Angstroms).
        min_samples: DBSCAN minimum samples in a neighborhood for a core point.
        
    Returns:
        atom_labels: Dict {atom_id: cluster_label_int}
        point_labels: Array of labels for the flattened points (for visualization)
        all_points: Array of coordinates (for visualization)
    """
    
    if not gmm:
        # n_jobs=-1 uses all CPU cores.
        # clustering = AffinityPropagation(damping=0.9, preference=-200, max_iter=500, convergence_iter=50)
        clustering = MeanShift(bandwidth=eps, bin_seeding=True, n_jobs=-1) # eps = 9 or 12 pls, less is baaaad
        # clustering = AgglomerativeClustering(n_clusters=None, distance_threshold=eps, linkage='ward') 
        # clustering = DBSCAN(eps=eps, min_samples=5)
        # clustering = DBSCAN(eps=6, min_samples=1)

        clustering.fit(all_points)
        point_labels = clustering.labels_

    if gmm:
        # get the optimal number of components
        bgmm = BayesianGaussianMixture(
            n_components=max(len(all_points), 1) - 1, 
            random_state=42,
            covariance_type='spherical',
        )

        bgmm.fit(all_points)

        active_clusters = sum(bgmm.weights_ > 0.1) # Check how many clusters are actually used - how many are composed of >10% of points
        clustering = BayesianGaussianMixture(
            n_components=max(active_clusters, 1), 
            random_state=42,
            covariance_type='spherical',
        )

        point_labels = clustering.fit_predict(all_points)
    
    # Majority Vote (Propagate to Atoms)
    atom_labels = {}
    
    # Get unique atom IDs present in the data
    unique_atoms = np.unique(point_to_atom_map)
    
    for atom_id in unique_atoms:
        # 1. Find indices in the master array belonging to this atom
        indices = np.where(point_to_atom_map == atom_id)[0]
        
        # 2. Extract the cluster labels for these points
        current_labels = point_labels[indices]
        
        # 3. Determine the most common label (majority vote)
        counts = Counter(current_labels)
        majority_label = counts.most_common(1)[0][0]
        atom_labels[atom_id] = majority_label

    return atom_labels

aal_prot = {
    "ALA", "ARG", "ASN", "ASP", "CYS", "GLN", "GLU", "GLY", "HIS", "ILE", 
    "LEU", "LYS", "MET", "PHE", "PRO", "SER", "THR", "TRP", "TYR", "VAL",
    "ASH", "GLH", "HIE", "HID", "HIP", "LYN", "CYX", "CYM", "TYM"
}
# Keeps only standard protein residues in the structure
def keep_only_protein(structure):
    """Keep only standard protein residues in the structure."""
    for residue in list(structure):
        if residue.get_resname() not in aal_prot:
            structure.detach_child(residue.id)
    return structure

def get_protein_surface_points(pdb_id, chain_id, predicted_binding_sites):
    p = MMCIFParser(QUIET=1)
    struct = p.get_structure("protein", f"{CIF_FILES}/{pdb_id}.cif")
    struct = struct[0][chain_id]  # Get first model, chain A
    struct = keep_only_protein(struct)

    # compute SASA
    sr = ShrakeRupley(n_points=POINTS_DENSITY_PER_ATOM, probe_radius=PROBE_RADIUS)
    sr.compute(struct, level="A")

    surface_points = []
    map_surface_points_to_atom_id = []
    atom_coords = {}
    residue_coords = {}
    map_atoms_to_residue_id = {}
    for residue in struct.get_residues():
        # consider only residues from predicted binding sites
        residue_id = residue.get_id()[1]
        
        if 'CA' in residue:
            residue_coords[residue_id] = residue['CA'].get_vector()
        else:
            # if no CA atom, use the first atom's coordinates
            first_atom = next(residue.get_atoms())
            residue_coords[residue_id] = first_atom.get_vector()
        
        if residue.get_id()[1] not in predicted_binding_sites:
            continue
        
        # get surface points for each atom in the residue
        for atom in residue.get_atoms():
            atom_id = atom.get_serial_number()
            surface_points.append(atom.sasa_points)
            map_surface_points_to_atom_id.extend([atom_id] * len(atom.sasa_points))
            atom_coords[atom_id] = atom.get_vector()
            map_atoms_to_residue_id[atom_id] = residue_id

    surface_points = np.vstack(surface_points)
    map_surface_points_to_atom_id = np.array(map_surface_points_to_atom_id)
    return surface_points, map_surface_points_to_atom_id, map_atoms_to_residue_id, atom_coords, residue_coords

# %% [markdown]
# ## try out approach from `src/B-evaluate-cryptoshow/residue-level-evaluation.ipynb`
# Don't pre-cluster the results first, use the smoothing without clustering.

# %%
MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/model-enhanced-scPDB.pt'
# ESM_EMBEDDINGS_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/embeddings-enhanced-scPDB'
ESM_EMBEDDINGS_PATH = '/home/skrhakv/esm2/embeddings/sc-PDB-debugging'
COORDINATES_DIR = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis-coordinates'
POSITIVE_DISTANCE_THRESHOLD = 15
PRECALCULATED = True
PREDICTIONS_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/predictions-enhanced-scPDB'
PRECALCULATED_PATH = F'{PREDICTIONS_PATH}/finetuning-without-smoothing'
LIGYSIS_ANNOTATION_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis_for_pocket_level_evaluation.csv'
DECISION_THRESHOLD = 0.5

model = torch.load(MODEL_PATH, weights_only=False)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

binding_residues, sequences = eval_utils.read_test_binding_residues(data_path=LIGYSIS_ANNOTATION_PATH, pocket_types=['NON_CRYPTIC'])

# debug on subset of 100 proteins
binding_residues = {k: binding_residues[k] for k in list(binding_residues.keys())[:100]}
sequences = {k: sequences[k] for k in list(sequences.keys())[:100]}

predicted_binding_sites = {}
ranks = {}
prediction_scores = {}

K = 2

DCCs_N = []
DCCs_N_plus_K = []
DCCs = []
number_of_overlapping_predictions_on_actual_pocket = []
number_of_overlapping_actual_sites_on_predicted_pocket = []
best_residue_overlaps = []

for i, protein_id in enumerate(sequences.keys()):
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    embeddings_path = f'{ESM_EMBEDDINGS_PATH}/{pdb_id}{chain_id}.npy'
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'
    actual_binding_sites = [np.array([int(i.split('_')[1]) for i in pocket]) for pocket in binding_residues[protein_id]]
    
    print(f'Processing {protein_id} ({i+1}/{len(sequences)})...')
    if not PRECALCULATED:
        # finetuned prediction
        probabilities = eval_utils.compute_prediction(
            sequence,
            f'/tmp/skrhakv',
            model,
            tokenizer
        )
    else:
        # load precalculated prediction
        probabilities = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')
    
    prediction_scores[protein_id] = probabilities

    coordinates = np.load(coordinates_path)
    distance_matrix = eval_utils.compute_distance_matrix(coordinates)

    predictions = (probabilities > DECISION_THRESHOLD).astype(float)
    predictions_copy = predictions.copy()

    assert distance_matrix.shape[0] == distance_matrix.shape[1]
    assert distance_matrix.shape[0] == predictions_copy.shape[0]
    
    X_test = np.load(embeddings_path)
    assert X_test.shape[0] == distance_matrix.shape[0]

    # loop over the residues that are not binding and are potential candidates for smoothing
    for residue_idx in np.where(predictions == 0.0)[0]:

        # get the embedding of the residue
        current_residue_embedding = X_test[residue_idx]

        # get the close binding residues
        close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
        close_binding_residues_indices = np.intersect1d(close_residues_indices, np.where(predictions == 1.0)[0])
        # create embedding 
        if len(close_binding_residues_indices) == 0:
            # no close binding residues - skip this residue
            continue
        elif len(close_binding_residues_indices) == 1:
            surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
        else:
            # get the mean of the close binding residues
            surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

        concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(device)
        
        # get the prediction
        test_logits = smoothing_model(concatenated_embedding).squeeze()
        result = (torch.sigmoid(test_logits)>SMOOTHING_DECISION_THRESHOLD).float()
        if result == 1:
            # set the residue as binding
            print(f"Smoothing changed residue {residue_idx} in protein {protein_id} to binding")
            predictions_copy[residue_idx] = 1

    indices_above_threshold = np.where(predictions_copy > DECISION_THRESHOLD)[0] # this gets residues that are equal to 1
    # no predicted residues - continue
    if len(indices_above_threshold) == 0:
        continue

    # run atom-level clustering and return residue-level pockets
    clusters, cluster_residues, cluster_scores, atom_coords, residue_coords = execute_atom_clustering(
        pdb_id,
        chain_id,
        indices_above_threshold,
        probabilities[indices_above_threshold],
        eps=9
    )

    # none of the residues are on the surface
    if cluster_residues is None:
        continue

    cluster_residues = cryptoshow_utils.map_auth_to_mmcif_numbering_array(
        pdb_id,
        chain_id,
        cluster_residues.values(),
        binding_residues_are_integers=True,
        numbers_only=True
    )[0]

    cluster_order = np.argsort(cluster_scores)[::-1]  # descending order
    N = len(actual_binding_sites)

    selected_clusters_N = cluster_order[:N]
    selected_clusters_N_plus_K = cluster_order[:N+K]

    predicted_centers = {}
    for cluster_label, atom_indices in clusters.items():
        cluster_coords = np.array([atom_coords[atom_id] for atom_id in atom_indices])
        cluster_center = np.mean(cluster_coords, axis=0).get_array()
        predicted_centers[cluster_label] = cluster_center
    
    actual_centers = []

    for pocket in actual_binding_sites:
        pocket_coords = coordinates[pocket]
        pocket_center = np.mean(pocket_coords, axis=0)
        actual_centers.append(pocket_center)
    
    for i, center in enumerate(actual_centers):
        DCC_N = float('inf')
        for j in selected_clusters_N:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N:
                DCC_N = distance
        
        if DCC_N != float('inf'):
            DCCs_N.append(DCC_N)

        DCC_N_plus_K = float('inf')
        for j in selected_clusters_N_plus_K:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N_plus_K:
                DCC_N_plus_K = distance
        
        if DCC_N_plus_K != float('inf'):
            DCCs_N_plus_K.append(DCC_N_plus_K)

        DCC = float('inf')
        for j, predicted_center in predicted_centers.items():
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC:
                DCC = distance    

        if DCC != float('inf'):
            DCCs.append(DCC)

    # actual_binding_sites_auth = cryptoshow_utils.map_mmcif_numbering_to_auth_array(
    #     pdb_id,
    #     chain_id,
    #     actual_binding_sites
    # )
    # print(actual_binding_sites_auth, actual_binding_sites)
    for pocket in actual_binding_sites:
        number_of_predicted_pockets = 0
        best_residue_overlap = 0
        for residues in cluster_residues:
            residue_overlap = len(set(pocket).intersection(residues)) / len(pocket)
            if residue_overlap > best_residue_overlap:
                best_residue_overlap = residue_overlap
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_actual_sites_on_predicted_pocket.append(number_of_predicted_pockets)
        if best_residue_overlap > 0:
            best_residue_overlaps.append(best_residue_overlap)

    for residues in cluster_residues:
        number_of_predicted_pockets = 0
        for pocket in actual_binding_sites:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_predictions_on_actual_pocket.append(number_of_predicted_pockets)
# Out:
# Processing 1a52_A (1/100)...
# Smoothing changed residue 33 in protein 1a52_A to binding
# Smoothing changed residue 49 in protein 1a52_A to binding
# Smoothing changed residue 76 in protein 1a52_A to binding
# Smoothing changed residue 99 in protein 1a52_A to binding
# Smoothing changed residue 109 in protein 1a52_A to binding
# Smoothing changed residue 111 in protein 1a52_A to binding
# Smoothing changed residue 116 in protein 1a52_A to binding
# Smoothing changed residue 125 in protein 1a52_A to binding
# Smoothing changed residue 221 in protein 1a52_A to binding
# Smoothing changed residue 223 in protein 1a52_A to binding
# Smoothing changed residue 227 in protein 1a52_A to binding
# Smoothing changed residue 237 in protein 1a52_A to binding
# Processing 1a9w_E (2/100)...
# Smoothing changed residue 10 in protein 1a9w_E to binding
# Smoothing changed residue 13 in protein 1a9w_E to binding
# Smoothing changed residue 30 in protein 1a9w_E to binding
# Smoothing changed residue 106 in protein 1a9w_E to binding
# Smoothing changed residue 112 in protein 1a9w_E to binding
# Smoothing changed residue 114 in protein 1a9w_E to binding
# Smoothing changed residue 125 in protein 1a9w_E to binding
# Processing 1aii_A (3/100)...
# Smoothing changed residue 7 in protein 1aii_A to binding
# Smoothing changed residue 21 in protein 1aii_A to binding
# Smoothing changed residue 45 in protein 1aii_A to binding
# Smoothing changed residue 64 in protein 1aii_A to binding
# Smoothing changed residue 65 in protein 1aii_A to binding
# Smoothing changed residue 79 in protein 1aii_A to binding
# Smoothing changed residue 95 in protein 1aii_A to binding
# Smoothing changed residue 99 in protein 1aii_A to binding
# Smoothing changed residue 114 in protein 1aii_A to binding
# Smoothing changed residue 116 in protein 1aii_A to binding
# Smoothing changed residue 149 in protein 1aii_A to binding
# Smoothing changed residue 151 in protein 1aii_A to binding
# Smoothing changed residue 176 in protein 1aii_A to binding
# Smoothing changed residue 212 in protein 1aii_A to binding
# Smoothing changed residue 213 in protein 1aii_A to binding
# Smoothing changed residue 215 in protein 1aii_A to binding
# Smoothing changed residue 220 in protein 1aii_A to binding
# Smoothing changed residue 227 in protein 1aii_A to binding
# Smoothing changed residue 228 in protein 1aii_A to binding
# Smoothing changed residue 235 in protein 1aii_A to binding
# Smoothing changed residue 255 in protein 1aii_A to binding
# Smoothing changed residue 271 in protein 1aii_A to binding
# Smoothing changed residue 295 in protein 1aii_A to binding
# Smoothing changed residue 302 in protein 1aii_A to binding
# Smoothing changed residue 315 in protein 1aii_A to binding
# Processing 1au1_A (4/100)...
# Smoothing changed residue 15 in protein 1au1_A to binding
# Smoothing changed residue 23 in protein 1au1_A to binding
# Smoothing changed residue 46 in protein 1au1_A to binding
# Smoothing changed residue 68 in protein 1au1_A to binding
# Smoothing changed residue 120 in protein 1au1_A to binding
# Smoothing changed residue 121 in protein 1au1_A to binding
# Smoothing changed residue 162 in protein 1au1_A to binding
# Processing 1aue_B (5/100)...
# Smoothing changed residue 0 in protein 1aue_B to binding
# Smoothing changed residue 17 in protein 1aue_B to binding
# Smoothing changed residue 36 in protein 1aue_B to binding
# Smoothing changed residue 40 in protein 1aue_B to binding
# Smoothing changed residue 41 in protein 1aue_B to binding
# Smoothing changed residue 42 in protein 1aue_B to binding
# Smoothing changed residue 43 in protein 1aue_B to binding
# Smoothing changed residue 44 in protein 1aue_B to binding
# Smoothing changed residue 49 in protein 1aue_B to binding
# Smoothing changed residue 53 in protein 1aue_B to binding
# Smoothing changed residue 63 in protein 1aue_B to binding
# Smoothing changed residue 88 in protein 1aue_B to binding
# Smoothing changed residue 90 in protein 1aue_B to binding
# Processing 1b1c_A (6/100)...
# Smoothing changed residue 80 in protein 1b1c_A to binding
# Smoothing changed residue 81 in protein 1b1c_A to binding
# Smoothing changed residue 104 in protein 1b1c_A to binding
# Smoothing changed residue 110 in protein 1b1c_A to binding
# Smoothing changed residue 146 in protein 1b1c_A to binding
# Processing 1b50_B (7/100)...
# Smoothing changed residue 3 in protein 1b50_B to binding
# Smoothing changed residue 5 in protein 1b50_B to binding
# Smoothing changed residue 7 in protein 1b50_B to binding
# Smoothing changed residue 23 in protein 1b50_B to binding
# Smoothing changed residue 65 in protein 1b50_B to binding
# Processing 1b55_B (8/100)...
# Smoothing changed residue 20 in protein 1b55_B to binding
# Smoothing changed residue 23 in protein 1b55_B to binding
# Smoothing changed residue 97 in protein 1b55_B to binding
# Smoothing changed residue 100 in protein 1b55_B to binding
# Smoothing changed residue 150 in protein 1b55_B to binding
# Processing 1b6c_F (9/100)...
# Smoothing changed residue 35 in protein 1b6c_F to binding
# Smoothing changed residue 52 in protein 1b6c_F to binding
# Smoothing changed residue 58 in protein 1b6c_F to binding
# Smoothing changed residue 62 in protein 1b6c_F to binding
# Smoothing changed residue 73 in protein 1b6c_F to binding
# Smoothing changed residue 76 in protein 1b6c_F to binding
# Smoothing changed residue 78 in protein 1b6c_F to binding
# Smoothing changed residue 79 in protein 1b6c_F to binding
# Smoothing changed residue 80 in protein 1b6c_F to binding
# Smoothing changed residue 91 in protein 1b6c_F to binding
# Smoothing changed residue 156 in protein 1b6c_F to binding
# Processing 1b9o_A (10/100)...
# Smoothing changed residue 20 in protein 1b9o_A to binding
# Processing 1bbo_A (11/100)...
# Smoothing changed residue 3 in protein 1bbo_A to binding
# Smoothing changed residue 21 in protein 1bbo_A to binding
# Processing 1bci_A (12/100)...
# Smoothing changed residue 28 in protein 1bci_A to binding
# Smoothing changed residue 45 in protein 1bci_A to binding
# Processing 1bf9_A (13/100)...
# Smoothing changed residue 0 in protein 1bf9_A to binding
# Smoothing changed residue 8 in protein 1bf9_A to binding
# Smoothing changed residue 10 in protein 1bf9_A to binding
# Smoothing changed residue 13 in protein 1bf9_A to binding
# Smoothing changed residue 14 in protein 1bf9_A to binding
# Smoothing changed residue 17 in protein 1bf9_A to binding
# Smoothing changed residue 19 in protein 1bf9_A to binding
# Smoothing changed residue 20 in protein 1bf9_A to binding
# Smoothing changed residue 21 in protein 1bf9_A to binding
# Smoothing changed residue 22 in protein 1bf9_A to binding
# Smoothing changed residue 24 in protein 1bf9_A to binding
# Smoothing changed residue 27 in protein 1bf9_A to binding
# Smoothing changed residue 35 in protein 1bf9_A to binding
# Smoothing changed residue 36 in protein 1bf9_A to binding
# Processing 1bhi_A (14/100)...
# Smoothing changed residue 4 in protein 1bhi_A to binding
# Smoothing changed residue 5 in protein 1bhi_A to binding
# Smoothing changed residue 16 in protein 1bhi_A to binding
# Smoothing changed residue 17 in protein 1bhi_A to binding
# Smoothing changed residue 28 in protein 1bhi_A to binding
# Smoothing changed residue 33 in protein 1bhi_A to binding
# Smoothing changed residue 35 in protein 1bhi_A to binding
# Processing 1bld_A (15/100)...
# Smoothing changed residue 68 in protein 1bld_A to binding
# Smoothing changed residue 69 in protein 1bld_A to binding
# Smoothing changed residue 71 in protein 1bld_A to binding
# Smoothing changed residue 114 in protein 1bld_A to binding
# Processing 1blx_A (16/100)...
# Smoothing changed residue 212 in protein 1blx_A to binding
# Processing 1bmo_A (17/100)...
# Smoothing changed residue 5 in protein 1bmo_A to binding
# Smoothing changed residue 6 in protein 1bmo_A to binding
# Smoothing changed residue 10 in protein 1bmo_A to binding
# Smoothing changed residue 33 in protein 1bmo_A to binding
# Smoothing changed residue 70 in protein 1bmo_A to binding
# Smoothing changed residue 72 in protein 1bmo_A to binding
# Smoothing changed residue 74 in protein 1bmo_A to binding
# Smoothing changed residue 76 in protein 1bmo_A to binding
# Smoothing changed residue 81 in protein 1bmo_A to binding
# Smoothing changed residue 89 in protein 1bmo_A to binding
# Smoothing changed residue 92 in protein 1bmo_A to binding
# Smoothing changed residue 93 in protein 1bmo_A to binding
# Smoothing changed residue 96 in protein 1bmo_A to binding
# Smoothing changed residue 99 in protein 1bmo_A to binding
# Smoothing changed residue 100 in protein 1bmo_A to binding
# Smoothing changed residue 189 in protein 1bmo_A to binding
# Smoothing changed residue 190 in protein 1bmo_A to binding
# Smoothing changed residue 197 in protein 1bmo_A to binding
# Smoothing changed residue 206 in protein 1bmo_A to binding
# Processing 1bnl_A (18/100)...
# Smoothing changed residue 13 in protein 1bnl_A to binding
# Smoothing changed residue 15 in protein 1bnl_A to binding
# Smoothing changed residue 16 in protein 1bnl_A to binding
# Smoothing changed residue 21 in protein 1bnl_A to binding
# Smoothing changed residue 25 in protein 1bnl_A to binding
# Smoothing changed residue 46 in protein 1bnl_A to binding
# Smoothing changed residue 102 in protein 1bnl_A to binding
# Smoothing changed residue 114 in protein 1bnl_A to binding
# Smoothing changed residue 123 in protein 1bnl_A to binding
# Smoothing changed residue 127 in protein 1bnl_A to binding
# Smoothing changed residue 130 in protein 1bnl_A to binding
# Smoothing changed residue 131 in protein 1bnl_A to binding
# Smoothing changed residue 132 in protein 1bnl_A to binding
# Smoothing changed residue 142 in protein 1bnl_A to binding
# Smoothing changed residue 143 in protein 1bnl_A to binding
# Smoothing changed residue 144 in protein 1bnl_A to binding
# Smoothing changed residue 148 in protein 1bnl_A to binding
# Smoothing changed residue 149 in protein 1bnl_A to binding
# Smoothing changed residue 160 in protein 1bnl_A to binding
# Smoothing changed residue 161 in protein 1bnl_A to binding
# Smoothing changed residue 169 in protein 1bnl_A to binding
# Smoothing changed residue 174 in protein 1bnl_A to binding
# Smoothing changed residue 175 in protein 1bnl_A to binding
# Processing 1boy_A (19/100)...
# Smoothing changed residue 11 in protein 1boy_A to binding
# Smoothing changed residue 35 in protein 1boy_A to binding
# Smoothing changed residue 61 in protein 1boy_A to binding
# Smoothing changed residue 131 in protein 1boy_A to binding
# Smoothing changed residue 144 in protein 1boy_A to binding
# Processing 1bp5_A (20/100)...
# Smoothing changed residue 58 in protein 1bp5_A to binding
# Smoothing changed residue 68 in protein 1bp5_A to binding
# Smoothing changed residue 115 in protein 1bp5_A to binding
# Smoothing changed residue 124 in protein 1bp5_A to binding
# Smoothing changed residue 205 in protein 1bp5_A to binding
# Smoothing changed residue 302 in protein 1bp5_A to binding
# Processing 1buv_M (21/100)...
# Smoothing changed residue 3 in protein 1buv_M to binding
# Smoothing changed residue 6 in protein 1buv_M to binding
# Smoothing changed residue 10 in protein 1buv_M to binding
# Smoothing changed residue 68 in protein 1buv_M to binding
# Smoothing changed residue 69 in protein 1buv_M to binding
# Smoothing changed residue 91 in protein 1buv_M to binding
# Smoothing changed residue 93 in protein 1buv_M to binding
# Smoothing changed residue 133 in protein 1buv_M to binding
# Smoothing changed residue 157 in protein 1buv_M to binding
# Smoothing changed residue 158 in protein 1buv_M to binding
# Smoothing changed residue 169 in protein 1buv_M to binding
# Processing 1byg_A (22/100)...
# Smoothing changed residue 27 in protein 1byg_A to binding
# Smoothing changed residue 43 in protein 1byg_A to binding
# Smoothing changed residue 50 in protein 1byg_A to binding
# Processing 1bzs_A (23/100)...
# Smoothing changed residue 5 in protein 1bzs_A to binding
# Smoothing changed residue 6 in protein 1bzs_A to binding
# Smoothing changed residue 11 in protein 1bzs_A to binding
# Smoothing changed residue 63 in protein 1bzs_A to binding
# Smoothing changed residue 64 in protein 1bzs_A to binding
# Smoothing changed residue 66 in protein 1bzs_A to binding
# Smoothing changed residue 67 in protein 1bzs_A to binding
# Smoothing changed residue 71 in protein 1bzs_A to binding
# Smoothing changed residue 73 in protein 1bzs_A to binding
# Smoothing changed residue 86 in protein 1bzs_A to binding
# Smoothing changed residue 87 in protein 1bzs_A to binding
# Smoothing changed residue 131 in protein 1bzs_A to binding
# Smoothing changed residue 150 in protein 1bzs_A to binding
# Smoothing changed residue 151 in protein 1bzs_A to binding
# Smoothing changed residue 154 in protein 1bzs_A to binding
# Smoothing changed residue 162 in protein 1bzs_A to binding
# Processing 1c07_A (24/100)...
# Smoothing changed residue 1 in protein 1c07_A to binding
# Smoothing changed residue 68 in protein 1c07_A to binding
# Smoothing changed residue 78 in protein 1c07_A to binding
# Smoothing changed residue 82 in protein 1c07_A to binding
# Smoothing changed residue 83 in protein 1c07_A to binding
# Smoothing changed residue 86 in protein 1c07_A to binding
# Smoothing changed residue 90 in protein 1c07_A to binding
# Smoothing changed residue 94 in protein 1c07_A to binding
# Processing 1c4z_A (25/100)...
# Smoothing changed residue 2 in protein 1c4z_A to binding
# Smoothing changed residue 8 in protein 1c4z_A to binding
# Smoothing changed residue 9 in protein 1c4z_A to binding
# Smoothing changed residue 34 in protein 1c4z_A to binding
# Smoothing changed residue 36 in protein 1c4z_A to binding
# Smoothing changed residue 39 in protein 1c4z_A to binding
# Smoothing changed residue 40 in protein 1c4z_A to binding
# Smoothing changed residue 41 in protein 1c4z_A to binding
# Smoothing changed residue 42 in protein 1c4z_A to binding
# Smoothing changed residue 56 in protein 1c4z_A to binding
# Smoothing changed residue 106 in protein 1c4z_A to binding
# Smoothing changed residue 108 in protein 1c4z_A to binding
# Smoothing changed residue 109 in protein 1c4z_A to binding
# Smoothing changed residue 258 in protein 1c4z_A to binding
# Smoothing changed residue 261 in protein 1c4z_A to binding
# Smoothing changed residue 267 in protein 1c4z_A to binding
# Smoothing changed residue 286 in protein 1c4z_A to binding
# Smoothing changed residue 288 in protein 1c4z_A to binding
# Smoothing changed residue 308 in protein 1c4z_A to binding
# Smoothing changed residue 309 in protein 1c4z_A to binding
# Smoothing changed residue 310 in protein 1c4z_A to binding
# Smoothing changed residue 311 in protein 1c4z_A to binding
# Smoothing changed residue 317 in protein 1c4z_A to binding
# Processing 1c9y_A (26/100)...
# Smoothing changed residue 162 in protein 1c9y_A to binding
# Processing 1cb6_A (27/100)...
# Smoothing changed residue 124 in protein 1cb6_A to binding
# Smoothing changed residue 156 in protein 1cb6_A to binding
# Smoothing changed residue 169 in protein 1cb6_A to binding
# Smoothing changed residue 172 in protein 1cb6_A to binding
# Smoothing changed residue 212 in protein 1cb6_A to binding
# Smoothing changed residue 376 in protein 1cb6_A to binding
# Smoothing changed residue 392 in protein 1cb6_A to binding
# Smoothing changed residue 397 in protein 1cb6_A to binding
# Smoothing changed residue 400 in protein 1cb6_A to binding
# Smoothing changed residue 403 in protein 1cb6_A to binding
# Smoothing changed residue 429 in protein 1cb6_A to binding
# Smoothing changed residue 459 in protein 1cb6_A to binding
# Smoothing changed residue 461 in protein 1cb6_A to binding
# Smoothing changed residue 495 in protein 1cb6_A to binding
# Smoothing changed residue 545 in protein 1cb6_A to binding
# Smoothing changed residue 548 in protein 1cb6_A to binding
# Smoothing changed residue 646 in protein 1cb6_A to binding
# Smoothing changed residue 647 in protein 1cb6_A to binding
# Smoothing changed residue 655 in protein 1cb6_A to binding
# Smoothing changed residue 658 in protein 1cb6_A to binding
# Smoothing changed residue 675 in protein 1cb6_A to binding
# Smoothing changed residue 684 in protein 1cb6_A to binding
# Smoothing changed residue 687 in protein 1cb6_A to binding
# Smoothing changed residue 689 in protein 1cb6_A to binding
# Smoothing changed residue 690 in protein 1cb6_A to binding
# Processing 1cjy_B (28/100)...
# Smoothing changed residue 19 in protein 1cjy_B to binding
# Smoothing changed residue 24 in protein 1cjy_B to binding
# Smoothing changed residue 51 in protein 1cjy_B to binding
# Smoothing changed residue 78 in protein 1cjy_B to binding
# Smoothing changed residue 84 in protein 1cjy_B to binding
# Smoothing changed residue 277 in protein 1cjy_B to binding
# Smoothing changed residue 284 in protein 1cjy_B to binding
# Smoothing changed residue 452 in protein 1cjy_B to binding
# Processing 1cm8_A (29/100)...
# Smoothing changed residue 43 in protein 1cm8_A to binding
# Smoothing changed residue 44 in protein 1cm8_A to binding
# Smoothing changed residue 45 in protein 1cm8_A to binding
# Smoothing changed residue 130 in protein 1cm8_A to binding
# Smoothing changed residue 135 in protein 1cm8_A to binding
# Smoothing changed residue 137 in protein 1cm8_A to binding
# Smoothing changed residue 171 in protein 1cm8_A to binding
# Smoothing changed residue 176 in protein 1cm8_A to binding
# Smoothing changed residue 200 in protein 1cm8_A to binding
# Smoothing changed residue 204 in protein 1cm8_A to binding
# Smoothing changed residue 209 in protein 1cm8_A to binding
# Smoothing changed residue 210 in protein 1cm8_A to binding
# Smoothing changed residue 211 in protein 1cm8_A to binding
# Smoothing changed residue 224 in protein 1cm8_A to binding
# Smoothing changed residue 227 in protein 1cm8_A to binding
# Smoothing changed residue 228 in protein 1cm8_A to binding
# Smoothing changed residue 230 in protein 1cm8_A to binding
# Smoothing changed residue 276 in protein 1cm8_A to binding
# Smoothing changed residue 278 in protein 1cm8_A to binding
# Smoothing changed residue 284 in protein 1cm8_A to binding
# Smoothing changed residue 301 in protein 1cm8_A to binding
# Processing 1cr8_A (30/100)...
# Processing 1cws_A (31/100)...
# Smoothing changed residue 24 in protein 1cws_A to binding
# Smoothing changed residue 27 in protein 1cws_A to binding
# Smoothing changed residue 115 in protein 1cws_A to binding
# Processing 1cx8_C (32/100)...
# Smoothing changed residue 138 in protein 1cx8_C to binding
# Smoothing changed residue 139 in protein 1cx8_C to binding
# Smoothing changed residue 142 in protein 1cx8_C to binding
# Smoothing changed residue 161 in protein 1cx8_C to binding
# Smoothing changed residue 166 in protein 1cx8_C to binding
# Smoothing changed residue 167 in protein 1cx8_C to binding
# Smoothing changed residue 170 in protein 1cx8_C to binding
# Smoothing changed residue 193 in protein 1cx8_C to binding
# Smoothing changed residue 288 in protein 1cx8_C to binding
# Smoothing changed residue 417 in protein 1cx8_C to binding
# Smoothing changed residue 438 in protein 1cx8_C to binding
# Processing 1cza_N (33/100)...
# Smoothing changed residue 49 in protein 1cza_N to binding
# Smoothing changed residue 72 in protein 1cza_N to binding
# Smoothing changed residue 73 in protein 1cza_N to binding
# Smoothing changed residue 142 in protein 1cza_N to binding
# Smoothing changed residue 144 in protein 1cza_N to binding
# Smoothing changed residue 158 in protein 1cza_N to binding
# Smoothing changed residue 171 in protein 1cza_N to binding
# Smoothing changed residue 195 in protein 1cza_N to binding
# Smoothing changed residue 196 in protein 1cza_N to binding
# Smoothing changed residue 207 in protein 1cza_N to binding
# Smoothing changed residue 247 in protein 1cza_N to binding
# Smoothing changed residue 381 in protein 1cza_N to binding
# Smoothing changed residue 392 in protein 1cza_N to binding
# Smoothing changed residue 396 in protein 1cza_N to binding
# Smoothing changed residue 398 in protein 1cza_N to binding
# Smoothing changed residue 400 in protein 1cza_N to binding
# Smoothing changed residue 422 in protein 1cza_N to binding
# Smoothing changed residue 423 in protein 1cza_N to binding
# Smoothing changed residue 425 in protein 1cza_N to binding
# Smoothing changed residue 428 in protein 1cza_N to binding
# Smoothing changed residue 430 in protein 1cza_N to binding
# Smoothing changed residue 431 in protein 1cza_N to binding
# Smoothing changed residue 433 in protein 1cza_N to binding
# Smoothing changed residue 498 in protein 1cza_N to binding
# Smoothing changed residue 518 in protein 1cza_N to binding
# Smoothing changed residue 520 in protein 1cza_N to binding
# Smoothing changed residue 529 in protein 1cza_N to binding
# Smoothing changed residue 531 in protein 1cza_N to binding
# Smoothing changed residue 590 in protein 1cza_N to binding
# Smoothing changed residue 592 in protein 1cza_N to binding
# Smoothing changed residue 603 in protein 1cza_N to binding
# Smoothing changed residue 606 in protein 1cza_N to binding
# Smoothing changed residue 607 in protein 1cza_N to binding
# Smoothing changed residue 643 in protein 1cza_N to binding
# Smoothing changed residue 655 in protein 1cza_N to binding
# Smoothing changed residue 663 in protein 1cza_N to binding
# Smoothing changed residue 695 in protein 1cza_N to binding
# Smoothing changed residue 729 in protein 1cza_N to binding
# Smoothing changed residue 753 in protein 1cza_N to binding
# Smoothing changed residue 833 in protein 1cza_N to binding
# Smoothing changed residue 845 in protein 1cza_N to binding
# Smoothing changed residue 846 in protein 1cza_N to binding
# Smoothing changed residue 848 in protein 1cza_N to binding
# Smoothing changed residue 851 in protein 1cza_N to binding
# Smoothing changed residue 873 in protein 1cza_N to binding
# Smoothing changed residue 878 in protein 1cza_N to binding
# Smoothing changed residue 879 in protein 1cza_N to binding
# Smoothing changed residue 880 in protein 1cza_N to binding
# Smoothing changed residue 881 in protein 1cza_N to binding
# Smoothing changed residue 897 in protein 1cza_N to binding
# Processing 1czv_A (34/100)...
# Smoothing changed residue 23 in protein 1czv_A to binding
# Smoothing changed residue 81 in protein 1czv_A to binding
# Processing 1d1s_A (35/100)...
# Smoothing changed residue 95 in protein 1d1s_A to binding
# Smoothing changed residue 113 in protein 1d1s_A to binding
# Smoothing changed residue 115 in protein 1d1s_A to binding
# Smoothing changed residue 116 in protein 1d1s_A to binding
# Smoothing changed residue 117 in protein 1d1s_A to binding
# Smoothing changed residue 118 in protein 1d1s_A to binding
# Smoothing changed residue 122 in protein 1d1s_A to binding
# Smoothing changed residue 138 in protein 1d1s_A to binding
# Smoothing changed residue 139 in protein 1d1s_A to binding
# Smoothing changed residue 141 in protein 1d1s_A to binding
# Smoothing changed residue 242 in protein 1d1s_A to binding
# Smoothing changed residue 314 in protein 1d1s_A to binding
# Processing 1d4u_A (36/100)...
# Smoothing changed residue 4 in protein 1d4u_A to binding
# Smoothing changed residue 17 in protein 1d4u_A to binding
# Smoothing changed residue 18 in protein 1d4u_A to binding
# Smoothing changed residue 23 in protein 1d4u_A to binding
# Smoothing changed residue 40 in protein 1d4u_A to binding
# Smoothing changed residue 43 in protein 1d4u_A to binding
# Smoothing changed residue 44 in protein 1d4u_A to binding
# Smoothing changed residue 48 in protein 1d4u_A to binding
# Smoothing changed residue 53 in protein 1d4u_A to binding
# Smoothing changed residue 63 in protein 1d4u_A to binding
# Smoothing changed residue 64 in protein 1d4u_A to binding
# Smoothing changed residue 65 in protein 1d4u_A to binding
# Smoothing changed residue 66 in protein 1d4u_A to binding
# Smoothing changed residue 68 in protein 1d4u_A to binding
# Smoothing changed residue 69 in protein 1d4u_A to binding
# Smoothing changed residue 70 in protein 1d4u_A to binding
# Smoothing changed residue 75 in protein 1d4u_A to binding
# Smoothing changed residue 77 in protein 1d4u_A to binding
# Smoothing changed residue 78 in protein 1d4u_A to binding
# Smoothing changed residue 81 in protein 1d4u_A to binding
# Smoothing changed residue 82 in protein 1d4u_A to binding
# Smoothing changed residue 91 in protein 1d4u_A to binding
# Processing 1d5g_A (37/100)...
# Smoothing changed residue 60 in protein 1d5g_A to binding
# Smoothing changed residue 65 in protein 1d5g_A to binding
# Smoothing changed residue 84 in protein 1d5g_A to binding
# Processing 1drf_A (38/100)...
# Smoothing changed residue 0 in protein 1drf_A to binding
# Smoothing changed residue 1 in protein 1drf_A to binding
# Smoothing changed residue 14 in protein 1drf_A to binding
# Smoothing changed residue 24 in protein 1drf_A to binding
# Smoothing changed residue 45 in protein 1drf_A to binding
# Smoothing changed residue 47 in protein 1drf_A to binding
# Smoothing changed residue 82 in protein 1drf_A to binding
# Smoothing changed residue 112 in protein 1drf_A to binding
# Smoothing changed residue 143 in protein 1drf_A to binding
# Smoothing changed residue 144 in protein 1drf_A to binding
# Smoothing changed residue 171 in protein 1drf_A to binding
# Processing 1ds6_A (39/100)...
# Smoothing changed residue 6 in protein 1ds6_A to binding
# Smoothing changed residue 8 in protein 1ds6_A to binding
# Smoothing changed residue 36 in protein 1ds6_A to binding
# Smoothing changed residue 37 in protein 1ds6_A to binding
# Smoothing changed residue 65 in protein 1ds6_A to binding
# Smoothing changed residue 66 in protein 1ds6_A to binding
# Smoothing changed residue 67 in protein 1ds6_A to binding
# Smoothing changed residue 69 in protein 1ds6_A to binding
# Smoothing changed residue 73 in protein 1ds6_A to binding
# Smoothing changed residue 82 in protein 1ds6_A to binding
# Smoothing changed residue 85 in protein 1ds6_A to binding
# Smoothing changed residue 87 in protein 1ds6_A to binding
# Smoothing changed residue 119 in protein 1ds6_A to binding
# Smoothing changed residue 122 in protein 1ds6_A to binding
# Smoothing changed residue 125 in protein 1ds6_A to binding
# Smoothing changed residue 127 in protein 1ds6_A to binding
# Smoothing changed residue 128 in protein 1ds6_A to binding
# Smoothing changed residue 131 in protein 1ds6_A to binding
# Smoothing changed residue 132 in protein 1ds6_A to binding
# Smoothing changed residue 164 in protein 1ds6_A to binding
# Smoothing changed residue 168 in protein 1ds6_A to binding
# Processing 1dsz_A (40/100)...
# Smoothing changed residue 9 in protein 1dsz_A to binding
# Smoothing changed residue 15 in protein 1dsz_A to binding
# Smoothing changed residue 47 in protein 1dsz_A to binding
# Smoothing changed residue 48 in protein 1dsz_A to binding
# Processing 1dtw_B (41/100)...
# Smoothing changed residue 31 in protein 1dtw_B to binding
# Smoothing changed residue 57 in protein 1dtw_B to binding
# Smoothing changed residue 59 in protein 1dtw_B to binding
# Smoothing changed residue 116 in protein 1dtw_B to binding
# Smoothing changed residue 118 in protein 1dtw_B to binding
# Processing 1dxt_D (42/100)...
# Smoothing changed residue 11 in protein 1dxt_D to binding
# Smoothing changed residue 31 in protein 1dxt_D to binding
# Smoothing changed residue 75 in protein 1dxt_D to binding
# Smoothing changed residue 93 in protein 1dxt_D to binding
# Smoothing changed residue 114 in protein 1dxt_D to binding
# Smoothing changed residue 118 in protein 1dxt_D to binding
# Smoothing changed residue 133 in protein 1dxt_D to binding
# Processing 1e0o_D (43/100)...
# Smoothing changed residue 23 in protein 1e0o_D to binding
# Smoothing changed residue 108 in protein 1e0o_D to binding
# Smoothing changed residue 114 in protein 1e0o_D to binding
# Smoothing changed residue 129 in protein 1e0o_D to binding
# Smoothing changed residue 131 in protein 1e0o_D to binding
# Smoothing changed residue 132 in protein 1e0o_D to binding
# Smoothing changed residue 137 in protein 1e0o_D to binding
# Smoothing changed residue 140 in protein 1e0o_D to binding
# Smoothing changed residue 178 in protein 1e0o_D to binding
# Smoothing changed residue 180 in protein 1e0o_D to binding
# Processing 1e17_A (44/100)...
# Smoothing changed residue 5 in protein 1e17_A to binding
# Smoothing changed residue 68 in protein 1e17_A to binding
# Processing 1e9t_A (45/100)...
# Smoothing changed residue 3 in protein 1e9t_A to binding
# Smoothing changed residue 10 in protein 1e9t_A to binding
# Smoothing changed residue 14 in protein 1e9t_A to binding
# Smoothing changed residue 40 in protein 1e9t_A to binding
# Smoothing changed residue 42 in protein 1e9t_A to binding
# Processing 1eh2_A (46/100)...
# Smoothing changed residue 0 in protein 1eh2_A to binding
# Smoothing changed residue 30 in protein 1eh2_A to binding
# Smoothing changed residue 41 in protein 1eh2_A to binding
# Smoothing changed residue 43 in protein 1eh2_A to binding
# Smoothing changed residue 46 in protein 1eh2_A to binding
# Smoothing changed residue 61 in protein 1eh2_A to binding
# Smoothing changed residue 67 in protein 1eh2_A to binding
# Smoothing changed residue 80 in protein 1eh2_A to binding
# Smoothing changed residue 84 in protein 1eh2_A to binding
# Smoothing changed residue 85 in protein 1eh2_A to binding
# Smoothing changed residue 93 in protein 1eh2_A to binding
# Processing 1ek6_A (47/100)...
# Smoothing changed residue 95 in protein 1ek6_A to binding
# Smoothing changed residue 157 in protein 1ek6_A to binding
# Smoothing changed residue 159 in protein 1ek6_A to binding
# Smoothing changed residue 203 in protein 1ek6_A to binding
# Smoothing changed residue 335 in protein 1ek6_A to binding
# Smoothing changed residue 342 in protein 1ek6_A to binding
# Smoothing changed residue 343 in protein 1ek6_A to binding
# Processing 1emn_A (48/100)...
# Smoothing changed residue 7 in protein 1emn_A to binding
# Smoothing changed residue 18 in protein 1emn_A to binding
# Smoothing changed residue 21 in protein 1emn_A to binding
# Smoothing changed residue 27 in protein 1emn_A to binding
# Smoothing changed residue 52 in protein 1emn_A to binding
# Smoothing changed residue 61 in protein 1emn_A to binding
# Smoothing changed residue 62 in protein 1emn_A to binding
# Processing 1equ_A (49/100)...
# Smoothing changed residue 94 in protein 1equ_A to binding
# Smoothing changed residue 193 in protein 1equ_A to binding
# Smoothing changed residue 196 in protein 1equ_A to binding
# Processing 1eub_A (50/100)...
# Smoothing changed residue 7 in protein 1eub_A to binding
# Smoothing changed residue 29 in protein 1eub_A to binding
# Smoothing changed residue 30 in protein 1eub_A to binding
# Smoothing changed residue 32 in protein 1eub_A to binding
# Smoothing changed residue 47 in protein 1eub_A to binding
# Smoothing changed residue 50 in protein 1eub_A to binding
# Smoothing changed residue 64 in protein 1eub_A to binding
# Smoothing changed residue 67 in protein 1eub_A to binding
# Smoothing changed residue 71 in protein 1eub_A to binding
# Smoothing changed residue 86 in protein 1eub_A to binding
# Smoothing changed residue 87 in protein 1eub_A to binding
# Smoothing changed residue 89 in protein 1eub_A to binding
# Smoothing changed residue 108 in protein 1eub_A to binding
# Smoothing changed residue 126 in protein 1eub_A to binding
# Smoothing changed residue 130 in protein 1eub_A to binding
# Smoothing changed residue 153 in protein 1eub_A to binding
# Smoothing changed residue 161 in protein 1eub_A to binding
# Smoothing changed residue 162 in protein 1eub_A to binding
# Processing 1evt_C (51/100)...
# Smoothing changed residue 30 in protein 1evt_C to binding
# Smoothing changed residue 103 in protein 1evt_C to binding
# Smoothing changed residue 138 in protein 1evt_C to binding
# Smoothing changed residue 176 in protein 1evt_C to binding
# Smoothing changed residue 179 in protein 1evt_C to binding
# Processing 1eyb_A (52/100)...
# Smoothing changed residue 200 in protein 1eyb_A to binding
# Smoothing changed residue 361 in protein 1eyb_A to binding
# Processing 1f13_B (53/100)...
# Smoothing changed residue 68 in protein 1f13_B to binding
# Smoothing changed residue 260 in protein 1f13_B to binding
# Smoothing changed residue 273 in protein 1f13_B to binding
# Smoothing changed residue 420 in protein 1f13_B to binding
# Smoothing changed residue 550 in protein 1f13_B to binding
# Processing 1f5y_A (54/100)...
# Smoothing changed residue 11 in protein 1f5y_A to binding
# Smoothing changed residue 46 in protein 1f5y_A to binding
# Smoothing changed residue 53 in protein 1f5y_A to binding
# Processing 1f62_A (55/100)...
# Smoothing changed residue 0 in protein 1f62_A to binding
# Smoothing changed residue 13 in protein 1f62_A to binding
# Smoothing changed residue 14 in protein 1f62_A to binding
# Smoothing changed residue 23 in protein 1f62_A to binding
# Smoothing changed residue 32 in protein 1f62_A to binding
# Smoothing changed residue 37 in protein 1f62_A to binding
# Smoothing changed residue 38 in protein 1f62_A to binding
# Smoothing changed residue 40 in protein 1f62_A to binding
# Smoothing changed residue 49 in protein 1f62_A to binding
# Processing 1f6w_A (56/100)...
# Smoothing changed residue 62 in protein 1f6w_A to binding
# Smoothing changed residue 73 in protein 1f6w_A to binding
# Smoothing changed residue 74 in protein 1f6w_A to binding
# Smoothing changed residue 76 in protein 1f6w_A to binding
# Smoothing changed residue 112 in protein 1f6w_A to binding
# Smoothing changed residue 114 in protein 1f6w_A to binding
# Smoothing changed residue 143 in protein 1f6w_A to binding
# Smoothing changed residue 145 in protein 1f6w_A to binding
# Smoothing changed residue 154 in protein 1f6w_A to binding
# Smoothing changed residue 156 in protein 1f6w_A to binding
# Smoothing changed residue 224 in protein 1f6w_A to binding
# Smoothing changed residue 228 in protein 1f6w_A to binding
# Smoothing changed residue 233 in protein 1f6w_A to binding
# Smoothing changed residue 235 in protein 1f6w_A to binding
# Smoothing changed residue 238 in protein 1f6w_A to binding
# Smoothing changed residue 242 in protein 1f6w_A to binding
# Smoothing changed residue 263 in protein 1f6w_A to binding
# Smoothing changed residue 269 in protein 1f6w_A to binding
# Smoothing changed residue 272 in protein 1f6w_A to binding
# Smoothing changed residue 291 in protein 1f6w_A to binding
# Smoothing changed residue 297 in protein 1f6w_A to binding
# Smoothing changed residue 319 in protein 1f6w_A to binding
# Smoothing changed residue 332 in protein 1f6w_A to binding
# Smoothing changed residue 346 in protein 1f6w_A to binding
# Smoothing changed residue 350 in protein 1f6w_A to binding
# Smoothing changed residue 361 in protein 1f6w_A to binding
# Smoothing changed residue 376 in protein 1f6w_A to binding
# Smoothing changed residue 444 in protein 1f6w_A to binding
# Smoothing changed residue 532 in protein 1f6w_A to binding
# Processing 1f8z_A (57/100)...
# Smoothing changed residue 7 in protein 1f8z_A to binding
# Smoothing changed residue 20 in protein 1f8z_A to binding
# Smoothing changed residue 36 in protein 1f8z_A to binding
# Processing 1fa9_A (58/100)...
# Smoothing changed residue 6 in protein 1fa9_A to binding
# Smoothing changed residue 44 in protein 1fa9_A to binding
# Smoothing changed residue 46 in protein 1fa9_A to binding
# Smoothing changed residue 47 in protein 1fa9_A to binding
# Smoothing changed residue 69 in protein 1fa9_A to binding
# Smoothing changed residue 82 in protein 1fa9_A to binding
# Smoothing changed residue 84 in protein 1fa9_A to binding
# Smoothing changed residue 86 in protein 1fa9_A to binding
# Smoothing changed residue 90 in protein 1fa9_A to binding
# Smoothing changed residue 91 in protein 1fa9_A to binding
# Smoothing changed residue 118 in protein 1fa9_A to binding
# Smoothing changed residue 158 in protein 1fa9_A to binding
# Smoothing changed residue 161 in protein 1fa9_A to binding
# Smoothing changed residue 163 in protein 1fa9_A to binding
# Smoothing changed residue 170 in protein 1fa9_A to binding
# Smoothing changed residue 177 in protein 1fa9_A to binding
# Smoothing changed residue 180 in protein 1fa9_A to binding
# Smoothing changed residue 197 in protein 1fa9_A to binding
# Smoothing changed residue 214 in protein 1fa9_A to binding
# Smoothing changed residue 215 in protein 1fa9_A to binding
# Smoothing changed residue 216 in protein 1fa9_A to binding
# Smoothing changed residue 220 in protein 1fa9_A to binding
# Smoothing changed residue 239 in protein 1fa9_A to binding
# Smoothing changed residue 252 in protein 1fa9_A to binding
# Smoothing changed residue 261 in protein 1fa9_A to binding
# Smoothing changed residue 272 in protein 1fa9_A to binding
# Smoothing changed residue 276 in protein 1fa9_A to binding
# Smoothing changed residue 286 in protein 1fa9_A to binding
# Smoothing changed residue 288 in protein 1fa9_A to binding
# Smoothing changed residue 289 in protein 1fa9_A to binding
# Smoothing changed residue 290 in protein 1fa9_A to binding
# Smoothing changed residue 291 in protein 1fa9_A to binding
# Smoothing changed residue 307 in protein 1fa9_A to binding
# Smoothing changed residue 331 in protein 1fa9_A to binding
# Smoothing changed residue 337 in protein 1fa9_A to binding
# Smoothing changed residue 351 in protein 1fa9_A to binding
# Smoothing changed residue 381 in protein 1fa9_A to binding
# Smoothing changed residue 383 in protein 1fa9_A to binding
# Smoothing changed residue 389 in protein 1fa9_A to binding
# Smoothing changed residue 399 in protein 1fa9_A to binding
# Smoothing changed residue 421 in protein 1fa9_A to binding
# Smoothing changed residue 422 in protein 1fa9_A to binding
# Smoothing changed residue 429 in protein 1fa9_A to binding
# Smoothing changed residue 433 in protein 1fa9_A to binding
# Smoothing changed residue 497 in protein 1fa9_A to binding
# Smoothing changed residue 506 in protein 1fa9_A to binding
# Smoothing changed residue 514 in protein 1fa9_A to binding
# Smoothing changed residue 517 in protein 1fa9_A to binding
# Smoothing changed residue 520 in protein 1fa9_A to binding
# Smoothing changed residue 533 in protein 1fa9_A to binding
# Smoothing changed residue 536 in protein 1fa9_A to binding
# Smoothing changed residue 537 in protein 1fa9_A to binding
# Smoothing changed residue 539 in protein 1fa9_A to binding
# Smoothing changed residue 548 in protein 1fa9_A to binding
# Smoothing changed residue 555 in protein 1fa9_A to binding
# Smoothing changed residue 557 in protein 1fa9_A to binding
# Smoothing changed residue 561 in protein 1fa9_A to binding
# Smoothing changed residue 593 in protein 1fa9_A to binding
# Smoothing changed residue 594 in protein 1fa9_A to binding
# Smoothing changed residue 596 in protein 1fa9_A to binding
# Smoothing changed residue 601 in protein 1fa9_A to binding
# Smoothing changed residue 603 in protein 1fa9_A to binding
# Smoothing changed residue 604 in protein 1fa9_A to binding
# Smoothing changed residue 641 in protein 1fa9_A to binding
# Smoothing changed residue 676 in protein 1fa9_A to binding
# Smoothing changed residue 681 in protein 1fa9_A to binding
# Smoothing changed residue 688 in protein 1fa9_A to binding
# Smoothing changed residue 689 in protein 1fa9_A to binding
# Smoothing changed residue 690 in protein 1fa9_A to binding
# Smoothing changed residue 693 in protein 1fa9_A to binding
# Smoothing changed residue 706 in protein 1fa9_A to binding
# Smoothing changed residue 779 in protein 1fa9_A to binding
# Smoothing changed residue 784 in protein 1fa9_A to binding
# Smoothing changed residue 802 in protein 1fa9_A to binding
# Processing 1fao_A (59/100)...
# Smoothing changed residue 65 in protein 1fao_A to binding
# Smoothing changed residue 99 in protein 1fao_A to binding
# Processing 1faq_A (60/100)...
# Smoothing changed residue 16 in protein 1faq_A to binding
# Smoothing changed residue 28 in protein 1faq_A to binding
# Processing 1fcg_A (61/100)...
# Smoothing changed residue 10 in protein 1fcg_A to binding
# Smoothing changed residue 16 in protein 1fcg_A to binding
# Smoothing changed residue 19 in protein 1fcg_A to binding
# Smoothing changed residue 88 in protein 1fcg_A to binding
# Smoothing changed residue 90 in protein 1fcg_A to binding
# Smoothing changed residue 105 in protein 1fcg_A to binding
# Smoothing changed residue 113 in protein 1fcg_A to binding
# Smoothing changed residue 114 in protein 1fcg_A to binding
# Smoothing changed residue 116 in protein 1fcg_A to binding
# Smoothing changed residue 118 in protein 1fcg_A to binding
# Smoothing changed residue 119 in protein 1fcg_A to binding
# Smoothing changed residue 120 in protein 1fcg_A to binding
# Smoothing changed residue 122 in protein 1fcg_A to binding
# Smoothing changed residue 123 in protein 1fcg_A to binding
# Smoothing changed residue 124 in protein 1fcg_A to binding
# Smoothing changed residue 126 in protein 1fcg_A to binding
# Smoothing changed residue 127 in protein 1fcg_A to binding
# Smoothing changed residue 132 in protein 1fcg_A to binding
# Smoothing changed residue 135 in protein 1fcg_A to binding
# Smoothing changed residue 148 in protein 1fcg_A to binding
# Smoothing changed residue 149 in protein 1fcg_A to binding
# Smoothing changed residue 152 in protein 1fcg_A to binding
# Smoothing changed residue 153 in protein 1fcg_A to binding
# Smoothing changed residue 157 in protein 1fcg_A to binding
# Processing 1fd3_C (62/100)...
# Smoothing changed residue 0 in protein 1fd3_C to binding
# Processing 1fdh_H (63/100)...
# Smoothing changed residue 13 in protein 1fdh_H to binding
# Smoothing changed residue 30 in protein 1fdh_H to binding
# Smoothing changed residue 74 in protein 1fdh_H to binding
# Smoothing changed residue 80 in protein 1fdh_H to binding
# Smoothing changed residue 84 in protein 1fdh_H to binding
# Smoothing changed residue 99 in protein 1fdh_H to binding
# Smoothing changed residue 132 in protein 1fdh_H to binding
# Processing 1fe8_C (64/100)...
# Smoothing changed residue 2 in protein 1fe8_C to binding
# Smoothing changed residue 3 in protein 1fe8_C to binding
# Smoothing changed residue 7 in protein 1fe8_C to binding
# Smoothing changed residue 33 in protein 1fe8_C to binding
# Smoothing changed residue 36 in protein 1fe8_C to binding
# Smoothing changed residue 37 in protein 1fe8_C to binding
# Smoothing changed residue 38 in protein 1fe8_C to binding
# Smoothing changed residue 39 in protein 1fe8_C to binding
# Smoothing changed residue 40 in protein 1fe8_C to binding
# Smoothing changed residue 114 in protein 1fe8_C to binding
# Smoothing changed residue 177 in protein 1fe8_C to binding
# Smoothing changed residue 180 in protein 1fe8_C to binding
# Smoothing changed residue 183 in protein 1fe8_C to binding
# Smoothing changed residue 184 in protein 1fe8_C to binding
# Smoothing changed residue 186 in protein 1fe8_C to binding
# Smoothing changed residue 188 in protein 1fe8_C to binding
# Smoothing changed residue 189 in protein 1fe8_C to binding
# Smoothing changed residue 190 in protein 1fe8_C to binding
# Processing 1fht_A (65/100)...
# Smoothing changed residue 5 in protein 1fht_A to binding
# Smoothing changed residue 7 in protein 1fht_A to binding
# Smoothing changed residue 20 in protein 1fht_A to binding
# Smoothing changed residue 44 in protein 1fht_A to binding
# Smoothing changed residue 45 in protein 1fht_A to binding
# Smoothing changed residue 46 in protein 1fht_A to binding
# Smoothing changed residue 58 in protein 1fht_A to binding
# Smoothing changed residue 68 in protein 1fht_A to binding
# Smoothing changed residue 71 in protein 1fht_A to binding
# Smoothing changed residue 103 in protein 1fht_A to binding
# Smoothing changed residue 104 in protein 1fht_A to binding
# Smoothing changed residue 105 in protein 1fht_A to binding
# Smoothing changed residue 106 in protein 1fht_A to binding
# Processing 1fkt_A (66/100)...
# Smoothing changed residue 19 in protein 1fkt_A to binding
# Smoothing changed residue 38 in protein 1fkt_A to binding
# Smoothing changed residue 39 in protein 1fkt_A to binding
# Smoothing changed residue 40 in protein 1fkt_A to binding
# Smoothing changed residue 43 in protein 1fkt_A to binding
# Smoothing changed residue 48 in protein 1fkt_A to binding
# Smoothing changed residue 84 in protein 1fkt_A to binding
# Smoothing changed residue 85 in protein 1fkt_A to binding
# Smoothing changed residue 87 in protein 1fkt_A to binding
# Processing 1flh_A (67/100)...
# Smoothing changed residue 48 in protein 1flh_A to binding
# Smoothing changed residue 155 in protein 1flh_A to binding
# Processing 1fsu_A (68/100)...
# Smoothing changed residue 68 in protein 1fsu_A to binding
# Smoothing changed residue 132 in protein 1fsu_A to binding
# Smoothing changed residue 264 in protein 1fsu_A to binding
# Smoothing changed residue 274 in protein 1fsu_A to binding
# Smoothing changed residue 279 in protein 1fsu_A to binding
# Smoothing changed residue 280 in protein 1fsu_A to binding
# Smoothing changed residue 282 in protein 1fsu_A to binding
# Processing 1fvr_B (69/100)...
# Smoothing changed residue 56 in protein 1fvr_B to binding
# Smoothing changed residue 97 in protein 1fvr_B to binding
# Smoothing changed residue 136 in protein 1fvr_B to binding
# Smoothing changed residue 168 in protein 1fvr_B to binding
# Processing 1fw1_A (70/100)...
# Smoothing changed residue 32 in protein 1fw1_A to binding
# Smoothing changed residue 112 in protein 1fw1_A to binding
# Smoothing changed residue 129 in protein 1fw1_A to binding
# Smoothing changed residue 163 in protein 1fw1_A to binding
# Processing 1fy1_A (71/100)...
# Smoothing changed residue 50 in protein 1fy1_A to binding
# Smoothing changed residue 58 in protein 1fy1_A to binding
# Smoothing changed residue 59 in protein 1fy1_A to binding
# Smoothing changed residue 69 in protein 1fy1_A to binding
# Smoothing changed residue 88 in protein 1fy1_A to binding
# Smoothing changed residue 136 in protein 1fy1_A to binding
# Smoothing changed residue 137 in protein 1fy1_A to binding
# Smoothing changed residue 138 in protein 1fy1_A to binding
# Smoothing changed residue 159 in protein 1fy1_A to binding
# Processing 1fzd_G (72/100)...
# Smoothing changed residue 19 in protein 1fzd_G to binding
# Smoothing changed residue 22 in protein 1fzd_G to binding
# Smoothing changed residue 37 in protein 1fzd_G to binding
# Smoothing changed residue 41 in protein 1fzd_G to binding
# Smoothing changed residue 43 in protein 1fzd_G to binding
# Smoothing changed residue 49 in protein 1fzd_G to binding
# Smoothing changed residue 81 in protein 1fzd_G to binding
# Smoothing changed residue 107 in protein 1fzd_G to binding
# Smoothing changed residue 109 in protein 1fzd_G to binding
# Smoothing changed residue 132 in protein 1fzd_G to binding
# Smoothing changed residue 144 in protein 1fzd_G to binding
# Smoothing changed residue 151 in protein 1fzd_G to binding
# Smoothing changed residue 165 in protein 1fzd_G to binding
# Processing 1g1q_C (73/100)...
# Smoothing changed residue 48 in protein 1g1q_C to binding
# Processing 1g25_A (74/100)...
# Smoothing changed residue 8 in protein 1g25_A to binding
# Smoothing changed residue 37 in protein 1g25_A to binding
# Smoothing changed residue 38 in protein 1g25_A to binding
# Smoothing changed residue 46 in protein 1g25_A to binding
# Processing 1g3f_A (75/100)...
# Smoothing changed residue 10 in protein 1g3f_A to binding
# Smoothing changed residue 11 in protein 1g3f_A to binding
# Smoothing changed residue 14 in protein 1g3f_A to binding
# Smoothing changed residue 15 in protein 1g3f_A to binding
# Smoothing changed residue 24 in protein 1g3f_A to binding
# Smoothing changed residue 28 in protein 1g3f_A to binding
# Smoothing changed residue 31 in protein 1g3f_A to binding
# Smoothing changed residue 52 in protein 1g3f_A to binding
# Smoothing changed residue 57 in protein 1g3f_A to binding
# Smoothing changed residue 62 in protein 1g3f_A to binding
# Smoothing changed residue 68 in protein 1g3f_A to binding
# Smoothing changed residue 69 in protein 1g3f_A to binding
# Smoothing changed residue 71 in protein 1g3f_A to binding
# Smoothing changed residue 94 in protein 1g3f_A to binding
# Smoothing changed residue 98 in protein 1g3f_A to binding
# Smoothing changed residue 102 in protein 1g3f_A to binding
# Smoothing changed residue 104 in protein 1g3f_A to binding
# Smoothing changed residue 107 in protein 1g3f_A to binding
# Processing 1g47_A (76/100)...
# Smoothing changed residue 4 in protein 1g47_A to binding
# Smoothing changed residue 5 in protein 1g47_A to binding
# Smoothing changed residue 7 in protein 1g47_A to binding
# Smoothing changed residue 19 in protein 1g47_A to binding
# Smoothing changed residue 22 in protein 1g47_A to binding
# Smoothing changed residue 41 in protein 1g47_A to binding
# Smoothing changed residue 52 in protein 1g47_A to binding
# Processing 1g55_A (77/100)...
# Smoothing changed residue 30 in protein 1g55_A to binding
# Smoothing changed residue 224 in protein 1g55_A to binding
# Processing 1g5v_A (78/100)...
# Processing 1g5w_A (79/100)...
# Smoothing changed residue 23 in protein 1g5w_A to binding
# Smoothing changed residue 41 in protein 1g5w_A to binding
# Smoothing changed residue 81 in protein 1g5w_A to binding
# Smoothing changed residue 96 in protein 1g5w_A to binding
# Processing 1ga5_E (80/100)...
# Smoothing changed residue 1 in protein 1ga5_E to binding
# Smoothing changed residue 42 in protein 1ga5_E to binding
# Smoothing changed residue 51 in protein 1ga5_E to binding
# Smoothing changed residue 76 in protein 1ga5_E to binding
# Smoothing changed residue 78 in protein 1ga5_E to binding
# Smoothing changed residue 79 in protein 1ga5_E to binding
# Processing 1ggz_A (81/100)...
# Smoothing changed residue 4 in protein 1ggz_A to binding
# Smoothing changed residue 30 in protein 1ggz_A to binding
# Smoothing changed residue 41 in protein 1ggz_A to binding
# Smoothing changed residue 43 in protein 1ggz_A to binding
# Smoothing changed residue 62 in protein 1ggz_A to binding
# Smoothing changed residue 69 in protein 1ggz_A to binding
# Smoothing changed residue 72 in protein 1ggz_A to binding
# Smoothing changed residue 77 in protein 1ggz_A to binding
# Smoothing changed residue 81 in protein 1ggz_A to binding
# Smoothing changed residue 90 in protein 1ggz_A to binding
# Smoothing changed residue 113 in protein 1ggz_A to binding
# Smoothing changed residue 142 in protein 1ggz_A to binding
# Processing 1gnh_D (82/100)...
# Smoothing changed residue 46 in protein 1gnh_D to binding
# Smoothing changed residue 49 in protein 1gnh_D to binding
# Smoothing changed residue 56 in protein 1gnh_D to binding
# Smoothing changed residue 57 in protein 1gnh_D to binding
# Smoothing changed residue 58 in protein 1gnh_D to binding
# Smoothing changed residue 61 in protein 1gnh_D to binding
# Smoothing changed residue 66 in protein 1gnh_D to binding
# Smoothing changed residue 67 in protein 1gnh_D to binding
# Smoothing changed residue 68 in protein 1gnh_D to binding
# Smoothing changed residue 80 in protein 1gnh_D to binding
# Smoothing changed residue 136 in protein 1gnh_D to binding
# Smoothing changed residue 147 in protein 1gnh_D to binding
# Processing 1gpz_B (83/100)...
# Smoothing changed residue 193 in protein 1gpz_B to binding
# Processing 1gr3_A (84/100)...
# Smoothing changed residue 57 in protein 1gr3_A to binding
# Processing 1gvl_A (85/100)...
# Smoothing changed residue 15 in protein 1gvl_A to binding
# Smoothing changed residue 85 in protein 1gvl_A to binding
# Processing 1gwb_B (86/100)...
# Smoothing changed residue 33 in protein 1gwb_B to binding
# Smoothing changed residue 62 in protein 1gwb_B to binding
# Smoothing changed residue 130 in protein 1gwb_B to binding
# Smoothing changed residue 149 in protein 1gwb_B to binding
# Smoothing changed residue 176 in protein 1gwb_B to binding
# Smoothing changed residue 178 in protein 1gwb_B to binding
# Smoothing changed residue 199 in protein 1gwb_B to binding
# Smoothing changed residue 236 in protein 1gwb_B to binding
# Smoothing changed residue 237 in protein 1gwb_B to binding
# Smoothing changed residue 238 in protein 1gwb_B to binding
# Processing 1gxd_A (87/100)...
# Smoothing changed residue 80 in protein 1gxd_A to binding
# Smoothing changed residue 85 in protein 1gxd_A to binding
# Smoothing changed residue 86 in protein 1gxd_A to binding
# Smoothing changed residue 88 in protein 1gxd_A to binding
# Smoothing changed residue 89 in protein 1gxd_A to binding
# Smoothing changed residue 95 in protein 1gxd_A to binding
# Smoothing changed residue 97 in protein 1gxd_A to binding
# Smoothing changed residue 105 in protein 1gxd_A to binding
# Smoothing changed residue 117 in protein 1gxd_A to binding
# Smoothing changed residue 128 in protein 1gxd_A to binding
# Smoothing changed residue 145 in protein 1gxd_A to binding
# Smoothing changed residue 146 in protein 1gxd_A to binding
# Smoothing changed residue 147 in protein 1gxd_A to binding
# Smoothing changed residue 166 in protein 1gxd_A to binding
# Smoothing changed residue 167 in protein 1gxd_A to binding
# Smoothing changed residue 168 in protein 1gxd_A to binding
# Smoothing changed residue 169 in protein 1gxd_A to binding
# Smoothing changed residue 181 in protein 1gxd_A to binding
# Smoothing changed residue 206 in protein 1gxd_A to binding
# Smoothing changed residue 244 in protein 1gxd_A to binding
# Smoothing changed residue 276 in protein 1gxd_A to binding
# Smoothing changed residue 302 in protein 1gxd_A to binding
# Smoothing changed residue 309 in protein 1gxd_A to binding
# Smoothing changed residue 311 in protein 1gxd_A to binding
# Smoothing changed residue 312 in protein 1gxd_A to binding
# Smoothing changed residue 330 in protein 1gxd_A to binding
# Smoothing changed residue 340 in protein 1gxd_A to binding
# Smoothing changed residue 348 in protein 1gxd_A to binding
# Smoothing changed residue 360 in protein 1gxd_A to binding
# Smoothing changed residue 367 in protein 1gxd_A to binding
# Smoothing changed residue 381 in protein 1gxd_A to binding
# Smoothing changed residue 407 in protein 1gxd_A to binding
# Smoothing changed residue 415 in protein 1gxd_A to binding
# Smoothing changed residue 417 in protein 1gxd_A to binding
# Smoothing changed residue 422 in protein 1gxd_A to binding
# Smoothing changed residue 445 in protein 1gxd_A to binding
# Smoothing changed residue 456 in protein 1gxd_A to binding
# Smoothing changed residue 469 in protein 1gxd_A to binding
# Smoothing changed residue 488 in protein 1gxd_A to binding
# Smoothing changed residue 509 in protein 1gxd_A to binding
# Smoothing changed residue 537 in protein 1gxd_A to binding
# Smoothing changed residue 544 in protein 1gxd_A to binding
# Smoothing changed residue 546 in protein 1gxd_A to binding
# Smoothing changed residue 566 in protein 1gxd_A to binding
# Smoothing changed residue 575 in protein 1gxd_A to binding
# Smoothing changed residue 577 in protein 1gxd_A to binding
# Smoothing changed residue 605 in protein 1gxd_A to binding
# Smoothing changed residue 606 in protein 1gxd_A to binding
# Smoothing changed residue 608 in protein 1gxd_A to binding
# Smoothing changed residue 610 in protein 1gxd_A to binding
# Processing 1gxr_A (88/100)...
# Smoothing changed residue 99 in protein 1gxr_A to binding
# Smoothing changed residue 184 in protein 1gxr_A to binding
# Smoothing changed residue 264 in protein 1gxr_A to binding
# Smoothing changed residue 322 in protein 1gxr_A to binding
# Processing 1gzq_A (89/100)...
# Smoothing changed residue 29 in protein 1gzq_A to binding
# Smoothing changed residue 46 in protein 1gzq_A to binding
# Smoothing changed residue 78 in protein 1gzq_A to binding
# Smoothing changed residue 87 in protein 1gzq_A to binding
# Smoothing changed residue 91 in protein 1gzq_A to binding
# Smoothing changed residue 112 in protein 1gzq_A to binding
# Smoothing changed residue 115 in protein 1gzq_A to binding
# Smoothing changed residue 120 in protein 1gzq_A to binding
# Smoothing changed residue 141 in protein 1gzq_A to binding
# Smoothing changed residue 144 in protein 1gzq_A to binding
# Processing 1h30_A (90/100)...
# Smoothing changed residue 44 in protein 1h30_A to binding
# Smoothing changed residue 70 in protein 1h30_A to binding
# Smoothing changed residue 80 in protein 1h30_A to binding
# Smoothing changed residue 83 in protein 1h30_A to binding
# Smoothing changed residue 92 in protein 1h30_A to binding
# Smoothing changed residue 152 in protein 1h30_A to binding
# Smoothing changed residue 359 in protein 1h30_A to binding
# Smoothing changed residue 362 in protein 1h30_A to binding
# Processing 1h6h_A (91/100)...
# Smoothing changed residue 30 in protein 1h6h_A to binding
# Smoothing changed residue 31 in protein 1h6h_A to binding
# Smoothing changed residue 92 in protein 1h6h_A to binding
# Smoothing changed residue 100 in protein 1h6h_A to binding
# Processing 1h6p_B (92/100)...
# Processing 1hcp_A (93/100)...
# Smoothing changed residue 16 in protein 1hcp_A to binding
# Smoothing changed residue 20 in protein 1hcp_A to binding
# Smoothing changed residue 21 in protein 1hcp_A to binding
# Smoothing changed residue 40 in protein 1hcp_A to binding
# Smoothing changed residue 52 in protein 1hcp_A to binding
# Processing 1hdo_A (94/100)...
# Smoothing changed residue 120 in protein 1hdo_A to binding
# Smoothing changed residue 121 in protein 1hdo_A to binding
# Smoothing changed residue 123 in protein 1hdo_A to binding
# Smoothing changed residue 169 in protein 1hdo_A to binding
# Smoothing changed residue 174 in protein 1hdo_A to binding
# Smoothing changed residue 199 in protein 1hdo_A to binding
# Processing 1hdr_A (95/100)...
# Smoothing changed residue 49 in protein 1hdr_A to binding
# Smoothing changed residue 50 in protein 1hdr_A to binding
# Smoothing changed residue 52 in protein 1hdr_A to binding
# Smoothing changed residue 138 in protein 1hdr_A to binding
# Smoothing changed residue 184 in protein 1hdr_A to binding
# Smoothing changed residue 185 in protein 1hdr_A to binding
# Smoothing changed residue 188 in protein 1hdr_A to binding
# Smoothing changed residue 194 in protein 1hdr_A to binding
# Processing 1hgu_A (96/100)...
# Smoothing changed residue 26 in protein 1hgu_A to binding
# Smoothing changed residue 33 in protein 1hgu_A to binding
# Smoothing changed residue 48 in protein 1hgu_A to binding
# Smoothing changed residue 49 in protein 1hgu_A to binding
# Smoothing changed residue 92 in protein 1hgu_A to binding
# Smoothing changed residue 95 in protein 1hgu_A to binding
# Smoothing changed residue 167 in protein 1hgu_A to binding
# Smoothing changed residue 171 in protein 1hgu_A to binding
# Processing 1hh4_D (97/100)...
# Smoothing changed residue 63 in protein 1hh4_D to binding
# Smoothing changed residue 88 in protein 1hh4_D to binding
# Smoothing changed residue 91 in protein 1hh4_D to binding
# Smoothing changed residue 106 in protein 1hh4_D to binding
# Smoothing changed residue 111 in protein 1hh4_D to binding
# Smoothing changed residue 113 in protein 1hh4_D to binding
# Smoothing changed residue 121 in protein 1hh4_D to binding
# Smoothing changed residue 122 in protein 1hh4_D to binding
# Smoothing changed residue 127 in protein 1hh4_D to binding
# Smoothing changed residue 129 in protein 1hh4_D to binding
# Smoothing changed residue 130 in protein 1hh4_D to binding
# Smoothing changed residue 132 in protein 1hh4_D to binding
# Smoothing changed residue 169 in protein 1hh4_D to binding
# Processing 1hnc_A (98/100)...
# Smoothing changed residue 39 in protein 1hnc_A to binding
# Smoothing changed residue 201 in protein 1hnc_A to binding
# Smoothing changed residue 204 in protein 1hnc_A to binding
# Smoothing changed residue 205 in protein 1hnc_A to binding
# Smoothing changed residue 212 in protein 1hnc_A to binding
# Smoothing changed residue 213 in protein 1hnc_A to binding
# Processing 1hnf_A (99/100)...
# Smoothing changed residue 98 in protein 1hnf_A to binding
# Smoothing changed residue 99 in protein 1hnf_A to binding
# Smoothing changed residue 105 in protein 1hnf_A to binding
# Smoothing changed residue 120 in protein 1hnf_A to binding
# Smoothing changed residue 125 in protein 1hnf_A to binding
# Smoothing changed residue 126 in protein 1hnf_A to binding
# Smoothing changed residue 161 in protein 1hnf_A to binding
# Smoothing changed residue 162 in protein 1hnf_A to binding
# Smoothing changed residue 164 in protein 1hnf_A to binding
# Processing 1hp7_A (100/100)...
# Smoothing changed residue 0 in protein 1hp7_A to binding
# Smoothing changed residue 1 in protein 1hp7_A to binding
# Smoothing changed residue 2 in protein 1hp7_A to binding
# Smoothing changed residue 3 in protein 1hp7_A to binding
# Smoothing changed residue 37 in protein 1hp7_A to binding
# Smoothing changed residue 41 in protein 1hp7_A to binding
# Smoothing changed residue 44 in protein 1hp7_A to binding
# Smoothing changed residue 53 in protein 1hp7_A to binding
# Smoothing changed residue 55 in protein 1hp7_A to binding
# Smoothing changed residue 57 in protein 1hp7_A to binding
# Smoothing changed residue 62 in protein 1hp7_A to binding
# Smoothing changed residue 67 in protein 1hp7_A to binding
# Smoothing changed residue 79 in protein 1hp7_A to binding
# Smoothing changed residue 81 in protein 1hp7_A to binding
# Smoothing changed residue 100 in protein 1hp7_A to binding
# Smoothing changed residue 105 in protein 1hp7_A to binding
# Smoothing changed residue 122 in protein 1hp7_A to binding
# Smoothing changed residue 125 in protein 1hp7_A to binding
# Smoothing changed residue 127 in protein 1hp7_A to binding
# Smoothing changed residue 131 in protein 1hp7_A to binding
# Smoothing changed residue 135 in protein 1hp7_A to binding
# Smoothing changed residue 157 in protein 1hp7_A to binding
# Smoothing changed residue 205 in protein 1hp7_A to binding
# Smoothing changed residue 234 in protein 1hp7_A to binding
# Smoothing changed residue 295 in protein 1hp7_A to binding
# Smoothing changed residue 305 in protein 1hp7_A to binding
# Smoothing changed residue 308 in protein 1hp7_A to binding
# Smoothing changed residue 310 in protein 1hp7_A to binding
# Smoothing changed residue 311 in protein 1hp7_A to binding
# Smoothing changed residue 334 in protein 1hp7_A to binding
# Smoothing changed residue 337 in protein 1hp7_A to binding
# Smoothing changed residue 340 in protein 1hp7_A to binding
# Smoothing changed residue 342 in protein 1hp7_A to binding
# Smoothing changed residue 343 in protein 1hp7_A to binding
# Smoothing changed residue 344 in protein 1hp7_A to binding

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

number_of_pockets = len(number_of_overlapping_actual_sites_on_predicted_pocket)

mean_br = np.mean(best_residue_overlaps)
median_br = np.median(best_residue_overlaps)
print(f'best_residue_overlap mean={mean_br:.4f}, median={median_br:.4f}')

print(np.sum(np.array(DCCs) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N_plus_K) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N_plus_K) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N) < 4) / number_of_pockets})')

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros = [i for i in number_of_overlapping_actual_sites_on_predicted_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Predicted Pockets Covering True Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Predicted Pockets Covering True Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_predictions_on_actual_pocket_without_zeros = [i for i in number_of_overlapping_predictions_on_actual_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_predictions_on_actual_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Actual Pockets Covering Predicted Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Actual Pockets Covering Predicted Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()
# Out:
# best_residue_overlap mean=0.5625, median=0.5556
# 0.7937062937062938 (0.2097902097902098)
# 0.7622377622377622 (0.1993006993006993)
# 0.6853146853146853 (0.18181818181818182)

# %% [markdown]
# ## Run clustering without smoothing

# %%
MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/model-enhanced-scPDB.pt'
COORDINATES_DIR = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis-coordinates'
PRECALCULATED = True
PREDICTIONS_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/predictions-enhanced-scPDB'
PRECALCULATED_PATH = F'{PREDICTIONS_PATH}/finetuning-without-smoothing'
LIGYSIS_ANNOTATION_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis_for_pocket_level_evaluation.csv'
DECISION_THRESHOLD = 0.5

model = torch.load(MODEL_PATH, weights_only=False)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

binding_residues, sequences = eval_utils.read_test_binding_residues(data_path=LIGYSIS_ANNOTATION_PATH, pocket_types=['NON_CRYPTIC'])

# debug on subset of 100 proteins
binding_residues = {k: binding_residues[k] for k in list(binding_residues.keys())[:100]}
sequences = {k: sequences[k] for k in list(sequences.keys())[:100]}

predicted_binding_sites = {}
ranks = {}
prediction_scores = {}

K = 2

DCCs_N = []
DCCs_N_plus_K = []
DCCs = []
number_of_overlapping_predictions_on_actual_pocket = []
number_of_overlapping_actual_sites_on_predicted_pocket = []
best_residue_overlaps = []

for i, protein_id in enumerate(sequences.keys()):
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'
    actual_binding_sites = [np.array([int(i.split('_')[1]) for i in pocket]) for pocket in binding_residues[protein_id]]
    
    print(f'Processing {protein_id} ({i+1}/{len(sequences)})...')
    if not PRECALCULATED:
        # finetuned prediction
        probabilities = eval_utils.compute_prediction(
            sequence,
            f'/tmp/skrhakv',
            model,
            tokenizer
        )
    else:
        # load precalculated prediction
        probabilities = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')
    
    prediction_scores[protein_id] = probabilities

    coordinates = np.load(coordinates_path)
    distance_matrix = eval_utils.compute_distance_matrix(coordinates)

    predictions = (probabilities > DECISION_THRESHOLD).astype(float)
    predictions_copy = predictions.copy()

    assert distance_matrix.shape[0] == distance_matrix.shape[1]
    assert distance_matrix.shape[0] == predictions_copy.shape[0]
    
    indices_above_threshold = np.where(predictions_copy > DECISION_THRESHOLD)[0] # this gets residues that are equal to 1
    # no predicted residues - continue
    if len(indices_above_threshold) == 0:
        continue

    # run atom-level clustering and return residue-level pockets
    clusters, cluster_residues, cluster_scores, atom_coords, residue_coords = execute_atom_clustering(
        pdb_id,
        chain_id,
        indices_above_threshold,
        probabilities[indices_above_threshold],
        eps=9
    )

    # none of the residues are on the surface
    if cluster_residues is None:
        continue

    cluster_residues = cryptoshow_utils.map_auth_to_mmcif_numbering_array(
        pdb_id,
        chain_id,
        cluster_residues.values(),
        binding_residues_are_integers=True,
        numbers_only=True
    )[0]

    cluster_order = np.argsort(cluster_scores)[::-1]  # descending order
    N = len(actual_binding_sites)

    selected_clusters_N = cluster_order[:N]
    selected_clusters_N_plus_K = cluster_order[:N+K]

    predicted_centers = {}
    for cluster_label, atom_indices in clusters.items():
        cluster_coords = np.array([atom_coords[atom_id] for atom_id in atom_indices])
        cluster_center = np.mean(cluster_coords, axis=0).get_array()
        predicted_centers[cluster_label] = cluster_center
    
    actual_centers = []

    for pocket in actual_binding_sites:
        pocket_coords = coordinates[pocket]
        pocket_center = np.mean(pocket_coords, axis=0)
        actual_centers.append(pocket_center)
    
    for i, center in enumerate(actual_centers):
        DCC_N = float('inf')
        for j in selected_clusters_N:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N:
                DCC_N = distance
        
        if DCC_N != float('inf'):
            DCCs_N.append(DCC_N)

        DCC_N_plus_K = float('inf')
        for j in selected_clusters_N_plus_K:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N_plus_K:
                DCC_N_plus_K = distance
        
        if DCC_N_plus_K != float('inf'):
            DCCs_N_plus_K.append(DCC_N_plus_K)

        DCC = float('inf')
        for j, predicted_center in predicted_centers.items():
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC:
                DCC = distance    

        if DCC != float('inf'):
            DCCs.append(DCC)

    for pocket in actual_binding_sites:
        number_of_predicted_pockets = 0
        best_residue_overlap = 0
        for residues in cluster_residues:
            residue_overlap = len(set(pocket).intersection(residues)) / len(pocket)
            if residue_overlap > best_residue_overlap:
                best_residue_overlap = residue_overlap
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_actual_sites_on_predicted_pocket.append(number_of_predicted_pockets)
        if best_residue_overlap > 0:
            best_residue_overlaps.append(best_residue_overlap)

    for residues in cluster_residues:
        number_of_predicted_pockets = 0
        for pocket in actual_binding_sites:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_predictions_on_actual_pocket.append(number_of_predicted_pockets)
# Out:
# Processing 1a52_A (1/100)...
# Processing 1a9w_E (2/100)...
# Processing 1aii_A (3/100)...
# Processing 1au1_A (4/100)...
# Processing 1aue_B (5/100)...
# Processing 1b1c_A (6/100)...
# Processing 1b50_B (7/100)...
# Processing 1b55_B (8/100)...
# Processing 1b6c_F (9/100)...
# Processing 1b9o_A (10/100)...
# Processing 1bbo_A (11/100)...
# Processing 1bci_A (12/100)...
# Processing 1bf9_A (13/100)...
# Processing 1bhi_A (14/100)...
# Processing 1bld_A (15/100)...
# Processing 1blx_A (16/100)...
# Processing 1bmo_A (17/100)...
# Processing 1bnl_A (18/100)...
# Processing 1boy_A (19/100)...
# Processing 1bp5_A (20/100)...
# Processing 1buv_M (21/100)...
# Processing 1byg_A (22/100)...
# Processing 1bzs_A (23/100)...
# Processing 1c07_A (24/100)...
# Processing 1c4z_A (25/100)...
# Processing 1c9y_A (26/100)...
# Processing 1cb6_A (27/100)...
# Processing 1cjy_B (28/100)...
# Processing 1cm8_A (29/100)...
# Processing 1cr8_A (30/100)...
# Processing 1cws_A (31/100)...
# Processing 1cx8_C (32/100)...
# Processing 1cza_N (33/100)...
# Processing 1czv_A (34/100)...
# Processing 1d1s_A (35/100)...
# Processing 1d4u_A (36/100)...
# Processing 1d5g_A (37/100)...
# Processing 1drf_A (38/100)...
# Processing 1ds6_A (39/100)...
# Processing 1dsz_A (40/100)...
# Processing 1dtw_B (41/100)...
# Processing 1dxt_D (42/100)...
# Processing 1e0o_D (43/100)...
# Processing 1e17_A (44/100)...
# Processing 1e9t_A (45/100)...
# Processing 1eh2_A (46/100)...
# Processing 1ek6_A (47/100)...
# Processing 1emn_A (48/100)...
# Processing 1equ_A (49/100)...
# Processing 1eub_A (50/100)...
# Processing 1evt_C (51/100)...
# Processing 1eyb_A (52/100)...
# Processing 1f13_B (53/100)...
# Processing 1f5y_A (54/100)...
# Processing 1f62_A (55/100)...
# Processing 1f6w_A (56/100)...
# Processing 1f8z_A (57/100)...
# Processing 1fa9_A (58/100)...
# Processing 1fao_A (59/100)...
# Processing 1faq_A (60/100)...
# Processing 1fcg_A (61/100)...
# Processing 1fd3_C (62/100)...
# Processing 1fdh_H (63/100)...
# Processing 1fe8_C (64/100)...
# Processing 1fht_A (65/100)...
# Processing 1fkt_A (66/100)...
# Processing 1flh_A (67/100)...
# Processing 1fsu_A (68/100)...
# Processing 1fvr_B (69/100)...
# Processing 1fw1_A (70/100)...
# Processing 1fy1_A (71/100)...
# Processing 1fzd_G (72/100)...
# Processing 1g1q_C (73/100)...
# Processing 1g25_A (74/100)...
# Processing 1g3f_A (75/100)...
# Processing 1g47_A (76/100)...
# Processing 1g55_A (77/100)...
# Processing 1g5v_A (78/100)...
# Processing 1g5w_A (79/100)...
# Processing 1ga5_E (80/100)...
# Processing 1ggz_A (81/100)...
# Processing 1gnh_D (82/100)...
# Processing 1gpz_B (83/100)...
# Processing 1gr3_A (84/100)...
# Processing 1gvl_A (85/100)...
# Processing 1gwb_B (86/100)...
# Processing 1gxd_A (87/100)...
# Processing 1gxr_A (88/100)...
# Processing 1gzq_A (89/100)...
# Processing 1h30_A (90/100)...
# Processing 1h6h_A (91/100)...
# Processing 1h6p_B (92/100)...
# Processing 1hcp_A (93/100)...
# Processing 1hdo_A (94/100)...
# Processing 1hdr_A (95/100)...
# Processing 1hgu_A (96/100)...
# Processing 1hh4_D (97/100)...
# Processing 1hnc_A (98/100)...
# Processing 1hnf_A (99/100)...
# Processing 1hp7_A (100/100)...

# %%
import numpy as np
import matplotlib.pyplot as plt

number_of_pockets = len(number_of_overlapping_actual_sites_on_predicted_pocket)

mean_br = np.mean(best_residue_overlaps)
median_br = np.median(best_residue_overlaps)
print(f'best_residue_overlap mean={mean_br:.4f}, median={median_br:.4f}')
print(np.sum(np.array(DCCs) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N_plus_K) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N_plus_K) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N) < 4) / number_of_pockets})')

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros = [i for i in number_of_overlapping_actual_sites_on_predicted_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Predicted Pockets Covering True Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Predicted Pockets Covering True Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_predictions_on_actual_pocket_without_zeros = [i for i in number_of_overlapping_predictions_on_actual_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_predictions_on_actual_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Actual Pockets Covering Predicted Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Actual Pockets Covering Predicted Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()
# Out:
# best_residue_overlap mean=0.5634, median=0.5436
# 0.7482517482517482 (0.23076923076923078)
# 0.7377622377622378 (0.22727272727272727)
# 0.6783216783216783 (0.2097902097902098)

# %%
# with smoothing (distance=10), meanshift eps=10
# 0.7307692307692307 (0.18181818181818182)
# 0.7237762237762237 (0.17832167832167833)
# 0.6783216783216783 (0.17132867132867133)

# with smoothing (distance=15), meanshift eps=10
# 0.7552447552447552 (0.19230769230769232)
# 0.7307692307692307 (0.17832167832167833)
# 0.6888111888111889 (0.16783216783216784)

# without smoothing (no distance), meanshift eps=10
# 0.7237762237762237 (0.2062937062937063)   -3
# 0.7202797202797203 (0.2062937062937063)   -1
# 0.6853146853146853 (0.1958041958041958)   -0

# with smoothing, eps=9:
# best_residue_overlap mean=0.5625, median=0.5556
# 0.7937062937062938 (0.2097902097902098)
# 0.7622377622377622 (0.1993006993006993)
# 0.6853146853146853 (0.18181818181818182)

# without smoothing, eps=9: 
# best_residue_overlap mean=0.5634, median=0.5436
# 0.7482517482517482 (0.23076923076923078)  -5
# 0.7377622377622378 (0.22727272727272727)  -3
# 0.6783216783216783 (0.2097902097902098)   -1
