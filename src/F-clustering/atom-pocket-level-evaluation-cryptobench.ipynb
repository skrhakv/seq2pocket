# %% [markdown]
# # Replicate pocket-level-evaluation.ipynb
# We need to create a plot where we will compare DCC and cluster fragmentation.
#
# Especially, we need to run the atom-level clustering and subsequently the smoothing.
#
# Let's run it on LIGYSIS, as the flexible nature of CBSs might be problematic.

# %%
from transformers import AutoTokenizer
import torch
import numpy as np
import functools
from sklearn import metrics
from torch.utils.data import DataLoader
import sys
import pickle

sys.path.append('/home/skrhakv/cryptoshow-analysis/src/B-evaluate-cryptoshow')
sys.path.append('/home/skrhakv/cryptic-nn/src')
import finetuning_utils
from finetuning_utils import FinetunedEsmModel
import eval_utils
from eval_utils import CryptoBenchClassifier
import cryptoshow_utils

MODEL_NAME = 'facebook/esm2_t36_3B_UR50D'
device = 'cuda' if torch.cuda.is_available() else 'cpu'

MODEL_PATH = "/home/skrhakv/cryptic-nn/final-data/trained-models/multitask-finetuned-model-with-ligysis.pt"

SMOOTHING_MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/C-optimize-smoother/smoother.pt'
smoothing_model = torch.load(SMOOTHING_MODEL_PATH, weights_only=False) #, map_location=torch.device('cpu'))

# %%
def execute_atom_clustering(pdb_id, chain_id, predictions, probabilities, eps=EPS):
    """
    Execute atom-level clustering based on predicted binding residues.
    Args:
        pdb_id: PDB identifier of the protein.
        chain_id: Chain identifier of the protein.
        predictions: List of predicted binding residue IDs (mmCIF numbering).
        probabilities: List of probabilities/scores for the predicted binding residues.
    Returns:
        clusters: Dict {cluster_id: [atom_id, ...], ...}
        cluster_residues: List of Lists [[residue_id, ...], ...] for each cluster. The ordering corresponds to cluster IDs.
        cluster_scores: List of average scores for each cluster. List has size of N, where N is number of clusters, and the ordering corresponds to cluster IDs.
        atom_coords: Dict {atom_id: np.array([x,y,z])}
    """
    # 1. Map mmCIF numbering to auth numbering
    auth_predictions, scores = cryptoshow_utils.map_mmcif_numbering_to_auth(pdb_id, chain_id, predictions, binding_scores=probabilities)

    # 2. Get surface points and their mapping to atoms, atom coordinates, and atom to residue mapping
    all_points, map_point_to_atom, map_atoms_to_residue_id, atom_coords, residue_coords = get_protein_surface_points(pdb_id, chain_id, auth_predictions)

    if all_points.shape[0] == 0:
        return None, None, None, None, None

    # 3. Cluster surface points and propagate labels to atoms    
    atom_labels = cluster_atoms_by_surface(
        all_points, map_point_to_atom, eps=eps)
    
    # get cluster dictionary {cluster_id: [atom_id, ...], ...}
    clusters = {}
    for atom_index, cluster_label in atom_labels.items():
        if cluster_label not in clusters:
            clusters[cluster_label] = []
        clusters[cluster_label].append(atom_index)

    # 4. Voting: the residue gets the label of the majority of its atoms
    # cluster_scores = [[] for _ in range(max(clusters) + 1)]
    cluster_residues = [[] for _ in range(max(clusters) + 1)]
    auth_predictions = np.array(auth_predictions)
    
    # 4.1 For each atom in each cluster, get its residue
    for atom_id, cluster_label in atom_labels.items():
        residue_id = map_atoms_to_residue_id[atom_id] # this is auth residue id
        # score = scores[np.where(auth_predictions == int(residue_id))[0][0]]
        # cluster_scores[cluster_label].append(score)
        cluster_residues[cluster_label].append(residue_id)
    
    # 4.2 Vote
    residue_voting = {residue: [0 for _ in range(len(cluster_residues))] for residue in auth_predictions}
    for i, labels in enumerate(cluster_residues):
        counts = Counter(labels)
        for residue, number_of_occurences in counts.items():
            residue_voting[residue][i] = number_of_occurences
    
    residue_clusters = {i: [] for i in range(len(cluster_residues))}
    # 4.3 get residue cluster assignment based on voting
    for residue, votes in residue_voting.items():
        cluster = np.argmax(votes)
        residue_clusters[cluster].append(residue)

    # 5. Compute average cluster scores
    final_cluster_scores = []
    residue_id_to_score_mapping = {auth_predictions[i]: scores[i] for i in range(len(auth_predictions))}
    for _, residues in residue_clusters.items():
        scores = []
        for residue in residues:
            scores.append(residue_id_to_score_mapping[residue])
            if residue_id_to_score_mapping[residue] <= 0.5:
                print(f"Residue {residue} in protein {pdb_id} chain {chain_id} has low score {residue_id_to_score_mapping[residue]} but is included in cluster.")
        if len(scores) == 0:
            final_cluster_scores.append(0.0)
        else:
            scores = np.array(scores)
            final_cluster_scores.append(np.mean(scores[scores > 0.5]))
    cluster_scores = final_cluster_scores

    return clusters, residue_clusters, cluster_scores, atom_coords, residue_coords
clusters, cluster_residues, cluster_scores, atom_coords, residue_coords = execute_atom_clustering(
        pdb_id,
        chain_id,
        indices_above_threshold,
        probabilities[indices_above_threshold],
        eps=9
    )

# %%
import sys
import numpy as np
from Bio.PDB import MMCIFParser
from Bio.PDB.SASA import ShrakeRupley
from sklearn.cluster import MeanShift, AgglomerativeClustering, DBSCAN, AffinityPropagation
from sklearn.mixture import BayesianGaussianMixture
from collections import Counter

CIF_FILES = '/home/skrhakv/cryptoshow-analysis/data/F-clustering/cif_files'
POINTS_DENSITY_PER_ATOM = 50
PROBE_RADIUS = 1.6

def execute_atom_clustering(pdb_id, chain_id, predictions, probabilities, eps=10):
    """
    Execute atom-level clustering based on predicted binding residues.
    Args:
        pdb_id: PDB identifier of the protein.
        chain_id: Chain identifier of the protein.
        predictions: List of predicted binding residue IDs (mmCIF numbering).
        probabilities: List of probabilities/scores for the predicted binding residues.
    Returns:
        clusters: Dict {cluster_id: [atom_id, ...], ...}
        cluster_residues: List of Lists [[residue_id, ...], ...] for each cluster. The ordering corresponds to cluster IDs.
        cluster_scores: List of average scores for each cluster. List has size of N, where N is number of clusters, and the ordering corresponds to cluster IDs.
        atom_coords: Dict {atom_id: np.array([x,y,z])}
    """
    # 1. Map mmCIF numbering to auth numbering
    auth_predictions, scores = cryptoshow_utils.map_mmcif_numbering_to_auth(pdb_id, chain_id, predictions, binding_scores=probabilities)

    # 2. Get surface points and their mapping to atoms, atom coordinates, and atom to residue mapping
    all_points, map_point_to_atom, map_atoms_to_residue_id, atom_coords, residue_coords = get_protein_surface_points(pdb_id, chain_id, auth_predictions)

    if all_points.shape[0] == 0:
        return None, None, None, None, None

    # 3. Cluster surface points and propagate labels to atoms    
    atom_labels = cluster_atoms_by_surface(
        all_points, map_point_to_atom, eps=eps)
    
    # get cluster dictionary {cluster_id: [atom_id, ...], ...}
    clusters = {}
    for atom_index, cluster_label in atom_labels.items():
        if cluster_label not in clusters:
            clusters[cluster_label] = []
        clusters[cluster_label].append(atom_index)

    # 4. Voting: the residue gets the label of the majority of its atoms
    cluster_scores = [[] for _ in range(max(clusters) + 1)]
    cluster_residues = [[] for _ in range(max(clusters) + 1)]
    auth_predictions = np.array(auth_predictions)
    
    # 4.1 For each atom in each cluster, get its residue and score
    for atom_id, cluster_label in atom_labels.items():
        residue_id = map_atoms_to_residue_id[atom_id] # this is auth residue id
        score = scores[np.where(auth_predictions == int(residue_id))[0][0]]
        cluster_scores[cluster_label].append(score)
        cluster_residues[cluster_label].append(residue_id)
    
    # 4.2 Vote
    residue_voting = {residue: [0 for _ in range(len(cluster_residues))] for residue in auth_predictions}
    for i, labels in enumerate(cluster_residues):
        counts = Counter(labels)
        for residue, number_of_occurences in counts.items():
            residue_voting[residue][i] = number_of_occurences
    
    residue_clusters = {i: [] for i in range(len(cluster_residues))}
    # 4.3 get residue cluster assignment based on voting
    for residue, votes in residue_voting.items():
        cluster = np.argmax(votes)
        residue_clusters[cluster].append(residue)

    # 5. Compute average cluster scores
    final_cluster_scores = []
    for scores in cluster_scores:
        if len(scores) == 0:
            final_cluster_scores.append(0.0)
        else:
            final_cluster_scores.append(np.mean(scores))
    cluster_scores = final_cluster_scores

    return clusters, residue_clusters, cluster_scores, atom_coords, residue_coords

def cluster_atoms_by_surface(all_points, point_to_atom_map, eps=1.5, gmm=False):
    """
    Clusters surface points and propagates labels to atoms via majority vote.
    
    Args:
        surface_points_dict: Dict {atom_id: np.array([[x,y,z], ...])}
        eps: DBSCAN maximum distance between two samples (in Angstroms).
        min_samples: DBSCAN minimum samples in a neighborhood for a core point.
        
    Returns:
        atom_labels: Dict {atom_id: cluster_label_int}
        point_labels: Array of labels for the flattened points (for visualization)
        all_points: Array of coordinates (for visualization)
    """
    
    if not gmm:
        # n_jobs=-1 uses all CPU cores.
        # clustering = AffinityPropagation(damping=0.9, preference=-200, max_iter=500, convergence_iter=50)
        clustering = MeanShift(bandwidth=eps, bin_seeding=True, n_jobs=-1) # eps = 9 or 12 pls, less is baaaad
        # clustering = AgglomerativeClustering(n_clusters=None, distance_threshold=eps, linkage='ward') 
        # clustering = DBSCAN(eps=eps, min_samples=5)
        # clustering = DBSCAN(eps=6, min_samples=1)

        clustering.fit(all_points)
        point_labels = clustering.labels_

    if gmm:
        # get the optimal number of components
        bgmm = BayesianGaussianMixture(
            n_components=max(len(all_points), 1) - 1, 
            random_state=42,
            covariance_type='spherical',
        )

        bgmm.fit(all_points)

        active_clusters = sum(bgmm.weights_ > 0.1) # Check how many clusters are actually used - how many are composed of >10% of points
        clustering = BayesianGaussianMixture(
            n_components=max(active_clusters, 1), 
            random_state=42,
            covariance_type='spherical',
        )

        point_labels = clustering.fit_predict(all_points)
    
    # Majority Vote (Propagate to Atoms)
    atom_labels = {}
    
    # Get unique atom IDs present in the data
    unique_atoms = np.unique(point_to_atom_map)
    
    for atom_id in unique_atoms:
        # 1. Find indices in the master array belonging to this atom
        indices = np.where(point_to_atom_map == atom_id)[0]
        
        # 2. Extract the cluster labels for these points
        current_labels = point_labels[indices]
        
        # 3. Determine the most common label (majority vote)
        counts = Counter(current_labels)
        majority_label = counts.most_common(1)[0][0]
        atom_labels[atom_id] = majority_label

    return atom_labels

aal_prot = {
    "ALA", "ARG", "ASN", "ASP", "CYS", "GLN", "GLU", "GLY", "HIS", "ILE", 
    "LEU", "LYS", "MET", "PHE", "PRO", "SER", "THR", "TRP", "TYR", "VAL",
    "ASH", "GLH", "HIE", "HID", "HIP", "LYN", "CYX", "CYM", "TYM"
}
# Keeps only standard protein residues in the structure
def keep_only_protein(structure):
    """Keep only standard protein residues in the structure."""
    for residue in list(structure):
        if residue.get_resname() not in aal_prot:
            structure.detach_child(residue.id)
    return structure

def get_protein_surface_points(pdb_id, chain_id, predicted_binding_sites):
    p = MMCIFParser(QUIET=1)
    struct = p.get_structure("protein", f"{CIF_FILES}/{pdb_id}.cif")
    struct = struct[0][chain_id]  # Get first model, chain A
    struct = keep_only_protein(struct)

    # compute SASA
    sr = ShrakeRupley(n_points=POINTS_DENSITY_PER_ATOM, probe_radius=PROBE_RADIUS)
    sr.compute(struct, level="A")

    surface_points = []
    map_surface_points_to_atom_id = []
    atom_coords = {}
    residue_coords = {}
    map_atoms_to_residue_id = {}
    for residue in struct.get_residues():
        # consider only residues from predicted binding sites
        residue_id = residue.get_id()[1]
        
        if 'CA' in residue:
            residue_coords[residue_id] = residue['CA'].get_vector()
        else:
            # if no CA atom, use the first atom's coordinates
            first_atom = next(residue.get_atoms())
            residue_coords[residue_id] = first_atom.get_vector()
        
        if residue.get_id()[1] not in predicted_binding_sites:
            continue
        
        # get surface points for each atom in the residue
        for atom in residue.get_atoms():
            atom_id = atom.get_serial_number()
            surface_points.append(atom.sasa_points)
            map_surface_points_to_atom_id.extend([atom_id] * len(atom.sasa_points))
            atom_coords[atom_id] = atom.get_vector()
            map_atoms_to_residue_id[atom_id] = residue_id

    surface_points = np.vstack(surface_points)
    map_surface_points_to_atom_id = np.array(map_surface_points_to_atom_id)
    return surface_points, map_surface_points_to_atom_id, map_atoms_to_residue_id, atom_coords, residue_coords

# %% [markdown]
# ## try out approach from `src/B-evaluate-cryptoshow/residue-level-evaluation.ipynb`
# Don't pre-cluster the results first, use the smoothing without clustering.

# %%
ESM_EMBEDDINGS_PATH = '/home/skrhakv/cryptic-nn/data/cryptobench/embeddings'
COORDINATES_DIR = '/home/skrhakv/cryptoshow-analysis/data/A-cluster-ligysis-data/coordinates'
POSITIVE_DISTANCE_THRESHOLD = 10
PRECALCULATED = True
PRECALCULATED_PATH = '/home/skrhakv/cryptoshow-analysis/data/B-evaluate-cryptoshow/predictions/finetuning-without-smoothing'
DECISION_THRESHOLD = 0.7

model = torch.load(MODEL_PATH, weights_only=False)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

binding_residues, sequences = eval_utils.read_test_binding_residues()

predicted_binding_sites = {}
ranks = {}
prediction_scores = {}

K = 2

DCCs_N = []
DCCs_N_plus_K = []
DCCs = []
number_of_overlapping_predictions_on_actual_pocket = []
number_of_overlapping_actual_sites_on_predicted_pocket = []
best_residue_overlaps = []

for i, protein_id in enumerate(sequences.keys()):
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    embeddings_path = f'{ESM_EMBEDDINGS_PATH}/{pdb_id}{chain_id}.npy'
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'
    actual_binding_sites = [np.array([int(i.split('_')[1]) for i in pocket]) for pocket in binding_residues[protein_id]]
    
    print(f'Processing {protein_id} ({i+1}/{len(sequences)})...')
    if not PRECALCULATED:
        # finetuned prediction
        probabilities = eval_utils.compute_prediction(
            sequence,
            f'/tmp/skrhakv',
            model,
            tokenizer
        )
    else:
        # load precalculated prediction
        probabilities = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')
    
    prediction_scores[protein_id] = probabilities

    coordinates = np.load(coordinates_path)
    distance_matrix = eval_utils.compute_distance_matrix(coordinates)

    predictions = (probabilities > DECISION_THRESHOLD).astype(float)
    predictions_copy = predictions.copy()

    assert distance_matrix.shape[0] == distance_matrix.shape[1]
    assert distance_matrix.shape[0] == predictions_copy.shape[0]
    
    X_test = np.load(embeddings_path)
    if X_test.shape[0] != distance_matrix.shape[0]:
        print(f"Skipping {protein_id} due to embedding/coordinate size mismatch.")
        continue
    # assert X_test.shape[0] == distance_matrix.shape[0]

    # loop over the residues that are not binding and are potential candidates for smoothing
    additional_residues = []
    for residue_idx in np.where(predictions == 0.0)[0]:

        # get the embedding of the residue
        current_residue_embedding = X_test[residue_idx]

        # get the close binding residues
        close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
        close_binding_residues_indices = np.intersect1d(close_residues_indices, np.where(predictions == 1.0)[0])
        # create embedding 
        if len(close_binding_residues_indices) == 0:
            # no close binding residues - skip this residue
            continue
        elif len(close_binding_residues_indices) == 1:
            surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
        else:
            # get the mean of the close binding residues
            surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

        concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(device)
        
        # get the prediction
        test_logits = smoothing_model(concatenated_embedding).squeeze()
        result = (torch.sigmoid(test_logits)>eval_utils.SMOOTHING_DECISION_THRESHOLD).float()
        if result == 1:
            # set the residue as binding
            print(f"Smoothing changed residue {residue_idx} in protein {protein_id} to binding")
            additional_residues.append(residue_idx)
            predictions_copy[residue_idx] = 1

    indices_above_threshold = np.where(predictions_copy > DECISION_THRESHOLD)[0] # this gets residues that are equal to 1
    # no predicted residues - continue
    if len(indices_above_threshold) == 0:
        continue

    # run atom-level clustering and return residue-level pockets
    clusters, cluster_residues, cluster_scores, atom_coords, residue_coords = execute_atom_clustering(
        pdb_id,
        chain_id,
        indices_above_threshold,
        probabilities[indices_above_threshold],
        eps=9
    )

    # none of the residues are on the surface
    if cluster_residues is None:
        continue

    cluster_residues = cryptoshow_utils.map_auth_to_mmcif_numbering_array(
        pdb_id,
        chain_id,
        cluster_residues.values(),
        binding_residues_are_integers=True,
        numbers_only=True
    )[0]

    cluster_order = np.argsort(cluster_scores)[::-1]  # descending order
    N = len(actual_binding_sites)

    selected_clusters_N = cluster_order[:N]
    selected_clusters_N_plus_K = cluster_order[:N+K]

    predicted_centers = {}
    for cluster_label, atom_indices in clusters.items():
        cluster_coords = np.array([atom_coords[atom_id] for atom_id in atom_indices])
        cluster_center = np.mean(cluster_coords, axis=0).get_array()
        predicted_centers[cluster_label] = cluster_center
    
    actual_centers = []

    for pocket in actual_binding_sites:
        pocket_coords = coordinates[pocket]
        pocket_center = np.mean(pocket_coords, axis=0)
        actual_centers.append(pocket_center)
    
    for i, center in enumerate(actual_centers):
        DCC_N = float('inf')
        for j in selected_clusters_N:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N:
                DCC_N = distance
        
        if DCC_N != float('inf'):
            DCCs_N.append(DCC_N)

        DCC_N_plus_K = float('inf')
        for j in selected_clusters_N_plus_K:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N_plus_K:
                DCC_N_plus_K = distance
        
        if DCC_N_plus_K != float('inf'):
            DCCs_N_plus_K.append(DCC_N_plus_K)

        DCC = float('inf')
        for j, predicted_center in predicted_centers.items():
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC:
                DCC = distance    

        if DCC != float('inf'):
            DCCs.append(DCC)

    # actual_binding_sites_auth = cryptoshow_utils.map_mmcif_numbering_to_auth_array(
    #     pdb_id,
    #     chain_id,
    #     actual_binding_sites
    # )
    # print(actual_binding_sites_auth, actual_binding_sites)
    for pocket in actual_binding_sites:
        number_of_predicted_pockets = 0
        best_residue_overlap = 0
        for residues in cluster_residues:
            residue_overlap = len(set(pocket).intersection(residues)) / len(pocket)
            if residue_overlap > best_residue_overlap:
                best_residue_overlap = residue_overlap
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_actual_sites_on_predicted_pocket.append(number_of_predicted_pockets)
        if best_residue_overlap > 0:
            best_residue_overlaps.append(best_residue_overlap)

    for residues in cluster_residues:
        number_of_predicted_pockets = 0
        for pocket in actual_binding_sites:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_predictions_on_actual_pocket.append(number_of_predicted_pockets)

    with open(f'/home/skrhakv/cryptoshow-analysis/data/F-clustering/predictions/cryptobench-with-clustering/{protein_id.replace("_", "")}.pkl', 'wb') as f:
        pickle.dump((cluster_residues, additional_residues), f)
# Out:
# Processing 7qoq_A (1/184)...
# Smoothing changed residue 70 in protein 7qoq_A to binding
# Smoothing changed residue 71 in protein 7qoq_A to binding
# Smoothing changed residue 74 in protein 7qoq_A to binding
# Smoothing changed residue 76 in protein 7qoq_A to binding
# Processing 8i84_B (2/184)...
# Smoothing changed residue 38 in protein 8i84_B to binding
# Smoothing changed residue 42 in protein 8i84_B to binding
# Smoothing changed residue 91 in protein 8i84_B to binding
# Smoothing changed residue 94 in protein 8i84_B to binding
# Smoothing changed residue 96 in protein 8i84_B to binding
# Smoothing changed residue 97 in protein 8i84_B to binding
# Smoothing changed residue 98 in protein 8i84_B to binding
# Smoothing changed residue 59 in protein 1kx9_A to binding
# Smoothing changed residue 80 in protein 1kx9_A to binding
# Smoothing changed residue 83 in protein 1kx9_A to binding
# Smoothing changed residue 97 in protein 1kx9_A to binding
# Processing 1kxr_A (14/184)...
# Smoothing changed residue 149 in protein 1kxr_A to binding
# Smoothing changed residue 154 in protein 1kxr_A to binding
# Smoothing changed residue 176 in protein 1kxr_A to binding
# Smoothing changed residue 219 in protein 1kxr_A to binding
# Smoothing changed residue 221 in protein 1kxr_A to binding
# Smoothing changed residue 241 in protein 1kxr_A to binding
# Smoothing changed residue 242 in protein 1kxr_A to binding
# Smoothing changed residue 262 in protein 1kxr_A to binding
# Processing 1ute_A (15/184)...
# Processing 7f4y_B (16/184)...
# Smoothing changed residue 215 in protein 7f4y_B to binding
# Smoothing changed residue 326 in protein 7f4y_B to binding
# Smoothing changed residue 683 in protein 7f4y_B to binding
# Processing 7nlx_A (17/184)...
# Smoothing changed residue 101 in protein 7nlx_A to binding
# Smoothing changed residue 103 in protein 7nlx_A to binding
# Smoothing changed residue 146 in protein 7nlx_A to binding
# Smoothing changed residue 208 in protein 7nlx_A to binding
# Smoothing changed residue 211 in protein 7nlx_A to binding
# Smoothing changed residue 213 in protein 7nlx_A to binding
# Processing 1se8_A (18/184)...
# Processing 7xgf_E (19/184)...
# Smoothing changed residue 40 in protein 7xgf_E to binding
# Smoothing changed residue 51 in protein 7xgf_E to binding
# Smoothing changed residue 55 in protein 7xgf_E to binding
# Smoothing changed residue 59 in protein 7xgf_E to binding
# Smoothing changed residue 62 in protein 7xgf_E to binding
# Smoothing changed residue 64 in protein 7xgf_E to binding
# Smoothing changed residue 93 in protein 7xgf_E to binding
# Smoothing changed residue 96 in protein 7xgf_E to binding
# Smoothing changed residue 128 in protein 7xgf_E to binding
# Smoothing changed residue 137 in protein 7xgf_E to binding
# Smoothing changed residue 140 in protein 7xgf_E to binding
# Smoothing changed residue 141 in protein 7xgf_E to binding
# Smoothing changed residue 142 in protein 7xgf_E to binding
# Smoothing changed residue 145 in protein 7xgf_E to binding
# Smoothing changed residue 146 in protein 7xgf_E to binding
# Processing 5yj2_C (20/184)...
# Smoothing changed residue 64 in protein 5yj2_C to binding
# Processing 7e5q_B (21/184)...
# Smoothing changed residue 158 in protein 7e5q_B to binding
# Smoothing changed residue 169 in protein 7e5q_B to binding
# Smoothing changed residue 177 in protein 7e5q_B to binding
# Smoothing changed residue 234 in protein 7e5q_B to binding
# Smoothing changed residue 262 in protein 7e5q_B to binding
# Processing 5e0v_A (22/184)...
# Processing 6jq9_B (23/184)...
# Processing 7o1i_A (24/184)...
# Smoothing changed residue 30 in protein 7o1i_A to binding
# Smoothing changed residue 39 in protein 7o1i_A to binding
# Smoothing changed residue 68 in protein 7o1i_A to binding
# Smoothing changed residue 70 in protein 7o1i_A to binding
# Smoothing changed residue 77 in protein 7o1i_A to binding
# Smoothing changed residue 117 in protein 7o1i_A to binding
# Smoothing changed residue 122 in protein 7o1i_A to binding
# Smoothing changed residue 305 in protein 7o1i_A to binding
# Smoothing changed residue 126 in protein 1nd7_A to binding
# Processing 4fkm_B (38/184)...
# Smoothing changed residue 84 in protein 4fkm_B to binding
# Smoothing changed residue 202 in protein 4fkm_B to binding
# Smoothing changed residue 235 in protein 4fkm_B to binding
# Processing 2phz_A (39/184)...
# Processing 3mwg_B (40/184)...
# Smoothing changed residue 147 in protein 3mwg_B to binding
# Smoothing changed residue 253 in protein 3mwg_B to binding
# Processing 2vl2_C (41/184)...
# Smoothing changed residue 41 in protein 2vl2_C to binding
# Processing 6bty_B (42/184)...
# Processing 2fhz_B (43/184)...
# Smoothing changed residue 37 in protein 2fhz_B to binding
# Processing 5caz_A (44/184)...
# Processing 3n4u_A (45/184)...
# Smoothing changed residue 27 in protein 3n4u_A to binding
# Smoothing changed residue 77 in protein 3n4u_A to binding
# Smoothing changed residue 98 in protein 3n4u_A to binding
# Smoothing changed residue 203 in protein 3n4u_A to binding
# Smoothing changed residue 270 in protein 3n4u_A to binding
# Smoothing changed residue 274 in protein 3n4u_A to binding
# Processing 6fc2_C (46/184)...
# Smoothing changed residue 54 in protein 6fc2_C to binding
# Smoothing changed residue 55 in protein 6fc2_C to binding
# Smoothing changed residue 84 in protein 6fc2_C to binding
# Smoothing changed residue 85 in protein 6fc2_C to binding
# Smoothing changed residue 125 in protein 6fc2_C to binding
# Smoothing changed residue 131 in protein 6fc2_C to binding
# Smoothing changed residue 165 in protein 6fc2_C to binding
# Smoothing changed residue 166 in protein 6fc2_C to binding
# Smoothing changed residue 171 in protein 6fc2_C to binding
# Smoothing changed residue 172 in protein 6fc2_C to binding
# Smoothing changed residue 173 in protein 6fc2_C to binding
# Processing 4hye_A (47/184)...
# Smoothing changed residue 16 in protein 4hye_A to binding
# Smoothing changed residue 169 in protein 4hye_A to binding
# Processing 1i7n_A (48/184)...
# Smoothing changed residue 111 in protein 1i7n_A to binding
# Smoothing changed residue 228 in protein 1i7n_A to binding
# Processing 1vsn_A (49/184)...
# Smoothing changed residue 20 in protein 1vsn_A to binding
# Smoothing changed residue 23 in protein 1vsn_A to binding
# Smoothing changed residue 25 in protein 1vsn_A to binding
# Smoothing changed residue 59 in protein 1vsn_A to binding
# Smoothing changed residue 60 in protein 1vsn_A to binding
# Smoothing changed residue 136 in protein 1vsn_A to binding
# Smoothing changed residue 162 in protein 1vsn_A to binding
# Processing 2d05_A (50/184)...
# Processing 1ksg_B (51/184)...
# Smoothing changed residue 13 in protein 1ksg_B to binding
# Smoothing changed residue 108 in protein 1ksg_B to binding
# Processing 3flg_A (52/184)...
# Smoothing changed residue 14 in protein 3flg_A to binding
# Smoothing changed residue 22 in protein 3flg_A to binding
# Smoothing changed residue 57 in protein 3flg_A to binding
# Smoothing changed residue 73 in protein 3flg_A to binding
# Smoothing changed residue 75 in protein 3flg_A to binding
# Smoothing changed residue 76 in protein 3flg_A to binding
# Smoothing changed residue 78 in protein 3flg_A to binding
# Smoothing changed residue 80 in protein 3flg_A to binding
# Smoothing changed residue 83 in protein 3flg_A to binding
# Smoothing changed residue 84 in protein 3flg_A to binding
# Smoothing changed residue 85 in protein 3flg_A to binding
# Smoothing changed residue 70 in protein 1xtc_A to binding
# Smoothing changed residue 113 in protein 1xtc_A to binding
# Processing 8aeq_A (69/184)...
# Smoothing changed residue 134 in protein 8aeq_A to binding
# Smoothing changed residue 135 in protein 8aeq_A to binding
# Smoothing changed residue 339 in protein 8aeq_A to binding
# Smoothing changed residue 383 in protein 8aeq_A to binding
# Processing 2dfp_A (70/184)...
# Smoothing changed residue 119 in protein 2dfp_A to binding
# Smoothing changed residue 200 in protein 2dfp_A to binding
# Smoothing changed residue 286 in protein 2dfp_A to binding
# Processing 5tvi_V (71/184)...
# Processing 2v6m_D (72/184)...
# Smoothing changed residue 5 in protein 2v6m_D to binding
# Smoothing changed residue 30 in protein 2v6m_D to binding
# Smoothing changed residue 36 in protein 2v6m_D to binding
# Smoothing changed residue 78 in protein 2v6m_D to binding
# Smoothing changed residue 111 in protein 2v6m_D to binding
# Smoothing changed residue 137 in protein 2v6m_D to binding
# Smoothing changed residue 213 in protein 2v6m_D to binding
# Processing 2rfj_B (73/184)...
# Smoothing changed residue 18 in protein 2rfj_B to binding
# Smoothing changed residue 30 in protein 2rfj_B to binding
# Smoothing changed residue 44 in protein 2rfj_B to binding
# Smoothing changed residue 76 in protein 2rfj_B to binding
# Smoothing changed residue 82 in protein 2rfj_B to binding
# Processing 7x0g_B (74/184)...
# Smoothing changed residue 72 in protein 7x0g_B to binding
# Processing 6vle_A (75/184)...
# Smoothing changed residue 108 in protein 6vle_A to binding
# Smoothing changed residue 112 in protein 6vle_A to binding
# Smoothing changed residue 115 in protein 6vle_A to binding
# Smoothing changed residue 141 in protein 6vle_A to binding
# Smoothing changed residue 292 in protein 6vle_A to binding
# Smoothing changed residue 351 in protein 6vle_A to binding
# Smoothing changed residue 358 in protein 6vle_A to binding
# Processing 5acv_B (76/184)...
# Processing 6g6y_A (77/184)...
# Smoothing changed residue 11 in protein 6g6y_A to binding
# Smoothing changed residue 14 in protein 6g6y_A to binding
# Smoothing changed residue 49 in protein 6g6y_A to binding
# Smoothing changed residue 140 in protein 6g6y_A to binding
# Smoothing changed residue 195 in protein 6g6y_A to binding
# Smoothing changed residue 198 in protein 6g6y_A to binding
# Smoothing changed residue 199 in protein 6g6y_A to binding
# Smoothing changed residue 209 in protein 6g6y_A to binding
# Smoothing changed residue 291 in protein 6g6y_A to binding
# Smoothing changed residue 292 in protein 6g6y_A to binding
# Smoothing changed residue 293 in protein 6g6y_A to binding
# Processing 5wbm_B (78/184)...
# Smoothing changed residue 179 in protein 5wbm_B to binding
# Smoothing changed residue 247 in protein 5wbm_B to binding
# Processing 2i3r_A (79/184)...
# Smoothing changed residue 97 in protein 2i3r_A to binding
# Smoothing changed residue 185 in protein 2i3r_A to binding
# Processing 7kay_A (80/184)...
# Smoothing changed residue 178 in protein 7kay_A to binding
# Smoothing changed residue 337 in protein 7kay_A to binding
# Smoothing changed residue 459 in protein 7kay_A to binding
# Smoothing changed residue 487 in protein 7kay_A to binding
# Processing 7yjc_A (81/184)...
# Smoothing changed residue 27 in protein 7yjc_A to binding
# Smoothing changed residue 224 in protein 7yjc_A to binding
# Processing 1p4v_A (98/184)...
# Smoothing changed residue 181 in protein 1p4v_A to binding
# Processing 5ey7_B (99/184)...
# Smoothing changed residue 27 in protein 5ey7_B to binding
# Smoothing changed residue 188 in protein 5ey7_B to binding
# Smoothing changed residue 218 in protein 5ey7_B to binding
# Smoothing changed residue 223 in protein 5ey7_B to binding
# Smoothing changed residue 235 in protein 5ey7_B to binding
# Smoothing changed residue 236 in protein 5ey7_B to binding
# Smoothing changed residue 239 in protein 5ey7_B to binding
# Smoothing changed residue 241 in protein 5ey7_B to binding
# Processing 2pkf_A (100/184)...
# Smoothing changed residue 15 in protein 2pkf_A to binding
# Smoothing changed residue 17 in protein 2pkf_A to binding
# Smoothing changed residue 204 in protein 2pkf_A to binding
# Smoothing changed residue 249 in protein 2pkf_A to binding
# Smoothing changed residue 251 in protein 2pkf_A to binding
# Smoothing changed residue 252 in protein 2pkf_A to binding
# Smoothing changed residue 253 in protein 2pkf_A to binding
# Processing 3idh_A (101/184)...
# Smoothing changed residue 159 in protein 3idh_A to binding
# Smoothing changed residue 286 in protein 3idh_A to binding
# Smoothing changed residue 288 in protein 3idh_A to binding
# Smoothing changed residue 409 in protein 3idh_A to binding
# Processing 4jax_F (102/184)...
# Smoothing changed residue 151 in protein 4jax_F to binding
# Smoothing changed residue 245 in protein 4jax_F to binding
# Smoothing changed residue 394 in protein 4jax_F to binding
# Processing 3w90_A (103/184)...
# Smoothing changed residue 93 in protein 3w90_A to binding
# Smoothing changed residue 124 in protein 3w90_A to binding
# Smoothing changed residue 145 in protein 3w90_A to binding
# Processing 2fem_A (104/184)...
# Smoothing changed residue 146 in protein 2fem_A to binding
# Processing 2w8n_A (105/184)...
# Smoothing changed residue 92 in protein 2w8n_A to binding
# Processing 6o4f_H (106/184)...
# Smoothing changed residue 227 in protein 6o4f_H to binding
# Smoothing changed residue 250 in protein 6o4f_H to binding
# Smoothing changed residue 251 in protein 6o4f_H to binding
# Smoothing changed residue 471 in protein 6o4f_H to binding
# Processing 6f52_A (107/184)...
# Smoothing changed residue 70 in protein 6f52_A to binding
# Smoothing changed residue 71 in protein 6f52_A to binding
# Smoothing changed residue 201 in protein 6f52_A to binding
# Smoothing changed residue 213 in protein 6f52_A to binding
# Processing 5hij_A (108/184)...
# Skipping 5hij_A due to embedding/coordinate size mismatch.
# Processing 2vqz_F (109/184)...
# Processing 6fgj_B (110/184)...
# Processing 1xgd_A (111/184)...
# Smoothing changed residue 49 in protein 1xgd_A to binding
# Smoothing changed residue 182 in protein 1xgd_A to binding
# Smoothing changed residue 212 in protein 1xgd_A to binding
# Smoothing changed residue 216 in protein 1xgd_A to binding
# Processing 3uyi_A (112/184)...
# Smoothing changed residue 20 in protein 3uyi_A to binding
# Smoothing changed residue 24 in protein 3uyi_A to binding
# Smoothing changed residue 201 in protein 3uyi_A to binding
# Smoothing changed residue 254 in protein 3uyi_A to binding
# Smoothing changed residue 258 in protein 3uyi_A to binding
# Processing 4ikv_A (113/184)...
# Smoothing changed residue 304 in protein 4ikv_A to binding
# Smoothing changed residue 308 in protein 4ikv_A to binding
# Smoothing changed residue 340 in protein 4ikv_A to binding
# Processing 8j11_X (114/184)...
# Smoothing changed residue 25 in protein 8j11_X to binding
# Smoothing changed residue 101 in protein 8j11_X to binding
# Smoothing changed residue 102 in protein 8j11_X to binding
# Smoothing changed residue 123 in protein 8j11_X to binding
# Smoothing changed residue 134 in protein 8j11_X to binding
# Smoothing changed residue 135 in protein 8j11_X to binding
# Processing 8u3n_A (115/184)...
# Smoothing changed residue 155 in protein 8u3n_A to binding
# Smoothing changed residue 220 in protein 8u3n_A to binding
# Smoothing changed residue 266 in protein 8u3n_A to binding
# Smoothing changed residue 291 in protein 8u3n_A to binding
# Smoothing changed residue 316 in protein 8u3n_A to binding
# Smoothing changed residue 317 in protein 8u3n_A to binding
# Smoothing changed residue 318 in protein 8u3n_A to binding
# Smoothing changed residue 322 in protein 8u3n_A to binding
# Smoothing changed residue 364 in protein 8u3n_A to binding
# Processing 2h7s_A (116/184)...
# Smoothing changed residue 149 in protein 2h7s_A to binding
# Smoothing changed residue 174 in protein 2h7s_A to binding
# Smoothing changed residue 240 in protein 2h7s_A to binding
# Smoothing changed residue 284 in protein 2h7s_A to binding
# Smoothing changed residue 343 in protein 2h7s_A to binding
# Smoothing changed residue 346 in protein 2h7s_A to binding
# Processing 4cmw_B (117/184)...
# Smoothing changed residue 29 in protein 4cmw_B to binding
# Smoothing changed residue 48 in protein 4cmw_B to binding
# Smoothing changed residue 83 in protein 4cmw_B to binding
# Smoothing changed residue 87 in protein 4cmw_B to binding
# Smoothing changed residue 91 in protein 4cmw_B to binding
# Smoothing changed residue 94 in protein 4cmw_B to binding
# Smoothing changed residue 95 in protein 4cmw_B to binding
# Smoothing changed residue 112 in protein 4cmw_B to binding
# Smoothing changed residue 195 in protein 4cmw_B to binding
# Smoothing changed residue 201 in protein 4cmw_B to binding
# Smoothing changed residue 204 in protein 4cmw_B to binding
# Smoothing changed residue 218 in protein 4cmw_B to binding
# Processing 7v8k_B (118/184)...
# Smoothing changed residue 79 in protein 7v8k_B to binding
# Smoothing changed residue 183 in protein 7v8k_B to binding
# Smoothing changed residue 474 in protein 7v8k_B to binding
# Processing 4uum_A (119/184)...
# Smoothing changed residue 42 in protein 4uum_A to binding
# Smoothing changed residue 69 in protein 4uum_A to binding
# Smoothing changed residue 90 in protein 4uum_A to binding
# Smoothing changed residue 152 in protein 4uum_A to binding
# Smoothing changed residue 156 in protein 4uum_A to binding
# Processing 1p4o_B (120/184)...
# Smoothing changed residue 185 in protein 1p4o_B to binding
# Processing 4ilg_A (121/184)...
# Processing 8h27_A (122/184)...
# Smoothing changed residue 32 in protein 8h27_A to binding
# Smoothing changed residue 116 in protein 8h27_A to binding
# Smoothing changed residue 133 in protein 8h27_A to binding
# Smoothing changed residue 169 in protein 8h27_A to binding
# Processing 1cwq_A (123/184)...
# Smoothing changed residue 116 in protein 1cwq_A to binding
# Smoothing changed residue 120 in protein 1cwq_A to binding
# Smoothing changed residue 184 in protein 1cwq_A to binding
# Processing 5zj4_D (124/184)...
# Smoothing changed residue 68 in protein 5zj4_D to binding
# Smoothing changed residue 121 in protein 5zj4_D to binding
# Smoothing changed residue 139 in protein 5zj4_D to binding
# Processing 2x47_A (125/184)...
# Smoothing changed residue 61 in protein 2x47_A to binding
# Smoothing changed residue 120 in protein 2x47_A to binding
# Processing 1rtc_A (126/184)...
# Processing 1p9o_A (127/184)...
# Smoothing changed residue 201 in protein 1p9o_A to binding
# Processing 7f2m_B (128/184)...
# Smoothing changed residue 70 in protein 7f2m_B to binding
# Smoothing changed residue 141 in protein 7f2m_B to binding
# Smoothing changed residue 239 in protein 7f2m_B to binding
# Smoothing changed residue 250 in protein 7f2m_B to binding
# Smoothing changed residue 258 in protein 7f2m_B to binding
# Smoothing changed residue 266 in protein 7f2m_B to binding
# Smoothing changed residue 267 in protein 7f2m_B to binding
# Smoothing changed residue 275 in protein 7f2m_B to binding
# Smoothing changed residue 277 in protein 7f2m_B to binding
# Smoothing changed residue 281 in protein 7f2m_B to binding
# Processing 2vyr_A (129/184)...
# Skipping 2vyr_A due to embedding/coordinate size mismatch.
# Processing 4r0x_A (130/184)...
# Smoothing changed residue 51 in protein 4r0x_A to binding
# Smoothing changed residue 64 in protein 4r0x_A to binding
# Processing 4nzv_B (131/184)...
# Processing 3fzo_A (132/184)...
# Smoothing changed residue 52 in protein 3fzo_A to binding
# Smoothing changed residue 60 in protein 3fzo_A to binding
# Processing 3nx1_B (133/184)...
# Smoothing changed residue 20 in protein 3nx1_B to binding
# Smoothing changed residue 49 in protein 3nx1_B to binding
# Smoothing changed residue 74 in protein 3nx1_B to binding
# Smoothing changed residue 88 in protein 3nx1_B to binding
# Smoothing changed residue 91 in protein 3nx1_B to binding
# Smoothing changed residue 93 in protein 3nx1_B to binding
# Smoothing changed residue 102 in protein 3nx1_B to binding
# Smoothing changed residue 103 in protein 3nx1_B to binding
# Smoothing changed residue 107 in protein 3nx1_B to binding
# Smoothing changed residue 108 in protein 3nx1_B to binding
# Smoothing changed residue 117 in protein 3nx1_B to binding
# Smoothing changed residue 121 in protein 3nx1_B to binding
# Smoothing changed residue 129 in protein 3nx1_B to binding
# Processing 6tx0_B (134/184)...
# Smoothing changed residue 29 in protein 6tx0_B to binding
# Smoothing changed residue 101 in protein 6tx0_B to binding
# Smoothing changed residue 183 in protein 6tx0_B to binding
# Smoothing changed residue 184 in protein 6tx0_B to binding
# Smoothing changed residue 185 in protein 6tx0_B to binding
# Smoothing changed residue 197 in protein 6tx0_B to binding
# Smoothing changed residue 260 in protein 6tx0_B to binding
# Smoothing changed residue 382 in protein 6tx0_B to binding
# Smoothing changed residue 393 in protein 6tx0_B to binding
# Smoothing changed residue 424 in protein 6tx0_B to binding
# Smoothing changed residue 425 in protein 6tx0_B to binding
# Processing 3vgm_A (135/184)...
# Smoothing changed residue 76 in protein 3vgm_A to binding
# Smoothing changed residue 77 in protein 3vgm_A to binding
# Smoothing changed residue 212 in protein 3vgm_A to binding
# Smoothing changed residue 263 in protein 3vgm_A to binding
# Smoothing changed residue 296 in protein 3vgm_A to binding
# Smoothing changed residue 297 in protein 3vgm_A to binding
# Smoothing changed residue 231 in protein 8onn_E to binding
# Processing 6w10_A (177/184)...
# Smoothing changed residue 81 in protein 6w10_A to binding
# Processing 3i8s_B (178/184)...
# Smoothing changed residue 10 in protein 3i8s_B to binding
# Smoothing changed residue 57 in protein 3i8s_B to binding
# Smoothing changed residue 71 in protein 3i8s_B to binding
# Smoothing changed residue 93 in protein 3i8s_B to binding
# Smoothing changed residue 118 in protein 3i8s_B to binding
# Smoothing changed residue 151 in protein 3i8s_B to binding
# Processing 5z18_C (179/184)...
# Smoothing changed residue 167 in protein 5z18_C to binding
# Smoothing changed residue 330 in protein 5z18_C to binding
# Smoothing changed residue 334 in protein 5z18_C to binding
# Smoothing changed residue 466 in protein 5z18_C to binding
# Smoothing changed residue 558 in protein 5z18_C to binding
# Smoothing changed residue 559 in protein 5z18_C to binding
# Processing 4e1y_A (180/184)...
# Smoothing changed residue 137 in protein 4e1y_A to binding
# Smoothing changed residue 177 in protein 4e1y_A to binding
# Smoothing changed residue 191 in protein 4e1y_A to binding
# Processing 6nei_B (181/184)...
# Smoothing changed residue 180 in protein 6nei_B to binding
# Smoothing changed residue 185 in protein 6nei_B to binding
# Smoothing changed residue 202 in protein 6nei_B to binding
# Smoothing changed residue 222 in protein 6nei_B to binding
# Smoothing changed residue 291 in protein 6nei_B to binding
# Processing 2xsa_A (182/184)...
# Smoothing changed residue 113 in protein 2xsa_A to binding
# Smoothing changed residue 156 in protein 2xsa_A to binding
# Smoothing changed residue 160 in protein 2xsa_A to binding
# Smoothing changed residue 195 in protein 2xsa_A to binding
# Smoothing changed residue 255 in protein 2xsa_A to binding
# Processing 5o8b_A (183/184)...
# Processing 3jzg_A (184/184)...

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

number_of_pockets = len(number_of_overlapping_actual_sites_on_predicted_pocket)

mean_br = np.mean(best_residue_overlaps)
median_br = np.median(best_residue_overlaps)
print(f'best_residue_overlap mean={mean_br:.4f}, median={median_br:.4f}')

print(np.sum(np.array(DCCs) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N_plus_K) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N_plus_K) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N) < 4) / number_of_pockets})')

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros = [i for i in number_of_overlapping_actual_sites_on_predicted_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Predicted Pockets Covering True Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Predicted Pockets Covering True Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_predictions_on_actual_pocket_without_zeros = [i for i in number_of_overlapping_predictions_on_actual_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_predictions_on_actual_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Actual Pockets Covering Predicted Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Actual Pockets Covering Predicted Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

# This is with EPS=9 for meanshift:

# DISTANCE=15
# with smoothing:                                           without smoothing:
# best_residue_overlap mean=0.5712, median=0.5848           best_residue_overlap mean=0.5790, median=0.5918        
# 0.8380952380952381 (0.19523809523809524)                  0.8317757009345794 (0.22429906542056074)
# 0.7904761904761904 (0.1761904761904762)                   0.8084112149532711 (0.21962616822429906)
# 0.638095238095238 (0.14761904761904762)                   0.677570093457944 (0.17757009345794392)

# DISTANCE=12
# with smoothing:                                           without smoothing:
# best_residue_overlap mean=0.5711, median=0.5603           best_residue_overlap mean=0.5790, median=0.5918
# 0.8380952380952381 (0.22380952380952382)                  0.8317757009345794 (0.22429906542056074)
# 0.8142857142857143 (0.20952380952380953)                  0.8084112149532711 (0.21962616822429906)
# 0.6333333333333333 (0.1619047619047619)                   0.677570093457944 (0.17757009345794392)

# DISTANCE=10
# with smoothing:                                           without smoothing:
# best_residue_overlap mean=0.5609, median=0.5556           best_residue_overlap mean=0.5790, median=0.5918
# 0.8523809523809524 (0.20952380952380953)                  0.8317757009345794 (0.22429906542056074)
# 0.8142857142857143 (0.19523809523809524)                  0.8084112149532711 (0.21962616822429906)
# 0.6761904761904762 (0.16666666666666666)                  0.677570093457944 (0.17757009345794392)

# DISTANCE=8
# with smoothing:                                           without smoothing:
# best_residue_overlap mean=0.5616, median=0.5556           best_residue_overlap mean=0.5790, median=0.5918
# 0.8238095238095238 (0.18095238095238095)                  0.8317757009345794 (0.22429906542056074)
# 0.7904761904761904 (0.16666666666666666)                  0.8084112149532711 (0.21962616822429906)
# 0.6571428571428571 (0.1380952380952381)                   0.677570093457944 (0.17757009345794392)

# DISTANCE=10, decision_threshold=0.7
# with smoothing:                                           without smoothing:
# best_residue_overlap mean=0.5240, median=0.5217           best_residue_overlap mean=0.4921, median=0.4749
# 0.8112244897959183 (0.20918367346938777)                  0.805 (0.22)
# 0.8112244897959183 (0.20918367346938777)                  0.805 (0.22)
# 0.7091836734693877 (0.16326530612244897)                  0.695 (0.18)


# remove scores which are below decision threshold (see execute_atom_clustering(...))
# best_residue_overlap mean=0.5619, median=0.5556
# 0.8428571428571429 (0.20952380952380953)
# 0.819047619047619 (0.20476190476190476)
# 0.6238095238095238 (0.14285714285714285)

# count each residue only once into the score (before I was counting each atom, i.e. if there was a large amino acid like
# tryptophan, it would count significantly more times into the score than a small amino acid like glycine), while removing scores
# that are below decision threshold
# with smoothing:                                           without smoothing:
# best_residue_overlap mean=0.5558, median=0.5477           best_residue_overlap mean=0.5790, median=0.5918          
# 0.8428571428571429 (0.20952380952380953)                  0.8317757009345794 (0.22429906542056074)  
# 0.8095238095238095 (0.20476190476190476)                  0.8084112149532711 (0.21962616822429906)  
# 0.5952380952380952 (0.12857142857142856)                  0.6448598130841121 (0.14953271028037382)  

# same as above, but without removing scores below decision threshold
# with smoothing:                                           without smoothing:
# best_residue_overlap mean=0.5731, median=0.5742           best_residue_overlap mean=0.5790, median=0.5918                        
# 0.8476190476190476 (0.22857142857142856)                  0.8317757009345794 (0.22429906542056074)                
# 0.8 (0.20952380952380953)                                 0.8084112149532711 (0.21962616822429906)
# 0.6428571428571429 (0.14285714285714285)                  0.6448598130841121 (0.14953271028037382)                




# DEBUG:
# before:
# best_residue_overlap mean=0.5203, median=0.5228
# 0.8112244897959183 (0.22448979591836735)
# 0.8061224489795918 (0.22448979591836735)
# 0.6785714285714286 (0.1836734693877551)

# after:
# Out:
# best_residue_overlap mean=0.5201, median=0.5179
# 0.8214285714285714 (0.22448979591836735)
# 0.8214285714285714 (0.22448979591836735)
# 0.7193877551020408 (0.18877551020408162)

# %% [markdown]
# ## Run clustering without smoothing

# %%
import pickle

ESM_EMBEDDINGS_PATH = '/home/skrhakv/cryptic-nn/data/cryptobench/embeddings'
COORDINATES_DIR = '/home/skrhakv/cryptoshow-analysis/data/A-cluster-ligysis-data/coordinates'
POSITIVE_DISTANCE_THRESHOLD = 10
PRECALCULATED = True
PRECALCULATED_PATH = '/home/skrhakv/cryptoshow-analysis/data/B-evaluate-cryptoshow/predictions/finetuning-without-smoothing'
DECISION_THRESHOLD = 0.7


model = torch.load(MODEL_PATH, weights_only=False)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

binding_residues, sequences = eval_utils.read_test_binding_residues()

predicted_binding_sites = {}
ranks = {}
prediction_scores = {}

K = 2

DCCs_N = []
DCCs_N_plus_K = []
DCCs = []
number_of_overlapping_predictions_on_actual_pocket = []
number_of_overlapping_actual_sites_on_predicted_pocket = []
best_residue_overlaps = []

for i, protein_id in enumerate(sequences.keys()):
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'
    actual_binding_sites = [np.array([int(i.split('_')[1]) for i in pocket]) for pocket in binding_residues[protein_id]]
    
    print(f'Processing {protein_id} ({i+1}/{len(sequences)})...')
    if not PRECALCULATED:
        # finetuned prediction
        probabilities = eval_utils.compute_prediction(
            sequence,
            f'/tmp/skrhakv',
            model,
            tokenizer
        )
    else:
        # load precalculated prediction
        probabilities = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')
    
    prediction_scores[protein_id] = probabilities

    coordinates = np.load(coordinates_path)
    distance_matrix = eval_utils.compute_distance_matrix(coordinates)

    predictions = (probabilities > DECISION_THRESHOLD).astype(float)
    predictions_copy = predictions.copy()

    assert distance_matrix.shape[0] == distance_matrix.shape[1]
    assert distance_matrix.shape[0] == predictions_copy.shape[0]
    
    indices_above_threshold = np.where(predictions_copy > DECISION_THRESHOLD)[0] # this gets residues that are equal to 1
    # no predicted residues - continue
    if len(indices_above_threshold) == 0:
        continue

    # run atom-level clustering and return residue-level pockets
    clusters, cluster_residues, cluster_scores, atom_coords, residue_coords = execute_atom_clustering(
        pdb_id,
        chain_id,
        indices_above_threshold,
        probabilities[indices_above_threshold],
        eps=9
    )

    # none of the residues are on the surface
    if cluster_residues is None:
        continue

    cluster_residues = cryptoshow_utils.map_auth_to_mmcif_numbering_array(
        pdb_id,
        chain_id,
        cluster_residues.values(),
        binding_residues_are_integers=True,
        numbers_only=True
    )[0]

    cluster_order = np.argsort(cluster_scores)[::-1]  # descending order
    N = len(actual_binding_sites)

    selected_clusters_N = cluster_order[:N]
    selected_clusters_N_plus_K = cluster_order[:N+K]

    predicted_centers = {}
    for cluster_label, atom_indices in clusters.items():
        cluster_coords = np.array([atom_coords[atom_id] for atom_id in atom_indices])
        cluster_center = np.mean(cluster_coords, axis=0).get_array()
        predicted_centers[cluster_label] = cluster_center
    
    actual_centers = []

    for pocket in actual_binding_sites:
        pocket_coords = coordinates[pocket]
        pocket_center = np.mean(pocket_coords, axis=0)
        actual_centers.append(pocket_center)
    
    for i, center in enumerate(actual_centers):
        DCC_N = float('inf')
        for j in selected_clusters_N:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N:
                DCC_N = distance
        
        if DCC_N != float('inf'):
            DCCs_N.append(DCC_N)

        DCC_N_plus_K = float('inf')
        for j in selected_clusters_N_plus_K:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N_plus_K:
                DCC_N_plus_K = distance
        
        if DCC_N_plus_K != float('inf'):
            DCCs_N_plus_K.append(DCC_N_plus_K)

        DCC = float('inf')
        for j, predicted_center in predicted_centers.items():
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC:
                DCC = distance    

        if DCC != float('inf'):
            DCCs.append(DCC)

    for pocket in actual_binding_sites:
        number_of_predicted_pockets = 0
        best_residue_overlap = 0
        for residues in cluster_residues:
            residue_overlap = len(set(pocket).intersection(residues)) / len(pocket)
            if residue_overlap > best_residue_overlap:
                best_residue_overlap = residue_overlap
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_actual_sites_on_predicted_pocket.append(number_of_predicted_pockets)
        if best_residue_overlap > 0:
            best_residue_overlaps.append(best_residue_overlap)

    for residues in cluster_residues:
        number_of_predicted_pockets = 0
        for pocket in actual_binding_sites:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_predictions_on_actual_pocket.append(number_of_predicted_pockets)

    with open(f'/home/skrhakv/cryptoshow-analysis/data/F-clustering/predictions/cryptobench-without-clustering/{protein_id}.pkl', 'wb') as f:
        pickle.dump(cluster_residues, f)
# Out:
# Processing 7qoq_A (1/184)...
# Processing 8i84_B (2/184)...
# Processing 5igh_A (3/184)...
# Processing 7w19_A (4/184)...
# Processing 5uxa_A (5/184)...
# Processing 3h8a_B (6/184)...
# Processing 6isu_A (7/184)...
# Processing 5yhb_A (8/184)...
# Processing 3rwv_A (9/184)...
# Processing 2i3a_D (10/184)...
# Processing 4oqo_B (11/184)...
# Processing 3gdg_B (12/184)...
# Processing 1kx9_A (13/184)...
# Processing 1kxr_A (14/184)...
# Processing 1ute_A (15/184)...
# Processing 7f4y_B (16/184)...
# Processing 7nlx_A (17/184)...
# Processing 1se8_A (18/184)...
# Processing 7xgf_E (19/184)...
# Processing 5yj2_C (20/184)...
# Processing 7e5q_B (21/184)...
# Processing 5e0v_A (22/184)...
# Processing 6jq9_B (23/184)...
# Processing 7o1i_A (24/184)...
# Processing 3ly8_A (25/184)...
# Processing 1bzj_A (26/184)...
# Processing 7c63_A (27/184)...
# Processing 7x0i_B (28/184)...
# Processing 5ysb_B (29/184)...
# Processing 3k01_A (30/184)...
# Processing 5kcg_B (31/184)...
# Processing 8b9p_A (32/184)...
# Processing 3bjp_A (33/184)...
# Processing 4uc8_A (34/184)...
# Processing 5b0e_B (35/184)...
# Processing 5yqp_A (36/184)...
# Processing 1nd7_A (37/184)...
# Processing 4fkm_B (38/184)...
# Processing 2phz_A (39/184)...
# Processing 3mwg_B (40/184)...
# Processing 2vl2_C (41/184)...
# Processing 6bty_B (42/184)...
# Processing 2fhz_B (43/184)...
# Processing 5caz_A (44/184)...
# Processing 3n4u_A (45/184)...
# Processing 6fc2_C (46/184)...
# Processing 4hye_A (47/184)...
# Processing 1i7n_A (48/184)...
# Processing 1vsn_A (49/184)...
# Processing 2d05_A (50/184)...
# Processing 1ksg_B (51/184)...
# Processing 3flg_A (52/184)...
# Processing 3t8b_A (53/184)...
# Processing 4gpi_C (54/184)...
# Processing 4gv9_A (55/184)...
# Processing 4kmy_A (56/184)...
# Processing 4mwi_A (57/184)...
# Processing 1lbe_B (58/184)...
# Processing 1zm0_A (59/184)...
# Processing 4dnc_B (60/184)...
# Processing 4ttp_A (61/184)...
# Processing 5i3t_E (62/184)...
# Processing 1arl_A (63/184)...
# Processing 6cqe_B (64/184)...
# Processing 2aka_A (65/184)...
# Processing 3ugk_A (66/184)...
# Processing 6eqj_A (67/184)...
# Processing 1xtc_A (68/184)...
# Processing 8aeq_A (69/184)...
# Processing 2dfp_A (70/184)...
# Processing 5tvi_V (71/184)...
# Processing 2v6m_D (72/184)...
# Processing 2rfj_B (73/184)...
# Processing 7x0g_B (74/184)...
# Processing 6vle_A (75/184)...
# Processing 5acv_B (76/184)...
# Processing 6g6y_A (77/184)...
# Processing 5wbm_B (78/184)...
# Processing 2i3r_A (79/184)...
# Processing 7kay_A (80/184)...
# Processing 7yjc_A (81/184)...
# Processing 1dq2_A (82/184)...
# Processing 5tc0_B (83/184)...
# Processing 7nc8_D (172/184)...
# Processing 6hei_A (173/184)...
# Processing 1e6k_A (174/184)...
# Processing 4p2f_A (175/184)...
# Processing 8onn_E (176/184)...
# Processing 6w10_A (177/184)...
# Processing 3i8s_B (178/184)...
# Processing 5z18_C (179/184)...
# Processing 4e1y_A (180/184)...
# Processing 6nei_B (181/184)...
# Processing 2xsa_A (182/184)...
# Processing 5o8b_A (183/184)...
# Processing 3jzg_A (184/184)...

# %%
import numpy as np
import matplotlib.pyplot as plt

number_of_pockets = len(number_of_overlapping_actual_sites_on_predicted_pocket)

mean_br = np.mean(best_residue_overlaps)
median_br = np.median(best_residue_overlaps)
print(f'best_residue_overlap mean={mean_br:.4f}, median={median_br:.4f}')
print(np.sum(np.array(DCCs) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N_plus_K) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N_plus_K) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N) < 4) / number_of_pockets})')

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros = [i for i in number_of_overlapping_actual_sites_on_predicted_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Predicted Pockets Covering True Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Predicted Pockets Covering True Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_predictions_on_actual_pocket_without_zeros = [i for i in number_of_overlapping_predictions_on_actual_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_predictions_on_actual_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Actual Pockets Covering Predicted Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Actual Pockets Covering Predicted Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()
# Out:
# best_residue_overlap mean=0.4921, median=0.4749
# 0.805 (0.22)
# 0.805 (0.22)
# 0.695 (0.18)
