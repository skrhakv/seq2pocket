# %%
from transformers import AutoTokenizer
import torch
import numpy as np
import functools
from sklearn import metrics
from torch.utils.data import DataLoader
import sys

PATH = '/home/skrhakv/Projects/seq2pocket'
torch.manual_seed(42)

sys.path.append(f'{PATH}/src/utils')
sys.path.append(f'{PATH}/../cryptic-nn/src')

import finetuning_utils # download from https://github.com/skrhakv/cryptic-finetuning/blob/master/src/finetuning_utils.py
from finetuning_utils import FinetunedEsmModel
import eval_utils
from eval_utils import CryptoBenchClassifier
import cryptoshow_utils
import clustering_utils

MODEL_NAME = 'facebook/esm2_t36_3B_UR50D'
device = 'cuda' if torch.cuda.is_available() else 'cpu'

MODEL_PATH = f'{PATH}/data/models/gbs-model-enhanced-scPDB-filtered.pt'

SMOOTHING_MODEL_PATH = f'{PATH}/data/models/smoother.pt'
smoothing_model = torch.load(SMOOTHING_MODEL_PATH, weights_only=False) #, map_location=torch.device('cpu'))
smoothing_model.eval()

ESM_EMBEDDINGS_PATH = f'{PATH}/data/embeddings/ligysis'
COORDINATES_DIR = f'{PATH}/data/coordinates/ligysis'
POSITIVE_DISTANCE_THRESHOLD = 15
PRECALCULATED = False
PREDICTIONS_PATH = f'{PATH}/data/predictions'
PRECALCULATED_PATH = f'{PREDICTIONS_PATH}/gbs-model'
LIGYSIS_ANNOTATION_PATH = f'{PATH}/data/data-extraction/ligysis_for_pocket_level_evaluation.csv'
DECISION_THRESHOLD = 0.7
DCC_HIT_THRESHOLD = 12.0  # Angstrom, Javier et al. Table 4 correctness gate for RRO

# %% [markdown]
# ## Run clustering with smoothing

# %%
import pickle

model = torch.load(MODEL_PATH, weights_only=False)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

binding_residues, sequences = eval_utils.read_test_binding_residues(data_path=LIGYSIS_ANNOTATION_PATH, pocket_types=['NON_CRYPTIC'])

predicted_binding_sites = {}
ranks = {}
prediction_scores = {}

K = 2

DCCs_N = []
DCCs_N_plus_K = []
DCCs = []

is_small_pocket_DCC_N = []
is_small_pocket_DCC_N_plus_K = []
is_small_pocket_DCC = []

number_of_added_residues = []

number_of_overlapping_predictions_on_actual_pocket = []
number_of_overlapping_actual_sites_on_predicted_pocket = []
best_residue_overlaps = []

for i, protein_id in enumerate(sequences.keys()):
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    embeddings_path = f'{ESM_EMBEDDINGS_PATH}/{pdb_id}{chain_id}.npy'
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'
    actual_binding_sites = [np.array([int(i.split('_')[1]) for i in pocket]) for pocket in binding_residues[protein_id]]
    
    print(f'Processing {protein_id} ({i+1}/{len(sequences)})...')
    if not PRECALCULATED:
        # finetuned prediction
        probabilities = eval_utils.compute_prediction(
            sequence,
            model,
            tokenizer
        )
    else:
        # load precalculated prediction
        probabilities = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')
    
    prediction_scores[protein_id] = probabilities

    coordinates = np.load(coordinates_path)
    distance_matrix = eval_utils.compute_distance_matrix(coordinates)

    predictions = (probabilities > DECISION_THRESHOLD).astype(float)
    predictions_copy = predictions.copy()

    assert distance_matrix.shape[0] == distance_matrix.shape[1]
    assert distance_matrix.shape[0] == predictions_copy.shape[0]
    
    X_test = np.load(embeddings_path)
    assert X_test.shape[0] == distance_matrix.shape[0]

    # loop over the residues that are not binding and are potential candidates for smoothing
    additional_residues = []
    added_residues_count = 0
    for residue_idx in np.where(predictions == 0.0)[0]:

        # get the embedding of the residue
        current_residue_embedding = X_test[residue_idx]

        # get the close binding residues
        close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
        close_binding_residues_indices = np.intersect1d(close_residues_indices, np.where(predictions == 1.0)[0])
        # create embedding 
        if len(close_binding_residues_indices) == 0:
            # no close binding residues - skip this residue
            continue
        elif len(close_binding_residues_indices) == 1:
            surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
        else:
            # get the mean of the close binding residues
            surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

        concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(device)
        
        # get the prediction
        test_logits = smoothing_model(concatenated_embedding).squeeze()
        result = (torch.sigmoid(test_logits)>eval_utils.SMOOTHING_DECISION_THRESHOLD).float()
        if result == 1:
            # set the residue as binding
            # print(f"Smoothing changed residue {residue_idx} in protein {protein_id} to binding")
            additional_residues.append(residue_idx)
            predictions_copy[residue_idx] = 1
            added_residues_count += 1

    number_of_added_residues.append(added_residues_count)
    
    indices_above_threshold = np.where(predictions_copy > DECISION_THRESHOLD)[0] # this gets residues that are equal to 1
    # no predicted residues - continue
    if len(indices_above_threshold) == 0:
        continue

    # run atom-level clustering and return residue-level pockets
    clusters, cluster_residues, cluster_scores, atom_coords, residue_coords = clustering_utils.execute_atom_clustering(
        pdb_id,
        chain_id,
        indices_above_threshold,
        probabilities[indices_above_threshold],
        eps=9
    )

    # none of the residues are on the surface
    if cluster_residues is None:
        continue

    cluster_residues = cryptoshow_utils.map_auth_to_mmcif_numbering_array(
        pdb_id,
        chain_id,
        cluster_residues.values(),
        binding_residues_are_integers=True,
        numbers_only=True
    )[0]

    cluster_order = np.argsort(cluster_scores)[::-1]  # descending order
    N = len(actual_binding_sites)

    selected_clusters_N = cluster_order[:N]
    selected_clusters_N_plus_K = cluster_order[:N+K]

    predicted_centers = {}
    for cluster_label, atom_indices in clusters.items():
        cluster_coords = np.array([atom_coords[atom_id] for atom_id in atom_indices])
        cluster_center = np.mean(cluster_coords, axis=0).get_array()
        predicted_centers[cluster_label] = cluster_center
    
    actual_centers = []
    is_small_pocket = []
    for pocket in actual_binding_sites:
        pocket_coords = coordinates[pocket]
        pocket_center = np.mean(pocket_coords, axis=0)
        actual_centers.append(pocket_center)
        is_small_pocket.append(len(pocket) < 10)
    
    for i, center in enumerate(actual_centers):
        DCC_N = float('inf')
        for j in selected_clusters_N:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N:
                DCC_N = distance
        
        if DCC_N != float('inf'):
            DCCs_N.append(DCC_N)
            is_small_pocket_DCC_N.append(is_small_pocket[i])

        DCC_N_plus_K = float('inf')
        for j in selected_clusters_N_plus_K:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N_plus_K:
                DCC_N_plus_K = distance
        
        if DCC_N_plus_K != float('inf'):
            DCCs_N_plus_K.append(DCC_N_plus_K)
            is_small_pocket_DCC_N_plus_K.append(is_small_pocket[i])

            
    dcc_rro_matches = clustering_utils.compute_dcc_matched_rro(
        actual_binding_sites, actual_centers, predicted_centers, cluster_residues,
        dcc_hit_threshold=DCC_HIT_THRESHOLD,
    )
    for i, match in enumerate(dcc_rro_matches):
        if match['dcc'] != float('inf'):
            DCCs.append(match['dcc'])
            is_small_pocket_DCC.append(is_small_pocket[i])
        if match['rro'] is not None:
            best_residue_overlaps.append(match['rro'])

    for pocket in actual_binding_sites:
        number_of_predicted_pockets = 0
        for residues in cluster_residues:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_actual_sites_on_predicted_pocket.append(number_of_predicted_pockets)

    for residues in cluster_residues:
        number_of_predicted_pockets = 0
        for pocket in actual_binding_sites:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_predictions_on_actual_pocket.append(number_of_predicted_pockets)

    with open(f'{PATH}/data/visualizations/predictions/ligysis/{protein_id.replace("_", "")}.pkl', 'wb') as f:
        pickle.dump((cluster_residues, additional_residues), f)
# Out:
# Processing 1a52_A (1/2775)...
# Processing 1a9w_E (2/2775)...
# Processing 1aii_A (3/2775)...
# Processing 1au1_A (4/2775)...
# Processing 1aue_B (5/2775)...
# Processing 1b1c_A (6/2775)...
# Processing 1b50_B (7/2775)...
# Processing 1b55_B (8/2775)...
# Processing 1b6c_F (9/2775)...
# Processing 1b9o_A (10/2775)...
# Processing 1bbo_A (11/2775)...
# Processing 1bci_A (12/2775)...
# Processing 1bf9_A (13/2775)...
# Processing 1bhi_A (14/2775)...
# Processing 1bld_A (15/2775)...
# Processing 1blx_A (16/2775)...
# Processing 1bmo_A (17/2775)...
# Processing 1bnl_A (18/2775)...
# Processing 1boy_A (19/2775)...
# Processing 1bp5_A (20/2775)...
# Processing 1buv_M (21/2775)...
# Processing 1byg_A (22/2775)...
# Processing 1bzs_A (23/2775)...
# Processing 1c07_A (24/2775)...
# Processing 1c4z_A (25/2775)...
# Processing 1c9y_A (26/2775)...
# Processing 1cb6_A (27/2775)...
# Processing 1cjy_B (28/2775)...
# Processing 1cm8_A (29/2775)...
# Processing 1cr8_A (30/2775)...
# Processing 1cws_A (31/2775)...
# Processing 1cx8_C (32/2775)...
# Processing 1cza_N (33/2775)...
# Processing 1czv_A (34/2775)...
# Processing 1d1s_A (35/2775)...
# Processing 1d4u_A (36/2775)...
# Processing 1d5g_A (37/2775)...
# Processing 1drf_A (38/2775)...
# Processing 1ds6_A (39/2775)...
# Processing 1dsz_A (40/2775)...
# Processing 1dtw_B (41/2775)...
# Processing 1dxt_D (42/2775)...
# Processing 1e0o_D (43/2775)...
# Processing 1e17_A (44/2775)...
# Processing 1e9t_A (45/2775)...
# Processing 1eh2_A (46/2775)...
# Processing 1ek6_A (47/2775)...
# Processing 1emn_A (48/2775)...
# Processing 1equ_A (49/2775)...
# Processing 1eub_A (50/2775)...
# Processing 1rnf_B (214/2775)...
# Processing 1ro4_A (215/2775)...
# Processing 1rtg_A (216/2775)...
# Processing 1rx0_D (217/2775)...
# Processing 1rxr_A (218/2775)...
# Processing 1s18_A (219/2775)...
# Processing 1s4b_P (220/2775)...
# Processing 1s4y_B (221/2775)...
# Processing 1s9i_A (222/2775)...
# Processing 1sg4_B (223/2775)...
# Processing 1shr_D (224/2775)...
# Processing 1siq_A (225/2775)...
# Processing 1sl6_E (226/2775)...
# Processing 1smo_B (227/2775)...
# Processing 1so0_B (228/2775)...
# Processing 1soj_I (229/2775)...
# Processing 1sp2_A (230/2775)...
# Processing 1st0_A (231/2775)...
# Processing 1su3_A (232/2775)...
# Processing 1szb_B (233/2775)...
# Processing 1t3n_B (234/2775)...
# Processing 1t6b_Y (235/2775)...
# Processing 1t8c_A (236/2775)...
# Processing 1tff_A (237/2775)...
# Processing 1tfi_A (238/2775)...
# Processing 1tg6_C (239/2775)...
# Processing 1tjj_A (240/2775)...
# Processing 1toz_A (241/2775)...
# Processing 1tpk_C (242/2775)...
# Processing 1ttx_A (243/2775)...
# Processing 1tu4_C (244/2775)...
# Processing 1tvx_D (245/2775)...
# Processing 1u31_A (246/2775)...
# Processing 1u3t_A (247/2775)...
# Processing 1u7f_B (248/2775)...
# Processing 1u7t_D (249/2775)...
# Processing 1ubd_C (250/2775)...
# Processing 1ul1_Z (251/2775)...
# Processing 1umk_A (252/2775)...
# Processing 1upr_A (253/2775)...
# Processing 1ur6_B (254/2775)...
# Processing 1uv0_A (255/2775)...
# Processing 1uvq_B (256/2775)...
# Processing 1uw5_A (257/2775)...
# Processing 1uzj_B (258/2775)...
# Processing 1v5h_A (259/2775)...
# Processing 1v84_A (260/2775)...
# Processing 1vd4_A (261/2775)...
# Processing 1vhr_A (262/2775)...
# Processing 1vtn_C (263/2775)...
# Processing 1w1h_C (264/2775)...
# Processing 1w45_B (265/2775)...
# Processing 1w4r_A (266/2775)...
# Processing 1w4u_A (267/2775)...
# Processing 1w6j_A (268/2775)...
# Processing 1war_A (269/2775)...
# Processing 1wch_A (270/2775)...
# Processing 1wl4_A (271/2775)...
# Processing 1wlj_A (272/2775)...
# Processing 1woj_A (273/2775)...
# Processing 1wq1_G (274/2775)...
# Processing 1wsr_A (275/2775)...
# Processing 1x03_A (276/2775)...
# Processing 1x3c_A (277/2775)...
# Processing 1x3s_A (278/2775)...
# Processing 1x61_A (279/2775)...
# Processing 1x6e_A (280/2775)...
# Processing 1x9d_A (281/2775)...
# Processing 1xa6_A (282/2775)...
# Processing 1xc5_A (283/2775)...
# Processing 1xcr_A (284/2775)...
# Processing 1xd3_A (285/2775)...
# Processing 1xd4_A (286/2775)...
# Processing 1xgd_A (287/2775)...
# Processing 1xpw_A (288/2775)...
# Processing 1xrj_A (289/2775)...
# Processing 1xvp_B (290/2775)...
# Processing 1xw6_D (291/2775)...
# Processing 1xwi_A (292/2775)...
# Processing 1y02_A (293/2775)...
# Processing 1y4j_B (294/2775)...
# Processing 1yb1_B (295/2775)...
# Processing 2cxy_A (378/2775)...
# Processing 2czh_B (379/2775)...
# Processing 2d07_A (380/2775)...
# Processing 2d7i_A (381/2775)...
# Processing 2dar_A (382/2775)...
# Processing 2dho_A (383/2775)...
# Processing 2dj7_A (384/2775)...
# Processing 2dko_B (385/2775)...
# Processing 2dlk_A (386/2775)...
# Processing 2dq7_X (387/2775)...
# Processing 2dud_B (388/2775)...
# Processing 2e2x_B (389/2775)...
# Processing 2e59_A (390/2775)...
# Processing 2e5s_A (391/2775)...
# Processing 2e6i_A (392/2775)...
# Processing 2e6s_A (393/2775)...
# Processing 2e6w_A (394/2775)...
# Processing 2eav_A (395/2775)...
# Processing 2eb1_B (396/2775)...
# Processing 2ebr_A (397/2775)...
# Processing 2ebt_A (398/2775)...
# Processing 2ecv_A (399/2775)...
# Processing 2egm_A (400/2775)...
# Processing 2eli_A (401/2775)...
# Processing 2enn_A (402/2775)...
# Processing 2eod_A (403/2775)...
# Processing 2epp_A (404/2775)...
# Processing 2erf_A (405/2775)...
# Processing 2erx_A (406/2775)...
# Processing 2ery_B (407/2775)...
# Processing 2esl_F (408/2775)...
# Processing 2ew1_A (409/2775)...
# Processing 2f0y_B (410/2775)...
# Processing 2f27_A (411/2775)...
# Processing 2f7s_A (412/2775)...
# Processing 2fby_A (413/2775)...
# Processing 2fcw_B (414/2775)...
# Processing 2fdv_D (415/2775)...
# Processing 2ffu_A (416/2775)...
# Processing 2ffw_A (417/2775)...
# Processing 2fg5_A (418/2775)...
# Processing 2fh1_B (419/2775)...
# Processing 2fim_B (420/2775)...
# Processing 2fj9_A (421/2775)...
# Processing 2fju_B (422/2775)...
# Processing 2fqq_B (423/2775)...
# Processing 2frw_A (424/2775)...
# Processing 2fsz_A (425/2775)...
# Processing 2fu5_B (426/2775)...
# Processing 2fvl_A (427/2775)...
# Processing 2fyl_B (428/2775)...
# Processing 2g2k_A (429/2775)...
# Processing 2g43_A (430/2775)...
# Processing 2g4a_A (431/2775)...
# Processing 2g6b_A (432/2775)...
# Processing 2g9o_A (433/2775)...
# Processing 2gao_B (434/2775)...
# Processing 2gf0_B (435/2775)...
# Processing 2gf9_A (436/2775)...
# Processing 2ggm_A (437/2775)...
# Processing 2ggz_B (438/2775)...
# Processing 2gjx_H (439/2775)...
# Processing 2gk1_Q (440/2775)...
# Processing 2gli_A (441/2775)...
# Processing 2gmv_A (442/2775)...
# Processing 2gp5_A (443/2775)...
# Processing 2gpq_A (444/2775)...
# Processing 2gqj_A (445/2775)...
# Processing 2gql_A (446/2775)...
# Processing 2gwh_A (447/2775)...
# Processing 2gz5_A (448/2775)...
# Processing 2h16_D (449/2775)...
# Processing 2h57_B (450/2775)...
# Processing 2h63_D (451/2775)...
# Processing 2h6h_A (452/2775)...
# Processing 2h8h_A (453/2775)...
# Processing 2h8k_B (454/2775)...
# Processing 2h9e_L (455/2775)...
# Processing 2ha8_A (456/2775)...
# Processing 2hei_B (457/2775)...
# Processing 2hgs_A (458/2775)...
# Processing 2hhl_A (459/2775)...
# Processing 2lv7_A (543/2775)...
# Processing 2lvz_A (544/2775)...
# Processing 2lxp_C (545/2775)...
# Processing 2lzu_A (546/2775)...
# Processing 2m0p_A (547/2775)...
# Processing 2m68_A (548/2775)...
# Processing 2m6n_A (549/2775)...
# Processing 2m96_A (550/2775)...
# Processing 2m9a_A (551/2775)...
# Processing 2m9w_A (552/2775)...
# Processing 2ma7_A (553/2775)...
# Processing 2miu_A (554/2775)...
# Processing 2mji_A (555/2775)...
# Processing 2mkd_A (556/2775)...
# Processing 2mm3_A (557/2775)...
# Processing 2mnz_A (558/2775)...
# Processing 2mpf_A (559/2775)...
# Processing 2mph_A (560/2775)...
# Processing 2mse_D (561/2775)...
# Processing 2msv_A (562/2775)...
# Processing 2mwx_A (563/2775)...
# Processing 2mzi_A (564/2775)...
# Processing 2n14_A (565/2775)...
# Processing 2n1a_A (566/2775)...
# Processing 2n1a_B (567/2775)...
# Processing 2n26_A (568/2775)...
# Processing 2n42_A (569/2775)...
# Processing 2n8a_A (570/2775)...
# Processing 2nll_B (571/2775)...
# Processing 2nxp_F (572/2775)...
# Processing 2nyt_C (573/2775)...
# Processing 2nz0_B (574/2775)...
# Processing 2nz2_A (575/2775)...
# Processing 2nzj_C (576/2775)...
# Processing 2nzt_B (577/2775)...
# Processing 2o06_A (578/2775)...
# Processing 2o10_A (579/2775)...
# Processing 2o13_A (580/2775)...
# Processing 2o2f_A (581/2775)...
# Processing 2o52_B (582/2775)...
# Processing 2o6g_E (583/2775)...
# Processing 2o8f_B (584/2775)...
# Processing 2obd_A (585/2775)...
# Processing 2obv_A (586/2775)...
# Processing 2ocb_A (587/2775)...
# Processing 2ocg_A (588/2775)...
# Processing 2ocp_C (589/2775)...
# Processing 2od1_A (590/2775)...
# Processing 2ohf_A (591/2775)...
# Processing 2oil_A (592/2775)...
# Processing 2okv_C (593/2775)...
# Processing 2oo4_B (594/2775)...
# Processing 2opw_A (595/2775)...
# Processing 2ox8_D (596/2775)...
# Processing 2oxc_A (597/2775)...
# Processing 2p0a_A (598/2775)...
# Processing 2p0d_A (599/2775)...
# Processing 2p0r_B (600/2775)...
# Processing 2p0w_A (601/2775)...
# Processing 2p1f_A (602/2775)...
# Processing 2p57_A (603/2775)...
# Processing 2p5s_B (604/2775)...
# Processing 2p8e_B (605/2775)...
# Processing 2pfr_A (606/2775)...
# Processing 2pg5_D (607/2775)...
# Processing 2pid_A (608/2775)...
# Processing 2pl0_A (609/2775)...
# Processing 2pla_A (610/2775)...
# Processing 2pmy_A (611/2775)...
# Processing 2pqf_D (612/2775)...
# Processing 2pru_B (613/2775)...
# Processing 2psn_D (614/2775)...
# Processing 2puy_A (615/2775)...
# Processing 2pvs_A (616/2775)...
# Processing 2q3f_B (617/2775)...
# Processing 2q3h_A (618/2775)...
# Processing 2q3z_A (619/2775)...
# Processing 2q5e_D (620/2775)...
# Processing 2q7r_F (621/2775)...
# Processing 2q8f_A (622/2775)...
# Processing 2q98_A (623/2775)...
# Processing 2qic_A (624/2775)...
# Processing 2qk4_B (625/2775)...
# Processing 2qkk_W (626/2775)...
# Processing 2qpp_B (627/2775)...
# Processing 2qra_C (628/2775)...
# Processing 2qst_B (629/2775)...
# Processing 2qt7_B (630/2775)...
# Processing 2qtz_A (631/2775)...
# Processing 2qym_A (632/2775)...
# Processing 2r3a_A (633/2775)...
# Processing 2r5g_A (634/2775)...
# Processing 2r83_A (635/2775)...
# Processing 2r8u_A (636/2775)...
# Processing 2ra4_B (637/2775)...
# Processing 2raj_A (638/2775)...
# Processing 2rb3_C (639/2775)...
# Processing 2rb4_B (640/2775)...
# Processing 2rc4_A (641/2775)...
# Processing 2rhp_A (642/2775)...
# Processing 2rje_B (643/2775)...
# Processing 2rjp_B (644/2775)...
# Processing 2rjq_A (645/2775)...
# Processing 2rkb_C (646/2775)...
# Processing 2rli_A (647/2775)...
# Processing 2rmk_A (648/2775)...
# Processing 2rsg_A (649/2775)...
# Processing 2rsq_A (650/2775)...
# Processing 2ruy_A (651/2775)...
# Processing 2uur_A (652/2775)...
# Processing 2uvl_A (653/2775)...
# Processing 2uyy_D (654/2775)...
# Processing 2uzg_A (655/2775)...
# Processing 2v40_A (656/2775)...
# Processing 2v55_B (657/2775)...
# Processing 2vac_A (658/2775)...
# Processing 2vcv_J (659/2775)...
# Processing 2vd5_B (660/2775)...
# Processing 2vdy_A (661/2775)...
# Processing 2vhf_A (662/2775)...
# Processing 2vkq_A (663/2775)...
# Processing 2vm5_A (664/2775)...
# Processing 2vn9_A (665/2775)...
# Processing 2vq3_A (666/2775)...
# Processing 2vr2_A (667/2775)...
# Processing 2vrd_A (668/2775)...
# Processing 2vrg_A (669/2775)...
# Processing 2vsc_C (670/2775)...
# Processing 2vwi_D (671/2775)...
# Processing 2vxo_A (672/2775)...
# Processing 2w0t_A (673/2775)...
# Processing 2w2i_A (674/2775)...
# Processing 2w3o_B (675/2775)...
# Processing 2w4l_E (676/2775)...
# Processing 2w4o_A (677/2775)...
# Processing 2w4r_D (678/2775)...
# Processing 2w86_A (679/2775)...
# Processing 2w8p_A (680/2775)...
# Processing 2wbi_B (681/2775)...
# Processing 2wce_A (682/2775)...
# Processing 2wef_A (683/2775)...
# Processing 2wh5_E (684/2775)...
# Processing 2wjy_A (685/2775)...
# Processing 2wk6_B (686/2775)...
# Processing 2wno_A (687/2775)...
# Processing 2wtk_E (688/2775)...
# Processing 2wtk_F (689/2775)...
# Processing 2wwy_B (690/2775)...
# Processing 2wwz_C (691/2775)...
# Processing 2wya_C (692/2775)...
# Processing 2wzb_A (693/2775)...
# Processing 2x10_A (694/2775)...
# Processing 2x11_B (695/2775)...
# Processing 2x4d_A (696/2775)...
# Processing 2x4f_B (697/2775)...
# Processing 2x4w_A (698/2775)...
# Processing 2x7g_A (699/2775)...
# Processing 2x7h_B (700/2775)...
# Processing 2xik_A (701/2775)...
# Processing 2xmr_C (702/2775)...
# Processing 2xn3_B (703/2775)...
# Processing 2xph_A (704/2775)...
# Processing 2xrc_D (705/2775)...
# Processing 2xsx_A (706/2775)...
# Processing 2xtp_A (707/2775)...
# Processing 2xzg_A (708/2775)...
# Processing 2y1h_A (709/2775)...
# Processing 2y1l_D (710/2775)...
# Processing 2y23_A (711/2775)...
# Processing 2y43_B (712/2775)...
# Processing 2y7j_D (713/2775)...
# Processing 2yan_A (714/2775)...
# Processing 2yd8_A (715/2775)...
# Processing 2ygq_A (716/2775)...
# Processing 2yh0_A (717/2775)...
# Processing 2yho_C (718/2775)...
# Processing 2yqm_A (719/2775)...
# Processing 2yrt_A (720/2775)...
# Processing 2ysl_A (721/2775)...
# Processing 2yu2_A (722/2775)...
# Processing 2yvr_A (723/2775)...
# Processing 2z0u_B (724/2775)...
# Processing 2z15_C (725/2775)...
# Processing 2z4e_E (726/2775)...
# Processing 2z5f_B (727/2775)...
# Processing 2zfu_B (728/2775)...
# Processing 2zg1_A (729/2775)...
# Processing 2znv_D (730/2775)...
# Processing 2zoc_A (731/2775)...
# Processing 2zoq_A (732/2775)...
# Processing 2zox_A (733/2775)...
# Processing 2zrt_G (734/2775)...
# Processing 3a2a_B (735/2775)...
# Processing 3a4s_A (736/2775)...
# Processing 3a4u_A (737/2775)...
# Processing 3aad_A (738/2775)...
# Processing 3aco_A (739/2775)...
# Processing 3ahq_A (740/2775)...
# Processing 3aih_A (741/2775)...
# Processing 3alq_R (742/2775)...
# Processing 3ap3_A (743/2775)...
# Processing 3b2d_A (744/2775)...
# Processing 3b3l_A (745/2775)...
# Processing 3b6r_B (746/2775)...
# Processing 3b6u_A (747/2775)...
# Processing 3b6v_A (748/2775)...
# Processing 3bce_A (749/2775)...
# Processing 3ber_A (750/2775)...
# Processing 3bfx_A (751/2775)...
# Processing 3bh7_B (752/2775)...
# Processing 3bhm_A (753/2775)...
# Processing 3bi6_A (754/2775)...
# Processing 3bjc_A (755/2775)...
# Processing 3bm4_B (756/2775)...
# Processing 3bo5_A (757/2775)...
# Processing 3brh_A (758/2775)...
# Processing 3bsu_H (759/2775)...
# Processing 3bvo_B (760/2775)...
# Processing 3c5c_D (761/2775)...
# Processing 3c5e_A (762/2775)...
# Processing 3c6k_A (763/2775)...
# Processing 3c6w_C (764/2775)...
# Processing 3cbb_B (765/2775)...
# Processing 3cbk_A (766/2775)...
# Processing 3cbq_A (767/2775)...
# Processing 3cfw_A (768/2775)...
# Processing 3cos_C (769/2775)...
# Processing 3ctz_A (770/2775)...
# Processing 3cxp_A (771/2775)...
# Processing 3d0e_B (772/2775)...
# Processing 3d24_C (773/2775)...
# Processing 3d2f_D (774/2775)...
# Processing 3d34_B (775/2775)...
# Processing 3d3l_B (776/2775)...
# Processing 3d3w_B (777/2775)...
# Processing 3d5o_B (778/2775)...
# Processing 3d87_B (779/2775)...
# Processing 3d8b_A (780/2775)...
# Processing 3d8e_C (781/2775)...
# Processing 3ddu_A (782/2775)...
# Processing 3dem_B (783/2775)...
# Processing 3dk9_A (784/2775)...
# Processing 3dko_A (785/2775)...
# Processing 3dlj_B (786/2775)...
# Processing 3dls_C (787/2775)...
# Processing 3dwb_A (788/2775)...
# Processing 3dyd_B (789/2775)...
# Processing 3dz4_B (790/2775)...
# Processing 3e1y_B (791/2775)...
# Processing 3e3r_B (792/2775)...
# Processing 3e4c_B (793/2775)...
# Processing 3e6i_B (794/2775)...
# Processing 3eb5_A (795/2775)...
# Processing 3edy_A (796/2775)...
# Processing 3eh1_A (797/2775)...
# Processing 3eh2_B (798/2775)...
# Processing 3elb_A (799/2775)...
# Processing 3epy_B (800/2775)...
# Processing 3epz_A (801/2775)...
# Processing 3eta_A (802/2775)...
# Processing 3eue_A (803/2775)...
# Processing 3exi_B (804/2775)...
# Processing 3eyh_A (805/2775)...
# Processing 3f1r_B (806/2775)...
# Processing 3f3y_A (807/2775)...
# Processing 3f5o_E (808/2775)...
# Processing 3f70_B (809/2775)...
# Processing 3f7u_C (810/2775)...
# Processing 3f9p_A (811/2775)...
# Processing 3fcx_B (812/2775)...
# Processing 3fd6_B (813/2775)...
# Processing 3fe2_B (814/2775)...
# Processing 3fe3_A (815/2775)...
# Processing 3fe4_A (816/2775)...
# Processing 3fec_A (817/2775)...
# Processing 3ff6_D (818/2775)...
# Processing 3ffk_A (819/2775)...
# Processing 3fg6_F (820/2775)...
# Processing 3fl2_A (821/2775)...
# Processing 3flv_B (822/2775)...
# Processing 3fvy_A (823/2775)...
# Processing 3fy1_A (824/2775)...
# Processing 3g4h_A (825/2775)...
# Processing 3g73_A (826/2775)...
# Processing 3g9y_A (827/2775)...
# Processing 3gbj_A (828/2775)...
# Processing 3gc9_B (829/2775)...
# Processing 3gdh_B (830/2775)...
# Processing 3gdq_A (831/2775)...
# Processing 3gep_B (832/2775)...
# Processing 3ggf_B (833/2775)...
# Processing 3ghg_C (834/2775)...
# Processing 3gis_Z (835/2775)...
# Processing 3gjx_E (836/2775)...
# Processing 3gkh_A (837/2775)...
# Processing 3gpd_G (838/2775)...
# Processing 3gqc_D (839/2775)...
# Processing 3gta_A (840/2775)...
# Processing 3gxb_A (841/2775)...
# Processing 3gzd_A (842/2775)...
# Processing 3h2u_B (843/2775)...
# Processing 3h53_B (844/2775)...
# Processing 3hco_B (845/2775)...
# Processing 3hf1_A (846/2775)...
# Processing 3hn3_B (847/2775)...
# Processing 3ho4_A (848/2775)...
# Processing 3hr4_G (849/2775)...
# Processing 3hud_B (850/2775)...
# Processing 3hxt_A (851/2775)...
# Processing 3hy8_A (852/2775)...
# Processing 3ia8_A (853/2775)...
# Processing 3iei_H (854/2775)...
# Processing 3ihp_B (855/2775)...
# Processing 3ik7_B (856/2775)...
# Processing 3io2_A (857/2775)...
# Processing 3isq_A (858/2775)...
# Processing 3iu6_A (859/2775)...
# Processing 3iuf_A (860/2775)...
# Processing 3iuy_A (861/2775)...
# Processing 3iwl_A (862/2775)...
# Processing 3ixe_B (863/2775)...
# Processing 3ixs_K (864/2775)...
# Processing 3j0a_A (865/2775)...
# Processing 3j2s_B (866/2775)...
# Processing 3jrx_A (867/2775)...
# Processing 3jub_A (868/2775)...
# Processing 3jue_A (869/2775)...
# Processing 3jyh_A (870/2775)...
# Processing 3k2s_B (871/2775)...
# Processing 3k51_B (872/2775)...
# Processing 3k5t_A (873/2775)...
# Processing 3k7v_A (874/2775)...
# Processing 3k9j_A (875/2775)...
# Processing 3k9o_A (876/2775)...
# Processing 3kcg_I (877/2775)...
# Processing 3kn1_A (878/2775)...
# Processing 3kq0_A (879/2775)...
# Processing 3kq4_B (880/2775)...
# Processing 3kqg_A (881/2775)...
# Processing 3kuc_A (882/2775)...
# Processing 3kv5_A (883/2775)...
# Processing 3kvo_A (884/2775)...
# Processing 3kyd_A (885/2775)...
# Processing 3l43_B (886/2775)...
# Processing 3lea_B (887/2775)...
# Processing 3lf5_B (888/2775)...
# Processing 3lgd_B (889/2775)...
# Processing 3ljw_A (890/2775)...
# Processing 3lkj_C (891/2775)...
# Processing 3llk_A (892/2775)...
# Processing 3lqc_A (893/2775)...
# Processing 3lqh_A (894/2775)...
# Processing 3lrq_C (895/2775)...
# Processing 3lru_B (896/2775)...
# Processing 3ltl_B (897/2775)...
# Processing 3luc_A (898/2775)...
# Processing 3lxj_A (899/2775)...
# Processing 3lxx_A (900/2775)...
# Processing 3ly5_A (901/2775)...
# Processing 3lyr_A (902/2775)...
# Processing 3m1d_B (903/2775)...
# Processing 3m52_A (904/2775)...
# Processing 3mb3_A (905/2775)...
# Processing 3mb4_B (906/2775)...
# Processing 3mbg_C (907/2775)...
# Processing 3mdi_A (908/2775)...
# Processing 3mdy_C (909/2775)...
# Processing 3mdz_A (910/2775)...
# Processing 3mgm_A (911/2775)...
# Processing 3mjh_B (912/2775)...
# Processing 3mp5_B (913/2775)...
# Processing 3mq7_L (914/2775)...
# Processing 3mqi_C (915/2775)...
# Processing 3mtg_B (916/2775)...
# Processing 3mtn_A (917/2775)...
# Processing 3my0_J (918/2775)...
# Processing 3mzg_B (919/2775)...
# Processing 3n1g_A (920/2775)...
# Processing 3n1m_B (921/2775)...
# Processing 3n5n_Y (922/2775)...
# Processing 3n7o_A (923/2775)...
# Processing 3na1_A (924/2775)...
# Processing 3ncu_A (925/2775)...
# Processing 3ner_B (926/2775)...
# Processing 3nks_A (927/2775)...
# Processing 3nmq_A (928/2775)...
# Processing 3nmz_B (929/2775)...
# Processing 3nv1_A (930/2775)...
# Processing 3nvq_B (931/2775)...
# Processing 3nwn_A (932/2775)...
# Processing 3nxb_A (933/2775)...
# Processing 3nyn_B (934/2775)...
# Processing 3o0g_A (935/2775)...
# Processing 3o4r_B (936/2775)...
# Processing 3o4s_A (937/2775)...
# Processing 3o7a_A (938/2775)...
# Processing 3oag_A (939/2775)...
# Processing 3oes_A (940/2775)...
# Processing 3oj3_J (941/2775)...
# Processing 3ojy_B (942/2775)...
# Processing 3orh_B (943/2775)...
# Processing 3otc_B (944/2775)...
# Processing 3ovp_B (945/2775)...
# Processing 3p0f_A (946/2775)...
# Processing 3p57_A (947/2775)...
# Processing 3pb4_X (948/2775)...
# Processing 3pe0_A (949/2775)...
# Processing 3pja_K (950/2775)...
# Processing 3pls_A (951/2775)...
# Processing 3pm0_A (952/2775)...
# Processing 3poo_A (953/2775)...
# Processing 3pse_B (954/2775)...
# Processing 3q13_A (955/2775)...
# Processing 3q19_A (956/2775)...
# Processing 3q1d_A (957/2775)...
# Processing 3q2u_A (958/2775)...
# Processing 3q3j_B (959/2775)...
# Processing 3q6z_A (960/2775)...
# Processing 3qcj_A (961/2775)...
# Processing 3qfb_B (962/2775)...
# Processing 3qj4_A (963/2775)...
# Processing 3qj5_B (964/2775)...
# Processing 3qmh_A (965/2775)...
# Processing 3qni_A (966/2775)...
# Processing 3qpu_A (967/2775)...
# Processing 3qrf_F (968/2775)...
# Processing 3qxy_B (969/2775)...
# Processing 3r6b_A (970/2775)...
# Processing 3rap_S (971/2775)...
# Processing 3ray_A (972/2775)...
# Processing 3rbl_B (973/2775)...
# Processing 3rc3_A (974/2775)...
# Processing 3rgk_A (975/2775)...
# Processing 3rk2_G (976/2775)...
# Processing 3rq4_A (977/2775)...
# Processing 3rz3_C (978/2775)...
# Processing 3rzv_A (979/2775)...
# Processing 3s4y_A (980/2775)...
# Processing 3sbz_A (981/2775)...
# Processing 3sh5_A (982/2775)...
# Processing 3sjv_F (983/2775)...
# Processing 3sn5_B (984/2775)...
# Processing 3szb_B (985/2775)...
# Processing 3t6a_A (986/2775)...
# Processing 3t7l_A (987/2775)...
# Processing 3t9i_A (988/2775)...
# Processing 3tac_A (989/2775)...
# Processing 3thd_D (990/2775)...
# Processing 3tkl_A (991/2775)...
# Processing 3top_A (992/2775)...
# Processing 3tvl_A (993/2775)...
# Processing 3twj_B (994/2775)...
# Processing 3u5n_A (995/2775)...
# Processing 3u8u_A (996/2775)...
# Processing 3ucw_A (997/2775)...
# Processing 3uh4_B (998/2775)...
# Processing 3uk3_C (999/2775)...
# Processing 3ukm_C (1000/2775)...
# Processing 3uyq_A (1001/2775)...
# Processing 3uzx_B (1002/2775)...
# Processing 3v3l_A (1003/2775)...
# Processing 3v4v_B (1004/2775)...
# Processing 3v4v_C (1005/2775)...
# Processing 3v70_A (1006/2775)...
# Processing 3v7t_A (1007/2775)...
# Processing 3v8x_B (1008/2775)...
# Processing 3vcm_B (1009/2775)...
# Processing 3vf0_A (1010/2775)...
# Processing 3vfq_A (1011/2775)...
# Processing 3vi3_A (1012/2775)...
# Processing 3vjc_A (1013/2775)...
# Processing 3vjm_A (1014/2775)...
# Processing 3vm8_A (1015/2775)...
# Processing 3vp6_B (1016/2775)...
# Processing 3vpp_B (1017/2775)...
# Processing 3vrn_A (1018/2775)...
# Processing 3vuy_D (1019/2775)...
# Processing 3vw9_B (1020/2775)...
# Processing 3w4u_E (1021/2775)...
# Processing 3w58_D (1022/2775)...
# Processing 3w5k_B (1023/2775)...
# Processing 3w8i_A (1024/2775)...
# Processing 3wh2_A (1025/2775)...
# Processing 3whd_A (1026/2775)...
# Processing 3wsr_B (1027/2775)...
# Processing 3wup_A (1028/2775)...
# Processing 3wv6_A (1029/2775)...
# Processing 3wzf_A (1030/2775)...
# Processing 3x1u_H (1031/2775)...
# Processing 4l58_A (1188/2775)...
# Processing 4l7n_A (1189/2775)...
# Processing 4l9m_A (1190/2775)...
# Processing 4lay_A (1191/2775)...
# Processing 4lec_B (1192/2775)...
# Processing 4lhx_B (1193/2775)...
# Processing 4liq_E (1194/2775)...
# Processing 4lot_A (1195/2775)...
# Processing 4lqy_A (1196/2775)...
# Processing 4lt6_A (1197/2775)...
# Processing 4m6r_D (1198/2775)...
# Processing 4mew_A (1199/2775)...
# Processing 4mf3_A (1200/2775)...
# Processing 4mhv_B (1201/2775)...
# Processing 4mqw_X (1202/2775)...
# Processing 4msp_A (1203/2775)...
# Processing 4mvt_C (1204/2775)...
# Processing 4mwi_A (1205/2775)...
# Processing 4myg_A (1206/2775)...
# Processing 4n2c_A (1207/2775)...
# Processing 4n4a_A (1208/2775)...
# Processing 4neh_A (1209/2775)...
# Processing 4ngg_A (1210/2775)...
# Processing 4nn2_B (1211/2775)...
# Processing 4nnr_B (1212/2775)...
# Processing 4npv_A (1213/2775)...
# Processing 4nqa_I (1214/2775)...
# Processing 4ns5_A (1215/2775)...
# Processing 4nsq_C (1216/2775)...
# Processing 4nt5_A (1217/2775)...
# Processing 4nxs_B (1218/2775)...
# Processing 4o0c_B (1219/2775)...
# Processing 4o2w_B (1220/2775)...
# Processing 4o68_A (1221/2775)...
# Processing 4oav_B (1222/2775)...
# Processing 4oem_B (1223/2775)...
# Processing 4oj2_X (1224/2775)...
# Processing 4ojk_A (1225/2775)...
# Processing 4omc_E (1226/2775)...
# Processing 4oni_A (1227/2775)...
# Processing 4onn_B (1228/2775)...
# Processing 4or9_A (1229/2775)...
# Processing 4orw_A (1230/2775)...
# Processing 4otg_A (1231/2775)...
# Processing 4p0p_A (1232/2775)...
# Processing 4p13_C (1233/2775)...
# Processing 4p5w_A (1234/2775)...
# Processing 4p60_A (1235/2775)...
# Processing 4pcu_A (1236/2775)...
# Processing 4pcw_B (1237/2775)...
# Processing 4px2_A (1238/2775)...
# Processing 4pzi_A (1239/2775)...
# Processing 4q4b_A (1240/2775)...
# Processing 4q4d_A (1241/2775)...
# Processing 4q6f_A (1242/2775)...
# Processing 4q7y_A (1243/2775)...
# Processing 4q93_A (1244/2775)...
# Processing 4q9u_E (1245/2775)...
# Processing 4qbm_A (1246/2775)...
# Processing 4qc3_A (1247/2775)...
# Processing 4qil_A (1248/2775)...
# Processing 4qmx_A (1249/2775)...
# Processing 4qn9_A (1250/2775)...
# Processing 4qpn_A (1251/2775)...
# Processing 4qu6_A (1252/2775)...
# Processing 4r1f_A (1253/2775)...
# Processing 4r2d_A (1254/2775)...
# Processing 4r6u_A (1255/2775)...
# Processing 4r7a_B (1256/2775)...
# Processing 4r7p_B (1257/2775)...
# Processing 4r8p_K (1258/2775)...
# Processing 4rau_L (1259/2775)...
# Processing 4rda_A (1260/2775)...
# Processing 4re1_A (1261/2775)...
# Processing 4re8_B (1262/2775)...
# Processing 4rec_A (1263/2775)...
# Processing 4rer_A (1264/2775)...
# Processing 4rfq_A (1265/2775)...
# Processing 4rg1_A (1266/2775)...
# Processing 4rkk_A (1267/2775)...
# Processing 4rn0_A (1268/2775)...
# Processing 4rr2_A (1269/2775)...
# Processing 4rsu_F (1270/2775)...
# Processing 4ruh_B (1271/2775)...
# Processing 4s15_A (1272/2775)...
# Processing 4s3o_B (1273/2775)...
# Processing 4s3o_C (1274/2775)...
# Processing 4tlg_A (1275/2775)...
# Processing 4tnt_A (1276/2775)...
# Processing 4ttv_A (1277/2775)...
# Processing 4twe_B (1278/2775)...
# Processing 4u5t_A (1279/2775)...
# Processing 4u8d_A (1280/2775)...
# Processing 4ueg_A (1281/2775)...
# Processing 4uem_A (1282/2775)...
# Processing 4ug2_A (1283/2775)...
# Processing 4uhz_A (1284/2775)...
# Processing 4ui9_S (1285/2775)...
# Processing 4um8_D (1286/2775)...
# Processing 4usf_B (1287/2775)...
# Processing 4ust_A (1288/2775)...
# Processing 4uu6_A (1289/2775)...
# Processing 4uuu_A (1290/2775)...
# Processing 4uy2_B (1291/2775)...
# Processing 4uy9_A (1292/2775)...
# Processing 4uya_A (1293/2775)...
# Processing 4uye_B (1294/2775)...
# Processing 4v0h_D (1295/2775)...
# Processing 4v3k_F (1296/2775)...
# Processing 4v6x_Aa (1297/2775)...
# Processing 4v6x_Af (1298/2775)...
# Processing 4wgk_A (1299/2775)...
# Processing 4whv_I (1300/2775)...
# Processing 4wle_D (1301/2775)...
# Processing 4wmq_A (1302/2775)...
# Processing 4wqn_B (1303/2775)...
# Processing 4wzx_A (1304/2775)...
# Processing 4x0q_B (1305/2775)...
# Processing 4x30_A (1306/2775)...
# Processing 4x7q_B (1307/2775)...
# Processing 4x93_B (1308/2775)...
# Processing 4xcx_A (1309/2775)...
# Processing 4xdp_A (1310/2775)...
# Processing 4xft_A (1311/2775)...
# Processing 4xhz_A (1312/2775)...
# Processing 4xp7_A (1313/2775)...
# Processing 4xwh_A (1314/2775)...
# Processing 4xyj_H (1315/2775)...
# Processing 4xzp_A (1316/2775)...
# Processing 4y05_A (1317/2775)...
# Processing 4y7b_A (1318/2775)...
# Processing 4y86_A (1319/2775)...
# Processing 4y88_A (1320/2775)...
# Processing 4y8w_A (1321/2775)...
# Processing 4y97_H (1322/2775)...
# Processing 4yhj_B (1323/2775)...
# Processing 4yiq_D (1324/2775)...
# Processing 4yj0_A (1325/2775)...
# Processing 4yls_A (1326/2775)...
# Processing 4ylz_B (1327/2775)...
# Processing 4ymd_B (1328/2775)...
# Processing 4ymj_A (1329/2775)...
# Processing 4ynd_A (1330/2775)...
# Processing 4yoc_C (1331/2775)...
# Processing 4yvp_A (1332/2775)...
# Processing 4ywt_D (1333/2775)...
# Processing 4z0o_A (1334/2775)...
# Processing 4z2b_A (1335/2775)...
# Processing 4z9m_D (1336/2775)...
# Processing 4zaj_A (1337/2775)...
# Processing 4zc4_B (1338/2775)...
# Processing 4zcv_A (1339/2775)...
# Processing 4zdp_A (1340/2775)...
# Processing 4zel_A (1341/2775)...
# Processing 4zes_B (1342/2775)...
# Processing 4zfg_A (1343/2775)...
# Processing 8b0a_K (2614/2775)...
# Processing 8b0f_C (2615/2775)...
# Processing 8b0f_F (2616/2775)...
# Processing 8b0g_J (2617/2775)...
# Processing 8b0h_E (2618/2775)...
# Processing 8b10_A (2619/2775)...
# Processing 8b5r_P (2620/2775)...
# Processing 8b6l_L (2621/2775)...
# Processing 8b6l_N (2622/2775)...
# Processing 8b6l_O (2623/2775)...
# Processing 8b9e_A (2624/2775)...
# Processing 8bah_B (2625/2775)...
# Processing 8bbg_C (2626/2775)...
# Processing 8bbs_A (2627/2775)...
# Processing 8bc9_J (2628/2775)...
# Processing 8blp_C (2629/2775)...
# Processing 8bot_U (2630/2775)...
# Processing 8bot_X (2631/2775)...
# Processing 8bub_B (2632/2775)...
# Processing 8bya_B (2633/2775)...
# Processing 8byl_B (2634/2775)...
# Processing 8bzy_A (2635/2775)...
# Processing 8c3u_A (2636/2775)...
# Processing 8c6j_7 (2637/2775)...
# Processing 8ca0_B (2638/2775)...
# Processing 8ch6_y (2639/2775)...
# Processing 8cqb_A (2640/2775)...
# Processing 8cr1_B (2641/2775)...
# Processing 8css_8 (2642/2775)...
# Processing 8cua_C (2643/2775)...
# Processing 8cuc_F (2644/2775)...
# Processing 8cv5_A (2645/2775)...
# Processing 8cx0_A (2646/2775)...
# Processing 8d1e_D (2647/2775)...
# Processing 8d1l_C (2648/2775)...
# Processing 8d30_A (2649/2775)...
# Processing 8d3c_E (2650/2775)...
# Processing 8d3v_A (2651/2775)...
# Processing 8d6e_A (2652/2775)...
# Processing 8d7z_C (2653/2775)...
# Processing 8d8i_A (2654/2775)...
# Processing 8daf_A (2655/2775)...
# Processing 8dbk_B (2656/2775)...
# Processing 8dey_F (2657/2775)...
# Processing 8dkm_P (2658/2775)...
# Processing 8dmk_G (2659/2775)...
# Processing 8dnu_D (2660/2775)...
# Processing 8dph_A (2661/2775)...
# Processing 8dyd_A (2662/2775)...
# Processing 8dyl_B (2663/2775)...
# Processing 8e0c_A (2664/2775)...
# Processing 8e0f_B (2665/2775)...
# Processing 8e1a_A (2666/2775)...
# Processing 8e3y_R (2667/2775)...
# Processing 8e4y_A (2668/2775)...
# Processing 8e8v_A (2669/2775)...
# Processing 8e93_B (2670/2775)...
# Processing 8e98_C (2671/2775)...
# Processing 8e9z_A (2672/2775)...
# Processing 8ede_B (2673/2775)...
# Processing 8ef7_A (2674/2775)...
# Processing 8efg_A (2675/2775)...
# Processing 8efq_R (2676/2775)...
# Processing 8eg3_A (2677/2775)...
# Processing 8egx_B (2678/2775)...
# Processing 8eih_A (2679/2775)...
# Processing 8eiq_A (2680/2775)...
# Processing 8ejm_A (2681/2775)...
# Processing 8emr_B (2682/2775)...
# Processing 8eok_G (2683/2775)...
# Processing 8eop_A (2684/2775)...
# Processing 8eor_B (2685/2775)...
# Processing 8epl_A (2686/2775)...
# Processing 8esv_A (2687/2775)...
# Processing 8eyk_F (2688/2775)...
# Processing 8eyo_A (2689/2775)...
# Processing 8f7s_R (2690/2775)...
# Processing 8fb2_B (2691/2775)...
# Processing 8fc7_B (2692/2775)...
# Processing 8ffv_A (2693/2775)...
# Processing 8ffw_D (2694/2775)...
# Processing 8fgw_C (2695/2775)...
# Processing 8fjx_A (2696/2775)...
# Processing 8fmu_B (2697/2775)...
# Processing 8fnb_B (2698/2775)...
# Processing 8foa_A (2699/2775)...
# Processing 8fp1_A (2700/2775)...
# Processing 8fw5_B (2701/2775)...
# Processing 8fyh_I (2702/2775)...
# Processing 8g0l_A (2703/2775)...
# Processing 8g46_B (2704/2775)...
# Processing 8g7n_A (2705/2775)...
# Processing 8g9p_D (2706/2775)...
# Processing 8gju_D (2707/2775)...
# Processing 8gk3_H (2708/2775)...
# Processing 8gnn_A (2709/2775)...
# Processing 8gui_K (2710/2775)...
# Processing 8gx3_A (2711/2775)...
# Processing 8gye_A (2712/2775)...
# Processing 8gyx_B (2713/2775)...
# Processing 8gz2_B (2714/2775)...
# Processing 8h65_C (2715/2775)...
# Processing 8h8j_C (2716/2775)...
# Processing 8hbe_B (2717/2775)...
# Processing 8hdp_R (2718/2775)...
# Processing 8hy5_B (2719/2775)...
# Processing 8i1o_A (2720/2775)...
# Processing 8i5y_A (2721/2775)...
# Processing 8i5y_B (2722/2775)...
# Processing 8i9u_J (2723/2775)...
# Processing 8i9u_O (2724/2775)...
# Processing 8ifo_A (2725/2775)...
# Processing 8il3_C (2726/2775)...
# Processing 8iqn_A (2727/2775)...
# Processing 8irr_R (2728/2775)...
# Processing 8iuh_3 (2729/2775)...
# Processing 8iwu_A (2730/2775)...
# Processing 8iys_R (2731/2775)...
# Processing 8jbn_B (2732/2775)...
# Processing 8jdl_AP (2733/2775)...
# Processing 8jhf_A (2734/2775)...
# Processing 8jii_A (2735/2775)...
# Processing 8jyg_B (2736/2775)...
# Processing 8kb5_G (2737/2775)...
# Processing 8odo_A (2738/2775)...
# Processing 8oew_O (2739/2775)...
# Processing 8oi8_A (2740/2775)...
# Processing 8oma_A (2741/2775)...
# Processing 8omr_A (2742/2775)...
# Processing 8oxy_A (2743/2775)...
# Processing 8p50_B (2744/2775)...
# Processing 8p8x_A (2745/2775)...
# Processing 8p94_A (2746/2775)...
# Processing 8pqh_A (2747/2775)...
# Processing 8q7n_K (2748/2775)...
# Processing 8qk3_E (2749/2775)...
# Processing 8qy4_D (2750/2775)...
# Processing 8rbx_W (2751/2775)...
# Processing 8sg5_H (2752/2775)...
# Processing 8sgo_C (2753/2775)...
# Processing 8syp_C (2754/2775)...
# Processing 8t6j_A (2755/2775)...
# Processing 8t9h_K (2756/2775)...
# Processing 8tar_N (2757/2775)...
# Processing 8tgd_A (2758/2775)...
# Processing 8tnq_B (2759/2775)...
# Processing 8tzo_C (2760/2775)...
# Processing 8tzs_A (2761/2775)...
# Processing 8u26_R (2762/2775)...
# Processing 8u37_A (2763/2775)...
# Processing 8ucd_C (2764/2775)...
# Processing 8uhd_Y (2765/2775)...
# Processing 8v4y_W (2766/2775)...
# Processing 8v8u_B (2767/2775)...
# Processing 8wej_B (2768/2775)...
# Processing 8x15_W (2769/2775)...
# Processing 8x72_A (2770/2775)...
# Processing 8xov_A (2771/2775)...
# Processing 8xpn_A (2772/2775)...
# Processing 8y14_A (2773/2775)...
# Processing 8y6b_F (2774/2775)...
# Processing 8y6o_H (2775/2775)...

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

number_of_pockets = sum([len(i) for i in binding_residues.values()])

mean_br = np.mean(best_residue_overlaps)
median_br = np.median(best_residue_overlaps)
print(f'best_residue_overlap mean={mean_br:.4f}, median={median_br:.4f}')

print(np.sum(np.array(DCCs) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N_plus_K) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N_plus_K) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N) < 4) / number_of_pockets})')


print('\nSmall binding pockets (less than 10 residues):')
small_pockets_DCCs = [DCCs[i] for i in range(len(DCCs)) if is_small_pocket_DCC[i]]
print(f'Overall DCC < 12: {np.sum(np.array(small_pockets_DCCs) < 12) / len(small_pockets_DCCs):.4f} ({np.sum(np.array(small_pockets_DCCs) < 4) / len(small_pockets_DCCs):.4f})')
small_pockets_DCCs_N_plus_K = [DCCs_N_plus_K[i] for i in range(len(DCCs_N_plus_K)) if is_small_pocket_DCC_N_plus_K[i]]
print(f'N+K DCC < 12: {np.sum(np.array(small_pockets_DCCs_N_plus_K) < 12) / len(small_pockets_DCCs_N_plus_K):.4f} ({np.sum(np.array(small_pockets_DCCs_N_plus_K) < 4) / len(small_pockets_DCCs_N_plus_K):.4f})')
small_pockets_DCCs_N = [DCCs_N[i] for i in range(len(DCCs_N)) if is_small_pocket_DCC_N[i]]
print(f'N DCC < 12: {np.sum(np.array(small_pockets_DCCs_N) < 12) / len(small_pockets_DCCs_N):.4f} ({np.sum(np.array(small_pockets_DCCs_N) < 4) / len(small_pockets_DCCs_N):.4f})')

print('\nLarge binding pockets (10 or more residues):')
large_pockets_DCCs = [DCCs[i] for i in range(len(DCCs)) if not is_small_pocket_DCC[i]]
print(f'Overall DCC < 12: {np.sum(np.array(large_pockets_DCCs) < 12) / len(large_pockets_DCCs):.4f} ({np.sum(np.array(large_pockets_DCCs) < 4) / len(large_pockets_DCCs):.4f})')
large_pockets_DCCs_N_plus_K = [DCCs_N_plus_K[i] for i in range(len(DCCs_N_plus_K)) if not is_small_pocket_DCC_N_plus_K[i]]
print(f'N+K DCC < 12: {np.sum(np.array(large_pockets_DCCs_N_plus_K) < 12) / len(large_pockets_DCCs_N_plus_K):.4f} ({np.sum(np.array(large_pockets_DCCs_N_plus_K) < 4) / len(large_pockets_DCCs_N_plus_K):.4f})')
large_pockets_DCCs_N = [DCCs_N[i] for i in range(len(DCCs_N)) if not is_small_pocket_DCC_N[i]]
print(f'N DCC < 12: {np.sum(np.array(large_pockets_DCCs_N) < 12) / len(large_pockets_DCCs_N):.4f} ({np.sum(np.array(large_pockets_DCCs_N) < 4) / len(large_pockets_DCCs_N):.4f})')  


fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros = [i for i in number_of_overlapping_actual_sites_on_predicted_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Predicted Pockets Covering True Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Predicted Pockets Covering True Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_predictions_on_actual_pocket_without_zeros = [i for i in number_of_overlapping_predictions_on_actual_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_predictions_on_actual_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Actual Pockets Covering Predicted Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Actual Pockets Covering Predicted Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()
# Out:
# best_residue_overlap mean=0.4949, median=0.5000
# 0.7194129613484452 (0.2073525138041267)
# 0.6862830572507992 (0.19383900029061318)
# 0.6201685556524266 (0.16419645451903517)
#
# Small binding pockets (less than 10 residues):
# Overall DCC < 12: 0.6334 (0.1563)
# N+K DCC < 12: 0.5892 (0.1396)
# N DCC < 12: 0.5085 (0.1040)
#
# Large binding pockets (10 or more residues):
# Overall DCC < 12: 0.8398 (0.2717)
# N+K DCC < 12: 0.8182 (0.2613)
# N DCC < 12: 0.7663 (0.2374)

# %% [markdown]
# ## Run clustering without smoothing

# %%
model = torch.load(MODEL_PATH, weights_only=False)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

binding_residues, sequences = eval_utils.read_test_binding_residues(data_path=LIGYSIS_ANNOTATION_PATH, pocket_types=['NON_CRYPTIC'])

# debug on subset of 100 proteins
# binding_residues = {k: binding_residues[k] for k in list(binding_residues.keys())[:1000]}
# sequences = {k: sequences[k] for k in list(sequences.keys())[:1000]}

predicted_binding_sites = {}
ranks = {}
prediction_scores = {}

K = 2

DCCs_N = []
DCCs_N_plus_K = []
DCCs = []
number_of_overlapping_predictions_on_actual_pocket = []
number_of_overlapping_actual_sites_on_predicted_pocket = []
best_residue_overlaps = []

for i, protein_id in enumerate(sequences.keys()):
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'
    actual_binding_sites = [np.array([int(i.split('_')[1]) for i in pocket]) for pocket in binding_residues[protein_id]]
    
    print(f'Processing {protein_id} ({i+1}/{len(sequences)})...')
    if not PRECALCULATED:
        # finetuned prediction
        probabilities = eval_utils.compute_prediction(
            sequence,
            model,
            tokenizer
        )
    else:
        # load precalculated prediction
        probabilities = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')
    
    prediction_scores[protein_id] = probabilities

    coordinates = np.load(coordinates_path)
    distance_matrix = eval_utils.compute_distance_matrix(coordinates)

    predictions = (probabilities > DECISION_THRESHOLD).astype(float)
    predictions_copy = predictions.copy()

    assert distance_matrix.shape[0] == distance_matrix.shape[1]
    assert distance_matrix.shape[0] == predictions_copy.shape[0]
    
    indices_above_threshold = np.where(predictions_copy > DECISION_THRESHOLD)[0] # this gets residues that are equal to 1
    # no predicted residues - continue
    if len(indices_above_threshold) == 0:
        continue

    # run atom-level clustering and return residue-level pockets
    clusters, cluster_residues, cluster_scores, atom_coords, residue_coords = clustering_utils.execute_atom_clustering(
        pdb_id,
        chain_id,
        indices_above_threshold,
        probabilities[indices_above_threshold],
        eps=9
    )

    # none of the residues are on the surface
    if cluster_residues is None:
        continue

    cluster_residues = cryptoshow_utils.map_auth_to_mmcif_numbering_array(
        pdb_id,
        chain_id,
        cluster_residues.values(),
        binding_residues_are_integers=True,
        numbers_only=True
    )[0]

    cluster_order = np.argsort(cluster_scores)[::-1]  # descending order
    N = len(actual_binding_sites)

    selected_clusters_N = cluster_order[:N]
    selected_clusters_N_plus_K = cluster_order[:N+K]

    predicted_centers = {}
    for cluster_label, atom_indices in clusters.items():
        cluster_coords = np.array([atom_coords[atom_id] for atom_id in atom_indices])
        cluster_center = np.mean(cluster_coords, axis=0).get_array()
        predicted_centers[cluster_label] = cluster_center
    
    actual_centers = []
    is_small_pocket = []

    for pocket in actual_binding_sites:
        pocket_coords = coordinates[pocket]
        pocket_center = np.mean(pocket_coords, axis=0)
        actual_centers.append(pocket_center)
        is_small_pocket.append(len(pocket) < 10)
    
    for i, center in enumerate(actual_centers):
        DCC_N = float('inf')
        for j in selected_clusters_N:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N:
                DCC_N = distance
        
        if DCC_N != float('inf'):
            DCCs_N.append(DCC_N)

        DCC_N_plus_K = float('inf')
        for j in selected_clusters_N_plus_K:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N_plus_K:
                DCC_N_plus_K = distance
        
        if DCC_N_plus_K != float('inf'):
            DCCs_N_plus_K.append(DCC_N_plus_K)


    dcc_rro_matches = clustering_utils.compute_dcc_matched_rro(
        actual_binding_sites, actual_centers, predicted_centers, cluster_residues,
        dcc_hit_threshold=DCC_HIT_THRESHOLD,
    )
    for match in dcc_rro_matches:
        if match['dcc'] != float('inf'):
            DCCs.append(match['dcc'])
        if match['rro'] is not None:
            best_residue_overlaps.append(match['rro'])

    for pocket in actual_binding_sites:
        number_of_predicted_pockets = 0
        for residues in cluster_residues:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_actual_sites_on_predicted_pocket.append(number_of_predicted_pockets)

    for residues in cluster_residues:
        number_of_predicted_pockets = 0
        for pocket in actual_binding_sites:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_predictions_on_actual_pocket.append(number_of_predicted_pockets)
# Out:
# Processing 1a52_A (1/2775)...
# Processing 1a9w_E (2/2775)...
# Processing 1aii_A (3/2775)...
# Processing 1au1_A (4/2775)...
# Processing 1aue_B (5/2775)...
# Processing 1b1c_A (6/2775)...
# Processing 1b50_B (7/2775)...
# Processing 1b55_B (8/2775)...
# Processing 1b6c_F (9/2775)...
# Processing 1b9o_A (10/2775)...
# Processing 1bbo_A (11/2775)...
# Processing 1bci_A (12/2775)...
# Processing 1bf9_A (13/2775)...
# Processing 1bhi_A (14/2775)...
# Processing 1bld_A (15/2775)...
# Processing 1blx_A (16/2775)...
# Processing 1bmo_A (17/2775)...
# Processing 1bnl_A (18/2775)...
# Processing 1boy_A (19/2775)...
# Processing 1bp5_A (20/2775)...
# Processing 1buv_M (21/2775)...
# Processing 1byg_A (22/2775)...
# Processing 1bzs_A (23/2775)...
# Processing 1c07_A (24/2775)...
# Processing 1pkx_B (188/2775)...
# Processing 1pl8_C (189/2775)...
# Processing 1plo_A (190/2775)...
# Processing 1psr_B (191/2775)...
# Processing 1pt6_B (192/2775)...
# Processing 1q0p_A (193/2775)...
# Processing 1q1u_A (194/2775)...
# Processing 1q33_A (195/2775)...
# Processing 1q3a_A (196/2775)...
# Processing 1q7l_C (197/2775)...
# Processing 1q7l_D (198/2775)...
# Processing 1q8l_A (199/2775)...
# Processing 1q8x_A (200/2775)...
# Processing 1q9s_A (201/2775)...
# Processing 1qh5_B (202/2775)...
# Processing 1qnm_A (203/2775)...
# Processing 1qzq_A (204/2775)...
# Processing 1qzu_B (205/2775)...
# Processing 1r3y_A (206/2775)...
# Processing 1r54_A (207/2775)...
# Processing 1r8q_E (208/2775)...
# Processing 1rgo_A (209/2775)...
# Processing 1riw_B (210/2775)...
# Processing 1rjv_A (211/2775)...
# Processing 1rkb_A (212/2775)...
# Processing 1rm8_A (213/2775)...
# Processing 1rnf_B (214/2775)...
# Processing 1ro4_A (215/2775)...
# Processing 1rtg_A (216/2775)...
# Processing 1rx0_D (217/2775)...
# Processing 1rxr_A (218/2775)...
# Processing 1s18_A (219/2775)...
# Processing 1s4b_P (220/2775)...
# Processing 1s4y_B (221/2775)...
# Processing 1s9i_A (222/2775)...
# Processing 1sg4_B (223/2775)...
# Processing 1shr_D (224/2775)...
# Processing 1siq_A (225/2775)...
# Processing 1sl6_E (226/2775)...
# Processing 1smo_B (227/2775)...
# Processing 1so0_B (228/2775)...
# Processing 1soj_I (229/2775)...
# Processing 1sp2_A (230/2775)...
# Processing 1st0_A (231/2775)...
# Processing 1su3_A (232/2775)...
# Processing 1szb_B (233/2775)...
# Processing 1t3n_B (234/2775)...
# Processing 1t6b_Y (235/2775)...
# Processing 1t8c_A (236/2775)...
# Processing 1tff_A (237/2775)...
# Processing 1tfi_A (238/2775)...
# Processing 1tg6_C (239/2775)...
# Processing 1tjj_A (240/2775)...
# Processing 1toz_A (241/2775)...
# Processing 1tpk_C (242/2775)...
# Processing 1ttx_A (243/2775)...
# Processing 1tu4_C (244/2775)...
# Processing 1tvx_D (245/2775)...
# Processing 1u31_A (246/2775)...
# Processing 1u3t_A (247/2775)...
# Processing 1u7f_B (248/2775)...
# Processing 1u7t_D (249/2775)...
# Processing 1ubd_C (250/2775)...
# Processing 1ul1_Z (251/2775)...
# Processing 1umk_A (252/2775)...
# Processing 1upr_A (253/2775)...
# Processing 1ur6_B (254/2775)...
# Processing 1uv0_A (255/2775)...
# Processing 1uvq_B (256/2775)...
# Processing 1uw5_A (257/2775)...
# Processing 1uzj_B (258/2775)...
# Processing 1v5h_A (259/2775)...
# Processing 1v84_A (260/2775)...
# Processing 1vd4_A (261/2775)...
# Processing 1vhr_A (262/2775)...
# Processing 1vtn_C (263/2775)...
# Processing 1w1h_C (264/2775)...
# Processing 1w45_B (265/2775)...
# Processing 1w4r_A (266/2775)...
# Processing 1w4u_A (267/2775)...
# Processing 1w6j_A (268/2775)...
# Processing 1war_A (269/2775)...
# Processing 2biv_A (352/2775)...
# Processing 2bka_A (353/2775)...
# Processing 2ble_A (354/2775)...
# Processing 2bme_B (355/2775)...
# Processing 2bo2_B (356/2775)...
# Processing 2bov_A (357/2775)...
# Processing 2bp1_D (358/2775)...
# Processing 2bwj_E (359/2775)...
# Processing 2bzg_A (360/2775)...
# Processing 2c30_A (361/2775)...
# Processing 2c3q_C (362/2775)...
# Processing 2c47_C (363/2775)...
# Processing 2c6a_A (364/2775)...
# Processing 2c7n_K (365/2775)...
# Processing 2c9y_A (366/2775)...
# Processing 2cg5_B (367/2775)...
# Processing 2cjw_A (368/2775)...
# Processing 2clp_K (369/2775)...
# Processing 2cmw_A (370/2775)...
# Processing 2co8_A (371/2775)...
# Processing 2cr8_A (372/2775)...
# Processing 2cs8_A (373/2775)...
# Processing 2csh_A (374/2775)...
# Processing 2csv_A (375/2775)...
# Processing 2cuq_A (376/2775)...
# Processing 2cw9_A (377/2775)...
# Processing 2cxy_A (378/2775)...
# Processing 2czh_B (379/2775)...
# Processing 2d07_A (380/2775)...
# Processing 2d7i_A (381/2775)...
# Processing 2dar_A (382/2775)...
# Processing 2dho_A (383/2775)...
# Processing 2dj7_A (384/2775)...
# Processing 2dko_B (385/2775)...
# Processing 2dlk_A (386/2775)...
# Processing 2dq7_X (387/2775)...
# Processing 2dud_B (388/2775)...
# Processing 2e2x_B (389/2775)...
# Processing 2e59_A (390/2775)...
# Processing 2e5s_A (391/2775)...
# Processing 2e6i_A (392/2775)...
# Processing 2e6s_A (393/2775)...
# Processing 2e6w_A (394/2775)...
# Processing 2eav_A (395/2775)...
# Processing 2eb1_B (396/2775)...
# Processing 2ebr_A (397/2775)...
# Processing 2ebt_A (398/2775)...
# Processing 2ecv_A (399/2775)...
# Processing 2egm_A (400/2775)...
# Processing 2eli_A (401/2775)...
# Processing 2enn_A (402/2775)...
# Processing 2eod_A (403/2775)...
# Processing 2epp_A (404/2775)...
# Processing 2erf_A (405/2775)...
# Processing 2erx_A (406/2775)...
# Processing 2ery_B (407/2775)...
# Processing 2esl_F (408/2775)...
# Processing 2ew1_A (409/2775)...
# Processing 2f0y_B (410/2775)...
# Processing 2f27_A (411/2775)...
# Processing 2f7s_A (412/2775)...
# Processing 2fby_A (413/2775)...
# Processing 2fcw_B (414/2775)...
# Processing 2fdv_D (415/2775)...
# Processing 2ffu_A (416/2775)...
# Processing 2ffw_A (417/2775)...
# Processing 2fg5_A (418/2775)...
# Processing 2fh1_B (419/2775)...
# Processing 2fim_B (420/2775)...
# Processing 2fj9_A (421/2775)...
# Processing 2fju_B (422/2775)...
# Processing 2fqq_B (423/2775)...
# Processing 2frw_A (424/2775)...
# Processing 2fsz_A (425/2775)...
# Processing 2fu5_B (426/2775)...
# Processing 2fvl_A (427/2775)...
# Processing 2fyl_B (428/2775)...
# Processing 2g2k_A (429/2775)...
# Processing 2g43_A (430/2775)...
# Processing 2g4a_A (431/2775)...
# Processing 2g6b_A (432/2775)...
# Processing 2g9o_A (433/2775)...
# Processing 2gao_B (434/2775)...
# Processing 2gf0_B (435/2775)...
# Processing 2gf9_A (436/2775)...
# Processing 2ggm_A (437/2775)...
# Processing 2ggz_B (438/2775)...
# Processing 2gjx_H (439/2775)...
# Processing 2gk1_Q (440/2775)...
# Processing 2gli_A (441/2775)...
# Processing 2gmv_A (442/2775)...
# Processing 2gp5_A (443/2775)...
# Processing 2gpq_A (444/2775)...
# Processing 2gqj_A (445/2775)...
# Processing 2gql_A (446/2775)...
# Processing 2gwh_A (447/2775)...
# Processing 2gz5_A (448/2775)...
# Processing 2h16_D (449/2775)...
# Processing 2h57_B (450/2775)...
# Processing 2h63_D (451/2775)...
# Processing 2h6h_A (452/2775)...
# Processing 2h8h_A (453/2775)...
# Processing 2h8k_B (454/2775)...
# Processing 2h9e_L (455/2775)...
# Processing 2ha8_A (456/2775)...
# Processing 2hei_B (457/2775)...
# Processing 2hgs_A (458/2775)...
# Processing 2hhl_A (459/2775)...
# Processing 2hhn_A (460/2775)...
# Processing 2hi4_A (461/2775)...
# Processing 2hrb_A (462/2775)...
# Processing 2hup_A (463/2775)...
# Processing 2hw5_A (464/2775)...
# Processing 2hw6_A (465/2775)...
# Processing 2hzq_A (466/2775)...
# Processing 2i0y_A (467/2775)...
# Processing 2i3c_B (468/2775)...
# Processing 2i50_A (469/2775)...
# Processing 2i6a_A (470/2775)...
# Processing 2i6s_A (471/2775)...
# Processing 2i7n_B (472/2775)...
# Processing 2i96_A (473/2775)...
# Processing 2i99_B (474/2775)...
# Processing 2i9a_D (475/2775)...
# Processing 2iby_A (476/2775)...
# Processing 2iim_A (477/2775)...
# Processing 2il1_A (478/2775)...
# Processing 2ipp_A (479/2775)...
# Processing 2iqj_B (480/2775)...
# Processing 2it4_B (481/2775)...
# Processing 2iuw_A (482/2775)...
# Processing 2iwy_A (483/2775)...
# Processing 2iyk_B (484/2775)...
# Processing 2j2p_C (485/2775)...
# Processing 2j2s_A (486/2775)...
# Processing 2j3s_A (487/2775)...
# Processing 2j4o_A (488/2775)...
# Processing 2j5z_B (489/2775)...
# Processing 2j8z_A (490/2775)...
# Processing 2jai_A (491/2775)...
# Processing 2jam_B (492/2775)...
# Processing 2jbh_B (493/2775)...
# Processing 2jdw_A (494/2775)...
# Processing 2jed_A (495/2775)...
# Processing 2jeo_A (496/2775)...
# Processing 2jg9_F (497/2775)...
# Processing 2jif_D (498/2775)...
# Processing 2jis_B (499/2775)...
# Processing 2jld_B (500/2775)...
# Processing 2jlp_C (501/2775)...
# Processing 2jm4_A (502/2775)...
# Processing 2jmo_A (503/2775)...
# Processing 2jox_A (504/2775)...
# Processing 2jrj_A (505/2775)...
# Processing 2jsd_A (506/2775)...
# Processing 2jtf_A (507/2775)...
# Processing 2jyo_A (508/2775)...
# Processing 2k01_C (509/2775)...
# Processing 2k1b_A (510/2775)...
# Processing 2k1j_A (511/2775)...
# Processing 2k2c_A (512/2775)...
# Processing 2k2d_A (513/2775)...
# Processing 2k7d_A (514/2775)...
# Processing 2kc3_A (515/2775)...
# Processing 2kht_A (516/2775)...
# Processing 2ki6_F (517/2775)...
# Processing 2kje_A (518/2775)...
# Processing 2kkr_A (519/2775)...
# Processing 2kkt_A (520/2775)...
# Processing 2kld_A (521/2775)...
# Processing 2knt_A (522/2775)...
# Processing 2ksg_A (523/2775)...
# Processing 2ku3_A (524/2775)...
# Processing 2kul_A (525/2775)...
# Processing 2kuo_A (526/2775)...
# Processing 2kwi_A (527/2775)...
# Processing 2l4s_A (528/2775)...
# Processing 2l51_B (529/2775)...
# Processing 2l70_A (530/2775)...
# Processing 2l7w_A (531/2775)...
# Processing 2l80_A (532/2775)...
# Processing 2lce_A (533/2775)...
# Processing 2lcp_A (534/2775)...
# Processing 2lgk_A (535/2775)...
# Processing 2lgq_A (536/2775)...
# Processing 2lgr_A (537/2775)...
# Processing 2lko_A (538/2775)...
# Processing 2ln0_A (539/2775)...
# Processing 2lnk_A (540/2775)...
# Processing 2lob_A (541/2775)...
# Processing 2lq6_A (542/2775)...
# Processing 2lv7_A (543/2775)...
# Processing 2lvz_A (544/2775)...
# Processing 2lxp_C (545/2775)...
# Processing 2lzu_A (546/2775)...
# Processing 2m0p_A (547/2775)...
# Processing 2m68_A (548/2775)...
# Processing 2m6n_A (549/2775)...
# Processing 2m96_A (550/2775)...
# Processing 2m9a_A (551/2775)...
# Processing 2m9w_A (552/2775)...
# Processing 2ma7_A (553/2775)...
# Processing 2miu_A (554/2775)...
# Processing 2mji_A (555/2775)...
# Processing 2mkd_A (556/2775)...
# Processing 2mm3_A (557/2775)...
# Processing 2mnz_A (558/2775)...
# Processing 2mpf_A (559/2775)...
# Processing 2mph_A (560/2775)...
# Processing 2mse_D (561/2775)...
# Processing 2msv_A (562/2775)...
# Processing 2mwx_A (563/2775)...
# Processing 2mzi_A (564/2775)...
# Processing 2n14_A (565/2775)...
# Processing 2n1a_A (566/2775)...
# Processing 2n1a_B (567/2775)...
# Processing 2n26_A (568/2775)...
# Processing 2n42_A (569/2775)...
# Processing 2n8a_A (570/2775)...
# Processing 2nll_B (571/2775)...
# Processing 2nxp_F (572/2775)...
# Processing 2nyt_C (573/2775)...
# Processing 2nz0_B (574/2775)...
# Processing 2nz2_A (575/2775)...
# Processing 2nzj_C (576/2775)...
# Processing 2nzt_B (577/2775)...
# Processing 2o06_A (578/2775)...
# Processing 2o10_A (579/2775)...
# Processing 2o13_A (580/2775)...
# Processing 2o2f_A (581/2775)...
# Processing 2o52_B (582/2775)...
# Processing 2o6g_E (583/2775)...
# Processing 2o8f_B (584/2775)...
# Processing 2obd_A (585/2775)...
# Processing 2obv_A (586/2775)...
# Processing 2ocb_A (587/2775)...
# Processing 2ocg_A (588/2775)...
# Processing 2ocp_C (589/2775)...
# Processing 2od1_A (590/2775)...
# Processing 2ohf_A (591/2775)...
# Processing 2oil_A (592/2775)...
# Processing 2okv_C (593/2775)...
# Processing 2oo4_B (594/2775)...
# Processing 2opw_A (595/2775)...
# Processing 2ox8_D (596/2775)...
# Processing 2oxc_A (597/2775)...
# Processing 2p0a_A (598/2775)...
# Processing 2p0d_A (599/2775)...
# Processing 2p0r_B (600/2775)...
# Processing 2p0w_A (601/2775)...
# Processing 2p1f_A (602/2775)...
# Processing 2p57_A (603/2775)...
# Processing 2p5s_B (604/2775)...
# Processing 2p8e_B (605/2775)...
# Processing 2pfr_A (606/2775)...
# Processing 2pg5_D (607/2775)...
# Processing 2pid_A (608/2775)...
# Processing 2pl0_A (609/2775)...
# Processing 2pla_A (610/2775)...
# Processing 2pmy_A (611/2775)...
# Processing 2pqf_D (612/2775)...
# Processing 2pru_B (613/2775)...
# Processing 2psn_D (614/2775)...
# Processing 2puy_A (615/2775)...
# Processing 2pvs_A (616/2775)...
# Processing 2q3f_B (617/2775)...
# Processing 2q3h_A (618/2775)...
# Processing 2q3z_A (619/2775)...
# Processing 2q5e_D (620/2775)...
# Processing 2q7r_F (621/2775)...
# Processing 2q8f_A (622/2775)...
# Processing 2q98_A (623/2775)...
# Processing 2qic_A (624/2775)...
# Processing 2qk4_B (625/2775)...
# Processing 2qkk_W (626/2775)...
# Processing 2qpp_B (627/2775)...
# Processing 2qra_C (628/2775)...
# Processing 2qst_B (629/2775)...
# Processing 2qt7_B (630/2775)...
# Processing 2qtz_A (631/2775)...
# Processing 2qym_A (632/2775)...
# Processing 2r3a_A (633/2775)...
# Processing 2r5g_A (634/2775)...
# Processing 2r83_A (635/2775)...
# Processing 2r8u_A (636/2775)...
# Processing 2ra4_B (637/2775)...
# Processing 2raj_A (638/2775)...
# Processing 2rb3_C (639/2775)...
# Processing 2rb4_B (640/2775)...
# Processing 2rc4_A (641/2775)...
# Processing 2rhp_A (642/2775)...
# Processing 2rje_B (643/2775)...
# Processing 2rjp_B (644/2775)...
# Processing 2rjq_A (645/2775)...
# Processing 2rkb_C (646/2775)...
# Processing 2rli_A (647/2775)...
# Processing 2rmk_A (648/2775)...
# Processing 2rsg_A (649/2775)...
# Processing 2rsq_A (650/2775)...
# Processing 2ruy_A (651/2775)...
# Processing 2uur_A (652/2775)...
# Processing 2uvl_A (653/2775)...
# Processing 2uyy_D (654/2775)...
# Processing 2uzg_A (655/2775)...
# Processing 2v40_A (656/2775)...
# Processing 2v55_B (657/2775)...
# Processing 2vac_A (658/2775)...
# Processing 2vcv_J (659/2775)...
# Processing 2vd5_B (660/2775)...
# Processing 2vdy_A (661/2775)...
# Processing 2vhf_A (662/2775)...
# Processing 2vkq_A (663/2775)...
# Processing 2vm5_A (664/2775)...
# Processing 2vn9_A (665/2775)...
# Processing 2vq3_A (666/2775)...
# Processing 2vr2_A (667/2775)...
# Processing 2vrd_A (668/2775)...
# Processing 2vrg_A (669/2775)...
# Processing 2vsc_C (670/2775)...
# Processing 2vwi_D (671/2775)...
# Processing 2vxo_A (672/2775)...
# Processing 2w0t_A (673/2775)...
# Processing 2w2i_A (674/2775)...
# Processing 2w3o_B (675/2775)...
# Processing 2w4l_E (676/2775)...
# Processing 2w4o_A (677/2775)...
# Processing 2w4r_D (678/2775)...
# Processing 2w86_A (679/2775)...
# Processing 2w8p_A (680/2775)...
# Processing 2wbi_B (681/2775)...
# Processing 2wce_A (682/2775)...
# Processing 2wef_A (683/2775)...
# Processing 2wh5_E (684/2775)...
# Processing 2wjy_A (685/2775)...
# Processing 2wk6_B (686/2775)...
# Processing 2wno_A (687/2775)...
# Processing 2wtk_E (688/2775)...
# Processing 2wtk_F (689/2775)...
# Processing 2wwy_B (690/2775)...
# Processing 2wwz_C (691/2775)...
# Processing 2wya_C (692/2775)...
# Processing 2wzb_A (693/2775)...
# Processing 2x10_A (694/2775)...
# Processing 2x11_B (695/2775)...
# Processing 2x4d_A (696/2775)...
# Processing 2x4f_B (697/2775)...
# Processing 2x4w_A (698/2775)...
# Processing 2x7g_A (699/2775)...
# Processing 2x7h_B (700/2775)...
# Processing 2xik_A (701/2775)...
# Processing 2xmr_C (702/2775)...
# Processing 2xn3_B (703/2775)...
# Processing 2xph_A (704/2775)...
# Processing 2xrc_D (705/2775)...
# Processing 2xsx_A (706/2775)...
# Processing 2xtp_A (707/2775)...
# Processing 2xzg_A (708/2775)...
# Processing 2y1h_A (709/2775)...
# Processing 2y1l_D (710/2775)...
# Processing 2y23_A (711/2775)...
# Processing 2y43_B (712/2775)...
# Processing 2y7j_D (713/2775)...
# Processing 2yan_A (714/2775)...
# Processing 2yd8_A (715/2775)...
# Processing 2ygq_A (716/2775)...
# Processing 2yh0_A (717/2775)...
# Processing 2yho_C (718/2775)...
# Processing 2yqm_A (719/2775)...
# Processing 2yrt_A (720/2775)...
# Processing 2ysl_A (721/2775)...
# Processing 2yu2_A (722/2775)...
# Processing 2yvr_A (723/2775)...
# Processing 2z0u_B (724/2775)...
# Processing 2z15_C (725/2775)...
# Processing 2z4e_E (726/2775)...
# Processing 2z5f_B (727/2775)...
# Processing 2zfu_B (728/2775)...
# Processing 2zg1_A (729/2775)...
# Processing 2znv_D (730/2775)...
# Processing 2zoc_A (731/2775)...
# Processing 2zoq_A (732/2775)...
# Processing 2zox_A (733/2775)...
# Processing 2zrt_G (734/2775)...
# Processing 3a2a_B (735/2775)...
# Processing 3a4s_A (736/2775)...
# Processing 3a4u_A (737/2775)...
# Processing 3aad_A (738/2775)...
# Processing 3aco_A (739/2775)...
# Processing 3ahq_A (740/2775)...
# Processing 3aih_A (741/2775)...
# Processing 3alq_R (742/2775)...
# Processing 3ap3_A (743/2775)...
# Processing 3b2d_A (744/2775)...
# Processing 3b3l_A (745/2775)...
# Processing 3b6r_B (746/2775)...
# Processing 3b6u_A (747/2775)...
# Processing 3b6v_A (748/2775)...
# Processing 3bce_A (749/2775)...
# Processing 3ber_A (750/2775)...
# Processing 3bfx_A (751/2775)...
# Processing 3bh7_B (752/2775)...
# Processing 3bhm_A (753/2775)...
# Processing 3bi6_A (754/2775)...
# Processing 3bjc_A (755/2775)...
# Processing 3bm4_B (756/2775)...
# Processing 3bo5_A (757/2775)...
# Processing 3brh_A (758/2775)...
# Processing 3bsu_H (759/2775)...
# Processing 3bvo_B (760/2775)...
# Processing 3c5c_D (761/2775)...
# Processing 3c5e_A (762/2775)...
# Processing 3c6k_A (763/2775)...
# Processing 3c6w_C (764/2775)...
# Processing 3cbb_B (765/2775)...
# Processing 3cbk_A (766/2775)...
# Processing 3cbq_A (767/2775)...
# Processing 3cfw_A (768/2775)...
# Processing 3cos_C (769/2775)...
# Processing 3ctz_A (770/2775)...
# Processing 3cxp_A (771/2775)...
# Processing 3d0e_B (772/2775)...
# Processing 3d24_C (773/2775)...
# Processing 3d2f_D (774/2775)...
# Processing 3d34_B (775/2775)...
# Processing 3d3l_B (776/2775)...
# Processing 3d3w_B (777/2775)...
# Processing 3d5o_B (778/2775)...
# Processing 3d87_B (779/2775)...
# Processing 3d8b_A (780/2775)...
# Processing 3d8e_C (781/2775)...
# Processing 3ddu_A (782/2775)...
# Processing 3dem_B (783/2775)...
# Processing 3dk9_A (784/2775)...
# Processing 3dko_A (785/2775)...
# Processing 3dlj_B (786/2775)...
# Processing 3dls_C (787/2775)...
# Processing 3dwb_A (788/2775)...
# Processing 3dyd_B (789/2775)...
# Processing 3dz4_B (790/2775)...
# Processing 3e1y_B (791/2775)...
# Processing 3e3r_B (792/2775)...
# Processing 3e4c_B (793/2775)...
# Processing 3e6i_B (794/2775)...
# Processing 3eb5_A (795/2775)...
# Processing 3edy_A (796/2775)...
# Processing 3eh1_A (797/2775)...
# Processing 3eh2_B (798/2775)...
# Processing 3elb_A (799/2775)...
# Processing 3epy_B (800/2775)...
# Processing 3epz_A (801/2775)...
# Processing 3eta_A (802/2775)...
# Processing 3eue_A (803/2775)...
# Processing 3exi_B (804/2775)...
# Processing 3eyh_A (805/2775)...
# Processing 3f1r_B (806/2775)...
# Processing 3f3y_A (807/2775)...
# Processing 3f5o_E (808/2775)...
# Processing 3f70_B (809/2775)...
# Processing 3f7u_C (810/2775)...
# Processing 3f9p_A (811/2775)...
# Processing 3fcx_B (812/2775)...
# Processing 3fd6_B (813/2775)...
# Processing 3fe2_B (814/2775)...
# Processing 3fe3_A (815/2775)...
# Processing 3fe4_A (816/2775)...
# Processing 3fec_A (817/2775)...
# Processing 3ff6_D (818/2775)...
# Processing 3ffk_A (819/2775)...
# Processing 3fg6_F (820/2775)...
# Processing 3fl2_A (821/2775)...
# Processing 3flv_B (822/2775)...
# Processing 3fvy_A (823/2775)...
# Processing 3fy1_A (824/2775)...
# Processing 3g4h_A (825/2775)...
# Processing 3g73_A (826/2775)...
# Processing 3g9y_A (827/2775)...
# Processing 3gbj_A (828/2775)...
# Processing 3gc9_B (829/2775)...
# Processing 3gdh_B (830/2775)...
# Processing 3gdq_A (831/2775)...
# Processing 3gep_B (832/2775)...
# Processing 3ggf_B (833/2775)...
# Processing 3ghg_C (834/2775)...
# Processing 3gis_Z (835/2775)...
# Processing 3gjx_E (836/2775)...
# Processing 3gkh_A (837/2775)...
# Processing 3gpd_G (838/2775)...
# Processing 3gqc_D (839/2775)...
# Processing 3gta_A (840/2775)...
# Processing 3gxb_A (841/2775)...
# Processing 3gzd_A (842/2775)...
# Processing 3h2u_B (843/2775)...
# Processing 3h53_B (844/2775)...
# Processing 3hco_B (845/2775)...
# Processing 3hf1_A (846/2775)...
# Processing 3hn3_B (847/2775)...
# Processing 3ho4_A (848/2775)...
# Processing 3hr4_G (849/2775)...
# Processing 3hud_B (850/2775)...
# Processing 3hxt_A (851/2775)...
# Processing 3hy8_A (852/2775)...
# Processing 3ia8_A (853/2775)...
# Processing 3iei_H (854/2775)...
# Processing 3ihp_B (855/2775)...
# Processing 3ik7_B (856/2775)...
# Processing 3io2_A (857/2775)...
# Processing 3isq_A (858/2775)...
# Processing 3iu6_A (859/2775)...
# Processing 3iuf_A (860/2775)...
# Processing 3iuy_A (861/2775)...
# Processing 3iwl_A (862/2775)...
# Processing 3ixe_B (863/2775)...
# Processing 3ixs_K (864/2775)...
# Processing 3j0a_A (865/2775)...
# Processing 3j2s_B (866/2775)...
# Processing 3jrx_A (867/2775)...
# Processing 3jub_A (868/2775)...
# Processing 3jue_A (869/2775)...
# Processing 3jyh_A (870/2775)...
# Processing 3k2s_B (871/2775)...
# Processing 3k51_B (872/2775)...
# Processing 3k5t_A (873/2775)...
# Processing 3k7v_A (874/2775)...
# Processing 3k9j_A (875/2775)...
# Processing 3k9o_A (876/2775)...
# Processing 3kcg_I (877/2775)...
# Processing 3kn1_A (878/2775)...
# Processing 3kq0_A (879/2775)...
# Processing 3kq4_B (880/2775)...
# Processing 3kqg_A (881/2775)...
# Processing 3kuc_A (882/2775)...
# Processing 3kv5_A (883/2775)...
# Processing 3kvo_A (884/2775)...
# Processing 3kyd_A (885/2775)...
# Processing 3l43_B (886/2775)...
# Processing 3lea_B (887/2775)...
# Processing 3lf5_B (888/2775)...
# Processing 3lgd_B (889/2775)...
# Processing 3ljw_A (890/2775)...
# Processing 3lkj_C (891/2775)...
# Processing 3llk_A (892/2775)...
# Processing 3lqc_A (893/2775)...
# Processing 3lqh_A (894/2775)...
# Processing 3lrq_C (895/2775)...
# Processing 3lru_B (896/2775)...
# Processing 3ltl_B (897/2775)...
# Processing 3luc_A (898/2775)...
# Processing 3lxj_A (899/2775)...
# Processing 3lxx_A (900/2775)...
# Processing 3ly5_A (901/2775)...
# Processing 3lyr_A (902/2775)...
# Processing 3m1d_B (903/2775)...
# Processing 3m52_A (904/2775)...
# Processing 3mb3_A (905/2775)...
# Processing 3mb4_B (906/2775)...
# Processing 3mbg_C (907/2775)...
# Processing 3mdi_A (908/2775)...
# Processing 3mdy_C (909/2775)...
# Processing 3mdz_A (910/2775)...
# Processing 3mgm_A (911/2775)...
# Processing 3mjh_B (912/2775)...
# Processing 3mp5_B (913/2775)...
# Processing 3mq7_L (914/2775)...
# Processing 3mqi_C (915/2775)...
# Processing 3mtg_B (916/2775)...
# Processing 3mtn_A (917/2775)...
# Processing 3my0_J (918/2775)...
# Processing 3mzg_B (919/2775)...
# Processing 3n1g_A (920/2775)...
# Processing 3n1m_B (921/2775)...
# Processing 3n5n_Y (922/2775)...
# Processing 3n7o_A (923/2775)...
# Processing 3na1_A (924/2775)...
# Processing 3ncu_A (925/2775)...
# Processing 3ner_B (926/2775)...
# Processing 3nks_A (927/2775)...
# Processing 3nmq_A (928/2775)...
# Processing 3nmz_B (929/2775)...
# Processing 3nv1_A (930/2775)...
# Processing 3nvq_B (931/2775)...
# Processing 3nwn_A (932/2775)...
# Processing 3nxb_A (933/2775)...
# Processing 3nyn_B (934/2775)...
# Processing 3o0g_A (935/2775)...
# Processing 3o4r_B (936/2775)...
# Processing 3o4s_A (937/2775)...
# Processing 3o7a_A (938/2775)...
# Processing 3oag_A (939/2775)...
# Processing 3oes_A (940/2775)...
# Processing 3oj3_J (941/2775)...
# Processing 3ojy_B (942/2775)...
# Processing 3orh_B (943/2775)...
# Processing 3otc_B (944/2775)...
# Processing 3ovp_B (945/2775)...
# Processing 3p0f_A (946/2775)...
# Processing 3p57_A (947/2775)...
# Processing 3pb4_X (948/2775)...
# Processing 3pe0_A (949/2775)...
# Processing 3pja_K (950/2775)...
# Processing 3pls_A (951/2775)...
# Processing 3pm0_A (952/2775)...
# Processing 3poo_A (953/2775)...
# Processing 3pse_B (954/2775)...
# Processing 3q13_A (955/2775)...
# Processing 3q19_A (956/2775)...
# Processing 3q1d_A (957/2775)...
# Processing 3q2u_A (958/2775)...
# Processing 3q3j_B (959/2775)...
# Processing 3q6z_A (960/2775)...
# Processing 3qcj_A (961/2775)...
# Processing 3qfb_B (962/2775)...
# Processing 3qj4_A (963/2775)...
# Processing 3qj5_B (964/2775)...
# Processing 3qmh_A (965/2775)...
# Processing 3qni_A (966/2775)...
# Processing 3qpu_A (967/2775)...
# Processing 3qrf_F (968/2775)...
# Processing 3qxy_B (969/2775)...
# Processing 3r6b_A (970/2775)...
# Processing 3rap_S (971/2775)...
# Processing 3ray_A (972/2775)...
# Processing 3rbl_B (973/2775)...
# Processing 3rc3_A (974/2775)...
# Processing 3rgk_A (975/2775)...
# Processing 3rk2_G (976/2775)...
# Processing 3rq4_A (977/2775)...
# Processing 3rz3_C (978/2775)...
# Processing 3rzv_A (979/2775)...
# Processing 3s4y_A (980/2775)...
# Processing 3sbz_A (981/2775)...
# Processing 3sh5_A (982/2775)...
# Processing 3sjv_F (983/2775)...
# Processing 3sn5_B (984/2775)...
# Processing 3szb_B (985/2775)...
# Processing 3t6a_A (986/2775)...
# Processing 3t7l_A (987/2775)...
# Processing 3t9i_A (988/2775)...
# Processing 3tac_A (989/2775)...
# Processing 3thd_D (990/2775)...
# Processing 3tkl_A (991/2775)...
# Processing 3top_A (992/2775)...
# Processing 3tvl_A (993/2775)...
# Processing 3twj_B (994/2775)...
# Processing 3u5n_A (995/2775)...
# Processing 3u8u_A (996/2775)...
# Processing 3ucw_A (997/2775)...
# Processing 3uh4_B (998/2775)...
# Processing 3uk3_C (999/2775)...
# Processing 3ukm_C (1000/2775)...
# Processing 3uyq_A (1001/2775)...
# Processing 3uzx_B (1002/2775)...
# Processing 3v3l_A (1003/2775)...
# Processing 3v4v_B (1004/2775)...
# Processing 3v4v_C (1005/2775)...
# Processing 3v70_A (1006/2775)...
# Processing 4cbo_A (1085/2775)...
# Processing 4cc0_A (1086/2775)...
# Processing 4ccg_X (1087/2775)...
# Processing 4ccz_A (1088/2775)...
# Processing 4cfr_Q (1089/2775)...
# Processing 4cj6_A (1090/2775)...
# Processing 4cmn_A (1091/2775)...
# Processing 4cql_G (1092/2775)...
# Processing 4cql_P (1093/2775)...
# Processing 4crs_A (1094/2775)...
# Processing 4ct4_D (1095/2775)...
# Processing 4cvh_A (1096/2775)...
# Processing 4cvo_A (1097/2775)...
# Processing 4cz2_B (1098/2775)...
# Processing 4d08_D (1099/2775)...
# Processing 4d0g_A (1100/2775)...
# Processing 4d1p_B (1101/2775)...
# Processing 4d2n_D (1102/2775)...
# Processing 4d50_A (1103/2775)...
# Processing 4d8k_A (1104/2775)...
# Processing 4d90_B (1105/2775)...
# Processing 4da1_A (1106/2775)...
# Processing 4dg6_A (1107/2775)...
# Processing 4dgl_A (1108/2775)...
# Processing 4dgl_C (1109/2775)...
# Processing 4din_B (1110/2775)...
# Processing 4diq_A (1111/2775)...
# Processing 4dir_A (1112/2775)...
# Processing 4drb_F (1113/2775)...
# Processing 4duq_B (1114/2775)...
# Processing 4dur_A (1115/2775)...
# Processing 4dxa_B (1116/2775)...
# Processing 4dy7_C (1117/2775)...
# Processing 4e3c_D (1118/2775)...
# Processing 4e4m_B (1119/2775)...
# Processing 4e93_A (1120/2775)...
# Processing 4e9e_A (1121/2775)...
# Processing 4egc_B (1122/2775)...
# Processing 4epu_A (1123/2775)...
# Processing 4erc_A (1124/2775)...
# Processing 4ezf_A (1125/2775)...
# Processing 4f14_A (1126/2775)...
# Processing 4f5b_A (1127/2775)...
# Processing 4f80_A (1128/2775)...
# Processing 4f9c_B (1129/2775)...
# Processing 4fao_B (1130/2775)...
# Processing 4fc7_C (1131/2775)...
# Processing 4fdi_A (1132/2775)...
# Processing 4fgb_A (1133/2775)...
# Processing 4fgu_B (1134/2775)...
# Processing 4fl6_B (1135/2775)...
# Processing 4fmw_B (1136/2775)...
# Processing 4fom_A (1137/2775)...
# Processing 4fqf_A (1138/2775)...
# Processing 4fr4_F (1139/2775)...
# Processing 4fu4_C (1140/2775)...
# Processing 4fvl_A (1141/2775)...
# Processing 4fwj_A (1142/2775)...
# Processing 4g8a_B (1143/2775)...
# Processing 4gei_A (1144/2775)...
# Processing 4gk0_F (1145/2775)...
# Processing 4gmj_B (1146/2775)...
# Processing 4gnf_A (1147/2775)...
# Processing 4gnk_D (1148/2775)...
# Processing 4gos_A (1149/2775)...
# Processing 4gqq_A (1150/2775)...
# Processing 4gup_C (1151/2775)...
# Processing 4h2d_B (1152/2775)...
# Processing 4h5r_B (1153/2775)...
# Processing 4h7w_A (1154/2775)...
# Processing 4hai_A (1155/2775)...
# Processing 4haz_A (1156/2775)...
# Processing 4hc7_A (1157/2775)...
# Processing 4hlq_A (1158/2775)...
# Processing 4hni_B (1159/2775)...
# Processing 4hon_A (1160/2775)...
# Processing 4hvy_A (1161/2775)...
# Processing 4i5j_A (1162/2775)...
# Processing 4i6b_A (1163/2775)...
# Processing 4ic2_A (1164/2775)...
# Processing 4ic7_D (1165/2775)...
# Processing 4iej_A (1166/2775)...
# Processing 4ig8_A (1167/2775)...
# Processing 4ii1_B (1168/2775)...
# Processing 4iqm_A (1169/2775)...
# Processing 4iqy_B (1170/2775)...
# Processing 4iy0_A (1171/2775)...
# Processing 4j14_A (1172/2775)...
# Processing 4j1y_B (1173/2775)...
# Processing 4j4p_B (1174/2775)...
# Processing 4jvn_A (1175/2775)...
# Processing 4jxf_A (1176/2775)...
# Processing 4jzj_C (1177/2775)...
# Processing 4k7i_C (1178/2775)...
# Processing 4k85_C (1179/2775)...
# Processing 4kfz_B (1180/2775)...
# Processing 4ki5_M (1181/2775)...
# Processing 4kki_A (1182/2775)...
# Processing 4klz_A (1183/2775)...
# Processing 4kq8_A (1184/2775)...
# Processing 4kxc_A (1185/2775)...
# Processing 4kyi_H (1186/2775)...
# Processing 4l1j_B (1187/2775)...
# Processing 4l58_A (1188/2775)...
# Processing 4l7n_A (1189/2775)...
# Processing 4l9m_A (1190/2775)...
# Processing 4lay_A (1191/2775)...
# Processing 4lec_B (1192/2775)...
# Processing 4lhx_B (1193/2775)...
# Processing 4liq_E (1194/2775)...
# Processing 4lot_A (1195/2775)...
# Processing 4lqy_A (1196/2775)...
# Processing 4lt6_A (1197/2775)...
# Processing 4m6r_D (1198/2775)...
# Processing 4mew_A (1199/2775)...
# Processing 4mf3_A (1200/2775)...
# Processing 4mhv_B (1201/2775)...
# Processing 4mqw_X (1202/2775)...
# Processing 4msp_A (1203/2775)...
# Processing 4mvt_C (1204/2775)...
# Processing 4mwi_A (1205/2775)...
# Processing 4myg_A (1206/2775)...
# Processing 4n2c_A (1207/2775)...
# Processing 4n4a_A (1208/2775)...
# Processing 4neh_A (1209/2775)...
# Processing 4ngg_A (1210/2775)...
# Processing 4nn2_B (1211/2775)...
# Processing 4nnr_B (1212/2775)...
# Processing 4npv_A (1213/2775)...
# Processing 4nqa_I (1214/2775)...
# Processing 4ns5_A (1215/2775)...
# Processing 4nsq_C (1216/2775)...
# Processing 4nt5_A (1217/2775)...
# Processing 4nxs_B (1218/2775)...
# Processing 4o0c_B (1219/2775)...
# Processing 4o2w_B (1220/2775)...
# Processing 4o68_A (1221/2775)...
# Processing 4oav_B (1222/2775)...
# Processing 4oem_B (1223/2775)...
# Processing 4oj2_X (1224/2775)...
# Processing 4ojk_A (1225/2775)...
# Processing 4omc_E (1226/2775)...
# Processing 4oni_A (1227/2775)...
# Processing 4onn_B (1228/2775)...
# Processing 4or9_A (1229/2775)...
# Processing 4orw_A (1230/2775)...
# Processing 4otg_A (1231/2775)...
# Processing 4p0p_A (1232/2775)...
# Processing 4p13_C (1233/2775)...
# Processing 4p5w_A (1234/2775)...
# Processing 4p60_A (1235/2775)...
# Processing 4pcu_A (1236/2775)...
# Processing 4pcw_B (1237/2775)...
# Processing 4px2_A (1238/2775)...
# Processing 4pzi_A (1239/2775)...
# Processing 4q4b_A (1240/2775)...
# Processing 4q4d_A (1241/2775)...
# Processing 4q6f_A (1242/2775)...
# Processing 4q7y_A (1243/2775)...
# Processing 4q93_A (1244/2775)...
# Processing 4q9u_E (1245/2775)...
# Processing 4qbm_A (1246/2775)...
# Processing 4qc3_A (1247/2775)...
# Processing 4qil_A (1248/2775)...
# Processing 4qmx_A (1249/2775)...
# Processing 4qn9_A (1250/2775)...
# Processing 4qpn_A (1251/2775)...
# Processing 4qu6_A (1252/2775)...
# Processing 4r1f_A (1253/2775)...
# Processing 4r2d_A (1254/2775)...
# Processing 4r6u_A (1255/2775)...
# Processing 4r7a_B (1256/2775)...
# Processing 4r7p_B (1257/2775)...
# Processing 4r8p_K (1258/2775)...
# Processing 4rau_L (1259/2775)...
# Processing 4rda_A (1260/2775)...
# Processing 4re1_A (1261/2775)...
# Processing 4re8_B (1262/2775)...
# Processing 4rec_A (1263/2775)...
# Processing 4rer_A (1264/2775)...
# Processing 4rfq_A (1265/2775)...
# Processing 4rg1_A (1266/2775)...
# Processing 4rkk_A (1267/2775)...
# Processing 4rn0_A (1268/2775)...
# Processing 4rr2_A (1269/2775)...
# Processing 4rsu_F (1270/2775)...
# Processing 4ruh_B (1271/2775)...
# Processing 4s15_A (1272/2775)...
# Processing 4s3o_B (1273/2775)...
# Processing 4s3o_C (1274/2775)...
# Processing 4tlg_A (1275/2775)...
# Processing 4tnt_A (1276/2775)...
# Processing 4ttv_A (1277/2775)...
# Processing 4twe_B (1278/2775)...
# Processing 4u5t_A (1279/2775)...
# Processing 4u8d_A (1280/2775)...
# Processing 4ueg_A (1281/2775)...
# Processing 4uem_A (1282/2775)...
# Processing 4ug2_A (1283/2775)...
# Processing 4uhz_A (1284/2775)...
# Processing 4ui9_S (1285/2775)...
# Processing 4um8_D (1286/2775)...
# Processing 4usf_B (1287/2775)...
# Processing 4ust_A (1288/2775)...
# Processing 4uu6_A (1289/2775)...
# Processing 4uuu_A (1290/2775)...
# Processing 4uy2_B (1291/2775)...
# Processing 4uy9_A (1292/2775)...
# Processing 4uya_A (1293/2775)...
# Processing 4uye_B (1294/2775)...
# Processing 4v0h_D (1295/2775)...
# Processing 4v3k_F (1296/2775)...
# Processing 4v6x_Aa (1297/2775)...
# Processing 4v6x_Af (1298/2775)...
# Processing 4wgk_A (1299/2775)...
# Processing 4whv_I (1300/2775)...
# Processing 4wle_D (1301/2775)...
# Processing 4wmq_A (1302/2775)...
# Processing 4wqn_B (1303/2775)...
# Processing 4wzx_A (1304/2775)...
# Processing 4x0q_B (1305/2775)...
# Processing 4x30_A (1306/2775)...
# Processing 4x7q_B (1307/2775)...
# Processing 4x93_B (1308/2775)...
# Processing 4xcx_A (1309/2775)...
# Processing 4xdp_A (1310/2775)...
# Processing 4xft_A (1311/2775)...
# Processing 4xhz_A (1312/2775)...
# Processing 4xp7_A (1313/2775)...
# Processing 4xwh_A (1314/2775)...
# Processing 4xyj_H (1315/2775)...
# Processing 4xzp_A (1316/2775)...
# Processing 4y05_A (1317/2775)...
# Processing 4y7b_A (1318/2775)...
# Processing 7zi9_A (2589/2775)...
# Processing 7zjv_A (2590/2775)...
# Processing 7zmk_X (2591/2775)...
# Processing 7zmv_D (2592/2775)...
# Processing 7zmx_A (2593/2775)...
# Processing 7zr0_A (2594/2775)...
# Processing 7zr6_P (2595/2775)...
# Processing 7zrr_A (2596/2775)...
# Processing 7zsc_C (2597/2775)...
# Processing 7zyg_A (2598/2775)...
# Processing 7zyh_J (2599/2775)...
# Processing 7zyu_A (2600/2775)...
# Processing 7zzp_A (2601/2775)...
# Processing 8a0v_A (2602/2775)...
# Processing 8a38_C (2603/2775)...
# Processing 8a40_U (2604/2775)...
# Processing 8a4c_D (2605/2775)...
# Processing 8a4k_B (2606/2775)...
# Processing 8a6l_B (2607/2775)...
# Processing 8a8m_A (2608/2775)...
# Processing 8ajo_A (2609/2775)...
# Processing 8ari_W (2610/2775)...
# Processing 8as4_B (2611/2775)...
# Processing 8ayf_A (2612/2775)...
# Processing 8aza_A (2613/2775)...
# Processing 8b0a_K (2614/2775)...
# Processing 8b0f_C (2615/2775)...
# Processing 8b0f_F (2616/2775)...
# Processing 8b0g_J (2617/2775)...
# Processing 8b0h_E (2618/2775)...
# Processing 8b10_A (2619/2775)...
# Processing 8b5r_P (2620/2775)...
# Processing 8b6l_L (2621/2775)...
# Processing 8b6l_N (2622/2775)...
# Processing 8b6l_O (2623/2775)...
# Processing 8b9e_A (2624/2775)...
# Processing 8bah_B (2625/2775)...
# Processing 8bbg_C (2626/2775)...
# Processing 8bbs_A (2627/2775)...
# Processing 8bc9_J (2628/2775)...
# Processing 8blp_C (2629/2775)...
# Processing 8bot_U (2630/2775)...
# Processing 8bot_X (2631/2775)...
# Processing 8bub_B (2632/2775)...
# Processing 8bya_B (2633/2775)...
# Processing 8byl_B (2634/2775)...
# Processing 8bzy_A (2635/2775)...
# Processing 8c3u_A (2636/2775)...
# Processing 8c6j_7 (2637/2775)...
# Processing 8ca0_B (2638/2775)...
# Processing 8ch6_y (2639/2775)...
# Processing 8cqb_A (2640/2775)...
# Processing 8cr1_B (2641/2775)...
# Processing 8css_8 (2642/2775)...
# Processing 8cua_C (2643/2775)...
# Processing 8cuc_F (2644/2775)...
# Processing 8cv5_A (2645/2775)...
# Processing 8cx0_A (2646/2775)...
# Processing 8d1e_D (2647/2775)...
# Processing 8d1l_C (2648/2775)...
# Processing 8d30_A (2649/2775)...
# Processing 8d3c_E (2650/2775)...
# Processing 8d3v_A (2651/2775)...
# Processing 8d6e_A (2652/2775)...
# Processing 8d7z_C (2653/2775)...
# Processing 8d8i_A (2654/2775)...
# Processing 8daf_A (2655/2775)...
# Processing 8dbk_B (2656/2775)...
# Processing 8dey_F (2657/2775)...
# Processing 8dkm_P (2658/2775)...
# Processing 8dmk_G (2659/2775)...
# Processing 8dnu_D (2660/2775)...
# Processing 8dph_A (2661/2775)...
# Processing 8dyd_A (2662/2775)...
# Processing 8dyl_B (2663/2775)...
# Processing 8e0c_A (2664/2775)...
# Processing 8e0f_B (2665/2775)...
# Processing 8e1a_A (2666/2775)...
# Processing 8e3y_R (2667/2775)...
# Processing 8e4y_A (2668/2775)...
# Processing 8e8v_A (2669/2775)...
# Processing 8e93_B (2670/2775)...
# Processing 8e98_C (2671/2775)...
# Processing 8e9z_A (2672/2775)...
# Processing 8ede_B (2673/2775)...
# Processing 8ef7_A (2674/2775)...
# Processing 8efg_A (2675/2775)...
# Processing 8efq_R (2676/2775)...
# Processing 8eg3_A (2677/2775)...
# Processing 8egx_B (2678/2775)...
# Processing 8eih_A (2679/2775)...
# Processing 8eiq_A (2680/2775)...
# Processing 8ejm_A (2681/2775)...
# Processing 8emr_B (2682/2775)...
# Processing 8eok_G (2683/2775)...
# Processing 8eop_A (2684/2775)...
# Processing 8eor_B (2685/2775)...
# Processing 8epl_A (2686/2775)...
# Processing 8esv_A (2687/2775)...
# Processing 8eyk_F (2688/2775)...
# Processing 8eyo_A (2689/2775)...
# Processing 8f7s_R (2690/2775)...
# Processing 8fb2_B (2691/2775)...
# Processing 8fc7_B (2692/2775)...
# Processing 8ffv_A (2693/2775)...
# Processing 8ffw_D (2694/2775)...
# Processing 8fgw_C (2695/2775)...
# Processing 8fjx_A (2696/2775)...
# Processing 8fmu_B (2697/2775)...
# Processing 8fnb_B (2698/2775)...
# Processing 8foa_A (2699/2775)...
# Processing 8fp1_A (2700/2775)...
# Processing 8fw5_B (2701/2775)...
# Processing 8fyh_I (2702/2775)...
# Processing 8g0l_A (2703/2775)...
# Processing 8g46_B (2704/2775)...
# Processing 8g7n_A (2705/2775)...
# Processing 8g9p_D (2706/2775)...
# Processing 8gju_D (2707/2775)...
# Processing 8gk3_H (2708/2775)...
# Processing 8gnn_A (2709/2775)...
# Processing 8gui_K (2710/2775)...
# Processing 8gx3_A (2711/2775)...
# Processing 8gye_A (2712/2775)...
# Processing 8gyx_B (2713/2775)...
# Processing 8gz2_B (2714/2775)...
# Processing 8h65_C (2715/2775)...
# Processing 8h8j_C (2716/2775)...
# Processing 8hbe_B (2717/2775)...
# Processing 8hdp_R (2718/2775)...
# Processing 8hy5_B (2719/2775)...
# Processing 8i1o_A (2720/2775)...
# Processing 8i5y_A (2721/2775)...
# Processing 8i5y_B (2722/2775)...
# Processing 8i9u_J (2723/2775)...
# Processing 8i9u_O (2724/2775)...
# Processing 8ifo_A (2725/2775)...
# Processing 8il3_C (2726/2775)...
# Processing 8iqn_A (2727/2775)...
# Processing 8irr_R (2728/2775)...
# Processing 8iuh_3 (2729/2775)...
# Processing 8iwu_A (2730/2775)...
# Processing 8iys_R (2731/2775)...
# Processing 8jbn_B (2732/2775)...
# Processing 8jdl_AP (2733/2775)...
# Processing 8jhf_A (2734/2775)...
# Processing 8jii_A (2735/2775)...
# Processing 8jyg_B (2736/2775)...
# Processing 8kb5_G (2737/2775)...
# Processing 8odo_A (2738/2775)...
# Processing 8oew_O (2739/2775)...
# Processing 8oi8_A (2740/2775)...
# Processing 8oma_A (2741/2775)...
# Processing 8omr_A (2742/2775)...
# Processing 8oxy_A (2743/2775)...
# Processing 8p50_B (2744/2775)...
# Processing 8p8x_A (2745/2775)...
# Processing 8p94_A (2746/2775)...
# Processing 8pqh_A (2747/2775)...
# Processing 8q7n_K (2748/2775)...
# Processing 8qk3_E (2749/2775)...
# Processing 8qy4_D (2750/2775)...
# Processing 8rbx_W (2751/2775)...
# Processing 8sg5_H (2752/2775)...
# Processing 8sgo_C (2753/2775)...
# Processing 8syp_C (2754/2775)...
# Processing 8t6j_A (2755/2775)...
# Processing 8t9h_K (2756/2775)...
# Processing 8tar_N (2757/2775)...
# Processing 8tgd_A (2758/2775)...
# Processing 8tnq_B (2759/2775)...
# Processing 8tzo_C (2760/2775)...
# Processing 8tzs_A (2761/2775)...
# Processing 8u26_R (2762/2775)...
# Processing 8u37_A (2763/2775)...
# Processing 8ucd_C (2764/2775)...
# Processing 8uhd_Y (2765/2775)...
# Processing 8v4y_W (2766/2775)...
# Processing 8v8u_B (2767/2775)...
# Processing 8wej_B (2768/2775)...
# Processing 8x15_W (2769/2775)...
# Processing 8x72_A (2770/2775)...
# Processing 8xov_A (2771/2775)...
# Processing 8xpn_A (2772/2775)...
# Processing 8y14_A (2773/2775)...
# Processing 8y6b_F (2774/2775)...
# Processing 8y6o_H (2775/2775)...

# %%
import numpy as np
import matplotlib.pyplot as plt

number_of_pockets = sum([len(i) for i in binding_residues.values()])

mean_br = np.mean(best_residue_overlaps)
median_br = np.median(best_residue_overlaps)
print(f'best_residue_overlap mean={mean_br:.4f}, median={median_br:.4f}')
print(np.sum(np.array(DCCs) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N_plus_K) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N_plus_K) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N) < 4) / number_of_pockets})')

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros = [i for i in number_of_overlapping_actual_sites_on_predicted_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Predicted Pockets Covering True Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Predicted Pockets Covering True Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_predictions_on_actual_pocket_without_zeros = [i for i in number_of_overlapping_predictions_on_actual_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_predictions_on_actual_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Actual Pockets Covering Predicted Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Actual Pockets Covering Predicted Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()
# Out:
# best_residue_overlap mean=0.4954, median=0.5000
# 0.6922406277244987 (0.21621621621621623)
# 0.6713164777680907 (0.2035745422842197)
# 0.6129032258064516 (0.17596628886951468)

# %% [markdown]
# ## Model with smoothing without ions
# Run the model that was trained on the original scPDB without enhancement.

# %%
MODEL_PATH = f'{PATH}/data/models/gbs-model-non-enhanced-scPDB-filtered.pt'
# ESM_EMBEDDINGS_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/embeddings-enhanced-scPDB'
ESM_EMBEDDINGS_PATH = f'{PATH}/data/embeddings/ligysis'
COORDINATES_DIR = f'{PATH}/data/coordinates/ligysis'
POSITIVE_DISTANCE_THRESHOLD = 15
PRECALCULATED = False
LIGYSIS_ANNOTATION_PATH = f'{PATH}/data/data-extraction/ligysis_for_pocket_level_evaluation.csv'
DECISION_THRESHOLD = 0.7
DCC_HIT_THRESHOLD = 12.0  # Angstrom, Javier et al. Table 4 correctness gate for RRO


model = torch.load(MODEL_PATH, weights_only=False)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

binding_residues, sequences = eval_utils.read_test_binding_residues(data_path=LIGYSIS_ANNOTATION_PATH, pocket_types=['NON_CRYPTIC'])

predicted_binding_sites = {}
ranks = {}
prediction_scores = {}

K = 2

DCCs_N = []
DCCs_N_plus_K = []
DCCs = []

is_small_pocket_DCC_N = []
is_small_pocket_DCC_N_plus_K = []
is_small_pocket_DCC = []

number_of_added_residues = []

number_of_overlapping_predictions_on_actual_pocket = []
number_of_overlapping_actual_sites_on_predicted_pocket = []
best_residue_overlaps = []

for i, protein_id in enumerate(sequences.keys()):
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    embeddings_path = f'{ESM_EMBEDDINGS_PATH}/{pdb_id}{chain_id}.npy'
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'
    actual_binding_sites = [np.array([int(i.split('_')[1]) for i in pocket]) for pocket in binding_residues[protein_id]]
    
    print(f'Processing {protein_id} ({i+1}/{len(sequences)})...')
    if not PRECALCULATED:
        # finetuned prediction
        probabilities = eval_utils.compute_prediction(
            sequence,
            model,
            tokenizer
        )
    else:
        # load precalculated prediction
        probabilities = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')
    
    prediction_scores[protein_id] = probabilities

    coordinates = np.load(coordinates_path)
    distance_matrix = eval_utils.compute_distance_matrix(coordinates)

    predictions = (probabilities > DECISION_THRESHOLD).astype(float)
    predictions_copy = predictions.copy()

    assert distance_matrix.shape[0] == distance_matrix.shape[1]
    assert distance_matrix.shape[0] == predictions_copy.shape[0]
    
    X_test = np.load(embeddings_path)
    assert X_test.shape[0] == distance_matrix.shape[0]

    # loop over the residues that are not binding and are potential candidates for smoothing
    additional_residues = []
    added_residues_count = 0
    for residue_idx in np.where(predictions == 0.0)[0]:

        # get the embedding of the residue
        current_residue_embedding = X_test[residue_idx]

        # get the close binding residues
        close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
        close_binding_residues_indices = np.intersect1d(close_residues_indices, np.where(predictions == 1.0)[0])
        # create embedding 
        if len(close_binding_residues_indices) == 0:
            # no close binding residues - skip this residue
            continue
        elif len(close_binding_residues_indices) == 1:
            surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
        else:
            # get the mean of the close binding residues
            surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

        concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(device)
        
        # get the prediction
        test_logits = smoothing_model(concatenated_embedding).squeeze()
        result = (torch.sigmoid(test_logits)>eval_utils.SMOOTHING_DECISION_THRESHOLD).float()
        if result == 1:
            # set the residue as binding
            # print(f"Smoothing changed residue {residue_idx} in protein {protein_id} to binding")
            predictions_copy[residue_idx] = 1
            added_residues_count += 1

    number_of_added_residues.append(added_residues_count)

    indices_above_threshold = np.where(predictions_copy > DECISION_THRESHOLD)[0] # this gets residues that are equal to 1
    # no predicted residues - continue
    if len(indices_above_threshold) == 0:
        continue

    # run atom-level clustering and return residue-level pockets
    clusters, cluster_residues, cluster_scores, atom_coords, residue_coords = clustering_utils.execute_atom_clustering(
        pdb_id,
        chain_id,
        indices_above_threshold,
        probabilities[indices_above_threshold],
        eps=9
    )

    # none of the residues are on the surface
    if cluster_residues is None:
        continue

    cluster_residues = cryptoshow_utils.map_auth_to_mmcif_numbering_array(
        pdb_id,
        chain_id,
        cluster_residues.values(),
        binding_residues_are_integers=True,
        numbers_only=True
    )[0]

    cluster_order = np.argsort(cluster_scores)[::-1]  # descending order
    N = len(actual_binding_sites)

    selected_clusters_N = cluster_order[:N]
    selected_clusters_N_plus_K = cluster_order[:N+K]

    predicted_centers = {}
    for cluster_label, atom_indices in clusters.items():
        cluster_coords = np.array([atom_coords[atom_id] for atom_id in atom_indices])
        cluster_center = np.mean(cluster_coords, axis=0).get_array()
        predicted_centers[cluster_label] = cluster_center
    
    actual_centers = []
    is_small_pocket = []

    for pocket in actual_binding_sites:
        pocket_coords = coordinates[pocket]
        pocket_center = np.mean(pocket_coords, axis=0)
        actual_centers.append(pocket_center)
        is_small_pocket.append(len(pocket) < 10)

    for i, center in enumerate(actual_centers):
        DCC_N = float('inf')
        for j in selected_clusters_N:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N:
                DCC_N = distance
        
        if DCC_N != float('inf'):
            DCCs_N.append(DCC_N)
            is_small_pocket_DCC_N.append(is_small_pocket[i])

        DCC_N_plus_K = float('inf')
        for j in selected_clusters_N_plus_K:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N_plus_K:
                DCC_N_plus_K = distance
        
        if DCC_N_plus_K != float('inf'):
            DCCs_N_plus_K.append(DCC_N_plus_K)
            is_small_pocket_DCC_N_plus_K.append(is_small_pocket[i])
            

    dcc_rro_matches = clustering_utils.compute_dcc_matched_rro(
        actual_binding_sites, actual_centers, predicted_centers, cluster_residues,
        dcc_hit_threshold=DCC_HIT_THRESHOLD,
    )
    for i, match in enumerate(dcc_rro_matches):
        if match['dcc'] != float('inf'):
            DCCs.append(match['dcc'])
            is_small_pocket_DCC.append(is_small_pocket[i])
        if match['rro'] is not None:
            best_residue_overlaps.append(match['rro'])

    for pocket in actual_binding_sites:
        number_of_predicted_pockets = 0
        for residues in cluster_residues:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_actual_sites_on_predicted_pocket.append(number_of_predicted_pockets)

    for residues in cluster_residues:
        number_of_predicted_pockets = 0
        for pocket in actual_binding_sites:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping
# Processing 1nnl_B (169/2775)...
# Processing 1now_B (170/2775)...
# Processing 1nq1_A (171/2775)...
# Processing 1nsi_C (172/2775)...
# Processing 1nst_A (173/2775)...
# Processing 1nuh_A (174/2775)...
# Processing 1nuu_B (175/2775)...
# Processing 1nyp_A (176/2775)...
# Processing 1ohc_A (177/2775)...
# Processing 1oj6_D (178/2775)...
# Processing 1opl_A (179/2775)...
# Processing 1oqj_B (180/2775)...
# Processing 1ozo_A (181/2775)...
# Processing 1ozs_A (182/2775)...
# Processing 1p32_A (183/2775)...
# Processing 1p4o_A (184/2775)...
# Processing 1p4q_B (185/2775)...
# Processing 1pb5_A (186/2775)...
# Processing 1pfl_A (187/2775)...
# Processing 1pkx_B (188/2775)...
# Processing 1pl8_C (189/2775)...
# Processing 1plo_A (190/2775)...
# Processing 1psr_B (191/2775)...
# Processing 1pt6_B (192/2775)...
# Processing 1q0p_A (193/2775)...
# Processing 1q1u_A (194/2775)...
# Processing 1q33_A (195/2775)...
# Processing 1q3a_A (196/2775)...
# Processing 1q7l_C (197/2775)...
# Processing 1q7l_D (198/2775)...
# Processing 1q8l_A (199/2775)...
# Processing 1q8x_A (200/2775)...
# Processing 1q9s_A (201/2775)...
# Processing 1qh5_B (202/2775)...
# Processing 1qnm_A (203/2775)...
# Processing 1qzq_A (204/2775)...
# Processing 1qzu_B (205/2775)...
# Processing 1r3y_A (206/2775)...
# Processing 1r54_A (207/2775)...
# Processing 1r8q_E (208/2775)...
# Processing 1rgo_A (209/2775)...
# Processing 1riw_B (210/2775)...
# Processing 1rjv_A (211/2775)...
# Processing 1rkb_A (212/2775)...
# Processing 1rm8_A (213/2775)...
# Processing 1rnf_B (214/2775)...
# Processing 1ro4_A (215/2775)...
# Processing 1rtg_A (216/2775)...
# Processing 1rx0_D (217/2775)...
# Processing 1rxr_A (218/2775)...
# Processing 1s18_A (219/2775)...
# Processing 1s4b_P (220/2775)...
# Processing 1s4y_B (221/2775)...
# Processing 1s9i_A (222/2775)...
# Processing 1sg4_B (223/2775)...
# Processing 1shr_D (224/2775)...
# Processing 1siq_A (225/2775)...
# Processing 1sl6_E (226/2775)...
# Processing 1smo_B (227/2775)...
# Processing 1so0_B (228/2775)...
# Processing 1soj_I (229/2775)...
# Processing 1sp2_A (230/2775)...
# Processing 1st0_A (231/2775)...
# Processing 1su3_A (232/2775)...
# Processing 1szb_B (233/2775)...
# Processing 1t3n_B (234/2775)...
# Processing 1t6b_Y (235/2775)...
# Processing 1t8c_A (236/2775)...
# Processing 1tff_A (237/2775)...
# Processing 1tfi_A (238/2775)...
# Processing 1tg6_C (239/2775)...
# Processing 1tjj_A (240/2775)...
# Processing 1toz_A (241/2775)...
# Processing 1tpk_C (242/2775)...
# Processing 1ttx_A (243/2775)...
# Processing 1tu4_C (244/2775)...
# Processing 1tvx_D (245/2775)...
# Processing 1u31_A (246/2775)...
# Processing 1u3t_A (247/2775)...
# Processing 1u7f_B (248/2775)...
# Processing 1u7t_D (249/2775)...
# Processing 1ubd_C (250/2775)...
# Processing 2ffu_A (416/2775)...
# Processing 2ffw_A (417/2775)...
# Processing 2fg5_A (418/2775)...
# Processing 2fh1_B (419/2775)...
# Processing 2fim_B (420/2775)...
# Processing 2fj9_A (421/2775)...
# Processing 2fju_B (422/2775)...
# Processing 2fqq_B (423/2775)...
# Processing 2frw_A (424/2775)...
# Processing 2fsz_A (425/2775)...
# Processing 2fu5_B (426/2775)...
# Processing 2fvl_A (427/2775)...
# Processing 2fyl_B (428/2775)...
# Processing 2g2k_A (429/2775)...
# Processing 2g43_A (430/2775)...
# Processing 2g4a_A (431/2775)...
# Processing 2g6b_A (432/2775)...
# Processing 2g9o_A (433/2775)...
# Processing 2gao_B (434/2775)...
# Processing 2gf0_B (435/2775)...
# Processing 2gf9_A (436/2775)...
# Processing 2ggm_A (437/2775)...
# Processing 2ggz_B (438/2775)...
# Processing 2gjx_H (439/2775)...
# Processing 2gk1_Q (440/2775)...
# Processing 2gli_A (441/2775)...
# Processing 2gmv_A (442/2775)...
# Processing 2gp5_A (443/2775)...
# Processing 2gpq_A (444/2775)...
# Processing 2gqj_A (445/2775)...
# Processing 2gql_A (446/2775)...
# Processing 2gwh_A (447/2775)...
# Processing 2gz5_A (448/2775)...
# Processing 2h16_D (449/2775)...
# Processing 2h57_B (450/2775)...
# Processing 2h63_D (451/2775)...
# Processing 2h6h_A (452/2775)...
# Processing 2h8h_A (453/2775)...
# Processing 2h8k_B (454/2775)...
# Processing 2h9e_L (455/2775)...
# Processing 2ha8_A (456/2775)...
# Processing 2hei_B (457/2775)...
# Processing 2hgs_A (458/2775)...
# Processing 2hhl_A (459/2775)...
# Processing 2hhn_A (460/2775)...
# Processing 2hi4_A (461/2775)...
# Processing 2hrb_A (462/2775)...
# Processing 2hup_A (463/2775)...
# Processing 2hw5_A (464/2775)...
# Processing 2hw6_A (465/2775)...
# Processing 2hzq_A (466/2775)...
# Processing 2i0y_A (467/2775)...
# Processing 2i3c_B (468/2775)...
# Processing 2i50_A (469/2775)...
# Processing 2i6a_A (470/2775)...
# Processing 2i6s_A (471/2775)...
# Processing 2i7n_B (472/2775)...
# Processing 2i96_A (473/2775)...
# Processing 2i99_B (474/2775)...
# Processing 2i9a_D (475/2775)...
# Processing 2iby_A (476/2775)...
# Processing 2iim_A (477/2775)...
# Processing 2il1_A (478/2775)...
# Processing 2ipp_A (479/2775)...
# Processing 2iqj_B (480/2775)...
# Processing 2it4_B (481/2775)...
# Processing 2iuw_A (482/2775)...
# Processing 2iwy_A (483/2775)...
# Processing 2iyk_B (484/2775)...
# Processing 2j2p_C (485/2775)...
# Processing 2j2s_A (486/2775)...
# Processing 2j3s_A (487/2775)...
# Processing 2j4o_A (488/2775)...
# Processing 2j5z_B (489/2775)...
# Processing 2j8z_A (490/2775)...
# Processing 2jai_A (491/2775)...
# Processing 2jam_B (492/2775)...
# Processing 2jbh_B (493/2775)...
# Processing 2jdw_A (494/2775)...
# Processing 2jed_A (495/2775)...
# Processing 2jeo_A (496/2775)...
# Processing 2jg9_F (497/2775)...
# Processing 2o13_A (580/2775)...
# Processing 2o2f_A (581/2775)...
# Processing 2o52_B (582/2775)...
# Processing 2o6g_E (583/2775)...
# Processing 2o8f_B (584/2775)...
# Processing 2obd_A (585/2775)...
# Processing 2obv_A (586/2775)...
# Processing 2ocb_A (587/2775)...
# Processing 2ocg_A (588/2775)...
# Processing 2ocp_C (589/2775)...
# Processing 2od1_A (590/2775)...
# Processing 2ohf_A (591/2775)...
# Processing 2oil_A (592/2775)...
# Processing 2okv_C (593/2775)...
# Processing 2oo4_B (594/2775)...
# Processing 2opw_A (595/2775)...
# Processing 2ox8_D (596/2775)...
# Processing 2oxc_A (597/2775)...
# Processing 2p0a_A (598/2775)...
# Processing 2p0d_A (599/2775)...
# Processing 2p0r_B (600/2775)...
# Processing 2p0w_A (601/2775)...
# Processing 2p1f_A (602/2775)...
# Processing 2p57_A (603/2775)...
# Processing 2p5s_B (604/2775)...
# Processing 2p8e_B (605/2775)...
# Processing 2pfr_A (606/2775)...
# Processing 2pg5_D (607/2775)...
# Processing 2pid_A (608/2775)...
# Processing 2pl0_A (609/2775)...
# Processing 2pla_A (610/2775)...
# Processing 2pmy_A (611/2775)...
# Processing 2pqf_D (612/2775)...
# Processing 2pru_B (613/2775)...
# Processing 2psn_D (614/2775)...
# Processing 2puy_A (615/2775)...
# Processing 2pvs_A (616/2775)...
# Processing 2q3f_B (617/2775)...
# Processing 2q3h_A (618/2775)...
# Processing 2q3z_A (619/2775)...
# Processing 2q5e_D (620/2775)...
# Processing 2q7r_F (621/2775)...
# Processing 2q8f_A (622/2775)...
# Processing 2q98_A (623/2775)...
# Processing 2qic_A (624/2775)...
# Processing 2qk4_B (625/2775)...
# Processing 2qkk_W (626/2775)...
# Processing 2qpp_B (627/2775)...
# Processing 2qra_C (628/2775)...
# Processing 2qst_B (629/2775)...
# Processing 2qt7_B (630/2775)...
# Processing 2qtz_A (631/2775)...
# Processing 2qym_A (632/2775)...
# Processing 2r3a_A (633/2775)...
# Processing 2r5g_A (634/2775)...
# Processing 2r83_A (635/2775)...
# Processing 2r8u_A (636/2775)...
# Processing 2ra4_B (637/2775)...
# Processing 2raj_A (638/2775)...
# Processing 2rb3_C (639/2775)...
# Processing 2rb4_B (640/2775)...
# Processing 2rc4_A (641/2775)...
# Processing 2rhp_A (642/2775)...
# Processing 2rje_B (643/2775)...
# Processing 2rjp_B (644/2775)...
# Processing 2rjq_A (645/2775)...
# Processing 2rkb_C (646/2775)...
# Processing 2rli_A (647/2775)...
# Processing 2rmk_A (648/2775)...
# Processing 2rsg_A (649/2775)...
# Processing 2rsq_A (650/2775)...
# Processing 2ruy_A (651/2775)...
# Processing 2uur_A (652/2775)...
# Processing 2uvl_A (653/2775)...
# Processing 2uyy_D (654/2775)...
# Processing 2uzg_A (655/2775)...
# Processing 2v40_A (656/2775)...
# Processing 2v55_B (657/2775)...
# Processing 2vac_A (658/2775)...
# Processing 2vcv_J (659/2775)...
# Processing 2vd5_B (660/2775)...
# Processing 2vdy_A (661/2775)...
# Processing 2vhf_A (662/2775)...
# Processing 2vkq_A (663/2775)...
# Processing 2vm5_A (664/2775)...
# Processing 2vn9_A (665/2775)...
# Processing 2vq3_A (666/2775)...
# Processing 2vr2_A (667/2775)...
# Processing 2vrd_A (668/2775)...
# Processing 2vrg_A (669/2775)...
# Processing 2vsc_C (670/2775)...
# Processing 2vwi_D (671/2775)...
# Processing 2vxo_A (672/2775)...
# Processing 2w0t_A (673/2775)...
# Processing 2w2i_A (674/2775)...
# Processing 2w3o_B (675/2775)...
# Processing 2w4l_E (676/2775)...
# Processing 2w4o_A (677/2775)...
# Processing 2w4r_D (678/2775)...
# Processing 2w86_A (679/2775)...
# Processing 2w8p_A (680/2775)...
# Processing 2wbi_B (681/2775)...
# Processing 2wce_A (682/2775)...
# Processing 2wef_A (683/2775)...
# Processing 2wh5_E (684/2775)...
# Processing 2wjy_A (685/2775)...
# Processing 2wk6_B (686/2775)...
# Processing 2wno_A (687/2775)...
# Processing 2wtk_E (688/2775)...
# Processing 2wtk_F (689/2775)...
# Processing 2wwy_B (690/2775)...
# Processing 2wwz_C (691/2775)...
# Processing 2wya_C (692/2775)...
# Processing 2wzb_A (693/2775)...
# Processing 2x10_A (694/2775)...
# Processing 2x11_B (695/2775)...
# Processing 2x4d_A (696/2775)...
# Processing 2x4f_B (697/2775)...
# Processing 2x4w_A (698/2775)...
# Processing 2x7g_A (699/2775)...
# Processing 2x7h_B (700/2775)...
# Processing 2xik_A (701/2775)...
# Processing 2xmr_C (702/2775)...
# Processing 2xn3_B (703/2775)...
# Processing 2xph_A (704/2775)...
# Processing 2xrc_D (705/2775)...
# Processing 2xsx_A (706/2775)...
# Processing 2xtp_A (707/2775)...
# Processing 2xzg_A (708/2775)...
# Processing 2y1h_A (709/2775)...
# Processing 2y1l_D (710/2775)...
# Processing 2y23_A (711/2775)...
# Processing 2y43_B (712/2775)...
# Processing 2y7j_D (713/2775)...
# Processing 2yan_A (714/2775)...
# Processing 2yd8_A (715/2775)...
# Processing 2ygq_A (716/2775)...
# Processing 2yh0_A (717/2775)...
# Processing 2yho_C (718/2775)...
# Processing 2yqm_A (719/2775)...
# Processing 2yrt_A (720/2775)...
# Processing 2ysl_A (721/2775)...
# Processing 2yu2_A (722/2775)...
# Processing 2yvr_A (723/2775)...
# Processing 2z0u_B (724/2775)...
# Processing 2z15_C (725/2775)...
# Processing 2z4e_E (726/2775)...
# Processing 2z5f_B (727/2775)...
# Processing 2zfu_B (728/2775)...
# Processing 2zg1_A (729/2775)...
# Processing 2znv_D (730/2775)...
# Processing 2zoc_A (731/2775)...
# Processing 2zoq_A (732/2775)...
# Processing 2zox_A (733/2775)...
# Processing 2zrt_G (734/2775)...
# Processing 3a2a_B (735/2775)...
# Processing 3a4s_A (736/2775)...
# Processing 3a4u_A (737/2775)...
# Processing 3aad_A (738/2775)...
# Processing 3aco_A (739/2775)...
# Processing 3ahq_A (740/2775)...
# Processing 3aih_A (741/2775)...
# Processing 3alq_R (742/2775)...
# Processing 3ap3_A (743/2775)...
# Processing 3b2d_A (744/2775)...
# Processing 3b3l_A (745/2775)...
# Processing 3b6r_B (746/2775)...
# Processing 3b6u_A (747/2775)...
# Processing 3b6v_A (748/2775)...
# Processing 3bce_A (749/2775)...
# Processing 3ber_A (750/2775)...
# Processing 3bfx_A (751/2775)...
# Processing 3bh7_B (752/2775)...
# Processing 3bhm_A (753/2775)...
# Processing 3bi6_A (754/2775)...
# Processing 3bjc_A (755/2775)...
# Processing 3bm4_B (756/2775)...
# Processing 3bo5_A (757/2775)...
# Processing 3brh_A (758/2775)...
# Processing 3bsu_H (759/2775)...
# Processing 3bvo_B (760/2775)...
# Processing 3c5c_D (761/2775)...
# Processing 3c5e_A (762/2775)...
# Processing 3c6k_A (763/2775)...
# Processing 3c6w_C (764/2775)...
# Processing 3cbb_B (765/2775)...
# Processing 3cbk_A (766/2775)...
# Processing 3cbq_A (767/2775)...
# Processing 3cfw_A (768/2775)...
# Processing 3cos_C (769/2775)...
# Processing 3ctz_A (770/2775)...
# Processing 3cxp_A (771/2775)...
# Processing 3d0e_B (772/2775)...
# Processing 3d24_C (773/2775)...
# Processing 3d2f_D (774/2775)...
# Processing 3d34_B (775/2775)...
# Processing 3d3l_B (776/2775)...
# Processing 3d3w_B (777/2775)...
# Processing 3d5o_B (778/2775)...
# Processing 3d87_B (779/2775)...
# Processing 3d8b_A (780/2775)...
# Processing 3d8e_C (781/2775)...
# Processing 3ddu_A (782/2775)...
# Processing 3dem_B (783/2775)...
# Processing 3dk9_A (784/2775)...
# Processing 3dko_A (785/2775)...
# Processing 3dlj_B (786/2775)...
# Processing 3dls_C (787/2775)...
# Processing 3dwb_A (788/2775)...
# Processing 3dyd_B (789/2775)...
# Processing 3dz4_B (790/2775)...
# Processing 3e1y_B (791/2775)...
# Processing 3e3r_B (792/2775)...
# Processing 3e4c_B (793/2775)...
# Processing 3e6i_B (794/2775)...
# Processing 3eb5_A (795/2775)...
# Processing 3edy_A (796/2775)...
# Processing 3eh1_A (797/2775)...
# Processing 3eh2_B (798/2775)...
# Processing 3elb_A (799/2775)...
# Processing 3epy_B (800/2775)...
# Processing 3epz_A (801/2775)...
# Processing 3eta_A (802/2775)...
# Processing 3eue_A (803/2775)...
# Processing 3exi_B (804/2775)...
# Processing 3eyh_A (805/2775)...
# Processing 3f1r_B (806/2775)...
# Processing 3f3y_A (807/2775)...
# Processing 3f5o_E (808/2775)...
# Processing 3f70_B (809/2775)...
# Processing 3f7u_C (810/2775)...
# Processing 3f9p_A (811/2775)...
# Processing 3fcx_B (812/2775)...
# Processing 3fd6_B (813/2775)...
# Processing 3fe2_B (814/2775)...
# Processing 3fe3_A (815/2775)...
# Processing 3fe4_A (816/2775)...
# Processing 3fec_A (817/2775)...
# Processing 3ff6_D (818/2775)...
# Processing 3ffk_A (819/2775)...
# Processing 3fg6_F (820/2775)...
# Processing 3fl2_A (821/2775)...
# Processing 3flv_B (822/2775)...
# Processing 3fvy_A (823/2775)...
# Processing 3fy1_A (824/2775)...
# Processing 3g4h_A (825/2775)...
# Processing 3g73_A (826/2775)...
# Processing 3g9y_A (827/2775)...
# Processing 3gbj_A (828/2775)...
# Processing 3gc9_B (829/2775)...
# Processing 3gdh_B (830/2775)...
# Processing 3gdq_A (831/2775)...
# Processing 3gep_B (832/2775)...
# Processing 3ggf_B (833/2775)...
# Processing 3ghg_C (834/2775)...
# Processing 3gis_Z (835/2775)...
# Processing 3gjx_E (836/2775)...
# Processing 3gkh_A (837/2775)...
# Processing 3gpd_G (838/2775)...
# Processing 3gqc_D (839/2775)...
# Processing 3gta_A (840/2775)...
# Processing 3gxb_A (841/2775)...
# Processing 3gzd_A (842/2775)...
# Processing 3h2u_B (843/2775)...
# Processing 3h53_B (844/2775)...
# Processing 3hco_B (845/2775)...
# Processing 3hf1_A (846/2775)...
# Processing 3hn3_B (847/2775)...
# Processing 3ho4_A (848/2775)...
# Processing 3hr4_G (849/2775)...
# Processing 3hud_B (850/2775)...
# Processing 3hxt_A (851/2775)...
# Processing 3hy8_A (852/2775)...
# Processing 3ia8_A (853/2775)...
# Processing 3iei_H (854/2775)...
# Processing 3ihp_B (855/2775)...
# Processing 3ik7_B (856/2775)...
# Processing 3io2_A (857/2775)...
# Processing 3isq_A (858/2775)...
# Processing 3iu6_A (859/2775)...
# Processing 3iuf_A (860/2775)...
# Processing 3iuy_A (861/2775)...
# Processing 3iwl_A (862/2775)...
# Processing 3ixe_B (863/2775)...
# Processing 3ixs_K (864/2775)...
# Processing 3j0a_A (865/2775)...
# Processing 3j2s_B (866/2775)...
# Processing 3jrx_A (867/2775)...
# Processing 3jub_A (868/2775)...
# Processing 3jue_A (869/2775)...
# Processing 3jyh_A (870/2775)...
# Processing 3k2s_B (871/2775)...
# Processing 3k51_B (872/2775)...
# Processing 3k5t_A (873/2775)...
# Processing 3k7v_A (874/2775)...
# Processing 3k9j_A (875/2775)...
# Processing 3k9o_A (876/2775)...
# Processing 3kcg_I (877/2775)...
# Processing 3kn1_A (878/2775)...
# Processing 3kq0_A (879/2775)...
# Processing 3kq4_B (880/2775)...
# Processing 3kqg_A (881/2775)...
# Processing 3kuc_A (882/2775)...
# Processing 3kv5_A (883/2775)...
# Processing 3kvo_A (884/2775)...
# Processing 3kyd_A (885/2775)...
# Processing 3l43_B (886/2775)...
# Processing 3lea_B (887/2775)...
# Processing 3lf5_B (888/2775)...
# Processing 3lgd_B (889/2775)...
# Processing 3ljw_A (890/2775)...
# Processing 3lkj_C (891/2775)...
# Processing 3llk_A (892/2775)...
# Processing 3lqc_A (893/2775)...
# Processing 3lqh_A (894/2775)...
# Processing 3lrq_C (895/2775)...
# Processing 3lru_B (896/2775)...
# Processing 3ltl_B (897/2775)...
# Processing 3luc_A (898/2775)...
# Processing 3lxj_A (899/2775)...
# Processing 3lxx_A (900/2775)...
# Processing 3ly5_A (901/2775)...
# Processing 3lyr_A (902/2775)...
# Processing 3m1d_B (903/2775)...
# Processing 3m52_A (904/2775)...
# Processing 3mb3_A (905/2775)...
# Processing 3mb4_B (906/2775)...
# Processing 3mbg_C (907/2775)...
# Processing 3mdi_A (908/2775)...
# Processing 3mdy_C (909/2775)...
# Processing 3mdz_A (910/2775)...
# Processing 3mgm_A (911/2775)...
# Processing 3mjh_B (912/2775)...
# Processing 3mp5_B (913/2775)...
# Processing 3mq7_L (914/2775)...
# Processing 3mqi_C (915/2775)...
# Processing 3mtg_B (916/2775)...
# Processing 3mtn_A (917/2775)...
# Processing 3my0_J (918/2775)...
# Processing 3mzg_B (919/2775)...
# Processing 3n1g_A (920/2775)...
# Processing 3n1m_B (921/2775)...
# Processing 3n5n_Y (922/2775)...
# Processing 3n7o_A (923/2775)...
# Processing 3na1_A (924/2775)...
# Processing 3ncu_A (925/2775)...
# Processing 3ner_B (926/2775)...
# Processing 3nks_A (927/2775)...
# Processing 3nmq_A (928/2775)...
# Processing 3nmz_B (929/2775)...
# Processing 3nv1_A (930/2775)...
# Processing 3nvq_B (931/2775)...
# Processing 3nwn_A (932/2775)...
# Processing 3nxb_A (933/2775)...
# Processing 3nyn_B (934/2775)...
# Processing 3o0g_A (935/2775)...
# Processing 3o4r_B (936/2775)...
# Processing 3o4s_A (937/2775)...
# Processing 3o7a_A (938/2775)...
# Processing 3oag_A (939/2775)...
# Processing 3oes_A (940/2775)...
# Processing 3oj3_J (941/2775)...
# Processing 3ojy_B (942/2775)...
# Processing 3orh_B (943/2775)...
# Processing 3otc_B (944/2775)...
# Processing 3ovp_B (945/2775)...
# Processing 3p0f_A (946/2775)...
# Processing 3p57_A (947/2775)...
# Processing 3pb4_X (948/2775)...
# Processing 3pe0_A (949/2775)...
# Processing 3pja_K (950/2775)...
# Processing 3pls_A (951/2775)...
# Processing 3pm0_A (952/2775)...
# Processing 3poo_A (953/2775)...
# Processing 3pse_B (954/2775)...
# Processing 3q13_A (955/2775)...
# Processing 3q19_A (956/2775)...
# Processing 3q1d_A (957/2775)...
# Processing 3q2u_A (958/2775)...
# Processing 3q3j_B (959/2775)...
# Processing 3q6z_A (960/2775)...
# Processing 3qcj_A (961/2775)...
# Processing 3qfb_B (962/2775)...
# Processing 3qj4_A (963/2775)...
# Processing 3qj5_B (964/2775)...
# Processing 3qmh_A (965/2775)...
# Processing 3qni_A (966/2775)...
# Processing 3qpu_A (967/2775)...
# Processing 3qrf_F (968/2775)...
# Processing 3qxy_B (969/2775)...
# Processing 3r6b_A (970/2775)...
# Processing 3rap_S (971/2775)...
# Processing 3ray_A (972/2775)...
# Processing 3rbl_B (973/2775)...
# Processing 3rc3_A (974/2775)...
# Processing 3rgk_A (975/2775)...
# Processing 3rk2_G (976/2775)...
# Processing 3rq4_A (977/2775)...
# Processing 3rz3_C (978/2775)...
# Processing 3rzv_A (979/2775)...
# Processing 3s4y_A (980/2775)...
# Processing 3sbz_A (981/2775)...
# Processing 3sh5_A (982/2775)...
# Processing 3sjv_F (983/2775)...
# Processing 3sn5_B (984/2775)...
# Processing 3szb_B (985/2775)...
# Processing 3t6a_A (986/2775)...
# Processing 3t7l_A (987/2775)...
# Processing 3t9i_A (988/2775)...
# Processing 3tac_A (989/2775)...
# Processing 3thd_D (990/2775)...
# Processing 3tkl_A (991/2775)...
# Processing 3top_A (992/2775)...
# Processing 3tvl_A (993/2775)...
# Processing 3twj_B (994/2775)...
# Processing 3u5n_A (995/2775)...
# Processing 3u8u_A (996/2775)...
# Processing 3ucw_A (997/2775)...
# Processing 3uh4_B (998/2775)...
# Processing 3uk3_C (999/2775)...
# Processing 3ukm_C (1000/2775)...
# Processing 3uyq_A (1001/2775)...
# Processing 3uzx_B (1002/2775)...
# Processing 3v3l_A (1003/2775)...
# Processing 3v4v_B (1004/2775)...
# Processing 3v4v_C (1005/2775)...
# Processing 3v70_A (1006/2775)...
# Processing 3v7t_A (1007/2775)...
# Processing 3v8x_B (1008/2775)...
# Processing 3vcm_B (1009/2775)...
# Processing 3vf0_A (1010/2775)...
# Processing 3vfq_A (1011/2775)...
# Processing 3vi3_A (1012/2775)...
# Processing 3vjc_A (1013/2775)...
# Processing 3vjm_A (1014/2775)...
# Processing 3vm8_A (1015/2775)...
# Processing 3vp6_B (1016/2775)...
# Processing 3vpp_B (1017/2775)...
# Processing 3vrn_A (1018/2775)...
# Processing 3vuy_D (1019/2775)...
# Processing 3vw9_B (1020/2775)...
# Processing 3w4u_E (1021/2775)...
# Processing 3w58_D (1022/2775)...
# Processing 3w5k_B (1023/2775)...
# Processing 3w8i_A (1024/2775)...
# Processing 3wh2_A (1025/2775)...
# Processing 3whd_A (1026/2775)...
# Processing 3wsr_B (1027/2775)...
# Processing 3wup_A (1028/2775)...
# Processing 3wv6_A (1029/2775)...
# Processing 3wzf_A (1030/2775)...
# Processing 3x1u_H (1031/2775)...
# Processing 3zdu_A (1032/2775)...
# Processing 3zjc_F (1033/2775)...
# Processing 3zli_A (1034/2775)...
# Processing 3znr_B (1035/2775)...
# Processing 3zwf_A (1036/2775)...
# Processing 3zyg_A (1037/2775)...
# Processing 3zyj_D (1038/2775)...
# Processing 3zyq_A (1039/2775)...
# Processing 4a24_A (1040/2775)...
# Processing 4a49_A (1041/2775)...
# Processing 4a4f_A (1042/2775)...
# Processing 4a69_A (1043/2775)...
# Processing 4a94_B (1044/2775)...
# Processing 4a9o_A (1045/2775)...
# Processing 4ad9_A (1046/2775)...
# Processing 4af3_A (1047/2775)...
# Processing 4afx_A (1048/2775)...
# Processing 4agc_A (1049/2775)...
# Processing 4agu_C (1050/2775)...
# Processing 4aoh_A (1051/2775)...
# Processing 4ap6_C (1052/2775)...
# Processing 4aqi_A (1053/2775)...
# Processing 4auq_E (1054/2775)...
# Processing 4awl_C (1055/2775)...
# Processing 4awn_A (1056/2775)...
# Processing 4az3_B (1057/2775)...
# Processing 4azm_A (1058/2775)...
# Processing 4b6l_A (1059/2775)...
# Processing 4b91_B (1060/2775)...
# Processing 4bb2_B (1061/2775)...
# Processing 4bbq_B (1062/2775)...
# Processing 4bc3_C (1063/2775)...
# Processing 4bcx_A (1064/2775)...
# Processing 4bgq_A (1065/2775)...
# Processing 4bj3_B (1066/2775)...
# Processing 4oem_B (1223/2775)...
# Processing 4oj2_X (1224/2775)...
# Processing 4ojk_A (1225/2775)...
# Processing 4omc_E (1226/2775)...
# Processing 4oni_A (1227/2775)...
# Processing 4onn_B (1228/2775)...
# Processing 4or9_A (1229/2775)...
# Processing 4orw_A (1230/2775)...
# Processing 4otg_A (1231/2775)...
# Processing 4p0p_A (1232/2775)...
# Processing 4p13_C (1233/2775)...
# Processing 4p5w_A (1234/2775)...
# Processing 4p60_A (1235/2775)...
# Processing 4pcu_A (1236/2775)...
# Processing 4pcw_B (1237/2775)...
# Processing 4px2_A (1238/2775)...
# Processing 4pzi_A (1239/2775)...
# Processing 4q4b_A (1240/2775)...
# Processing 4q4d_A (1241/2775)...
# Processing 4q6f_A (1242/2775)...
# Processing 4q7y_A (1243/2775)...
# Processing 4q93_A (1244/2775)...
# Processing 4q9u_E (1245/2775)...
# Processing 4qbm_A (1246/2775)...
# Processing 4qc3_A (1247/2775)...
# Processing 4qil_A (1248/2775)...
# Processing 4qmx_A (1249/2775)...
# Processing 4qn9_A (1250/2775)...
# Processing 4qpn_A (1251/2775)...
# Processing 4qu6_A (1252/2775)...
# Processing 4r1f_A (1253/2775)...
# Processing 4r2d_A (1254/2775)...
# Processing 4r6u_A (1255/2775)...
# Processing 4r7a_B (1256/2775)...
# Processing 4r7p_B (1257/2775)...
# Processing 4r8p_K (1258/2775)...
# Processing 4rau_L (1259/2775)...
# Processing 4rda_A (1260/2775)...
# Processing 4re1_A (1261/2775)...
# Processing 4re8_B (1262/2775)...
# Processing 4rec_A (1263/2775)...
# Processing 4rer_A (1264/2775)...
# Processing 4rfq_A (1265/2775)...
# Processing 4rg1_A (1266/2775)...
# Processing 4rkk_A (1267/2775)...
# Processing 4rn0_A (1268/2775)...
# Processing 4rr2_A (1269/2775)...
# Processing 4rsu_F (1270/2775)...
# Processing 4ruh_B (1271/2775)...
# Processing 4s15_A (1272/2775)...
# Processing 4s3o_B (1273/2775)...
# Processing 4s3o_C (1274/2775)...
# Processing 4tlg_A (1275/2775)...
# Processing 4tnt_A (1276/2775)...
# Processing 4ttv_A (1277/2775)...
# Processing 4twe_B (1278/2775)...
# Processing 4u5t_A (1279/2775)...
# Processing 4u8d_A (1280/2775)...
# Processing 4ueg_A (1281/2775)...
# Processing 4uem_A (1282/2775)...
# Processing 4ug2_A (1283/2775)...
# Processing 4uhz_A (1284/2775)...
# Processing 4ui9_S (1285/2775)...
# Processing 4um8_D (1286/2775)...
# Processing 4usf_B (1287/2775)...
# Processing 4ust_A (1288/2775)...
# Processing 4uu6_A (1289/2775)...
# Processing 4uuu_A (1290/2775)...
# Processing 4uy2_B (1291/2775)...
# Processing 4uy9_A (1292/2775)...
# Processing 4uya_A (1293/2775)...
# Processing 4uye_B (1294/2775)...
# Processing 4v0h_D (1295/2775)...
# Processing 4v3k_F (1296/2775)...
# Processing 4v6x_Aa (1297/2775)...
# Processing 4v6x_Af (1298/2775)...
# Processing 4wgk_A (1299/2775)...
# Processing 4whv_I (1300/2775)...
# Processing 4wle_D (1301/2775)...
# Processing 4wmq_A (1302/2775)...
# Processing 4wqn_B (1303/2775)...
# Processing 4wzx_A (1304/2775)...
# Processing 4x0q_B (1305/2775)...
# Processing 4x30_A (1306/2775)...
# Processing 4x7q_B (1307/2775)...
# Processing 4x93_B (1308/2775)...
# Processing 4xcx_A (1309/2775)...
# Processing 4xdp_A (1310/2775)...
# Processing 4xft_A (1311/2775)...
# Processing 4xhz_A (1312/2775)...
# Processing 4xp7_A (1313/2775)...
# Processing 4xwh_A (1314/2775)...
# Processing 4xyj_H (1315/2775)...
# Processing 4xzp_A (1316/2775)...
# Processing 4y05_A (1317/2775)...
# Processing 4y7b_A (1318/2775)...
# Processing 4y86_A (1319/2775)...
# Processing 4y88_A (1320/2775)...
# Processing 4y8w_A (1321/2775)...
# Processing 4y97_H (1322/2775)...
# Processing 4yhj_B (1323/2775)...
# Processing 4yiq_D (1324/2775)...
# Processing 4yj0_A (1325/2775)...
# Processing 4yls_A (1326/2775)...
# Processing 4ylz_B (1327/2775)...
# Processing 4ymd_B (1328/2775)...
# Processing 4ymj_A (1329/2775)...
# Processing 4ynd_A (1330/2775)...
# Processing 4yoc_C (1331/2775)...
# Processing 4yvp_A (1332/2775)...
# Processing 4ywt_D (1333/2775)...
# Processing 4z0o_A (1334/2775)...
# Processing 4z2b_A (1335/2775)...
# Processing 4z9m_D (1336/2775)...
# Processing 4zaj_A (1337/2775)...
# Processing 4zc4_B (1338/2775)...
# Processing 4zcv_A (1339/2775)...
# Processing 4zdp_A (1340/2775)...
# Processing 4zel_A (1341/2775)...
# Processing 4zes_B (1342/2775)...
# Processing 4zfg_A (1343/2775)...
# Processing 4zg4_B (1344/2775)...
# Processing 4zg9_B (1345/2775)...
# Processing 4zht_B (1346/2775)...
# Processing 4zji_C (1347/2775)...
# Processing 4zlp_A (1348/2775)...
# Processing 4zma_L (1349/2775)...
# Processing 4zrp_B (1350/2775)...
# Processing 4zso_F (1351/2775)...
# Processing 4zvj_A (1352/2775)...
# Processing 4zvw_D (1353/2775)...
# Processing 4zya_A (1354/2775)...
# Processing 4zyo_A (1355/2775)...
# Processing 5a0e_A (1356/2775)...
# Processing 5a15_I (1357/2775)...
# Processing 5a46_A (1358/2775)...
# Processing 5a4k_B (1359/2775)...
# Processing 5a9j_D (1360/2775)...
# Processing 5aaq_A (1361/2775)...
# Processing 5aaz_A (1362/2775)...
# Processing 5ay8_E (1363/2775)...
# Processing 5b0h_B (1364/2775)...
# Processing 5b1x_B (1365/2775)...
# Processing 5b4x_D (1366/2775)...
# Processing 5b4y_B (1367/2775)...
# Processing 5bq8_B (1368/2775)...
# Processing 5bqd_B (1369/2775)...
# Processing 5bqe_C (1370/2775)...
# Processing 5brk_A (1371/2775)...
# Processing 5bwl_A (1372/2775)...
# Processing 5bx1_A (1373/2775)...
# Processing 5c11_A (1374/2775)...
# Processing 5c16_D (1375/2775)...
# Processing 5c41_B (1376/2775)...
# Processing 5c4v_F (1377/2775)...
# Processing 5c5c_A (1378/2775)...
# Processing 7yni_A (2571/2775)...
# Processing 7yox_F (2572/2775)...
# Processing 7yq8_B (2573/2775)...
# Processing 7ys6_A (2574/2775)...
# Processing 7yu8_R (2575/2775)...
# Processing 7yui_A (2576/2775)...
# Processing 7z5h_A (2577/2775)...
# Processing 7z6h_D (2578/2775)...
# Processing 7z6h_E (2579/2775)...
# Processing 7z6h_F (2580/2775)...
# Processing 7z6h_G (2581/2775)...
# Processing 7z71_A (2582/2775)...
# Processing 7z9f_A (2583/2775)...
# Processing 7zan_C (2584/2775)...
# Processing 7zcw_G (2585/2775)...
# Processing 7zel_A (2586/2775)...
# Processing 7zh3_D (2587/2775)...
# Processing 7zha_A (2588/2775)...
# Processing 7zi9_A (2589/2775)...
# Processing 7zjv_A (2590/2775)...
# Processing 7zmk_X (2591/2775)...
# Processing 7zmv_D (2592/2775)...
# Processing 7zmx_A (2593/2775)...
# Processing 7zr0_A (2594/2775)...
# Processing 7zr6_P (2595/2775)...
# Processing 7zrr_A (2596/2775)...
# Processing 7zsc_C (2597/2775)...
# Processing 7zyg_A (2598/2775)...
# Processing 7zyh_J (2599/2775)...
# Processing 7zyu_A (2600/2775)...
# Processing 7zzp_A (2601/2775)...
# Processing 8a0v_A (2602/2775)...
# Processing 8a38_C (2603/2775)...
# Processing 8a40_U (2604/2775)...
# Processing 8a4c_D (2605/2775)...
# Processing 8a4k_B (2606/2775)...
# Processing 8a6l_B (2607/2775)...
# Processing 8a8m_A (2608/2775)...
# Processing 8ajo_A (2609/2775)...
# Processing 8ari_W (2610/2775)...
# Processing 8as4_B (2611/2775)...
# Processing 8ayf_A (2612/2775)...
# Processing 8aza_A (2613/2775)...
# Processing 8b0a_K (2614/2775)...
# Processing 8b0f_C (2615/2775)...
# Processing 8b0f_F (2616/2775)...
# Processing 8b0g_J (2617/2775)...
# Processing 8b0h_E (2618/2775)...
# Processing 8b10_A (2619/2775)...
# Processing 8b5r_P (2620/2775)...
# Processing 8b6l_L (2621/2775)...
# Processing 8b6l_N (2622/2775)...
# Processing 8b6l_O (2623/2775)...
# Processing 8b9e_A (2624/2775)...
# Processing 8bah_B (2625/2775)...
# Processing 8bbg_C (2626/2775)...
# Processing 8bbs_A (2627/2775)...
# Processing 8bc9_J (2628/2775)...
# Processing 8blp_C (2629/2775)...
# Processing 8bot_U (2630/2775)...
# Processing 8bot_X (2631/2775)...
# Processing 8bub_B (2632/2775)...
# Processing 8bya_B (2633/2775)...
# Processing 8byl_B (2634/2775)...
# Processing 8bzy_A (2635/2775)...
# Processing 8c3u_A (2636/2775)...
# Processing 8c6j_7 (2637/2775)...
# Processing 8ca0_B (2638/2775)...
# Processing 8ch6_y (2639/2775)...
# Processing 8cqb_A (2640/2775)...
# Processing 8cr1_B (2641/2775)...
# Processing 8css_8 (2642/2775)...
# Processing 8cua_C (2643/2775)...
# Processing 8cuc_F (2644/2775)...
# Processing 8cv5_A (2645/2775)...
# Processing 8cx0_A (2646/2775)...
# Processing 8d1e_D (2647/2775)...
# Processing 8d1l_C (2648/2775)...
# Processing 8d30_A (2649/2775)...
# Processing 8d3c_E (2650/2775)...
# Processing 8d3v_A (2651/2775)...
# Processing 8d6e_A (2652/2775)...
# Processing 8d7z_C (2653/2775)...
# Processing 8d8i_A (2654/2775)...
# Processing 8daf_A (2655/2775)...
# Processing 8dbk_B (2656/2775)...
# Processing 8dey_F (2657/2775)...
# Processing 8dkm_P (2658/2775)...
# Processing 8dmk_G (2659/2775)...
# Processing 8dnu_D (2660/2775)...
# Processing 8dph_A (2661/2775)...
# Processing 8dyd_A (2662/2775)...
# Processing 8dyl_B (2663/2775)...
# Processing 8e0c_A (2664/2775)...
# Processing 8e0f_B (2665/2775)...
# Processing 8e1a_A (2666/2775)...
# Processing 8e3y_R (2667/2775)...
# Processing 8e4y_A (2668/2775)...
# Processing 8e8v_A (2669/2775)...
# Processing 8e93_B (2670/2775)...
# Processing 8e98_C (2671/2775)...
# Processing 8e9z_A (2672/2775)...
# Processing 8ede_B (2673/2775)...
# Processing 8ef7_A (2674/2775)...
# Processing 8efg_A (2675/2775)...
# Processing 8efq_R (2676/2775)...
# Processing 8eg3_A (2677/2775)...
# Processing 8egx_B (2678/2775)...
# Processing 8eih_A (2679/2775)...
# Processing 8eiq_A (2680/2775)...
# Processing 8ejm_A (2681/2775)...
# Processing 8emr_B (2682/2775)...
# Processing 8eok_G (2683/2775)...
# Processing 8eop_A (2684/2775)...
# Processing 8eor_B (2685/2775)...
# Processing 8epl_A (2686/2775)...
# Processing 8esv_A (2687/2775)...
# Processing 8eyk_F (2688/2775)...
# Processing 8eyo_A (2689/2775)...
# Processing 8f7s_R (2690/2775)...
# Processing 8fb2_B (2691/2775)...
# Processing 8fc7_B (2692/2775)...
# Processing 8ffv_A (2693/2775)...
# Processing 8ffw_D (2694/2775)...
# Processing 8fgw_C (2695/2775)...
# Processing 8fjx_A (2696/2775)...
# Processing 8fmu_B (2697/2775)...
# Processing 8fnb_B (2698/2775)...
# Processing 8foa_A (2699/2775)...
# Processing 8fp1_A (2700/2775)...
# Processing 8fw5_B (2701/2775)...
# Processing 8fyh_I (2702/2775)...
# Processing 8g0l_A (2703/2775)...
# Processing 8g46_B (2704/2775)...
# Processing 8g7n_A (2705/2775)...
# Processing 8g9p_D (2706/2775)...
# Processing 8gju_D (2707/2775)...
# Processing 8gk3_H (2708/2775)...
# Processing 8gnn_A (2709/2775)...
# Processing 8gui_K (2710/2775)...
# Processing 8gx3_A (2711/2775)...
# Processing 8gye_A (2712/2775)...
# Processing 8gyx_B (2713/2775)...
# Processing 8gz2_B (2714/2775)...
# Processing 8h65_C (2715/2775)...
# Processing 8h8j_C (2716/2775)...
# Processing 8hbe_B (2717/2775)...
# Processing 8hdp_R (2718/2775)...
# Processing 8hy5_B (2719/2775)...
# Processing 8i1o_A (2720/2775)...
# Processing 8i5y_A (2721/2775)...
# Processing 8i5y_B (2722/2775)...
# Processing 8i9u_J (2723/2775)...
# Processing 8i9u_O (2724/2775)...
# Processing 8ifo_A (2725/2775)...
# Processing 8il3_C (2726/2775)...
# Processing 8iqn_A (2727/2775)...
# Processing 8irr_R (2728/2775)...
# Processing 8iuh_3 (2729/2775)...
# Processing 8iwu_A (2730/2775)...
# Processing 8iys_R (2731/2775)...
# Processing 8jbn_B (2732/2775)...
# Processing 8jdl_AP (2733/2775)...
# Processing 8jhf_A (2734/2775)...
# Processing 8jii_A (2735/2775)...
# Processing 8jyg_B (2736/2775)...
# Processing 8kb5_G (2737/2775)...
# Processing 8odo_A (2738/2775)...
# Processing 8oew_O (2739/2775)...
# Processing 8oi8_A (2740/2775)...
# Processing 8oma_A (2741/2775)...
# Processing 8omr_A (2742/2775)...
# Processing 8oxy_A (2743/2775)...
# Processing 8p50_B (2744/2775)...
# Processing 8p8x_A (2745/2775)...
# Processing 8p94_A (2746/2775)...
# Processing 8pqh_A (2747/2775)...
# Processing 8q7n_K (2748/2775)...
# Processing 8qk3_E (2749/2775)...
# Processing 8qy4_D (2750/2775)...
# Processing 8rbx_W (2751/2775)...
# Processing 8sg5_H (2752/2775)...
# Processing 8sgo_C (2753/2775)...
# Processing 8syp_C (2754/2775)...
# Processing 8t6j_A (2755/2775)...
# Processing 8t9h_K (2756/2775)...
# Processing 8tar_N (2757/2775)...
# Processing 8tgd_A (2758/2775)...
# Processing 8tnq_B (2759/2775)...
# Processing 8tzo_C (2760/2775)...
# Processing 8tzs_A (2761/2775)...
# Processing 8u26_R (2762/2775)...
# Processing 8u37_A (2763/2775)...
# Processing 8ucd_C (2764/2775)...
# Processing 8uhd_Y (2765/2775)...
# Processing 8v4y_W (2766/2775)...
# Processing 8v8u_B (2767/2775)...
# Processing 8wej_B (2768/2775)...
# Processing 8x15_W (2769/2775)...
# Processing 8x72_A (2770/2775)...
# Processing 8xov_A (2771/2775)...
# Processing 8xpn_A (2772/2775)...
# Processing 8y14_A (2773/2775)...
# Processing 8y6b_F (2774/2775)...
# Processing 8y6o_H (2775/2775)...

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

number_of_pockets = sum([len(i) for i in binding_residues.values()])

mean_br = np.mean(best_residue_overlaps)
median_br = np.median(best_residue_overlaps)
print(f'best_residue_overlap mean={mean_br:.4f}, median={median_br:.4f}')

print(np.sum(np.array(DCCs) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N_plus_K) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N_plus_K) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N) < 4) / number_of_pockets})')


print('\nSmall binding pockets (less than 10 residues):')
small_pockets_DCCs = [DCCs[i] for i in range(len(DCCs)) if is_small_pocket_DCC[i]]
print(f'Overall DCC < 12: {np.sum(np.array(small_pockets_DCCs) < 12) / len(small_pockets_DCCs):.4f} ({np.sum(np.array(small_pockets_DCCs) < 4) / len(small_pockets_DCCs):.4f})')
small_pockets_DCCs_N_plus_K = [DCCs_N_plus_K[i] for i in range(len(DCCs_N_plus_K)) if is_small_pocket_DCC_N_plus_K[i]]
print(f'N+K DCC < 12: {np.sum(np.array(small_pockets_DCCs_N_plus_K) < 12) / len(small_pockets_DCCs_N_plus_K):.4f} ({np.sum(np.array(small_pockets_DCCs_N_plus_K) < 4) / len(small_pockets_DCCs_N_plus_K):.4f})')
small_pockets_DCCs_N = [DCCs_N[i] for i in range(len(DCCs_N)) if is_small_pocket_DCC_N[i]]
print(f'N DCC < 12: {np.sum(np.array(small_pockets_DCCs_N) < 12) / len(small_pockets_DCCs_N):.4f} ({np.sum(np.array(small_pockets_DCCs_N) < 4) / len(small_pockets_DCCs_N):.4f})')

print('\nLarge binding pockets (10 or more residues):')
large_pockets_DCCs = [DCCs[i] for i in range(len(DCCs)) if not is_small_pocket_DCC[i]]
print(f'Overall DCC < 12: {np.sum(np.array(large_pockets_DCCs) < 12) / len(large_pockets_DCCs):.4f} ({np.sum(np.array(large_pockets_DCCs) < 4) / len(large_pockets_DCCs):.4f})')
large_pockets_DCCs_N_plus_K = [DCCs_N_plus_K[i] for i in range(len(DCCs_N_plus_K)) if not is_small_pocket_DCC_N_plus_K[i]]
print(f'N+K DCC < 12: {np.sum(np.array(large_pockets_DCCs_N_plus_K) < 12) / len(large_pockets_DCCs_N_plus_K):.4f} ({np.sum(np.array(large_pockets_DCCs_N_plus_K) < 4) / len(large_pockets_DCCs_N_plus_K):.4f})')
large_pockets_DCCs_N = [DCCs_N[i] for i in range(len(DCCs_N)) if not is_small_pocket_DCC_N[i]]
print(f'N DCC < 12: {np.sum(np.array(large_pockets_DCCs_N) < 12) / len(large_pockets_DCCs_N):.4f} ({np.sum(np.array(large_pockets_DCCs_N) < 4) / len(large_pockets_DCCs_N):.4f})')  


fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros = [i for i in number_of_overlapping_actual_sites_on_predicted_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Predicted Pockets Covering True Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Predicted Pockets Covering True Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_predictions_on_actual_pocket_without_zeros = [i for i in number_of_overlapping_predictions_on_actual_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_predictions_on_actual_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Actual Pockets Covering Predicted Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Actual Pockets Covering Predicted Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()
# Out:
# best_residue_overlap mean=0.4530, median=0.4516
# 0.5993897122929381 (0.14559721011333915)
# 0.5757047369950595 (0.13905841325196164)
# 0.5257192676547515 (0.12598081952920662)
#
# Small binding pockets (less than 10 residues):
# Overall DCC < 12: 0.5113 (0.0754)
# N+K DCC < 12: 0.4806 (0.0650)
# N DCC < 12: 0.4165 (0.0500)
#
# Large binding pockets (10 or more residues):
# Overall DCC < 12: 0.7651 (0.2407)
# N+K DCC < 12: 0.7466 (0.2378)
# N DCC < 12: 0.7070 (0.2255)

# %% [markdown]
# # Run on 40% filtered model
# Filter the scPDB to 40% seq. identity with respect to LIGYSIS, train a model and evaluate it on LIGYSIS.

# %%
MODEL_PATH = f'{PATH}/data/models/gbs-model-enhanced-scPDB-filtered_to_40_identity.pt'

model = torch.load(MODEL_PATH, weights_only=False)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

binding_residues, sequences = eval_utils.read_test_binding_residues(data_path=LIGYSIS_ANNOTATION_PATH, pocket_types=['NON_CRYPTIC'])

predicted_binding_sites = {}
ranks = {}
prediction_scores = {}

K = 2

DCCs_N = []
DCCs_N_plus_K = []
DCCs = []

is_small_pocket_DCC_N = []
is_small_pocket_DCC_N_plus_K = []
is_small_pocket_DCC = []

number_of_added_residues = []

number_of_overlapping_predictions_on_actual_pocket = []
number_of_overlapping_actual_sites_on_predicted_pocket = []
best_residue_overlaps = []

for i, protein_id in enumerate(sequences.keys()):
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    embeddings_path = f'{ESM_EMBEDDINGS_PATH}/{pdb_id}{chain_id}.npy'
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'
    actual_binding_sites = [np.array([int(i.split('_')[1]) for i in pocket]) for pocket in binding_residues[protein_id]]
    
    print(f'Processing {protein_id} ({i+1}/{len(sequences)})...')
    if not PRECALCULATED:
        # finetuned prediction
        probabilities = eval_utils.compute_prediction(
            sequence,
            model,
            tokenizer
        )
    else:
        # load precalculated prediction
        probabilities = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')
    
    prediction_scores[protein_id] = probabilities

    coordinates = np.load(coordinates_path)
    distance_matrix = eval_utils.compute_distance_matrix(coordinates)

    predictions = (probabilities > DECISION_THRESHOLD).astype(float)
    predictions_copy = predictions.copy()

    assert distance_matrix.shape[0] == distance_matrix.shape[1]
    assert distance_matrix.shape[0] == predictions_copy.shape[0]
    
    X_test = np.load(embeddings_path)
    assert X_test.shape[0] == distance_matrix.shape[0]

    # loop over the residues that are not binding and are potential candidates for smoothing
    additional_residues = []
    added_residues_count = 0
    for residue_idx in np.where(predictions == 0.0)[0]:

        # get the embedding of the residue
        current_residue_embedding = X_test[residue_idx]

        # get the close binding residues
        close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
        close_binding_residues_indices = np.intersect1d(close_residues_indices, np.where(predictions == 1.0)[0])
        # create embedding 
        if len(close_binding_residues_indices) == 0:
            # no close binding residues - skip this residue
            continue
        elif len(close_binding_residues_indices) == 1:
            surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
        else:
            # get the mean of the close binding residues
            surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

        concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(device)
        
        # get the prediction
        test_logits = smoothing_model(concatenated_embedding).squeeze()
        result = (torch.sigmoid(test_logits)>eval_utils.SMOOTHING_DECISION_THRESHOLD).float()
        if result == 1:
            # set the residue as binding
            # print(f"Smoothing changed residue {residue_idx} in protein {protein_id} to binding")
            additional_residues.append(residue_idx)
            predictions_copy[residue_idx] = 1
            added_residues_count += 1

    number_of_added_residues.append(added_residues_count)
    
    indices_above_threshold = np.where(predictions_copy > DECISION_THRESHOLD)[0] # this gets residues that are equal to 1
    # no predicted residues - continue
    if len(indices_above_threshold) == 0:
        continue

    # run atom-level clustering and return residue-level pockets
    clusters, cluster_residues, cluster_scores, atom_coords, residue_coords = clustering_utils.execute_atom_clustering(
        pdb_id,
        chain_id,
        indices_above_threshold,
        probabilities[indices_above_threshold],
        eps=9,
        
    )

    # none of the residues are on the surface
    if cluster_residues is None:
        continue

    cluster_residues = cryptoshow_utils.map_auth_to_mmcif_numbering_array(
        pdb_id,
        chain_id,
        cluster_residues.values(),
        binding_residues_are_integers=True,
        numbers_only=True
    )[0]

    cluster_order = np.argsort(cluster_scores)[::-1]  # descending order
    N = len(actual_binding_sites)

    selected_clusters_N = cluster_order[:N]
    selected_clusters_N_plus_K = cluster_order[:N+K]

    predicted_centers = {}
    for cluster_label, atom_indices in clusters.items():
        cluster_coords = np.array([atom_coords[atom_id] for atom_id in atom_indices])
        cluster_center = np.mean(cluster_coords, axis=0).get_array()
        predicted_centers[cluster_label] = cluster_center
    
    actual_centers = []
    is_small_pocket = []
    for pocket in actual_binding_sites:
        pocket_coords = coordinates[pocket]
        pocket_center = np.mean(pocket_coords, axis=0)
        actual_centers.append(pocket_center)
        is_small_pocket.append(len(pocket) < 10)
    
    for i, center in enumerate(actual_centers):
        DCC_N = float('inf')
        for j in selected_clusters_N:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N:
                DCC_N = distance
        
        if DCC_N != float('inf'):
            DCCs_N.append(DCC_N)
            is_small_pocket_DCC_N.append(is_small_pocket[i])

        DCC_N_plus_K = float('inf')
        for j in selected_clusters_N_plus_K:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N_plus_K:
                DCC_N_plus_K = distance
        
        if DCC_N_plus_K != float('inf'):
            DCCs_N_plus_K.append(DCC_N_plus_K)
            is_small_pocket_DCC_N_plus_K.append(is_small_pocket[i])
            

    dcc_rro_matches = clustering_utils.compute_dcc_matched_rro(
        actual_binding_sites, actual_centers, predicted_centers, cluster_residues,
        dcc_hit_threshold=DCC_HIT_THRESHOLD,
    )
    for i, match in enumerate(dcc_rro_matches):
        if match['dcc'] != float('inf'):
            DCCs.append(match['dcc'])
            is_small_pocket_DCC.append(is_small_pocket[i])
        if match['rro'] is not None:
            best_residue_overlaps.append(match['rro'])

    for pocket in actual_binding_sites:
        number_of_predicted_pockets = 0
        for residues in cluster_residues:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_actual_sites_on_predicted_pocket.append(number_of_predicted_pockets)

    for residues in cluster_residues:
        number_of_predicted_pockets = 0
        for pocket in actual_binding_sites:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_predictions_on_actual_pocket.append(number_of_predicted_pockets)
# Out:
# Processing 1a52_A (1/2775)...
# Processing 1a9w_E (2/2775)...
# Processing 1aii_A (3/2775)...
# Processing 1au1_A (4/2775)...
# Processing 1aue_B (5/2775)...
# Processing 1b1c_A (6/2775)...
# Processing 1b50_B (7/2775)...
# Processing 1b55_B (8/2775)...
# Processing 1b6c_F (9/2775)...
# Processing 1b9o_A (10/2775)...
# Processing 1bbo_A (11/2775)...
# Processing 1bci_A (12/2775)...
# Processing 1ohc_A (177/2775)...
# Processing 1oj6_D (178/2775)...
# Processing 1opl_A (179/2775)...
# Processing 1oqj_B (180/2775)...
# Processing 1ozo_A (181/2775)...
# Processing 1ozs_A (182/2775)...
# Processing 1p32_A (183/2775)...
# Processing 1p4o_A (184/2775)...
# Processing 1p4q_B (185/2775)...
# Processing 1pb5_A (186/2775)...
# Processing 1pfl_A (187/2775)...
# Processing 1pkx_B (188/2775)...
# Processing 1pl8_C (189/2775)...
# Processing 1plo_A (190/2775)...
# Processing 1psr_B (191/2775)...
# Processing 1pt6_B (192/2775)...
# Processing 1q0p_A (193/2775)...
# Processing 1q1u_A (194/2775)...
# Processing 1q33_A (195/2775)...
# Processing 1q3a_A (196/2775)...
# Processing 1q7l_C (197/2775)...
# Processing 1q7l_D (198/2775)...
# Processing 1q8l_A (199/2775)...
# Processing 1q8x_A (200/2775)...
# Processing 1q9s_A (201/2775)...
# Processing 1qh5_B (202/2775)...
# Processing 1qnm_A (203/2775)...
# Processing 1qzq_A (204/2775)...
# Processing 1qzu_B (205/2775)...
# Processing 1r3y_A (206/2775)...
# Processing 1r54_A (207/2775)...
# Processing 1r8q_E (208/2775)...
# Processing 1rgo_A (209/2775)...
# Processing 1riw_B (210/2775)...
# Processing 1rjv_A (211/2775)...
# Processing 1rkb_A (212/2775)...
# Processing 1rm8_A (213/2775)...
# Processing 1rnf_B (214/2775)...
# Processing 1ro4_A (215/2775)...
# Processing 1rtg_A (216/2775)...
# Processing 1rx0_D (217/2775)...
# Processing 1rxr_A (218/2775)...
# Processing 1s18_A (219/2775)...
# Processing 1s4b_P (220/2775)...
# Processing 1s4y_B (221/2775)...
# Processing 1s9i_A (222/2775)...
# Processing 1sg4_B (223/2775)...
# Processing 1shr_D (224/2775)...
# Processing 1siq_A (225/2775)...
# Processing 1sl6_E (226/2775)...
# Processing 1smo_B (227/2775)...
# Processing 1so0_B (228/2775)...
# Processing 1soj_I (229/2775)...
# Processing 1sp2_A (230/2775)...
# Processing 1st0_A (231/2775)...
# Processing 1su3_A (232/2775)...
# Processing 1szb_B (233/2775)...
# Processing 1t3n_B (234/2775)...
# Processing 1t6b_Y (235/2775)...
# Processing 1t8c_A (236/2775)...
# Processing 1tff_A (237/2775)...
# Processing 1tfi_A (238/2775)...
# Processing 1tg6_C (239/2775)...
# Processing 1tjj_A (240/2775)...
# Processing 1toz_A (241/2775)...
# Processing 1tpk_C (242/2775)...
# Processing 1ttx_A (243/2775)...
# Processing 1tu4_C (244/2775)...
# Processing 1tvx_D (245/2775)...
# Processing 1u31_A (246/2775)...
# Processing 1u3t_A (247/2775)...
# Processing 1u7f_B (248/2775)...
# Processing 1u7t_D (249/2775)...
# Processing 1ubd_C (250/2775)...
# Processing 1ul1_Z (251/2775)...
# Processing 1umk_A (252/2775)...
# Processing 1upr_A (253/2775)...
# Processing 1ur6_B (254/2775)...
# Processing 1uv0_A (255/2775)...
# Processing 1uvq_B (256/2775)...
# Processing 1uw5_A (257/2775)...
# Processing 2fqq_B (423/2775)...
# Processing 2frw_A (424/2775)...
# Processing 2fsz_A (425/2775)...
# Processing 2fu5_B (426/2775)...
# Processing 2fvl_A (427/2775)...
# Processing 2fyl_B (428/2775)...
# Processing 2g2k_A (429/2775)...
# Processing 2g43_A (430/2775)...
# Processing 2g4a_A (431/2775)...
# Processing 2g6b_A (432/2775)...
# Processing 2g9o_A (433/2775)...
# Processing 2gao_B (434/2775)...
# Processing 2gf0_B (435/2775)...
# Processing 2gf9_A (436/2775)...
# Processing 2ggm_A (437/2775)...
# Processing 2ggz_B (438/2775)...
# Processing 2gjx_H (439/2775)...
# Processing 2gk1_Q (440/2775)...
# Processing 2gli_A (441/2775)...
# Processing 2gmv_A (442/2775)...
# Processing 2gp5_A (443/2775)...
# Processing 2gpq_A (444/2775)...
# Processing 2gqj_A (445/2775)...
# Processing 2gql_A (446/2775)...
# Processing 2gwh_A (447/2775)...
# Processing 2gz5_A (448/2775)...
# Processing 2h16_D (449/2775)...
# Processing 2h57_B (450/2775)...
# Processing 2h63_D (451/2775)...
# Processing 2h6h_A (452/2775)...
# Processing 2h8h_A (453/2775)...
# Processing 2h8k_B (454/2775)...
# Processing 2h9e_L (455/2775)...
# Processing 2ha8_A (456/2775)...
# Processing 2hei_B (457/2775)...
# Processing 2hgs_A (458/2775)...
# Processing 2hhl_A (459/2775)...
# Processing 2hhn_A (460/2775)...
# Processing 2hi4_A (461/2775)...
# Processing 2hrb_A (462/2775)...
# Processing 2hup_A (463/2775)...
# Processing 2hw5_A (464/2775)...
# Processing 2hw6_A (465/2775)...
# Processing 2hzq_A (466/2775)...
# Processing 2i0y_A (467/2775)...
# Processing 2i3c_B (468/2775)...
# Processing 2i50_A (469/2775)...
# Processing 2i6a_A (470/2775)...
# Processing 2i6s_A (471/2775)...
# Processing 2i7n_B (472/2775)...
# Processing 2i96_A (473/2775)...
# Processing 2i99_B (474/2775)...
# Processing 2i9a_D (475/2775)...
# Processing 2iby_A (476/2775)...
# Processing 2iim_A (477/2775)...
# Processing 2il1_A (478/2775)...
# Processing 2ipp_A (479/2775)...
# Processing 2iqj_B (480/2775)...
# Processing 2it4_B (481/2775)...
# Processing 2iuw_A (482/2775)...
# Processing 2iwy_A (483/2775)...
# Processing 2iyk_B (484/2775)...
# Processing 2j2p_C (485/2775)...
# Processing 2j2s_A (486/2775)...
# Processing 2j3s_A (487/2775)...
# Processing 2j4o_A (488/2775)...
# Processing 2j5z_B (489/2775)...
# Processing 2j8z_A (490/2775)...
# Processing 2jai_A (491/2775)...
# Processing 2jam_B (492/2775)...
# Processing 2jbh_B (493/2775)...
# Processing 2jdw_A (494/2775)...
# Processing 2jed_A (495/2775)...
# Processing 2jeo_A (496/2775)...
# Processing 2jg9_F (497/2775)...
# Processing 2jif_D (498/2775)...
# Processing 2jis_B (499/2775)...
# Processing 2jld_B (500/2775)...
# Processing 2jlp_C (501/2775)...
# Processing 2jm4_A (502/2775)...
# Processing 2jmo_A (503/2775)...
# Processing 2jox_A (504/2775)...
# Processing 2ocb_A (587/2775)...
# Processing 2ocg_A (588/2775)...
# Processing 2ocp_C (589/2775)...
# Processing 2od1_A (590/2775)...
# Processing 2ohf_A (591/2775)...
# Processing 2oil_A (592/2775)...
# Processing 2okv_C (593/2775)...
# Processing 2oo4_B (594/2775)...
# Processing 2opw_A (595/2775)...
# Processing 2ox8_D (596/2775)...
# Processing 2oxc_A (597/2775)...
# Processing 2p0a_A (598/2775)...
# Processing 2p0d_A (599/2775)...
# Processing 2p0r_B (600/2775)...
# Processing 2p0w_A (601/2775)...
# Processing 2p1f_A (602/2775)...
# Processing 2p57_A (603/2775)...
# Processing 2p5s_B (604/2775)...
# Processing 2p8e_B (605/2775)...
# Processing 2pfr_A (606/2775)...
# Processing 2pg5_D (607/2775)...
# Processing 2pid_A (608/2775)...
# Processing 2pl0_A (609/2775)...
# Processing 2pla_A (610/2775)...
# Processing 2pmy_A (611/2775)...
# Processing 2pqf_D (612/2775)...
# Processing 2pru_B (613/2775)...
# Processing 2psn_D (614/2775)...
# Processing 2puy_A (615/2775)...
# Processing 2pvs_A (616/2775)...
# Processing 2q3f_B (617/2775)...
# Processing 2q3h_A (618/2775)...
# Processing 2q3z_A (619/2775)...
# Processing 2q5e_D (620/2775)...
# Processing 2q7r_F (621/2775)...
# Processing 2q8f_A (622/2775)...
# Processing 2q98_A (623/2775)...
# Processing 2qic_A (624/2775)...
# Processing 2qk4_B (625/2775)...
# Processing 2qkk_W (626/2775)...
# Processing 2qpp_B (627/2775)...
# Processing 2qra_C (628/2775)...
# Processing 2qst_B (629/2775)...
# Processing 2qt7_B (630/2775)...
# Processing 2qtz_A (631/2775)...
# Processing 2qym_A (632/2775)...
# Processing 2r3a_A (633/2775)...
# Processing 2r5g_A (634/2775)...
# Processing 2r83_A (635/2775)...
# Processing 2r8u_A (636/2775)...
# Processing 2ra4_B (637/2775)...
# Processing 2raj_A (638/2775)...
# Processing 2rb3_C (639/2775)...
# Processing 2rb4_B (640/2775)...
# Processing 2rc4_A (641/2775)...
# Processing 2rhp_A (642/2775)...
# Processing 2rje_B (643/2775)...
# Processing 2rjp_B (644/2775)...
# Processing 2rjq_A (645/2775)...
# Processing 2rkb_C (646/2775)...
# Processing 2rli_A (647/2775)...
# Processing 2rmk_A (648/2775)...
# Processing 2rsg_A (649/2775)...
# Processing 2rsq_A (650/2775)...
# Processing 2ruy_A (651/2775)...
# Processing 2uur_A (652/2775)...
# Processing 2uvl_A (653/2775)...
# Processing 2uyy_D (654/2775)...
# Processing 2uzg_A (655/2775)...
# Processing 2v40_A (656/2775)...
# Processing 2v55_B (657/2775)...
# Processing 2vac_A (658/2775)...
# Processing 2vcv_J (659/2775)...
# Processing 2vd5_B (660/2775)...
# Processing 2vdy_A (661/2775)...
# Processing 2vhf_A (662/2775)...
# Processing 2vkq_A (663/2775)...
# Processing 2vm5_A (664/2775)...
# Processing 2vn9_A (665/2775)...
# Processing 2vq3_A (666/2775)...
# Processing 2vr2_A (667/2775)...
# Processing 2vrd_A (668/2775)...
# Processing 2vrg_A (669/2775)...
# Processing 2vsc_C (670/2775)...
# Processing 2vwi_D (671/2775)...
# Processing 2vxo_A (672/2775)...
# Processing 2w0t_A (673/2775)...
# Processing 2w2i_A (674/2775)...
# Processing 2w3o_B (675/2775)...
# Processing 2w4l_E (676/2775)...
# Processing 2w4o_A (677/2775)...
# Processing 2w4r_D (678/2775)...
# Processing 2w86_A (679/2775)...
# Processing 2w8p_A (680/2775)...
# Processing 2wbi_B (681/2775)...
# Processing 2wce_A (682/2775)...
# Processing 2wef_A (683/2775)...
# Processing 2wh5_E (684/2775)...
# Processing 2wjy_A (685/2775)...
# Processing 2wk6_B (686/2775)...
# Processing 2wno_A (687/2775)...
# Processing 2wtk_E (688/2775)...
# Processing 2wtk_F (689/2775)...
# Processing 2wwy_B (690/2775)...
# Processing 2wwz_C (691/2775)...
# Processing 2wya_C (692/2775)...
# Processing 2wzb_A (693/2775)...
# Processing 2x10_A (694/2775)...
# Processing 2x11_B (695/2775)...
# Processing 2x4d_A (696/2775)...
# Processing 2x4f_B (697/2775)...
# Processing 2x4w_A (698/2775)...
# Processing 2x7g_A (699/2775)...
# Processing 2x7h_B (700/2775)...
# Processing 2xik_A (701/2775)...
# Processing 2xmr_C (702/2775)...
# Processing 2xn3_B (703/2775)...
# Processing 2xph_A (704/2775)...
# Processing 2xrc_D (705/2775)...
# Processing 2xsx_A (706/2775)...
# Processing 2xtp_A (707/2775)...
# Processing 2xzg_A (708/2775)...
# Processing 2y1h_A (709/2775)...
# Processing 2y1l_D (710/2775)...
# Processing 2y23_A (711/2775)...
# Processing 2y43_B (712/2775)...
# Processing 2y7j_D (713/2775)...
# Processing 2yan_A (714/2775)...
# Processing 2yd8_A (715/2775)...
# Processing 2ygq_A (716/2775)...
# Processing 2yh0_A (717/2775)...
# Processing 2yho_C (718/2775)...
# Processing 2yqm_A (719/2775)...
# Processing 2yrt_A (720/2775)...
# Processing 2ysl_A (721/2775)...
# Processing 2yu2_A (722/2775)...
# Processing 2yvr_A (723/2775)...
# Processing 2z0u_B (724/2775)...
# Processing 2z15_C (725/2775)...
# Processing 2z4e_E (726/2775)...
# Processing 2z5f_B (727/2775)...
# Processing 2zfu_B (728/2775)...
# Processing 2zg1_A (729/2775)...
# Processing 2znv_D (730/2775)...
# Processing 2zoc_A (731/2775)...
# Processing 2zoq_A (732/2775)...
# Processing 2zox_A (733/2775)...
# Processing 2zrt_G (734/2775)...
# Processing 3a2a_B (735/2775)...
# Processing 3a4s_A (736/2775)...
# Processing 3a4u_A (737/2775)...
# Processing 3aad_A (738/2775)...
# Processing 3aco_A (739/2775)...
# Processing 3ahq_A (740/2775)...
# Processing 3aih_A (741/2775)...
# Processing 3alq_R (742/2775)...
# Processing 3ap3_A (743/2775)...
# Processing 3b2d_A (744/2775)...
# Processing 3b3l_A (745/2775)...
# Processing 3b6r_B (746/2775)...
# Processing 3b6u_A (747/2775)...
# Processing 3b6v_A (748/2775)...
# Processing 3bce_A (749/2775)...
# Processing 3ber_A (750/2775)...
# Processing 3bfx_A (751/2775)...
# Processing 3bh7_B (752/2775)...
# Processing 3bhm_A (753/2775)...
# Processing 3bi6_A (754/2775)...
# Processing 3bjc_A (755/2775)...
# Processing 3bm4_B (756/2775)...
# Processing 3bo5_A (757/2775)...
# Processing 3brh_A (758/2775)...
# Processing 3bsu_H (759/2775)...
# Processing 3bvo_B (760/2775)...
# Processing 3c5c_D (761/2775)...
# Processing 3c5e_A (762/2775)...
# Processing 3c6k_A (763/2775)...
# Processing 3c6w_C (764/2775)...
# Processing 3cbb_B (765/2775)...
# Processing 3cbk_A (766/2775)...
# Processing 3cbq_A (767/2775)...
# Processing 3cfw_A (768/2775)...
# Processing 3cos_C (769/2775)...
# Processing 3ctz_A (770/2775)...
# Processing 3cxp_A (771/2775)...
# Processing 3d0e_B (772/2775)...
# Processing 3d24_C (773/2775)...
# Processing 3d2f_D (774/2775)...
# Processing 3d34_B (775/2775)...
# Processing 3d3l_B (776/2775)...
# Processing 3d3w_B (777/2775)...
# Processing 3d5o_B (778/2775)...
# Processing 3d87_B (779/2775)...
# Processing 3d8b_A (780/2775)...
# Processing 3d8e_C (781/2775)...
# Processing 3ddu_A (782/2775)...
# Processing 3dem_B (783/2775)...
# Processing 3dk9_A (784/2775)...
# Processing 3dko_A (785/2775)...
# Processing 3dlj_B (786/2775)...
# Processing 3dls_C (787/2775)...
# Processing 3dwb_A (788/2775)...
# Processing 3dyd_B (789/2775)...
# Processing 3dz4_B (790/2775)...
# Processing 3e1y_B (791/2775)...
# Processing 3e3r_B (792/2775)...
# Processing 3e4c_B (793/2775)...
# Processing 3e6i_B (794/2775)...
# Processing 3eb5_A (795/2775)...
# Processing 3edy_A (796/2775)...
# Processing 3eh1_A (797/2775)...
# Processing 3eh2_B (798/2775)...
# Processing 3elb_A (799/2775)...
# Processing 3epy_B (800/2775)...
# Processing 3epz_A (801/2775)...
# Processing 3eta_A (802/2775)...
# Processing 3eue_A (803/2775)...
# Processing 3exi_B (804/2775)...
# Processing 3eyh_A (805/2775)...
# Processing 3f1r_B (806/2775)...
# Processing 3f3y_A (807/2775)...
# Processing 3f5o_E (808/2775)...
# Processing 3f70_B (809/2775)...
# Processing 3f7u_C (810/2775)...
# Processing 3f9p_A (811/2775)...
# Processing 3fcx_B (812/2775)...
# Processing 3fd6_B (813/2775)...
# Processing 3fe2_B (814/2775)...
# Processing 3fe3_A (815/2775)...
# Processing 3fe4_A (816/2775)...
# Processing 3fec_A (817/2775)...
# Processing 3ff6_D (818/2775)...
# Processing 3ffk_A (819/2775)...
# Processing 3fg6_F (820/2775)...
# Processing 3fl2_A (821/2775)...
# Processing 3flv_B (822/2775)...
# Processing 3fvy_A (823/2775)...
# Processing 3fy1_A (824/2775)...
# Processing 3g4h_A (825/2775)...
# Processing 3g73_A (826/2775)...
# Processing 3g9y_A (827/2775)...
# Processing 3gbj_A (828/2775)...
# Processing 3gc9_B (829/2775)...
# Processing 3gdh_B (830/2775)...
# Processing 3gdq_A (831/2775)...
# Processing 3gep_B (832/2775)...
# Processing 3ggf_B (833/2775)...
# Processing 3ghg_C (834/2775)...
# Processing 3gis_Z (835/2775)...
# Processing 3gjx_E (836/2775)...
# Processing 3gkh_A (837/2775)...
# Processing 3gpd_G (838/2775)...
# Processing 3gqc_D (839/2775)...
# Processing 3gta_A (840/2775)...
# Processing 3gxb_A (841/2775)...
# Processing 3gzd_A (842/2775)...
# Processing 3h2u_B (843/2775)...
# Processing 3h53_B (844/2775)...
# Processing 3hco_B (845/2775)...
# Processing 3hf1_A (846/2775)...
# Processing 3hn3_B (847/2775)...
# Processing 3ho4_A (848/2775)...
# Processing 3hr4_G (849/2775)...
# Processing 3hud_B (850/2775)...
# Processing 3hxt_A (851/2775)...
# Processing 3hy8_A (852/2775)...
# Processing 3ia8_A (853/2775)...
# Processing 3iei_H (854/2775)...
# Processing 3ihp_B (855/2775)...
# Processing 3ik7_B (856/2775)...
# Processing 3io2_A (857/2775)...
# Processing 3isq_A (858/2775)...
# Processing 3iu6_A (859/2775)...
# Processing 3iuf_A (860/2775)...
# Processing 3iuy_A (861/2775)...
# Processing 3iwl_A (862/2775)...
# Processing 3ixe_B (863/2775)...
# Processing 3ixs_K (864/2775)...
# Processing 3j0a_A (865/2775)...
# Processing 3j2s_B (866/2775)...
# Processing 3jrx_A (867/2775)...
# Processing 3jub_A (868/2775)...
# Processing 3jue_A (869/2775)...
# Processing 3jyh_A (870/2775)...
# Processing 3k2s_B (871/2775)...
# Processing 3k51_B (872/2775)...
# Processing 3k5t_A (873/2775)...
# Processing 3k7v_A (874/2775)...
# Processing 3k9j_A (875/2775)...
# Processing 3k9o_A (876/2775)...
# Processing 3kcg_I (877/2775)...
# Processing 3kn1_A (878/2775)...
# Processing 3kq0_A (879/2775)...
# Processing 3kq4_B (880/2775)...
# Processing 3kqg_A (881/2775)...
# Processing 3kuc_A (882/2775)...
# Processing 3kv5_A (883/2775)...
# Processing 3kvo_A (884/2775)...
# Processing 3kyd_A (885/2775)...
# Processing 3l43_B (886/2775)...
# Processing 3lea_B (887/2775)...
# Processing 3lf5_B (888/2775)...
# Processing 3lgd_B (889/2775)...
# Processing 3ljw_A (890/2775)...
# Processing 3lkj_C (891/2775)...
# Processing 3llk_A (892/2775)...
# Processing 3lqc_A (893/2775)...
# Processing 3lqh_A (894/2775)...
# Processing 3lrq_C (895/2775)...
# Processing 3lru_B (896/2775)...
# Processing 3ltl_B (897/2775)...
# Processing 3luc_A (898/2775)...
# Processing 3lxj_A (899/2775)...
# Processing 3lxx_A (900/2775)...
# Processing 3ly5_A (901/2775)...
# Processing 3lyr_A (902/2775)...
# Processing 3m1d_B (903/2775)...
# Processing 3m52_A (904/2775)...
# Processing 3mb3_A (905/2775)...
# Processing 3mb4_B (906/2775)...
# Processing 3mbg_C (907/2775)...
# Processing 3mdi_A (908/2775)...
# Processing 3mdy_C (909/2775)...
# Processing 3mdz_A (910/2775)...
# Processing 3mgm_A (911/2775)...
# Processing 3mjh_B (912/2775)...
# Processing 3mp5_B (913/2775)...
# Processing 3mq7_L (914/2775)...
# Processing 3mqi_C (915/2775)...
# Processing 3mtg_B (916/2775)...
# Processing 3mtn_A (917/2775)...
# Processing 3my0_J (918/2775)...
# Processing 3mzg_B (919/2775)...
# Processing 3n1g_A (920/2775)...
# Processing 3n1m_B (921/2775)...
# Processing 3n5n_Y (922/2775)...
# Processing 3n7o_A (923/2775)...
# Processing 3na1_A (924/2775)...
# Processing 3ncu_A (925/2775)...
# Processing 3ner_B (926/2775)...
# Processing 3nks_A (927/2775)...
# Processing 3nmq_A (928/2775)...
# Processing 3nmz_B (929/2775)...
# Processing 3nv1_A (930/2775)...
# Processing 3nvq_B (931/2775)...
# Processing 3nwn_A (932/2775)...
# Processing 3nxb_A (933/2775)...
# Processing 3nyn_B (934/2775)...
# Processing 3o0g_A (935/2775)...
# Processing 3o4r_B (936/2775)...
# Processing 3o4s_A (937/2775)...
# Processing 3o7a_A (938/2775)...
# Processing 3oag_A (939/2775)...
# Processing 3oes_A (940/2775)...
# Processing 3oj3_J (941/2775)...
# Processing 3ojy_B (942/2775)...
# Processing 3orh_B (943/2775)...
# Processing 3otc_B (944/2775)...
# Processing 3ovp_B (945/2775)...
# Processing 3p0f_A (946/2775)...
# Processing 3p57_A (947/2775)...
# Processing 3pb4_X (948/2775)...
# Processing 3pe0_A (949/2775)...
# Processing 3pja_K (950/2775)...
# Processing 3pls_A (951/2775)...
# Processing 3pm0_A (952/2775)...
# Processing 3poo_A (953/2775)...
# Processing 3pse_B (954/2775)...
# Processing 3q13_A (955/2775)...
# Processing 3q19_A (956/2775)...
# Processing 3q1d_A (957/2775)...
# Processing 3q2u_A (958/2775)...
# Processing 3q3j_B (959/2775)...
# Processing 3q6z_A (960/2775)...
# Processing 3qcj_A (961/2775)...
# Processing 3qfb_B (962/2775)...
# Processing 3qj4_A (963/2775)...
# Processing 3qj5_B (964/2775)...
# Processing 3qmh_A (965/2775)...
# Processing 3qni_A (966/2775)...
# Processing 3qpu_A (967/2775)...
# Processing 3qrf_F (968/2775)...
# Processing 3qxy_B (969/2775)...
# Processing 3r6b_A (970/2775)...
# Processing 3rap_S (971/2775)...
# Processing 3ray_A (972/2775)...
# Processing 3rbl_B (973/2775)...
# Processing 3rc3_A (974/2775)...
# Processing 3rgk_A (975/2775)...
# Processing 3rk2_G (976/2775)...
# Processing 3rq4_A (977/2775)...
# Processing 3rz3_C (978/2775)...
# Processing 3rzv_A (979/2775)...
# Processing 3s4y_A (980/2775)...
# Processing 3sbz_A (981/2775)...
# Processing 3sh5_A (982/2775)...
# Processing 3sjv_F (983/2775)...
# Processing 3sn5_B (984/2775)...
# Processing 3szb_B (985/2775)...
# Processing 3t6a_A (986/2775)...
# Processing 3t7l_A (987/2775)...
# Processing 3t9i_A (988/2775)...
# Processing 3tac_A (989/2775)...
# Processing 3thd_D (990/2775)...
# Processing 3tkl_A (991/2775)...
# Processing 3top_A (992/2775)...
# Processing 3tvl_A (993/2775)...
# Processing 3twj_B (994/2775)...
# Processing 3u5n_A (995/2775)...
# Processing 4orw_A (1230/2775)...
# Processing 4otg_A (1231/2775)...
# Processing 4p0p_A (1232/2775)...
# Processing 4p13_C (1233/2775)...
# Processing 4p5w_A (1234/2775)...
# Processing 4p60_A (1235/2775)...
# Processing 4pcu_A (1236/2775)...
# Processing 4pcw_B (1237/2775)...
# Processing 4px2_A (1238/2775)...
# Processing 4pzi_A (1239/2775)...
# Processing 4q4b_A (1240/2775)...
# Processing 4q4d_A (1241/2775)...
# Processing 4q6f_A (1242/2775)...
# Processing 4q7y_A (1243/2775)...
# Processing 4q93_A (1244/2775)...
# Processing 4q9u_E (1245/2775)...
# Processing 4qbm_A (1246/2775)...
# Processing 4qc3_A (1247/2775)...
# Processing 4qil_A (1248/2775)...
# Processing 4qmx_A (1249/2775)...
# Processing 4qn9_A (1250/2775)...
# Processing 4qpn_A (1251/2775)...
# Processing 4qu6_A (1252/2775)...
# Processing 4r1f_A (1253/2775)...
# Processing 4r2d_A (1254/2775)...
# Processing 4r6u_A (1255/2775)...
# Processing 4r7a_B (1256/2775)...
# Processing 4r7p_B (1257/2775)...
# Processing 4r8p_K (1258/2775)...
# Processing 4rau_L (1259/2775)...
# Processing 4rda_A (1260/2775)...
# Processing 4re1_A (1261/2775)...
# Processing 4re8_B (1262/2775)...
# Processing 4rec_A (1263/2775)...
# Processing 4rer_A (1264/2775)...
# Processing 4rfq_A (1265/2775)...
# Processing 4rg1_A (1266/2775)...
# Processing 4rkk_A (1267/2775)...
# Processing 4rn0_A (1268/2775)...
# Processing 4rr2_A (1269/2775)...
# Processing 4rsu_F (1270/2775)...
# Processing 4ruh_B (1271/2775)...
# Processing 4s15_A (1272/2775)...
# Processing 4s3o_B (1273/2775)...
# Processing 4s3o_C (1274/2775)...
# Processing 4tlg_A (1275/2775)...
# Processing 4tnt_A (1276/2775)...
# Processing 4ttv_A (1277/2775)...
# Processing 4twe_B (1278/2775)...
# Processing 4u5t_A (1279/2775)...
# Processing 4u8d_A (1280/2775)...
# Processing 4ueg_A (1281/2775)...
# Processing 4uem_A (1282/2775)...
# Processing 4ug2_A (1283/2775)...
# Processing 4uhz_A (1284/2775)...
# Processing 4ui9_S (1285/2775)...
# Processing 4um8_D (1286/2775)...
# Processing 4usf_B (1287/2775)...
# Processing 4ust_A (1288/2775)...
# Processing 4uu6_A (1289/2775)...
# Processing 4uuu_A (1290/2775)...
# Processing 4uy2_B (1291/2775)...
# Processing 4uy9_A (1292/2775)...
# Processing 4uya_A (1293/2775)...
# Processing 4uye_B (1294/2775)...
# Processing 4v0h_D (1295/2775)...
# Processing 4v3k_F (1296/2775)...
# Processing 4v6x_Aa (1297/2775)...
# Processing 4v6x_Af (1298/2775)...
# Processing 4wgk_A (1299/2775)...
# Processing 4whv_I (1300/2775)...
# Processing 4wle_D (1301/2775)...
# Processing 4wmq_A (1302/2775)...
# Processing 4wqn_B (1303/2775)...
# Processing 4wzx_A (1304/2775)...
# Processing 4x0q_B (1305/2775)...
# Processing 4x30_A (1306/2775)...
# Processing 4x7q_B (1307/2775)...
# Processing 7z6h_D (2578/2775)...
# Processing 7z6h_E (2579/2775)...
# Processing 7z6h_F (2580/2775)...
# Processing 7z6h_G (2581/2775)...
# Processing 7z71_A (2582/2775)...
# Processing 7z9f_A (2583/2775)...
# Processing 7zan_C (2584/2775)...
# Processing 7zcw_G (2585/2775)...
# Processing 7zel_A (2586/2775)...
# Processing 7zh3_D (2587/2775)...
# Processing 7zha_A (2588/2775)...
# Processing 7zi9_A (2589/2775)...
# Processing 7zjv_A (2590/2775)...
# Processing 7zmk_X (2591/2775)...
# Processing 7zmv_D (2592/2775)...
# Processing 7zmx_A (2593/2775)...
# Processing 7zr0_A (2594/2775)...
# Processing 7zr6_P (2595/2775)...
# Processing 7zrr_A (2596/2775)...
# Processing 7zsc_C (2597/2775)...
# Processing 7zyg_A (2598/2775)...
# Processing 7zyh_J (2599/2775)...
# Processing 7zyu_A (2600/2775)...
# Processing 7zzp_A (2601/2775)...
# Processing 8a0v_A (2602/2775)...
# Processing 8a38_C (2603/2775)...
# Processing 8a40_U (2604/2775)...
# Processing 8a4c_D (2605/2775)...
# Processing 8a4k_B (2606/2775)...
# Processing 8a6l_B (2607/2775)...
# Processing 8a8m_A (2608/2775)...
# Processing 8ajo_A (2609/2775)...
# Processing 8ari_W (2610/2775)...
# Processing 8as4_B (2611/2775)...
# Processing 8ayf_A (2612/2775)...
# Processing 8aza_A (2613/2775)...
# Processing 8b0a_K (2614/2775)...
# Processing 8b0f_C (2615/2775)...
# Processing 8b0f_F (2616/2775)...
# Processing 8b0g_J (2617/2775)...
# Processing 8b0h_E (2618/2775)...
# Processing 8b10_A (2619/2775)...
# Processing 8b5r_P (2620/2775)...
# Processing 8b6l_L (2621/2775)...
# Processing 8b6l_N (2622/2775)...
# Processing 8b6l_O (2623/2775)...
# Processing 8b9e_A (2624/2775)...
# Processing 8bah_B (2625/2775)...
# Processing 8bbg_C (2626/2775)...
# Processing 8bbs_A (2627/2775)...
# Processing 8bc9_J (2628/2775)...
# Processing 8blp_C (2629/2775)...
# Processing 8bot_U (2630/2775)...
# Processing 8bot_X (2631/2775)...
# Processing 8bub_B (2632/2775)...
# Processing 8bya_B (2633/2775)...
# Processing 8byl_B (2634/2775)...
# Processing 8bzy_A (2635/2775)...
# Processing 8c3u_A (2636/2775)...
# Processing 8c6j_7 (2637/2775)...
# Processing 8ca0_B (2638/2775)...
# Processing 8ch6_y (2639/2775)...
# Processing 8cqb_A (2640/2775)...
# Processing 8cr1_B (2641/2775)...
# Processing 8css_8 (2642/2775)...
# Processing 8cua_C (2643/2775)...
# Processing 8cuc_F (2644/2775)...
# Processing 8cv5_A (2645/2775)...
# Processing 8cx0_A (2646/2775)...
# Processing 8d1e_D (2647/2775)...
# Processing 8d1l_C (2648/2775)...
# Processing 8d30_A (2649/2775)...
# Processing 8d3c_E (2650/2775)...
# Processing 8d3v_A (2651/2775)...
# Processing 8d6e_A (2652/2775)...
# Processing 8d7z_C (2653/2775)...
# Processing 8d8i_A (2654/2775)...
# Processing 8daf_A (2655/2775)...
# Processing 8dbk_B (2656/2775)...
# Processing 8dey_F (2657/2775)...
# Processing 8dkm_P (2658/2775)...
# Processing 8dmk_G (2659/2775)...
# Processing 8dnu_D (2660/2775)...
# Processing 8dph_A (2661/2775)...
# Processing 8dyd_A (2662/2775)...
# Processing 8dyl_B (2663/2775)...
# Processing 8e0c_A (2664/2775)...
# Processing 8e0f_B (2665/2775)...
# Processing 8e1a_A (2666/2775)...
# Processing 8e3y_R (2667/2775)...
# Processing 8e4y_A (2668/2775)...
# Processing 8e8v_A (2669/2775)...
# Processing 8e93_B (2670/2775)...
# Processing 8e98_C (2671/2775)...
# Processing 8e9z_A (2672/2775)...
# Processing 8ede_B (2673/2775)...
# Processing 8ef7_A (2674/2775)...
# Processing 8efg_A (2675/2775)...
# Processing 8efq_R (2676/2775)...
# Processing 8eg3_A (2677/2775)...
# Processing 8egx_B (2678/2775)...
# Processing 8eih_A (2679/2775)...
# Processing 8eiq_A (2680/2775)...
# Processing 8ejm_A (2681/2775)...
# Processing 8emr_B (2682/2775)...
# Processing 8eok_G (2683/2775)...
# Processing 8eop_A (2684/2775)...
# Processing 8eor_B (2685/2775)...
# Processing 8epl_A (2686/2775)...
# Processing 8esv_A (2687/2775)...
# Processing 8eyk_F (2688/2775)...
# Processing 8eyo_A (2689/2775)...
# Processing 8f7s_R (2690/2775)...
# Processing 8fb2_B (2691/2775)...
# Processing 8fc7_B (2692/2775)...
# Processing 8ffv_A (2693/2775)...
# Processing 8ffw_D (2694/2775)...
# Processing 8fgw_C (2695/2775)...
# Processing 8fjx_A (2696/2775)...
# Processing 8fmu_B (2697/2775)...
# Processing 8fnb_B (2698/2775)...
# Processing 8foa_A (2699/2775)...
# Processing 8fp1_A (2700/2775)...
# Processing 8fw5_B (2701/2775)...
# Processing 8fyh_I (2702/2775)...
# Processing 8g0l_A (2703/2775)...
# Processing 8g46_B (2704/2775)...
# Processing 8g7n_A (2705/2775)...
# Processing 8g9p_D (2706/2775)...
# Processing 8gju_D (2707/2775)...
# Processing 8gk3_H (2708/2775)...
# Processing 8gnn_A (2709/2775)...
# Processing 8gui_K (2710/2775)...
# Processing 8gx3_A (2711/2775)...
# Processing 8gye_A (2712/2775)...
# Processing 8gyx_B (2713/2775)...
# Processing 8gz2_B (2714/2775)...
# Processing 8h65_C (2715/2775)...
# Processing 8h8j_C (2716/2775)...
# Processing 8hbe_B (2717/2775)...
# Processing 8hdp_R (2718/2775)...
# Processing 8hy5_B (2719/2775)...
# Processing 8i1o_A (2720/2775)...
# Processing 8i5y_A (2721/2775)...
# Processing 8i5y_B (2722/2775)...
# Processing 8i9u_J (2723/2775)...
# Processing 8i9u_O (2724/2775)...
# Processing 8ifo_A (2725/2775)...
# Processing 8il3_C (2726/2775)...
# Processing 8iqn_A (2727/2775)...
# Processing 8irr_R (2728/2775)...
# Processing 8iuh_3 (2729/2775)...
# Processing 8iwu_A (2730/2775)...
# Processing 8iys_R (2731/2775)...
# Processing 8jbn_B (2732/2775)...
# Processing 8jdl_AP (2733/2775)...
# Processing 8jhf_A (2734/2775)...
# Processing 8jii_A (2735/2775)...
# Processing 8jyg_B (2736/2775)...
# Processing 8kb5_G (2737/2775)...
# Processing 8odo_A (2738/2775)...
# Processing 8oew_O (2739/2775)...
# Processing 8oi8_A (2740/2775)...
# Processing 8oma_A (2741/2775)...
# Processing 8omr_A (2742/2775)...
# Processing 8oxy_A (2743/2775)...
# Processing 8p50_B (2744/2775)...
# Processing 8p8x_A (2745/2775)...
# Processing 8p94_A (2746/2775)...
# Processing 8pqh_A (2747/2775)...
# Processing 8q7n_K (2748/2775)...
# Processing 8qk3_E (2749/2775)...
# Processing 8qy4_D (2750/2775)...
# Processing 8rbx_W (2751/2775)...
# Processing 8sg5_H (2752/2775)...
# Processing 8sgo_C (2753/2775)...
# Processing 8syp_C (2754/2775)...
# Processing 8t6j_A (2755/2775)...
# Processing 8t9h_K (2756/2775)...
# Processing 8tar_N (2757/2775)...
# Processing 8tgd_A (2758/2775)...
# Processing 8tnq_B (2759/2775)...
# Processing 8tzo_C (2760/2775)...
# Processing 8tzs_A (2761/2775)...
# Processing 8u26_R (2762/2775)...
# Processing 8u37_A (2763/2775)...
# Processing 8ucd_C (2764/2775)...
# Processing 8uhd_Y (2765/2775)...
# Processing 8v4y_W (2766/2775)...
# Processing 8v8u_B (2767/2775)...
# Processing 8wej_B (2768/2775)...
# Processing 8x15_W (2769/2775)...
# Processing 8x72_A (2770/2775)...
# Processing 8xov_A (2771/2775)...
# Processing 8xpn_A (2772/2775)...
# Processing 8y14_A (2773/2775)...
# Processing 8y6b_F (2774/2775)...
# Processing 8y6o_H (2775/2775)...

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

number_of_pockets = sum([len(i) for i in binding_residues.values()])

mean_br = np.mean(best_residue_overlaps)
median_br = np.median(best_residue_overlaps)
print(f'best_residue_overlap mean={mean_br:.4f}, median={median_br:.4f}')

print(np.sum(np.array(DCCs) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N_plus_K) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N_plus_K) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N) < 4) / number_of_pockets})')


print('\nSmall binding pockets (less than 10 residues):')
small_pockets_DCCs = [DCCs[i] for i in range(len(DCCs)) if is_small_pocket_DCC[i]]
print(f'Overall DCC < 12: {np.sum(np.array(small_pockets_DCCs) < 12) / len(small_pockets_DCCs):.4f} ({np.sum(np.array(small_pockets_DCCs) < 4) / len(small_pockets_DCCs):.4f})')
small_pockets_DCCs_N_plus_K = [DCCs_N_plus_K[i] for i in range(len(DCCs_N_plus_K)) if is_small_pocket_DCC_N_plus_K[i]]
print(f'N+K DCC < 12: {np.sum(np.array(small_pockets_DCCs_N_plus_K) < 12) / len(small_pockets_DCCs_N_plus_K):.4f} ({np.sum(np.array(small_pockets_DCCs_N_plus_K) < 4) / len(small_pockets_DCCs_N_plus_K):.4f})')
small_pockets_DCCs_N = [DCCs_N[i] for i in range(len(DCCs_N)) if is_small_pocket_DCC_N[i]]
print(f'N DCC < 12: {np.sum(np.array(small_pockets_DCCs_N) < 12) / len(small_pockets_DCCs_N):.4f} ({np.sum(np.array(small_pockets_DCCs_N) < 4) / len(small_pockets_DCCs_N):.4f})')

print('\nLarge binding pockets (10 or more residues):')
large_pockets_DCCs = [DCCs[i] for i in range(len(DCCs)) if not is_small_pocket_DCC[i]]
print(f'Overall DCC < 12: {np.sum(np.array(large_pockets_DCCs) < 12) / len(large_pockets_DCCs):.4f} ({np.sum(np.array(large_pockets_DCCs) < 4) / len(large_pockets_DCCs):.4f})')
large_pockets_DCCs_N_plus_K = [DCCs_N_plus_K[i] for i in range(len(DCCs_N_plus_K)) if not is_small_pocket_DCC_N_plus_K[i]]
print(f'N+K DCC < 12: {np.sum(np.array(large_pockets_DCCs_N_plus_K) < 12) / len(large_pockets_DCCs_N_plus_K):.4f} ({np.sum(np.array(large_pockets_DCCs_N_plus_K) < 4) / len(large_pockets_DCCs_N_plus_K):.4f})')
large_pockets_DCCs_N = [DCCs_N[i] for i in range(len(DCCs_N)) if not is_small_pocket_DCC_N[i]]
print(f'N DCC < 12: {np.sum(np.array(large_pockets_DCCs_N) < 12) / len(large_pockets_DCCs_N):.4f} ({np.sum(np.array(large_pockets_DCCs_N) < 4) / len(large_pockets_DCCs_N):.4f})')  


fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros = [i for i in number_of_overlapping_actual_sites_on_predicted_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Predicted Pockets Covering True Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Predicted Pockets Covering True Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_predictions_on_actual_pocket_without_zeros = [i for i in number_of_overlapping_predictions_on_actual_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_predictions_on_actual_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Actual Pockets Covering Predicted Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Actual Pockets Covering Predicted Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()
# Out:
# best_residue_overlap mean=0.4787, median=0.5000
# 0.6684103458297007 (0.2092414995640802)
# 0.6566405114792212 (0.20255739610578322)
# 0.6031676838128451 (0.17654751525719267)
#
# Small binding pockets (less than 10 residues):
# Overall DCC < 12: 0.5630 (0.1467)
# N+K DCC < 12: 0.5468 (0.1372)
# N DCC < 12: 0.4824 (0.1049)
#
# Large binding pockets (10 or more residues):
# Overall DCC < 12: 0.8114 (0.2873)
# N+K DCC < 12: 0.8041 (0.2836)
# N DCC < 12: 0.7611 (0.2638)

# %% [markdown]
# ## Run 650M version

# %%
PREDICTIONS_PATH = f'{PATH}/data/predictions'
PRECALCULATED_PATH = f'{PREDICTIONS_PATH}/gbs-model-650M'

MODEL_PATH = f'{PATH}/data/models/gbs-model-enhanced-scPDB-filtered-650M.pt'
PRECALCULATED = False
SMOOTHING_MODEL_PATH = f'{PATH}/data/models/smoother-650M.pt'
ESM_EMBEDDINGS_PATH = f'{PATH}/data/embeddings/ligysis-650M'
MODEL_NAME = 'facebook/esm2_t33_650M_UR50D'

smoothing_model = torch.load(SMOOTHING_MODEL_PATH, weights_only=False) #, map_location=torch.device('cpu'))
smoothing_model.eval()

model = torch.load(MODEL_PATH, weights_only=False)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

binding_residues, sequences = eval_utils.read_test_binding_residues(data_path=LIGYSIS_ANNOTATION_PATH, pocket_types=['NON_CRYPTIC'])

predicted_binding_sites = {}
ranks = {}
prediction_scores = {}

K = 2

DCCs_N = []
DCCs_N_plus_K = []
DCCs = []

is_small_pocket_DCC_N = []
is_small_pocket_DCC_N_plus_K = []
is_small_pocket_DCC = []

number_of_added_residues = []

number_of_overlapping_predictions_on_actual_pocket = []
number_of_overlapping_actual_sites_on_predicted_pocket = []
best_residue_overlaps = []

for i, protein_id in enumerate(sequences.keys()):
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    embeddings_path = f'{ESM_EMBEDDINGS_PATH}/{pdb_id}{chain_id}.npy'
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'
    actual_binding_sites = [np.array([int(i.split('_')[1]) for i in pocket]) for pocket in binding_residues[protein_id]]
    
    print(f'Processing {protein_id} ({i+1}/{len(sequences)})...')
    if not PRECALCULATED:
        # finetuned prediction
        probabilities = eval_utils.compute_prediction(
            sequence,
            model,
            tokenizer
        )
    else:
        # load precalculated prediction
        probabilities = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')
    
    prediction_scores[protein_id] = probabilities

    coordinates = np.load(coordinates_path)
    distance_matrix = eval_utils.compute_distance_matrix(coordinates)

    predictions = (probabilities > DECISION_THRESHOLD).astype(float)
    predictions_copy = predictions.copy()

    assert distance_matrix.shape[0] == distance_matrix.shape[1]
    assert distance_matrix.shape[0] == predictions_copy.shape[0]
    
    X_test = np.load(embeddings_path)
    assert X_test.shape[0] == distance_matrix.shape[0]

    # loop over the residues that are not binding and are potential candidates for smoothing
    additional_residues = []
    added_residues_count = 0
    for residue_idx in np.where(predictions == 0.0)[0]:

        # get the embedding of the residue
        current_residue_embedding = X_test[residue_idx]

        # get the close binding residues
        close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
        close_binding_residues_indices = np.intersect1d(close_residues_indices, np.where(predictions == 1.0)[0])
        # create embedding 
        if len(close_binding_residues_indices) == 0:
            # no close binding residues - skip this residue
            continue
        elif len(close_binding_residues_indices) == 1:
            surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
        else:
            # get the mean of the close binding residues
            surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

        concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(device)
        
        # get the prediction
        test_logits = smoothing_model(concatenated_embedding).squeeze()
        result = (torch.sigmoid(test_logits)>eval_utils.SMOOTHING_DECISION_THRESHOLD).float()
        if result == 1:
            # set the residue as binding
            # print(f"Smoothing changed residue {residue_idx} in protein {protein_id} to binding")
            additional_residues.append(residue_idx)
            predictions_copy[residue_idx] = 1
            added_residues_count += 1

    number_of_added_residues.append(added_residues_count)
    
    indices_above_threshold = np.where(predictions_copy > DECISION_THRESHOLD)[0] # this gets residues that are equal to 1
    # no predicted residues - continue
    if len(indices_above_threshold) == 0:
        continue

    # run atom-level clustering and return residue-level pockets
    clusters, cluster_residues, cluster_scores, atom_coords, residue_coords = clustering_utils.execute_atom_clustering(
        pdb_id,
        chain_id,
        indices_above_threshold,
        probabilities[indices_above_threshold],
        eps=9
    )

    # none of the residues are on the surface
    if cluster_residues is None:
        continue

    cluster_residues = cryptoshow_utils.map_auth_to_mmcif_numbering_array(
        pdb_id,
        chain_id,
        cluster_residues.values(),
        binding_residues_are_integers=True,
        numbers_only=True
    )[0]

    cluster_order = np.argsort(cluster_scores)[::-1]  # descending order
    N = len(actual_binding_sites)

    selected_clusters_N = cluster_order[:N]
    selected_clusters_N_plus_K = cluster_order[:N+K]

    predicted_centers = {}
    for cluster_label, atom_indices in clusters.items():
        cluster_coords = np.array([atom_coords[atom_id] for atom_id in atom_indices])
        cluster_center = np.mean(cluster_coords, axis=0).get_array()
        predicted_centers[cluster_label] = cluster_center
    
    actual_centers = []
    is_small_pocket = []
    for pocket in actual_binding_sites:
        pocket_coords = coordinates[pocket]
        pocket_center = np.mean(pocket_coords, axis=0)
        actual_centers.append(pocket_center)
        is_small_pocket.append(len(pocket) < 10)
    
    for i, center in enumerate(actual_centers):
        DCC_N = float('inf')
        for j in selected_clusters_N:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N:
                DCC_N = distance
        
        if DCC_N != float('inf'):
            DCCs_N.append(DCC_N)
            is_small_pocket_DCC_N.append(is_small_pocket[i])

        DCC_N_plus_K = float('inf')
        for j in selected_clusters_N_plus_K:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N_plus_K:
                DCC_N_plus_K = distance
        
        if DCC_N_plus_K != float('inf'):
            DCCs_N_plus_K.append(DCC_N_plus_K)
            is_small_pocket_DCC_N_plus_K.append(is_small_pocket[i])
            

    dcc_rro_matches = clustering_utils.compute_dcc_matched_rro(
        actual_binding_sites, actual_centers, predicted_centers, cluster_residues,
        dcc_hit_threshold=DCC_HIT_THRESHOLD,
    )
    for i, match in enumerate(dcc_rro_matches):
        if match['dcc'] != float('inf'):
            DCCs.append(match['dcc'])
            is_small_pocket_DCC.append(is_small_pocket[i])
        if match['rro'] is not None:
            best_residue_overlaps.append(match['rro'])

    for pocket in actual_binding_sites:
        number_of_predicted_pockets = 0
        for residues in cluster_residues:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_actual_sites_on_predicted_pocket.append(number_of_predicted_pockets)

    for residues in cluster_residues:
        number_of_predicted_pockets = 0
        for pocket in actual_binding_sites:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_predictions_on_actual_pocket.append(number_of_predicted_pockets)
# Out:
# Processing 1a52_A (1/2775)...
# Processing 1a9w_E (2/2775)...
# Processing 1aii_A (3/2775)...
# Processing 1au1_A (4/2775)...
# Processing 1aue_B (5/2775)...
# Processing 1b1c_A (6/2775)...
# Processing 1b50_B (7/2775)...
# Processing 1b55_B (8/2775)...
# Processing 1b6c_F (9/2775)...
# Processing 1nst_A (173/2775)...
# Processing 1nuh_A (174/2775)...
# Processing 1nuu_B (175/2775)...
# Processing 1nyp_A (176/2775)...
# Processing 1ohc_A (177/2775)...
# Processing 1oj6_D (178/2775)...
# Processing 1opl_A (179/2775)...
# Processing 1oqj_B (180/2775)...
# Processing 1ozo_A (181/2775)...
# Processing 1ozs_A (182/2775)...
# Processing 1p32_A (183/2775)...
# Processing 1p4o_A (184/2775)...
# Processing 1p4q_B (185/2775)...
# Processing 1pb5_A (186/2775)...
# Processing 1pfl_A (187/2775)...
# Processing 1pkx_B (188/2775)...
# Processing 1pl8_C (189/2775)...
# Processing 1plo_A (190/2775)...
# Processing 1psr_B (191/2775)...
# Processing 1pt6_B (192/2775)...
# Processing 1q0p_A (193/2775)...
# Processing 1q1u_A (194/2775)...
# Processing 1q33_A (195/2775)...
# Processing 1q3a_A (196/2775)...
# Processing 1q7l_C (197/2775)...
# Processing 1q7l_D (198/2775)...
# Processing 1q8l_A (199/2775)...
# Processing 1q8x_A (200/2775)...
# Processing 1q9s_A (201/2775)...
# Processing 1qh5_B (202/2775)...
# Processing 1qnm_A (203/2775)...
# Processing 1qzq_A (204/2775)...
# Processing 1qzu_B (205/2775)...
# Processing 1r3y_A (206/2775)...
# Processing 1r54_A (207/2775)...
# Processing 1r8q_E (208/2775)...
# Processing 1rgo_A (209/2775)...
# Processing 1riw_B (210/2775)...
# Processing 1rjv_A (211/2775)...
# Processing 1rkb_A (212/2775)...
# Processing 1rm8_A (213/2775)...
# Processing 1rnf_B (214/2775)...
# Processing 1ro4_A (215/2775)...
# Processing 1rtg_A (216/2775)...
# Processing 1rx0_D (217/2775)...
# Processing 1rxr_A (218/2775)...
# Processing 1s18_A (219/2775)...
# Processing 1s4b_P (220/2775)...
# Processing 1s4y_B (221/2775)...
# Processing 1s9i_A (222/2775)...
# Processing 1sg4_B (223/2775)...
# Processing 1shr_D (224/2775)...
# Processing 1siq_A (225/2775)...
# Processing 1sl6_E (226/2775)...
# Processing 1smo_B (227/2775)...
# Processing 1so0_B (228/2775)...
# Processing 1soj_I (229/2775)...
# Processing 1sp2_A (230/2775)...
# Processing 1st0_A (231/2775)...
# Processing 1su3_A (232/2775)...
# Processing 1szb_B (233/2775)...
# Processing 1t3n_B (234/2775)...
# Processing 1t6b_Y (235/2775)...
# Processing 1t8c_A (236/2775)...
# Processing 1tff_A (237/2775)...
# Processing 1tfi_A (238/2775)...
# Processing 1tg6_C (239/2775)...
# Processing 1tjj_A (240/2775)...
# Processing 1toz_A (241/2775)...
# Processing 1tpk_C (242/2775)...
# Processing 1ttx_A (243/2775)...
# Processing 1tu4_C (244/2775)...
# Processing 1tvx_D (245/2775)...
# Processing 1u31_A (246/2775)...
# Processing 1u3t_A (247/2775)...
# Processing 1u7f_B (248/2775)...
# Processing 1u7t_D (249/2775)...
# Processing 1ubd_C (250/2775)...
# Processing 1ul1_Z (251/2775)...
# Processing 1umk_A (252/2775)...
# Processing 1upr_A (253/2775)...
# Processing 1ur6_B (254/2775)...
# Processing 2fim_B (420/2775)...
# Processing 2fj9_A (421/2775)...
# Processing 2fju_B (422/2775)...
# Processing 2fqq_B (423/2775)...
# Processing 2frw_A (424/2775)...
# Processing 2fsz_A (425/2775)...
# Processing 2fu5_B (426/2775)...
# Processing 2fvl_A (427/2775)...
# Processing 2fyl_B (428/2775)...
# Processing 2g2k_A (429/2775)...
# Processing 2g43_A (430/2775)...
# Processing 2g4a_A (431/2775)...
# Processing 2g6b_A (432/2775)...
# Processing 2g9o_A (433/2775)...
# Processing 2gao_B (434/2775)...
# Processing 2gf0_B (435/2775)...
# Processing 2gf9_A (436/2775)...
# Processing 2ggm_A (437/2775)...
# Processing 2ggz_B (438/2775)...
# Processing 2gjx_H (439/2775)...
# Processing 2gk1_Q (440/2775)...
# Processing 2gli_A (441/2775)...
# Processing 2gmv_A (442/2775)...
# Processing 2gp5_A (443/2775)...
# Processing 2gpq_A (444/2775)...
# Processing 2gqj_A (445/2775)...
# Processing 2gql_A (446/2775)...
# Processing 2gwh_A (447/2775)...
# Processing 2gz5_A (448/2775)...
# Processing 2h16_D (449/2775)...
# Processing 2h57_B (450/2775)...
# Processing 2h63_D (451/2775)...
# Processing 2h6h_A (452/2775)...
# Processing 2h8h_A (453/2775)...
# Processing 2h8k_B (454/2775)...
# Processing 2h9e_L (455/2775)...
# Processing 2ha8_A (456/2775)...
# Processing 2hei_B (457/2775)...
# Processing 2hgs_A (458/2775)...
# Processing 2hhl_A (459/2775)...
# Processing 2hhn_A (460/2775)...
# Processing 2hi4_A (461/2775)...
# Processing 2hrb_A (462/2775)...
# Processing 2hup_A (463/2775)...
# Processing 2hw5_A (464/2775)...
# Processing 2hw6_A (465/2775)...
# Processing 2hzq_A (466/2775)...
# Processing 2i0y_A (467/2775)...
# Processing 2i3c_B (468/2775)...
# Processing 2i50_A (469/2775)...
# Processing 2i6a_A (470/2775)...
# Processing 2i6s_A (471/2775)...
# Processing 2i7n_B (472/2775)...
# Processing 2i96_A (473/2775)...
# Processing 2i99_B (474/2775)...
# Processing 2i9a_D (475/2775)...
# Processing 2iby_A (476/2775)...
# Processing 2iim_A (477/2775)...
# Processing 2il1_A (478/2775)...
# Processing 2ipp_A (479/2775)...
# Processing 2iqj_B (480/2775)...
# Processing 2it4_B (481/2775)...
# Processing 2iuw_A (482/2775)...
# Processing 2iwy_A (483/2775)...
# Processing 2iyk_B (484/2775)...
# Processing 2j2p_C (485/2775)...
# Processing 2j2s_A (486/2775)...
# Processing 2j3s_A (487/2775)...
# Processing 2j4o_A (488/2775)...
# Processing 2j5z_B (489/2775)...
# Processing 2j8z_A (490/2775)...
# Processing 2jai_A (491/2775)...
# Processing 2jam_B (492/2775)...
# Processing 2jbh_B (493/2775)...
# Processing 2jdw_A (494/2775)...
# Processing 2jed_A (495/2775)...
# Processing 2jeo_A (496/2775)...
# Processing 2jg9_F (497/2775)...
# Processing 2jif_D (498/2775)...
# Processing 2jis_B (499/2775)...
# Processing 2jld_B (500/2775)...
# Processing 2jlp_C (501/2775)...
# Processing 2o8f_B (584/2775)...
# Processing 2obd_A (585/2775)...
# Processing 2obv_A (586/2775)...
# Processing 2ocb_A (587/2775)...
# Processing 2ocg_A (588/2775)...
# Processing 2ocp_C (589/2775)...
# Processing 2od1_A (590/2775)...
# Processing 2ohf_A (591/2775)...
# Processing 2oil_A (592/2775)...
# Processing 2okv_C (593/2775)...
# Processing 2oo4_B (594/2775)...
# Processing 2opw_A (595/2775)...
# Processing 2ox8_D (596/2775)...
# Processing 2oxc_A (597/2775)...
# Processing 2p0a_A (598/2775)...
# Processing 2p0d_A (599/2775)...
# Processing 2p0r_B (600/2775)...
# Processing 2p0w_A (601/2775)...
# Processing 2p1f_A (602/2775)...
# Processing 2p57_A (603/2775)...
# Processing 2p5s_B (604/2775)...
# Processing 2p8e_B (605/2775)...
# Processing 2pfr_A (606/2775)...
# Processing 2pg5_D (607/2775)...
# Processing 2pid_A (608/2775)...
# Processing 2pl0_A (609/2775)...
# Processing 2pla_A (610/2775)...
# Processing 2pmy_A (611/2775)...
# Processing 2pqf_D (612/2775)...
# Processing 2pru_B (613/2775)...
# Processing 2psn_D (614/2775)...
# Processing 2puy_A (615/2775)...
# Processing 2pvs_A (616/2775)...
# Processing 2q3f_B (617/2775)...
# Processing 2q3h_A (618/2775)...
# Processing 2q3z_A (619/2775)...
# Processing 2q5e_D (620/2775)...
# Processing 2q7r_F (621/2775)...
# Processing 2q8f_A (622/2775)...
# Processing 2q98_A (623/2775)...
# Processing 2qic_A (624/2775)...
# Processing 2qk4_B (625/2775)...
# Processing 2qkk_W (626/2775)...
# Processing 2qpp_B (627/2775)...
# Processing 2qra_C (628/2775)...
# Processing 2qst_B (629/2775)...
# Processing 2qt7_B (630/2775)...
# Processing 2qtz_A (631/2775)...
# Processing 2qym_A (632/2775)...
# Processing 2r3a_A (633/2775)...
# Processing 2r5g_A (634/2775)...
# Processing 2r83_A (635/2775)...
# Processing 2r8u_A (636/2775)...
# Processing 2ra4_B (637/2775)...
# Processing 2raj_A (638/2775)...
# Processing 2rb3_C (639/2775)...
# Processing 2rb4_B (640/2775)...
# Processing 2rc4_A (641/2775)...
# Processing 2rhp_A (642/2775)...
# Processing 2rje_B (643/2775)...
# Processing 2rjp_B (644/2775)...
# Processing 2rjq_A (645/2775)...
# Processing 2rkb_C (646/2775)...
# Processing 2rli_A (647/2775)...
# Processing 2rmk_A (648/2775)...
# Processing 2rsg_A (649/2775)...
# Processing 2rsq_A (650/2775)...
# Processing 2ruy_A (651/2775)...
# Processing 2uur_A (652/2775)...
# Processing 2uvl_A (653/2775)...
# Processing 2uyy_D (654/2775)...
# Processing 2uzg_A (655/2775)...
# Processing 2v40_A (656/2775)...
# Processing 2v55_B (657/2775)...
# Processing 2vac_A (658/2775)...
# Processing 2vcv_J (659/2775)...
# Processing 2vd5_B (660/2775)...
# Processing 2vdy_A (661/2775)...
# Processing 2vhf_A (662/2775)...
# Processing 2vkq_A (663/2775)...
# Processing 2vm5_A (664/2775)...
# Processing 2vn9_A (665/2775)...
# Processing 2vq3_A (666/2775)...
# Processing 2vr2_A (667/2775)...
# Processing 2vrd_A (668/2775)...
# Processing 2vrg_A (669/2775)...
# Processing 2vsc_C (670/2775)...
# Processing 2vwi_D (671/2775)...
# Processing 2vxo_A (672/2775)...
# Processing 2w0t_A (673/2775)...
# Processing 2w2i_A (674/2775)...
# Processing 2w3o_B (675/2775)...
# Processing 2w4l_E (676/2775)...
# Processing 2w4o_A (677/2775)...
# Processing 2w4r_D (678/2775)...
# Processing 2w86_A (679/2775)...
# Processing 2w8p_A (680/2775)...
# Processing 2wbi_B (681/2775)...
# Processing 2wce_A (682/2775)...
# Processing 2wef_A (683/2775)...
# Processing 2wh5_E (684/2775)...
# Processing 2wjy_A (685/2775)...
# Processing 2wk6_B (686/2775)...
# Processing 2wno_A (687/2775)...
# Processing 2wtk_E (688/2775)...
# Processing 2wtk_F (689/2775)...
# Processing 2wwy_B (690/2775)...
# Processing 2wwz_C (691/2775)...
# Processing 2wya_C (692/2775)...
# Processing 2wzb_A (693/2775)...
# Processing 2x10_A (694/2775)...
# Processing 2x11_B (695/2775)...
# Processing 2x4d_A (696/2775)...
# Processing 2x4f_B (697/2775)...
# Processing 2x4w_A (698/2775)...
# Processing 2x7g_A (699/2775)...
# Processing 2x7h_B (700/2775)...
# Processing 2xik_A (701/2775)...
# Processing 2xmr_C (702/2775)...
# Processing 2xn3_B (703/2775)...
# Processing 2xph_A (704/2775)...
# Processing 2xrc_D (705/2775)...
# Processing 2xsx_A (706/2775)...
# Processing 2xtp_A (707/2775)...
# Processing 2xzg_A (708/2775)...
# Processing 2y1h_A (709/2775)...
# Processing 2y1l_D (710/2775)...
# Processing 2y23_A (711/2775)...
# Processing 2y43_B (712/2775)...
# Processing 2y7j_D (713/2775)...
# Processing 2yan_A (714/2775)...
# Processing 2yd8_A (715/2775)...
# Processing 2ygq_A (716/2775)...
# Processing 2yh0_A (717/2775)...
# Processing 2yho_C (718/2775)...
# Processing 2yqm_A (719/2775)...
# Processing 2yrt_A (720/2775)...
# Processing 2ysl_A (721/2775)...
# Processing 2yu2_A (722/2775)...
# Processing 2yvr_A (723/2775)...
# Processing 2z0u_B (724/2775)...
# Processing 2z15_C (725/2775)...
# Processing 2z4e_E (726/2775)...
# Processing 2z5f_B (727/2775)...
# Processing 2zfu_B (728/2775)...
# Processing 2zg1_A (729/2775)...
# Processing 2znv_D (730/2775)...
# Processing 2zoc_A (731/2775)...
# Processing 2zoq_A (732/2775)...
# Processing 2zox_A (733/2775)...
# Processing 2zrt_G (734/2775)...
# Processing 3a2a_B (735/2775)...
# Processing 3a4s_A (736/2775)...
# Processing 3a4u_A (737/2775)...
# Processing 3aad_A (738/2775)...
# Processing 3aco_A (739/2775)...
# Processing 3ahq_A (740/2775)...
# Processing 3aih_A (741/2775)...
# Processing 3alq_R (742/2775)...
# Processing 3ap3_A (743/2775)...
# Processing 3b2d_A (744/2775)...
# Processing 3b3l_A (745/2775)...
# Processing 3b6r_B (746/2775)...
# Processing 3b6u_A (747/2775)...
# Processing 3b6v_A (748/2775)...
# Processing 3bce_A (749/2775)...
# Processing 3ber_A (750/2775)...
# Processing 3bfx_A (751/2775)...
# Processing 3bh7_B (752/2775)...
# Processing 3bhm_A (753/2775)...
# Processing 3bi6_A (754/2775)...
# Processing 3bjc_A (755/2775)...
# Processing 3bm4_B (756/2775)...
# Processing 3bo5_A (757/2775)...
# Processing 3brh_A (758/2775)...
# Processing 3bsu_H (759/2775)...
# Processing 3bvo_B (760/2775)...
# Processing 3c5c_D (761/2775)...
# Processing 3c5e_A (762/2775)...
# Processing 3c6k_A (763/2775)...
# Processing 3c6w_C (764/2775)...
# Processing 3cbb_B (765/2775)...
# Processing 3cbk_A (766/2775)...
# Processing 3cbq_A (767/2775)...
# Processing 3cfw_A (768/2775)...
# Processing 3cos_C (769/2775)...
# Processing 3ctz_A (770/2775)...
# Processing 3cxp_A (771/2775)...
# Processing 3d0e_B (772/2775)...
# Processing 3d24_C (773/2775)...
# Processing 3d2f_D (774/2775)...
# Processing 3d34_B (775/2775)...
# Processing 3d3l_B (776/2775)...
# Processing 3d3w_B (777/2775)...
# Processing 3d5o_B (778/2775)...
# Processing 3d87_B (779/2775)...
# Processing 3d8b_A (780/2775)...
# Processing 3d8e_C (781/2775)...
# Processing 3ddu_A (782/2775)...
# Processing 3dem_B (783/2775)...
# Processing 3dk9_A (784/2775)...
# Processing 3dko_A (785/2775)...
# Processing 3dlj_B (786/2775)...
# Processing 3dls_C (787/2775)...
# Processing 3dwb_A (788/2775)...
# Processing 3dyd_B (789/2775)...
# Processing 3dz4_B (790/2775)...
# Processing 3e1y_B (791/2775)...
# Processing 3e3r_B (792/2775)...
# Processing 3e4c_B (793/2775)...
# Processing 3e6i_B (794/2775)...
# Processing 3eb5_A (795/2775)...
# Processing 3edy_A (796/2775)...
# Processing 3eh1_A (797/2775)...
# Processing 3eh2_B (798/2775)...
# Processing 3elb_A (799/2775)...
# Processing 3epy_B (800/2775)...
# Processing 3epz_A (801/2775)...
# Processing 3eta_A (802/2775)...
# Processing 3eue_A (803/2775)...
# Processing 3exi_B (804/2775)...
# Processing 3eyh_A (805/2775)...
# Processing 3f1r_B (806/2775)...
# Processing 3f3y_A (807/2775)...
# Processing 3f5o_E (808/2775)...
# Processing 3f70_B (809/2775)...
# Processing 3f7u_C (810/2775)...
# Processing 3f9p_A (811/2775)...
# Processing 3fcx_B (812/2775)...
# Processing 3fd6_B (813/2775)...
# Processing 3fe2_B (814/2775)...
# Processing 3fe3_A (815/2775)...
# Processing 3fe4_A (816/2775)...
# Processing 3fec_A (817/2775)...
# Processing 3ff6_D (818/2775)...
# Processing 3ffk_A (819/2775)...
# Processing 3fg6_F (820/2775)...
# Processing 3fl2_A (821/2775)...
# Processing 3flv_B (822/2775)...
# Processing 3fvy_A (823/2775)...
# Processing 3fy1_A (824/2775)...
# Processing 3g4h_A (825/2775)...
# Processing 3g73_A (826/2775)...
# Processing 3g9y_A (827/2775)...
# Processing 3gbj_A (828/2775)...
# Processing 3gc9_B (829/2775)...
# Processing 3gdh_B (830/2775)...
# Processing 3gdq_A (831/2775)...
# Processing 3gep_B (832/2775)...
# Processing 3ggf_B (833/2775)...
# Processing 3ghg_C (834/2775)...
# Processing 3gis_Z (835/2775)...
# Processing 3gjx_E (836/2775)...
# Processing 3gkh_A (837/2775)...
# Processing 3gpd_G (838/2775)...
# Processing 3gqc_D (839/2775)...
# Processing 3gta_A (840/2775)...
# Processing 3gxb_A (841/2775)...
# Processing 3gzd_A (842/2775)...
# Processing 3h2u_B (843/2775)...
# Processing 3h53_B (844/2775)...
# Processing 3hco_B (845/2775)...
# Processing 3hf1_A (846/2775)...
# Processing 3hn3_B (847/2775)...
# Processing 3ho4_A (848/2775)...
# Processing 3hr4_G (849/2775)...
# Processing 3hud_B (850/2775)...
# Processing 3hxt_A (851/2775)...
# Processing 3hy8_A (852/2775)...
# Processing 3ia8_A (853/2775)...
# Processing 3iei_H (854/2775)...
# Processing 3ihp_B (855/2775)...
# Processing 3ik7_B (856/2775)...
# Processing 3io2_A (857/2775)...
# Processing 3isq_A (858/2775)...
# Processing 3iu6_A (859/2775)...
# Processing 3iuf_A (860/2775)...
# Processing 3iuy_A (861/2775)...
# Processing 3iwl_A (862/2775)...
# Processing 3ixe_B (863/2775)...
# Processing 3ixs_K (864/2775)...
# Processing 3j0a_A (865/2775)...
# Processing 3j2s_B (866/2775)...
# Processing 3jrx_A (867/2775)...
# Processing 3jub_A (868/2775)...
# Processing 3jue_A (869/2775)...
# Processing 3jyh_A (870/2775)...
# Processing 3k2s_B (871/2775)...
# Processing 3k51_B (872/2775)...
# Processing 3k5t_A (873/2775)...
# Processing 3k7v_A (874/2775)...
# Processing 3k9j_A (875/2775)...
# Processing 3k9o_A (876/2775)...
# Processing 3kcg_I (877/2775)...
# Processing 3kn1_A (878/2775)...
# Processing 3kq0_A (879/2775)...
# Processing 3kq4_B (880/2775)...
# Processing 3kqg_A (881/2775)...
# Processing 3kuc_A (882/2775)...
# Processing 3kv5_A (883/2775)...
# Processing 3kvo_A (884/2775)...
# Processing 3kyd_A (885/2775)...
# Processing 3l43_B (886/2775)...
# Processing 3lea_B (887/2775)...
# Processing 3lf5_B (888/2775)...
# Processing 3lgd_B (889/2775)...
# Processing 3ljw_A (890/2775)...
# Processing 3lkj_C (891/2775)...
# Processing 3llk_A (892/2775)...
# Processing 3lqc_A (893/2775)...
# Processing 3lqh_A (894/2775)...
# Processing 3lrq_C (895/2775)...
# Processing 3lru_B (896/2775)...
# Processing 3ltl_B (897/2775)...
# Processing 3luc_A (898/2775)...
# Processing 3lxj_A (899/2775)...
# Processing 3lxx_A (900/2775)...
# Processing 3ly5_A (901/2775)...
# Processing 3lyr_A (902/2775)...
# Processing 3m1d_B (903/2775)...
# Processing 3m52_A (904/2775)...
# Processing 3mb3_A (905/2775)...
# Processing 3mb4_B (906/2775)...
# Processing 3mbg_C (907/2775)...
# Processing 3mdi_A (908/2775)...
# Processing 3mdy_C (909/2775)...
# Processing 3mdz_A (910/2775)...
# Processing 3mgm_A (911/2775)...
# Processing 3mjh_B (912/2775)...
# Processing 3mp5_B (913/2775)...
# Processing 3mq7_L (914/2775)...
# Processing 3mqi_C (915/2775)...
# Processing 3mtg_B (916/2775)...
# Processing 3mtn_A (917/2775)...
# Processing 3my0_J (918/2775)...
# Processing 3mzg_B (919/2775)...
# Processing 3n1g_A (920/2775)...
# Processing 3n1m_B (921/2775)...
# Processing 3n5n_Y (922/2775)...
# Processing 3n7o_A (923/2775)...
# Processing 3na1_A (924/2775)...
# Processing 3ncu_A (925/2775)...
# Processing 3ner_B (926/2775)...
# Processing 3nks_A (927/2775)...
# Processing 3nmq_A (928/2775)...
# Processing 3nmz_B (929/2775)...
# Processing 3nv1_A (930/2775)...
# Processing 3nvq_B (931/2775)...
# Processing 3nwn_A (932/2775)...
# Processing 3nxb_A (933/2775)...
# Processing 3nyn_B (934/2775)...
# Processing 3o0g_A (935/2775)...
# Processing 3o4r_B (936/2775)...
# Processing 3o4s_A (937/2775)...
# Processing 3o7a_A (938/2775)...
# Processing 3oag_A (939/2775)...
# Processing 3oes_A (940/2775)...
# Processing 3oj3_J (941/2775)...
# Processing 3ojy_B (942/2775)...
# Processing 3orh_B (943/2775)...
# Processing 3otc_B (944/2775)...
# Processing 3ovp_B (945/2775)...
# Processing 3p0f_A (946/2775)...
# Processing 3p57_A (947/2775)...
# Processing 3pb4_X (948/2775)...
# Processing 3pe0_A (949/2775)...
# Processing 3pja_K (950/2775)...
# Processing 3pls_A (951/2775)...
# Processing 3pm0_A (952/2775)...
# Processing 3poo_A (953/2775)...
# Processing 3pse_B (954/2775)...
# Processing 3q13_A (955/2775)...
# Processing 3q19_A (956/2775)...
# Processing 3q1d_A (957/2775)...
# Processing 3q2u_A (958/2775)...
# Processing 3q3j_B (959/2775)...
# Processing 3q6z_A (960/2775)...
# Processing 3qcj_A (961/2775)...
# Processing 3qfb_B (962/2775)...
# Processing 3qj4_A (963/2775)...
# Processing 3qj5_B (964/2775)...
# Processing 3qmh_A (965/2775)...
# Processing 3qni_A (966/2775)...
# Processing 3qpu_A (967/2775)...
# Processing 3qrf_F (968/2775)...
# Processing 3qxy_B (969/2775)...
# Processing 3r6b_A (970/2775)...
# Processing 3rap_S (971/2775)...
# Processing 3ray_A (972/2775)...
# Processing 3rbl_B (973/2775)...
# Processing 3rc3_A (974/2775)...
# Processing 3rgk_A (975/2775)...
# Processing 3rk2_G (976/2775)...
# Processing 3rq4_A (977/2775)...
# Processing 3rz3_C (978/2775)...
# Processing 3rzv_A (979/2775)...
# Processing 3s4y_A (980/2775)...
# Processing 3sbz_A (981/2775)...
# Processing 3sh5_A (982/2775)...
# Processing 3sjv_F (983/2775)...
# Processing 3sn5_B (984/2775)...
# Processing 3szb_B (985/2775)...
# Processing 3t6a_A (986/2775)...
# Processing 3t7l_A (987/2775)...
# Processing 3t9i_A (988/2775)...
# Processing 3tac_A (989/2775)...
# Processing 3thd_D (990/2775)...
# Processing 3tkl_A (991/2775)...
# Processing 3top_A (992/2775)...
# Processing 4oni_A (1227/2775)...
# Processing 4onn_B (1228/2775)...
# Processing 4or9_A (1229/2775)...
# Processing 4orw_A (1230/2775)...
# Processing 4otg_A (1231/2775)...
# Processing 4p0p_A (1232/2775)...
# Processing 4p13_C (1233/2775)...
# Processing 4p5w_A (1234/2775)...
# Processing 4p60_A (1235/2775)...
# Processing 4pcu_A (1236/2775)...
# Processing 4pcw_B (1237/2775)...
# Processing 4px2_A (1238/2775)...
# Processing 4pzi_A (1239/2775)...
# Processing 4q4b_A (1240/2775)...
# Processing 4q4d_A (1241/2775)...
# Processing 4q6f_A (1242/2775)...
# Processing 4q7y_A (1243/2775)...
# Processing 4q93_A (1244/2775)...
# Processing 4q9u_E (1245/2775)...
# Processing 4qbm_A (1246/2775)...
# Processing 4qc3_A (1247/2775)...
# Processing 4qil_A (1248/2775)...
# Processing 4qmx_A (1249/2775)...
# Processing 4qn9_A (1250/2775)...
# Processing 4qpn_A (1251/2775)...
# Processing 4qu6_A (1252/2775)...
# Processing 4r1f_A (1253/2775)...
# Processing 4r2d_A (1254/2775)...
# Processing 4r6u_A (1255/2775)...
# Processing 4r7a_B (1256/2775)...
# Processing 4r7p_B (1257/2775)...
# Processing 4r8p_K (1258/2775)...
# Processing 4rau_L (1259/2775)...
# Processing 4rda_A (1260/2775)...
# Processing 4re1_A (1261/2775)...
# Processing 4re8_B (1262/2775)...
# Processing 4rec_A (1263/2775)...
# Processing 4rer_A (1264/2775)...
# Processing 4rfq_A (1265/2775)...
# Processing 4rg1_A (1266/2775)...
# Processing 4rkk_A (1267/2775)...
# Processing 4rn0_A (1268/2775)...
# Processing 4rr2_A (1269/2775)...
# Processing 4rsu_F (1270/2775)...
# Processing 4ruh_B (1271/2775)...
# Processing 4s15_A (1272/2775)...
# Processing 4s3o_B (1273/2775)...
# Processing 4s3o_C (1274/2775)...
# Processing 4tlg_A (1275/2775)...
# Processing 4tnt_A (1276/2775)...
# Processing 4ttv_A (1277/2775)...
# Processing 4twe_B (1278/2775)...
# Processing 4u5t_A (1279/2775)...
# Processing 4u8d_A (1280/2775)...
# Processing 4ueg_A (1281/2775)...
# Processing 4uem_A (1282/2775)...
# Processing 4ug2_A (1283/2775)...
# Processing 4uhz_A (1284/2775)...
# Processing 4ui9_S (1285/2775)...
# Processing 4um8_D (1286/2775)...
# Processing 4usf_B (1287/2775)...
# Processing 4ust_A (1288/2775)...
# Processing 4uu6_A (1289/2775)...
# Processing 4uuu_A (1290/2775)...
# Processing 4uy2_B (1291/2775)...
# Processing 4uy9_A (1292/2775)...
# Processing 4uya_A (1293/2775)...
# Processing 4uye_B (1294/2775)...
# Processing 4v0h_D (1295/2775)...
# Processing 4v3k_F (1296/2775)...
# Processing 4v6x_Aa (1297/2775)...
# Processing 4v6x_Af (1298/2775)...
# Processing 4wgk_A (1299/2775)...
# Processing 4whv_I (1300/2775)...
# Processing 4wle_D (1301/2775)...
# Processing 4wmq_A (1302/2775)...
# Processing 4wqn_B (1303/2775)...
# Processing 4wzx_A (1304/2775)...
# Processing 4x0q_B (1305/2775)...
# Processing 4x30_A (1306/2775)...
# Processing 4x7q_B (1307/2775)...
# Processing 4x93_B (1308/2775)...
# Processing 4xcx_A (1309/2775)...
# Processing 4xdp_A (1310/2775)...
# Processing 4xft_A (1311/2775)...
# Processing 4xhz_A (1312/2775)...
# Processing 4xp7_A (1313/2775)...
# Processing 4xwh_A (1314/2775)...
# Processing 4xyj_H (1315/2775)...
# Processing 4xzp_A (1316/2775)...
# Processing 4y05_A (1317/2775)...
# Processing 4y7b_A (1318/2775)...
# Processing 4y86_A (1319/2775)...
# Processing 4y88_A (1320/2775)...
# Processing 4y8w_A (1321/2775)...
# Processing 4y97_H (1322/2775)...
# Processing 4yhj_B (1323/2775)...
# Processing 4yiq_D (1324/2775)...
# Processing 4yj0_A (1325/2775)...
# Processing 4yls_A (1326/2775)...
# Processing 4ylz_B (1327/2775)...
# Processing 4ymd_B (1328/2775)...
# Processing 4ymj_A (1329/2775)...
# Processing 4ynd_A (1330/2775)...
# Processing 4yoc_C (1331/2775)...
# Processing 4yvp_A (1332/2775)...
# Processing 4ywt_D (1333/2775)...
# Processing 4z0o_A (1334/2775)...
# Processing 4z2b_A (1335/2775)...
# Processing 4z9m_D (1336/2775)...
# Processing 4zaj_A (1337/2775)...
# Processing 4zc4_B (1338/2775)...
# Processing 4zcv_A (1339/2775)...
# Processing 4zdp_A (1340/2775)...
# Processing 4zel_A (1341/2775)...
# Processing 4zes_B (1342/2775)...
# Processing 4zfg_A (1343/2775)...
# Processing 4zg4_B (1344/2775)...
# Processing 4zg9_B (1345/2775)...
# Processing 4zht_B (1346/2775)...
# Processing 4zji_C (1347/2775)...
# Processing 4zlp_A (1348/2775)...
# Processing 4zma_L (1349/2775)...
# Processing 4zrp_B (1350/2775)...
# Processing 4zso_F (1351/2775)...
# Processing 4zvj_A (1352/2775)...
# Processing 4zvw_D (1353/2775)...
# Processing 4zya_A (1354/2775)...
# Processing 4zyo_A (1355/2775)...
# Processing 5a0e_A (1356/2775)...
# Processing 5a15_I (1357/2775)...
# Processing 5a46_A (1358/2775)...
# Processing 5a4k_B (1359/2775)...
# Processing 5a9j_D (1360/2775)...
# Processing 5aaq_A (1361/2775)...
# Processing 5aaz_A (1362/2775)...
# Processing 5ay8_E (1363/2775)...
# Processing 5b0h_B (1364/2775)...
# Processing 5b1x_B (1365/2775)...
# Processing 5b4x_D (1366/2775)...
# Processing 5b4y_B (1367/2775)...
# Processing 5bq8_B (1368/2775)...
# Processing 5bqd_B (1369/2775)...
# Processing 5bqe_C (1370/2775)...
# Processing 5brk_A (1371/2775)...
# Processing 5bwl_A (1372/2775)...
# Processing 5bx1_A (1373/2775)...
# Processing 5c11_A (1374/2775)...
# Processing 5c16_D (1375/2775)...
# Processing 5c41_B (1376/2775)...
# Processing 5c4v_F (1377/2775)...
# Processing 5c5c_A (1378/2775)...
# Processing 5c7j_B (1379/2775)...
# Processing 5c8w_C (1380/2775)...
# Processing 5cc0_B (1381/2775)...
# Processing 7yu8_R (2575/2775)...
# Processing 7yui_A (2576/2775)...
# Processing 7z5h_A (2577/2775)...
# Processing 7z6h_D (2578/2775)...
# Processing 7z6h_E (2579/2775)...
# Processing 7z6h_F (2580/2775)...
# Processing 7z6h_G (2581/2775)...
# Processing 7z71_A (2582/2775)...
# Processing 7z9f_A (2583/2775)...
# Processing 7zan_C (2584/2775)...
# Processing 7zcw_G (2585/2775)...
# Processing 7zel_A (2586/2775)...
# Processing 7zh3_D (2587/2775)...
# Processing 7zha_A (2588/2775)...
# Processing 7zi9_A (2589/2775)...
# Processing 7zjv_A (2590/2775)...
# Processing 7zmk_X (2591/2775)...
# Processing 7zmv_D (2592/2775)...
# Processing 7zmx_A (2593/2775)...
# Processing 7zr0_A (2594/2775)...
# Processing 7zr6_P (2595/2775)...
# Processing 7zrr_A (2596/2775)...
# Processing 7zsc_C (2597/2775)...
# Processing 7zyg_A (2598/2775)...
# Processing 7zyh_J (2599/2775)...
# Processing 7zyu_A (2600/2775)...
# Processing 7zzp_A (2601/2775)...
# Processing 8a0v_A (2602/2775)...
# Processing 8a38_C (2603/2775)...
# Processing 8a40_U (2604/2775)...
# Processing 8a4c_D (2605/2775)...
# Processing 8a4k_B (2606/2775)...
# Processing 8a6l_B (2607/2775)...
# Processing 8a8m_A (2608/2775)...
# Processing 8ajo_A (2609/2775)...
# Processing 8ari_W (2610/2775)...
# Processing 8as4_B (2611/2775)...
# Processing 8ayf_A (2612/2775)...
# Processing 8aza_A (2613/2775)...
# Processing 8b0a_K (2614/2775)...
# Processing 8b0f_C (2615/2775)...
# Processing 8b0f_F (2616/2775)...
# Processing 8b0g_J (2617/2775)...
# Processing 8b0h_E (2618/2775)...
# Processing 8b10_A (2619/2775)...
# Processing 8b5r_P (2620/2775)...
# Processing 8b6l_L (2621/2775)...
# Processing 8b6l_N (2622/2775)...
# Processing 8b6l_O (2623/2775)...
# Processing 8b9e_A (2624/2775)...
# Processing 8bah_B (2625/2775)...
# Processing 8bbg_C (2626/2775)...
# Processing 8bbs_A (2627/2775)...
# Processing 8bc9_J (2628/2775)...
# Processing 8blp_C (2629/2775)...
# Processing 8bot_U (2630/2775)...
# Processing 8bot_X (2631/2775)...
# Processing 8bub_B (2632/2775)...
# Processing 8bya_B (2633/2775)...
# Processing 8byl_B (2634/2775)...
# Processing 8bzy_A (2635/2775)...
# Processing 8c3u_A (2636/2775)...
# Processing 8c6j_7 (2637/2775)...
# Processing 8ca0_B (2638/2775)...
# Processing 8ch6_y (2639/2775)...
# Processing 8cqb_A (2640/2775)...
# Processing 8cr1_B (2641/2775)...
# Processing 8css_8 (2642/2775)...
# Processing 8cua_C (2643/2775)...
# Processing 8cuc_F (2644/2775)...
# Processing 8cv5_A (2645/2775)...
# Processing 8cx0_A (2646/2775)...
# Processing 8d1e_D (2647/2775)...
# Processing 8d1l_C (2648/2775)...
# Processing 8d30_A (2649/2775)...
# Processing 8d3c_E (2650/2775)...
# Processing 8d3v_A (2651/2775)...
# Processing 8d6e_A (2652/2775)...
# Processing 8d7z_C (2653/2775)...
# Processing 8d8i_A (2654/2775)...
# Processing 8daf_A (2655/2775)...
# Processing 8dbk_B (2656/2775)...
# Processing 8dey_F (2657/2775)...
# Processing 8dkm_P (2658/2775)...
# Processing 8dmk_G (2659/2775)...
# Processing 8dnu_D (2660/2775)...
# Processing 8dph_A (2661/2775)...
# Processing 8dyd_A (2662/2775)...
# Processing 8dyl_B (2663/2775)...
# Processing 8e0c_A (2664/2775)...
# Processing 8e0f_B (2665/2775)...
# Processing 8e1a_A (2666/2775)...
# Processing 8e3y_R (2667/2775)...
# Processing 8e4y_A (2668/2775)...
# Processing 8e8v_A (2669/2775)...
# Processing 8e93_B (2670/2775)...
# Processing 8e98_C (2671/2775)...
# Processing 8e9z_A (2672/2775)...
# Processing 8ede_B (2673/2775)...
# Processing 8ef7_A (2674/2775)...
# Processing 8efg_A (2675/2775)...
# Processing 8efq_R (2676/2775)...
# Processing 8eg3_A (2677/2775)...
# Processing 8egx_B (2678/2775)...
# Processing 8eih_A (2679/2775)...
# Processing 8eiq_A (2680/2775)...
# Processing 8ejm_A (2681/2775)...
# Processing 8emr_B (2682/2775)...
# Processing 8eok_G (2683/2775)...
# Processing 8eop_A (2684/2775)...
# Processing 8eor_B (2685/2775)...
# Processing 8epl_A (2686/2775)...
# Processing 8esv_A (2687/2775)...
# Processing 8eyk_F (2688/2775)...
# Processing 8eyo_A (2689/2775)...
# Processing 8f7s_R (2690/2775)...
# Processing 8fb2_B (2691/2775)...
# Processing 8fc7_B (2692/2775)...
# Processing 8ffv_A (2693/2775)...
# Processing 8ffw_D (2694/2775)...
# Processing 8fgw_C (2695/2775)...
# Processing 8fjx_A (2696/2775)...
# Processing 8fmu_B (2697/2775)...
# Processing 8fnb_B (2698/2775)...
# Processing 8foa_A (2699/2775)...
# Processing 8fp1_A (2700/2775)...
# Processing 8fw5_B (2701/2775)...
# Processing 8fyh_I (2702/2775)...
# Processing 8g0l_A (2703/2775)...
# Processing 8g46_B (2704/2775)...
# Processing 8g7n_A (2705/2775)...
# Processing 8g9p_D (2706/2775)...
# Processing 8gju_D (2707/2775)...
# Processing 8gk3_H (2708/2775)...
# Processing 8gnn_A (2709/2775)...
# Processing 8gui_K (2710/2775)...
# Processing 8gx3_A (2711/2775)...
# Processing 8gye_A (2712/2775)...
# Processing 8gyx_B (2713/2775)...
# Processing 8gz2_B (2714/2775)...
# Processing 8h65_C (2715/2775)...
# Processing 8h8j_C (2716/2775)...
# Processing 8hbe_B (2717/2775)...
# Processing 8hdp_R (2718/2775)...
# Processing 8hy5_B (2719/2775)...
# Processing 8i1o_A (2720/2775)...
# Processing 8i5y_A (2721/2775)...
# Processing 8i5y_B (2722/2775)...
# Processing 8i9u_J (2723/2775)...
# Processing 8i9u_O (2724/2775)...
# Processing 8ifo_A (2725/2775)...
# Processing 8il3_C (2726/2775)...
# Processing 8iqn_A (2727/2775)...
# Processing 8irr_R (2728/2775)...
# Processing 8iuh_3 (2729/2775)...
# Processing 8iwu_A (2730/2775)...
# Processing 8iys_R (2731/2775)...
# Processing 8jbn_B (2732/2775)...
# Processing 8jdl_AP (2733/2775)...
# Processing 8jhf_A (2734/2775)...
# Processing 8jii_A (2735/2775)...
# Processing 8jyg_B (2736/2775)...
# Processing 8kb5_G (2737/2775)...
# Processing 8odo_A (2738/2775)...
# Processing 8oew_O (2739/2775)...
# Processing 8oi8_A (2740/2775)...
# Processing 8oma_A (2741/2775)...
# Processing 8omr_A (2742/2775)...
# Processing 8oxy_A (2743/2775)...
# Processing 8p50_B (2744/2775)...
# Processing 8p8x_A (2745/2775)...
# Processing 8p94_A (2746/2775)...
# Processing 8pqh_A (2747/2775)...
# Processing 8q7n_K (2748/2775)...
# Processing 8qk3_E (2749/2775)...
# Processing 8qy4_D (2750/2775)...
# Processing 8rbx_W (2751/2775)...
# Processing 8sg5_H (2752/2775)...
# Processing 8sgo_C (2753/2775)...
# Processing 8syp_C (2754/2775)...
# Processing 8t6j_A (2755/2775)...
# Processing 8t9h_K (2756/2775)...
# Processing 8tar_N (2757/2775)...
# Processing 8tgd_A (2758/2775)...
# Processing 8tnq_B (2759/2775)...
# Processing 8tzo_C (2760/2775)...
# Processing 8tzs_A (2761/2775)...
# Processing 8u26_R (2762/2775)...
# Processing 8u37_A (2763/2775)...
# Processing 8ucd_C (2764/2775)...
# Processing 8uhd_Y (2765/2775)...
# Processing 8v4y_W (2766/2775)...
# Processing 8v8u_B (2767/2775)...
# Processing 8wej_B (2768/2775)...
# Processing 8x15_W (2769/2775)...
# Processing 8x72_A (2770/2775)...
# Processing 8xov_A (2771/2775)...
# Processing 8xpn_A (2772/2775)...
# Processing 8y14_A (2773/2775)...
# Processing 8y6b_F (2774/2775)...
# Processing 8y6o_H (2775/2775)...

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

number_of_pockets = sum([len(i) for i in binding_residues.values()])

mean_br = np.mean(best_residue_overlaps)
median_br = np.median(best_residue_overlaps)
print(f'best_residue_overlap mean={mean_br:.4f}, median={median_br:.4f}')

print(np.sum(np.array(DCCs) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N_plus_K) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N_plus_K) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N) < 4) / number_of_pockets})')


print('\nSmall binding pockets (less than 10 residues):')
small_pockets_DCCs = [DCCs[i] for i in range(len(DCCs)) if is_small_pocket_DCC[i]]
print(f'Overall DCC < 12: {np.sum(np.array(small_pockets_DCCs) < 12) / len(small_pockets_DCCs):.4f} ({np.sum(np.array(small_pockets_DCCs) < 4) / len(small_pockets_DCCs):.4f})')
small_pockets_DCCs_N_plus_K = [DCCs_N_plus_K[i] for i in range(len(DCCs_N_plus_K)) if is_small_pocket_DCC_N_plus_K[i]]
print(f'N+K DCC < 12: {np.sum(np.array(small_pockets_DCCs_N_plus_K) < 12) / len(small_pockets_DCCs_N_plus_K):.4f} ({np.sum(np.array(small_pockets_DCCs_N_plus_K) < 4) / len(small_pockets_DCCs_N_plus_K):.4f})')
small_pockets_DCCs_N = [DCCs_N[i] for i in range(len(DCCs_N)) if is_small_pocket_DCC_N[i]]
print(f'N DCC < 12: {np.sum(np.array(small_pockets_DCCs_N) < 12) / len(small_pockets_DCCs_N):.4f} ({np.sum(np.array(small_pockets_DCCs_N) < 4) / len(small_pockets_DCCs_N):.4f})')

print('\nLarge binding pockets (10 or more residues):')
large_pockets_DCCs = [DCCs[i] for i in range(len(DCCs)) if not is_small_pocket_DCC[i]]
print(f'Overall DCC < 12: {np.sum(np.array(large_pockets_DCCs) < 12) / len(large_pockets_DCCs):.4f} ({np.sum(np.array(large_pockets_DCCs) < 4) / len(large_pockets_DCCs):.4f})')
large_pockets_DCCs_N_plus_K = [DCCs_N_plus_K[i] for i in range(len(DCCs_N_plus_K)) if not is_small_pocket_DCC_N_plus_K[i]]
print(f'N+K DCC < 12: {np.sum(np.array(large_pockets_DCCs_N_plus_K) < 12) / len(large_pockets_DCCs_N_plus_K):.4f} ({np.sum(np.array(large_pockets_DCCs_N_plus_K) < 4) / len(large_pockets_DCCs_N_plus_K):.4f})')
large_pockets_DCCs_N = [DCCs_N[i] for i in range(len(DCCs_N)) if not is_small_pocket_DCC_N[i]]
print(f'N DCC < 12: {np.sum(np.array(large_pockets_DCCs_N) < 12) / len(large_pockets_DCCs_N):.4f} ({np.sum(np.array(large_pockets_DCCs_N) < 4) / len(large_pockets_DCCs_N):.4f})')  


fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros = [i for i in number_of_overlapping_actual_sites_on_predicted_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Predicted Pockets Covering True Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Predicted Pockets Covering True Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_predictions_on_actual_pocket_without_zeros = [i for i in number_of_overlapping_predictions_on_actual_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_predictions_on_actual_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Actual Pockets Covering Predicted Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Actual Pockets Covering Predicted Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()
# Out:
# best_residue_overlap mean=0.4854, median=0.5000
# 0.6583841906422552 (0.23394362104039523)
# 0.6490845684394071 (0.22900319674513223)
# 0.6099970938680616 (0.2053182214472537)
#
# Small binding pockets (less than 10 residues):
# Overall DCC < 12: 0.5537 (0.1672)
# N+K DCC < 12: 0.5403 (0.1601)
# N DCC < 12: 0.4943 (0.1315)
#
# Large binding pockets (10 or more residues):
# Overall DCC < 12: 0.8142 (0.3221)
# N+K DCC < 12: 0.8088 (0.3192)
# N DCC < 12: 0.7751 (0.2997)

# %% [markdown]
# ### Inference speed & memory comparison (650M vs 3B)
#
# Compares per-sequence inference latency, throughput, and peak GPU memory between the ESM-2 3B model (40%-identity-filtered training) and the ESM-2 650M model, using a fixed subset of LIGYSIS test sequences and the same `eval_utils.compute_prediction` inference path used in the sections above. The full-set accuracy comparison between these two models is already covered above (DCC / coverage metrics) -- this section only adds the speed/memory axis requested by the reviewer.

# %%
import time
import gc
import os
import pandas as pd

N_BENCHMARK_SEQUENCES = 100  # subset of LIGYSIS test sequences used for timing/memory
N_WARMUP = 5  # excluded from timing -- first calls pay for CUDA kernel/allocator warm-up

def reset_gpu_memory_stats():
    if device == 'cuda':
        torch.cuda.empty_cache()
        torch.cuda.reset_peak_memory_stats()

def peak_gpu_memory_mb():
    if device != 'cuda':
        return float('nan')
    return torch.cuda.max_memory_allocated() / (1024 ** 2)

def benchmark_model(model_path, model_name, tokenizer_name, sequences_by_id, protein_ids):
    model = torch.load(model_path, weights_only=False)
    model.eval()
    tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)

    n_parameters_millions = sum(p.numel() for p in model.parameters()) / 1e6
    checkpoint_size_mb = os.path.getsize(model_path) / (1024 ** 2)

    # warm-up (not timed)
    for protein_id in protein_ids[:N_WARMUP]:
        eval_utils.compute_prediction(sequences_by_id[protein_id], model, tokenizer)

    reset_gpu_memory_stats()

    per_sequence_times = []
    total_residues = 0

    start = time.perf_counter()
    for protein_id in protein_ids:
        sequence = sequences_by_id[protein_id]
        if device == 'cuda':
            torch.cuda.synchronize()
        t0 = time.perf_counter()
        eval_utils.compute_prediction(sequence, model, tokenizer)
        if device == 'cuda':
            torch.cuda.synchronize()
        per_sequence_times.append(time.perf_counter() - t0)
        total_residues += len(sequence)
    total_time = time.perf_counter() - start

    result = {
        'model': model_name,
        'n_parameters_millions': n_parameters_millions,
        'checkpoint_size_mb': checkpoint_size_mb,
        'n_sequences': len(protein_ids),
        'mean_ms_per_sequence': np.mean(per_sequence_times) * 1000,
        'median_ms_per_sequence': np.median(per_sequence_times) * 1000,
        'sequences_per_second': len(protein_ids) / total_time,
        'residues_per_second': total_residues / total_time,
        'peak_gpu_memory_mb': peak_gpu_memory_mb(),
    }

    del model, tokenizer
    gc.collect()
    if device == 'cuda':
        torch.cuda.empty_cache()

    return result

_, benchmark_sequences = eval_utils.read_test_binding_residues(data_path=LIGYSIS_ANNOTATION_PATH, pocket_types=['NON_CRYPTIC'])
rng = np.random.RandomState(42)
benchmark_protein_ids = list(rng.choice(list(benchmark_sequences.keys()), size=min(N_BENCHMARK_SEQUENCES, len(benchmark_sequences)), replace=False))

benchmark_results = []
benchmark_results.append(benchmark_model(
    model_path=f'{PATH}/data/models/gbs-model-enhanced-scPDB-filtered.pt',
    model_name='ESM-2 3B',
    tokenizer_name='facebook/esm2_t36_3B_UR50D',
    sequences_by_id=benchmark_sequences,
    protein_ids=benchmark_protein_ids,
))
benchmark_results.append(benchmark_model(
    model_path=f'{PATH}/data/models/gbs-model-enhanced-scPDB-filtered-650M.pt',
    model_name='ESM-2 650M',
    tokenizer_name='facebook/esm2_t33_650M_UR50D',
    sequences_by_id=benchmark_sequences,
    protein_ids=benchmark_protein_ids,
))

benchmark_df = pd.DataFrame(benchmark_results).set_index('model')
benchmark_df.round(3)
# Out:
#             n_parameters_millions  checkpoint_size_mb  n_sequences  \
# model
# ESM-2 3B                 2841.630            5424.872          100
# ESM-2 650M                652.355            1248.798          100
#
#             mean_ms_per_sequence  median_ms_per_sequence  \
# model
# ESM-2 3B                  45.163                  43.904
# ESM-2 650M                20.803                  20.107
#
#             sequences_per_second  residues_per_second  peak_gpu_memory_mb
# model
# ESM-2 3B                  22.084             6963.440            6933.596
# ESM-2 650M                48.050            15150.613            2654.635

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 4))

model_colors = {'ESM-2 3B': '#2a78d6', 'ESM-2 650M': '#eb6834'}
bar_colors = [model_colors[m] for m in benchmark_df.index]

axs[0].bar(benchmark_df.index, benchmark_df['mean_ms_per_sequence'], color=bar_colors, edgecolor='k', alpha=0.85)
axs[0].set_ylabel('ms / sequence')
axs[0].set_title('Mean inference latency')
for i, v in enumerate(benchmark_df['mean_ms_per_sequence']):
    axs[0].text(i, v, f'{v:.1f}', ha='center', va='bottom')

axs[1].bar(benchmark_df.index, benchmark_df['sequences_per_second'], color=bar_colors, edgecolor='k', alpha=0.85)
axs[1].set_ylabel('sequences / second')
axs[1].set_title('Throughput')
for i, v in enumerate(benchmark_df['sequences_per_second']):
    axs[1].text(i, v, f'{v:.2f}', ha='center', va='bottom')

axs[2].bar(benchmark_df.index, benchmark_df['peak_gpu_memory_mb'], color=bar_colors, edgecolor='k', alpha=0.85)
axs[2].set_ylabel('MB')
axs[2].set_title('Peak GPU memory (inference)')
for i, v in enumerate(benchmark_df['peak_gpu_memory_mb']):
    axs[2].text(i, v, f'{v:.0f}', ha='center', va='bottom')

for ax in axs:
    ax.grid(alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Version 650M, batch_size=4
# We increased batch size for the 650M. Let's see if the performance improved.

# %%
PREDICTIONS_PATH = f'{PATH}/data/predictions'
PRECALCULATED_PATH = f'{PREDICTIONS_PATH}/gbs-model-650M'

MODEL_PATH = f'{PATH}/data/models/gbs-model-enhanced-scPDB-filtered-650M,batch_size=4.pt'
PRECALCULATED = False
SMOOTHING_MODEL_PATH = f'{PATH}/data/models/smoother-650M.pt'
ESM_EMBEDDINGS_PATH = f'{PATH}/data/embeddings/ligysis-650M'
MODEL_NAME = 'facebook/esm2_t33_650M_UR50D'

smoothing_model = torch.load(SMOOTHING_MODEL_PATH, weights_only=False) #, map_location=torch.device('cpu'))
smoothing_model.eval()

model = torch.load(MODEL_PATH, weights_only=False)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

binding_residues, sequences = eval_utils.read_test_binding_residues(data_path=LIGYSIS_ANNOTATION_PATH, pocket_types=['NON_CRYPTIC'])

predicted_binding_sites = {}
ranks = {}
prediction_scores = {}

K = 2

DCCs_N = []
DCCs_N_plus_K = []
DCCs = []

is_small_pocket_DCC_N = []
is_small_pocket_DCC_N_plus_K = []
is_small_pocket_DCC = []

number_of_added_residues = []

number_of_overlapping_predictions_on_actual_pocket = []
number_of_overlapping_actual_sites_on_predicted_pocket = []
best_residue_overlaps = []

for i, protein_id in enumerate(sequences.keys()):
    pdb_id, chain_id = protein_id.split('_')
    sequence = sequences[protein_id]
    embeddings_path = f'{ESM_EMBEDDINGS_PATH}/{pdb_id}{chain_id}.npy'
    coordinates_path = f'{COORDINATES_DIR}/{pdb_id}{chain_id}.npy'
    actual_binding_sites = [np.array([int(i.split('_')[1]) for i in pocket]) for pocket in binding_residues[protein_id]]
    
    print(f'Processing {protein_id} ({i+1}/{len(sequences)})...')
    if not PRECALCULATED:
        # finetuned prediction
        probabilities = eval_utils.compute_prediction(
            sequence,
            model,
            tokenizer
        )
    else:
        # load precalculated prediction
        probabilities = np.load(f'{PRECALCULATED_PATH}/{protein_id.replace("_","")}.npy')
    
    prediction_scores[protein_id] = probabilities

    coordinates = np.load(coordinates_path)
    distance_matrix = eval_utils.compute_distance_matrix(coordinates)

    predictions = (probabilities > DECISION_THRESHOLD).astype(float)
    predictions_copy = predictions.copy()

    assert distance_matrix.shape[0] == distance_matrix.shape[1]
    assert distance_matrix.shape[0] == predictions_copy.shape[0]
    
    X_test = np.load(embeddings_path)
    assert X_test.shape[0] == distance_matrix.shape[0]

    # loop over the residues that are not binding and are potential candidates for smoothing
    additional_residues = []
    added_residues_count = 0
    for residue_idx in np.where(predictions == 0.0)[0]:

        # get the embedding of the residue
        current_residue_embedding = X_test[residue_idx]

        # get the close binding residues
        close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
        close_binding_residues_indices = np.intersect1d(close_residues_indices, np.where(predictions == 1.0)[0])
        # create embedding 
        if len(close_binding_residues_indices) == 0:
            # no close binding residues - skip this residue
            continue
        elif len(close_binding_residues_indices) == 1:
            surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
        else:
            # get the mean of the close binding residues
            surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

        concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(device)
        
        # get the prediction
        test_logits = smoothing_model(concatenated_embedding).squeeze()
        result = (torch.sigmoid(test_logits)>eval_utils.SMOOTHING_DECISION_THRESHOLD).float()
        if result == 1:
            # set the residue as binding
            # print(f"Smoothing changed residue {residue_idx} in protein {protein_id} to binding")
            additional_residues.append(residue_idx)
            predictions_copy[residue_idx] = 1
            added_residues_count += 1

    number_of_added_residues.append(added_residues_count)
    
    indices_above_threshold = np.where(predictions_copy > DECISION_THRESHOLD)[0] # this gets residues that are equal to 1
    # no predicted residues - continue
    if len(indices_above_threshold) == 0:
        continue

    # run atom-level clustering and return residue-level pockets
    clusters, cluster_residues, cluster_scores, atom_coords, residue_coords = clustering_utils.execute_atom_clustering(
        pdb_id,
        chain_id,
        indices_above_threshold,
        probabilities[indices_above_threshold],
        eps=9
    )

    # none of the residues are on the surface
    if cluster_residues is None:
        continue

    cluster_residues = cryptoshow_utils.map_auth_to_mmcif_numbering_array(
        pdb_id,
        chain_id,
        cluster_residues.values(),
        binding_residues_are_integers=True,
        numbers_only=True
    )[0]

    cluster_order = np.argsort(cluster_scores)[::-1]  # descending order
    N = len(actual_binding_sites)

    selected_clusters_N = cluster_order[:N]
    selected_clusters_N_plus_K = cluster_order[:N+K]

    predicted_centers = {}
    for cluster_label, atom_indices in clusters.items():
        cluster_coords = np.array([atom_coords[atom_id] for atom_id in atom_indices])
        cluster_center = np.mean(cluster_coords, axis=0).get_array()
        predicted_centers[cluster_label] = cluster_center
    
    actual_centers = []
    is_small_pocket = []
    for pocket in actual_binding_sites:
        pocket_coords = coordinates[pocket]
        pocket_center = np.mean(pocket_coords, axis=0)
        actual_centers.append(pocket_center)
        is_small_pocket.append(len(pocket) < 10)
    
    for i, center in enumerate(actual_centers):
        DCC_N = float('inf')
        for j in selected_clusters_N:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N:
                DCC_N = distance
        
        if DCC_N != float('inf'):
            DCCs_N.append(DCC_N)
            is_small_pocket_DCC_N.append(is_small_pocket[i])

        DCC_N_plus_K = float('inf')
        for j in selected_clusters_N_plus_K:
            predicted_center = predicted_centers[j]
            distance = np.linalg.norm(center - predicted_center)
            if distance < DCC_N_plus_K:
                DCC_N_plus_K = distance
        
        if DCC_N_plus_K != float('inf'):
            DCCs_N_plus_K.append(DCC_N_plus_K)
            is_small_pocket_DCC_N_plus_K.append(is_small_pocket[i])
            

    dcc_rro_matches = clustering_utils.compute_dcc_matched_rro(
        actual_binding_sites, actual_centers, predicted_centers, cluster_residues,
        dcc_hit_threshold=DCC_HIT_THRESHOLD,
    )
    for i, match in enumerate(dcc_rro_matches):
        if match['dcc'] != float('inf'):
            DCCs.append(match['dcc'])
            is_small_pocket_DCC.append(is_small_pocket[i])
        if match['rro'] is not None:
            best_residue_overlaps.append(match['rro'])

    for pocket in actual_binding_sites:
        number_of_predicted_pockets = 0
        for residues in cluster_residues:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_actual_sites_on_predicted_pocket.append(number_of_predicted_pockets)

    for residues in cluster_residues:
        number_of_predicted_pockets = 0
        for pocket in actual_binding_sites:
            if any(residue in pocket for residue in residues):
                number_of_predicted_pockets += 1
        number_of_overlapping_predictions_on_actual_pocket.append(number_of_predicted_pockets)
# Out:
# Processing 1a52_A (1/2775)...
# Processing 1a9w_E (2/2775)...
# Processing 1aii_A (3/2775)...
# Processing 1au1_A (4/2775)...
# Processing 1aue_B (5/2775)...
# Processing 1b1c_A (6/2775)...
# Processing 1b50_B (7/2775)...
# Processing 1b55_B (8/2775)...
# Processing 1b6c_F (9/2775)...
# Processing 1b9o_A (10/2775)...
# Processing 1bbo_A (11/2775)...
# Processing 1bci_A (12/2775)...
# Processing 1bf9_A (13/2775)...
# Processing 1bhi_A (14/2775)...
# Processing 1bld_A (15/2775)...
# Processing 1blx_A (16/2775)...
# Processing 1bmo_A (17/2775)...
# Processing 1bnl_A (18/2775)...
# Processing 1boy_A (19/2775)...
# Processing 1bp5_A (20/2775)...
# Processing 1buv_M (21/2775)...
# Processing 1byg_A (22/2775)...
# Processing 1bzs_A (23/2775)...
# Processing 1c07_A (24/2775)...
# Processing 1c4z_A (25/2775)...
# Processing 1c9y_A (26/2775)...
# Processing 1cb6_A (27/2775)...
# Processing 1cjy_B (28/2775)...
# Processing 1cm8_A (29/2775)...
# Processing 1cr8_A (30/2775)...
# Processing 1q33_A (195/2775)...
# Processing 1q3a_A (196/2775)...
# Processing 1q7l_C (197/2775)...
# Processing 1q7l_D (198/2775)...
# Processing 1q8l_A (199/2775)...
# Processing 1q8x_A (200/2775)...
# Processing 1q9s_A (201/2775)...
# Processing 1qh5_B (202/2775)...
# Processing 1qnm_A (203/2775)...
# Processing 1qzq_A (204/2775)...
# Processing 1qzu_B (205/2775)...
# Processing 1r3y_A (206/2775)...
# Processing 1r54_A (207/2775)...
# Processing 1r8q_E (208/2775)...
# Processing 1rgo_A (209/2775)...
# Processing 1riw_B (210/2775)...
# Processing 1rjv_A (211/2775)...
# Processing 1rkb_A (212/2775)...
# Processing 1rm8_A (213/2775)...
# Processing 1rnf_B (214/2775)...
# Processing 1ro4_A (215/2775)...
# Processing 1rtg_A (216/2775)...
# Processing 1rx0_D (217/2775)...
# Processing 1rxr_A (218/2775)...
# Processing 1s18_A (219/2775)...
# Processing 1s4b_P (220/2775)...
# Processing 1s4y_B (221/2775)...
# Processing 1s9i_A (222/2775)...
# Processing 1sg4_B (223/2775)...
# Processing 1shr_D (224/2775)...
# Processing 1siq_A (225/2775)...
# Processing 1sl6_E (226/2775)...
# Processing 1smo_B (227/2775)...
# Processing 1so0_B (228/2775)...
# Processing 1soj_I (229/2775)...
# Processing 1sp2_A (230/2775)...
# Processing 1st0_A (231/2775)...
# Processing 1su3_A (232/2775)...
# Processing 1szb_B (233/2775)...
# Processing 1t3n_B (234/2775)...
# Processing 1t6b_Y (235/2775)...
# Processing 1t8c_A (236/2775)...
# Processing 1tff_A (237/2775)...
# Processing 1tfi_A (238/2775)...
# Processing 1tg6_C (239/2775)...
# Processing 1tjj_A (240/2775)...
# Processing 1toz_A (241/2775)...
# Processing 1tpk_C (242/2775)...
# Processing 1ttx_A (243/2775)...
# Processing 1tu4_C (244/2775)...
# Processing 1tvx_D (245/2775)...
# Processing 1u31_A (246/2775)...
# Processing 1u3t_A (247/2775)...
# Processing 1u7f_B (248/2775)...
# Processing 1u7t_D (249/2775)...
# Processing 1ubd_C (250/2775)...
# Processing 1ul1_Z (251/2775)...
# Processing 1umk_A (252/2775)...
# Processing 1upr_A (253/2775)...
# Processing 1ur6_B (254/2775)...
# Processing 1uv0_A (255/2775)...
# Processing 1uvq_B (256/2775)...
# Processing 1uw5_A (257/2775)...
# Processing 1uzj_B (258/2775)...
# Processing 1v5h_A (259/2775)...
# Processing 1v84_A (260/2775)...
# Processing 1vd4_A (261/2775)...
# Processing 1vhr_A (262/2775)...
# Processing 1vtn_C (263/2775)...
# Processing 1w1h_C (264/2775)...
# Processing 1w45_B (265/2775)...
# Processing 1w4r_A (266/2775)...
# Processing 1w4u_A (267/2775)...
# Processing 1w6j_A (268/2775)...
# Processing 1war_A (269/2775)...
# Processing 1wch_A (270/2775)...
# Processing 1wl4_A (271/2775)...
# Processing 1wlj_A (272/2775)...
# Processing 1woj_A (273/2775)...
# Processing 1wq1_G (274/2775)...
# Processing 1wsr_A (275/2775)...
# Processing 1x03_A (276/2775)...
# Processing 2bwj_E (359/2775)...
# Processing 2bzg_A (360/2775)...
# Processing 2c30_A (361/2775)...
# Processing 2c3q_C (362/2775)...
# Processing 2c47_C (363/2775)...
# Processing 2c6a_A (364/2775)...
# Processing 2c7n_K (365/2775)...
# Processing 2c9y_A (366/2775)...
# Processing 2cg5_B (367/2775)...
# Processing 2cjw_A (368/2775)...
# Processing 2clp_K (369/2775)...
# Processing 2cmw_A (370/2775)...
# Processing 2co8_A (371/2775)...
# Processing 2cr8_A (372/2775)...
# Processing 2cs8_A (373/2775)...
# Processing 2csh_A (374/2775)...
# Processing 2csv_A (375/2775)...
# Processing 2cuq_A (376/2775)...
# Processing 2cw9_A (377/2775)...
# Processing 2cxy_A (378/2775)...
# Processing 2czh_B (379/2775)...
# Processing 2d07_A (380/2775)...
# Processing 2d7i_A (381/2775)...
# Processing 2dar_A (382/2775)...
# Processing 2dho_A (383/2775)...
# Processing 2dj7_A (384/2775)...
# Processing 2dko_B (385/2775)...
# Processing 2dlk_A (386/2775)...
# Processing 2dq7_X (387/2775)...
# Processing 2dud_B (388/2775)...
# Processing 2e2x_B (389/2775)...
# Processing 2e59_A (390/2775)...
# Processing 2e5s_A (391/2775)...
# Processing 2e6i_A (392/2775)...
# Processing 2e6s_A (393/2775)...
# Processing 2e6w_A (394/2775)...
# Processing 2eav_A (395/2775)...
# Processing 2eb1_B (396/2775)...
# Processing 2ebr_A (397/2775)...
# Processing 2ebt_A (398/2775)...
# Processing 2ecv_A (399/2775)...
# Processing 2egm_A (400/2775)...
# Processing 2eli_A (401/2775)...
# Processing 2enn_A (402/2775)...
# Processing 2eod_A (403/2775)...
# Processing 2epp_A (404/2775)...
# Processing 2erf_A (405/2775)...
# Processing 2erx_A (406/2775)...
# Processing 2ery_B (407/2775)...
# Processing 2esl_F (408/2775)...
# Processing 2ew1_A (409/2775)...
# Processing 2f0y_B (410/2775)...
# Processing 2f27_A (411/2775)...
# Processing 2f7s_A (412/2775)...
# Processing 2fby_A (413/2775)...
# Processing 2fcw_B (414/2775)...
# Processing 2fdv_D (415/2775)...
# Processing 2ffu_A (416/2775)...
# Processing 2ffw_A (417/2775)...
# Processing 2fg5_A (418/2775)...
# Processing 2fh1_B (419/2775)...
# Processing 2fim_B (420/2775)...
# Processing 2fj9_A (421/2775)...
# Processing 2fju_B (422/2775)...
# Processing 2fqq_B (423/2775)...
# Processing 2frw_A (424/2775)...
# Processing 2fsz_A (425/2775)...
# Processing 2fu5_B (426/2775)...
# Processing 2fvl_A (427/2775)...
# Processing 2fyl_B (428/2775)...
# Processing 2g2k_A (429/2775)...
# Processing 2g43_A (430/2775)...
# Processing 2g4a_A (431/2775)...
# Processing 2g6b_A (432/2775)...
# Processing 2g9o_A (433/2775)...
# Processing 2gao_B (434/2775)...
# Processing 2gf0_B (435/2775)...
# Processing 2gf9_A (436/2775)...
# Processing 2ggm_A (437/2775)...
# Processing 2ggz_B (438/2775)...
# Processing 2gjx_H (439/2775)...
# Processing 2gk1_Q (440/2775)...
# Processing 2gli_A (441/2775)...
# Processing 2gmv_A (442/2775)...
# Processing 2gp5_A (443/2775)...
# Processing 2gpq_A (444/2775)...
# Processing 2gqj_A (445/2775)...
# Processing 2gql_A (446/2775)...
# Processing 2gwh_A (447/2775)...
# Processing 2gz5_A (448/2775)...
# Processing 2h16_D (449/2775)...
# Processing 2h57_B (450/2775)...
# Processing 2h63_D (451/2775)...
# Processing 2h6h_A (452/2775)...
# Processing 2h8h_A (453/2775)...
# Processing 2h8k_B (454/2775)...
# Processing 2h9e_L (455/2775)...
# Processing 2ha8_A (456/2775)...
# Processing 2hei_B (457/2775)...
# Processing 2hgs_A (458/2775)...
# Processing 2hhl_A (459/2775)...
# Processing 2hhn_A (460/2775)...
# Processing 2hi4_A (461/2775)...
# Processing 2hrb_A (462/2775)...
# Processing 2hup_A (463/2775)...
# Processing 2hw5_A (464/2775)...
# Processing 2hw6_A (465/2775)...
# Processing 2hzq_A (466/2775)...
# Processing 2i0y_A (467/2775)...
# Processing 2i3c_B (468/2775)...
# Processing 2i50_A (469/2775)...
# Processing 2i6a_A (470/2775)...
# Processing 2i6s_A (471/2775)...
# Processing 2i7n_B (472/2775)...
# Processing 2i96_A (473/2775)...
# Processing 2i99_B (474/2775)...
# Processing 2i9a_D (475/2775)...
# Processing 2iby_A (476/2775)...
# Processing 2iim_A (477/2775)...
# Processing 2il1_A (478/2775)...
# Processing 2ipp_A (479/2775)...
# Processing 2iqj_B (480/2775)...
# Processing 2it4_B (481/2775)...
# Processing 2iuw_A (482/2775)...
# Processing 2iwy_A (483/2775)...
# Processing 2iyk_B (484/2775)...
# Processing 2j2p_C (485/2775)...
# Processing 2j2s_A (486/2775)...
# Processing 2j3s_A (487/2775)...
# Processing 2j4o_A (488/2775)...
# Processing 2j5z_B (489/2775)...
# Processing 2j8z_A (490/2775)...
# Processing 2jai_A (491/2775)...
# Processing 2jam_B (492/2775)...
# Processing 2jbh_B (493/2775)...
# Processing 2jdw_A (494/2775)...
# Processing 2jed_A (495/2775)...
# Processing 2jeo_A (496/2775)...
# Processing 2jg9_F (497/2775)...
# Processing 2jif_D (498/2775)...
# Processing 2jis_B (499/2775)...
# Processing 2jld_B (500/2775)...
# Processing 2jlp_C (501/2775)...
# Processing 2jm4_A (502/2775)...
# Processing 2jmo_A (503/2775)...
# Processing 2jox_A (504/2775)...
# Processing 2jrj_A (505/2775)...
# Processing 2jsd_A (506/2775)...
# Processing 2jtf_A (507/2775)...
# Processing 2jyo_A (508/2775)...
# Processing 2k01_C (509/2775)...
# Processing 2k1b_A (510/2775)...
# Processing 2k1j_A (511/2775)...
# Processing 2k2c_A (512/2775)...
# Processing 2k2d_A (513/2775)...
# Processing 2k7d_A (514/2775)...
# Processing 2kc3_A (515/2775)...
# Processing 2kht_A (516/2775)...
# Processing 2ki6_F (517/2775)...
# Processing 2kje_A (518/2775)...
# Processing 2kkr_A (519/2775)...
# Processing 2kkt_A (520/2775)...
# Processing 2kld_A (521/2775)...
# Processing 2knt_A (522/2775)...
# Processing 2ksg_A (523/2775)...
# Processing 2ku3_A (524/2775)...
# Processing 2kul_A (525/2775)...
# Processing 2kuo_A (526/2775)...
# Processing 2kwi_A (527/2775)...
# Processing 2l4s_A (528/2775)...
# Processing 2l51_B (529/2775)...
# Processing 2l70_A (530/2775)...
# Processing 2l7w_A (531/2775)...
# Processing 2l80_A (532/2775)...
# Processing 2lce_A (533/2775)...
# Processing 2lcp_A (534/2775)...
# Processing 2lgk_A (535/2775)...
# Processing 2lgq_A (536/2775)...
# Processing 2lgr_A (537/2775)...
# Processing 2lko_A (538/2775)...
# Processing 2ln0_A (539/2775)...
# Processing 2lnk_A (540/2775)...
# Processing 2lob_A (541/2775)...
# Processing 2lq6_A (542/2775)...
# Processing 2lv7_A (543/2775)...
# Processing 2lvz_A (544/2775)...
# Processing 2lxp_C (545/2775)...
# Processing 2lzu_A (546/2775)...
# Processing 2m0p_A (547/2775)...
# Processing 2m68_A (548/2775)...
# Processing 2m6n_A (549/2775)...
# Processing 2m96_A (550/2775)...
# Processing 2m9a_A (551/2775)...
# Processing 2m9w_A (552/2775)...
# Processing 2ma7_A (553/2775)...
# Processing 2miu_A (554/2775)...
# Processing 2mji_A (555/2775)...
# Processing 2mkd_A (556/2775)...
# Processing 2mm3_A (557/2775)...
# Processing 2mnz_A (558/2775)...
# Processing 2mpf_A (559/2775)...
# Processing 2mph_A (560/2775)...
# Processing 2mse_D (561/2775)...
# Processing 2msv_A (562/2775)...
# Processing 2mwx_A (563/2775)...
# Processing 2mzi_A (564/2775)...
# Processing 2n14_A (565/2775)...
# Processing 2n1a_A (566/2775)...
# Processing 2n1a_B (567/2775)...
# Processing 2n26_A (568/2775)...
# Processing 2n42_A (569/2775)...
# Processing 2n8a_A (570/2775)...
# Processing 2nll_B (571/2775)...
# Processing 2nxp_F (572/2775)...
# Processing 2nyt_C (573/2775)...
# Processing 2nz0_B (574/2775)...
# Processing 2nz2_A (575/2775)...
# Processing 2nzj_C (576/2775)...
# Processing 2nzt_B (577/2775)...
# Processing 2o06_A (578/2775)...
# Processing 2o10_A (579/2775)...
# Processing 2o13_A (580/2775)...
# Processing 2o2f_A (581/2775)...
# Processing 2o52_B (582/2775)...
# Processing 2o6g_E (583/2775)...
# Processing 2o8f_B (584/2775)...
# Processing 2obd_A (585/2775)...
# Processing 2obv_A (586/2775)...
# Processing 2ocb_A (587/2775)...
# Processing 2ocg_A (588/2775)...
# Processing 2ocp_C (589/2775)...
# Processing 2od1_A (590/2775)...
# Processing 2ohf_A (591/2775)...
# Processing 2oil_A (592/2775)...
# Processing 2okv_C (593/2775)...
# Processing 2oo4_B (594/2775)...
# Processing 2opw_A (595/2775)...
# Processing 2ox8_D (596/2775)...
# Processing 2oxc_A (597/2775)...
# Processing 2p0a_A (598/2775)...
# Processing 2p0d_A (599/2775)...
# Processing 2p0r_B (600/2775)...
# Processing 2p0w_A (601/2775)...
# Processing 2p1f_A (602/2775)...
# Processing 2p57_A (603/2775)...
# Processing 2p5s_B (604/2775)...
# Processing 2p8e_B (605/2775)...
# Processing 2pfr_A (606/2775)...
# Processing 2pg5_D (607/2775)...
# Processing 2pid_A (608/2775)...
# Processing 2pl0_A (609/2775)...
# Processing 2pla_A (610/2775)...
# Processing 2pmy_A (611/2775)...
# Processing 2pqf_D (612/2775)...
# Processing 2pru_B (613/2775)...
# Processing 2psn_D (614/2775)...
# Processing 2puy_A (615/2775)...
# Processing 2pvs_A (616/2775)...
# Processing 2q3f_B (617/2775)...
# Processing 2q3h_A (618/2775)...
# Processing 2q3z_A (619/2775)...
# Processing 2q5e_D (620/2775)...
# Processing 2q7r_F (621/2775)...
# Processing 2q8f_A (622/2775)...
# Processing 2q98_A (623/2775)...
# Processing 2qic_A (624/2775)...
# Processing 2qk4_B (625/2775)...
# Processing 2qkk_W (626/2775)...
# Processing 2qpp_B (627/2775)...
# Processing 2qra_C (628/2775)...
# Processing 2qst_B (629/2775)...
# Processing 2qt7_B (630/2775)...
# Processing 2qtz_A (631/2775)...
# Processing 2qym_A (632/2775)...
# Processing 2r3a_A (633/2775)...
# Processing 2r5g_A (634/2775)...
# Processing 2r83_A (635/2775)...
# Processing 2r8u_A (636/2775)...
# Processing 2ra4_B (637/2775)...
# Processing 2raj_A (638/2775)...
# Processing 2rb3_C (639/2775)...
# Processing 2rb4_B (640/2775)...
# Processing 2rc4_A (641/2775)...
# Processing 2rhp_A (642/2775)...
# Processing 2rje_B (643/2775)...
# Processing 2rjp_B (644/2775)...
# Processing 2rjq_A (645/2775)...
# Processing 2rkb_C (646/2775)...
# Processing 2rli_A (647/2775)...
# Processing 2rmk_A (648/2775)...
# Processing 2rsg_A (649/2775)...
# Processing 2rsq_A (650/2775)...
# Processing 2ruy_A (651/2775)...
# Processing 2uur_A (652/2775)...
# Processing 2uvl_A (653/2775)...
# Processing 2uyy_D (654/2775)...
# Processing 2uzg_A (655/2775)...
# Processing 2v40_A (656/2775)...
# Processing 2v55_B (657/2775)...
# Processing 2vac_A (658/2775)...
# Processing 2vcv_J (659/2775)...
# Processing 2vd5_B (660/2775)...
# Processing 2vdy_A (661/2775)...
# Processing 2vhf_A (662/2775)...
# Processing 2vkq_A (663/2775)...
# Processing 2vm5_A (664/2775)...
# Processing 2vn9_A (665/2775)...
# Processing 2vq3_A (666/2775)...
# Processing 2vr2_A (667/2775)...
# Processing 2vrd_A (668/2775)...
# Processing 2vrg_A (669/2775)...
# Processing 2vsc_C (670/2775)...
# Processing 2vwi_D (671/2775)...
# Processing 2vxo_A (672/2775)...
# Processing 2w0t_A (673/2775)...
# Processing 2w2i_A (674/2775)...
# Processing 2w3o_B (675/2775)...
# Processing 2w4l_E (676/2775)...
# Processing 2w4o_A (677/2775)...
# Processing 2w4r_D (678/2775)...
# Processing 2w86_A (679/2775)...
# Processing 2w8p_A (680/2775)...
# Processing 2wbi_B (681/2775)...
# Processing 2wce_A (682/2775)...
# Processing 2wef_A (683/2775)...
# Processing 2wh5_E (684/2775)...
# Processing 2wjy_A (685/2775)...
# Processing 2wk6_B (686/2775)...
# Processing 2wno_A (687/2775)...
# Processing 2wtk_E (688/2775)...
# Processing 2wtk_F (689/2775)...
# Processing 2wwy_B (690/2775)...
# Processing 2wwz_C (691/2775)...
# Processing 2wya_C (692/2775)...
# Processing 2wzb_A (693/2775)...
# Processing 2x10_A (694/2775)...
# Processing 2x11_B (695/2775)...
# Processing 2x4d_A (696/2775)...
# Processing 2x4f_B (697/2775)...
# Processing 2x4w_A (698/2775)...
# Processing 2x7g_A (699/2775)...
# Processing 2x7h_B (700/2775)...
# Processing 2xik_A (701/2775)...
# Processing 2xmr_C (702/2775)...
# Processing 2xn3_B (703/2775)...
# Processing 2xph_A (704/2775)...
# Processing 2xrc_D (705/2775)...
# Processing 2xsx_A (706/2775)...
# Processing 2xtp_A (707/2775)...
# Processing 2xzg_A (708/2775)...
# Processing 2y1h_A (709/2775)...
# Processing 2y1l_D (710/2775)...
# Processing 2y23_A (711/2775)...
# Processing 2y43_B (712/2775)...
# Processing 2y7j_D (713/2775)...
# Processing 2yan_A (714/2775)...
# Processing 2yd8_A (715/2775)...
# Processing 2ygq_A (716/2775)...
# Processing 2yh0_A (717/2775)...
# Processing 2yho_C (718/2775)...
# Processing 2yqm_A (719/2775)...
# Processing 2yrt_A (720/2775)...
# Processing 2ysl_A (721/2775)...
# Processing 2yu2_A (722/2775)...
# Processing 2yvr_A (723/2775)...
# Processing 2z0u_B (724/2775)...
# Processing 2z15_C (725/2775)...
# Processing 2z4e_E (726/2775)...
# Processing 2z5f_B (727/2775)...
# Processing 2zfu_B (728/2775)...
# Processing 2zg1_A (729/2775)...
# Processing 2znv_D (730/2775)...
# Processing 2zoc_A (731/2775)...
# Processing 2zoq_A (732/2775)...
# Processing 2zox_A (733/2775)...
# Processing 2zrt_G (734/2775)...
# Processing 3a2a_B (735/2775)...
# Processing 3a4s_A (736/2775)...
# Processing 3a4u_A (737/2775)...
# Processing 3aad_A (738/2775)...
# Processing 3aco_A (739/2775)...
# Processing 3ahq_A (740/2775)...
# Processing 3aih_A (741/2775)...
# Processing 3alq_R (742/2775)...
# Processing 3ap3_A (743/2775)...
# Processing 3b2d_A (744/2775)...
# Processing 3b3l_A (745/2775)...
# Processing 3b6r_B (746/2775)...
# Processing 3b6u_A (747/2775)...
# Processing 3b6v_A (748/2775)...
# Processing 3bce_A (749/2775)...
# Processing 3ber_A (750/2775)...
# Processing 3bfx_A (751/2775)...
# Processing 3bh7_B (752/2775)...
# Processing 3bhm_A (753/2775)...
# Processing 3bi6_A (754/2775)...
# Processing 3bjc_A (755/2775)...
# Processing 3bm4_B (756/2775)...
# Processing 3bo5_A (757/2775)...
# Processing 3brh_A (758/2775)...
# Processing 3bsu_H (759/2775)...
# Processing 3bvo_B (760/2775)...
# Processing 3c5c_D (761/2775)...
# Processing 3c5e_A (762/2775)...
# Processing 3c6k_A (763/2775)...
# Processing 3c6w_C (764/2775)...
# Processing 3cbb_B (765/2775)...
# Processing 3cbk_A (766/2775)...
# Processing 3cbq_A (767/2775)...
# Processing 3cfw_A (768/2775)...
# Processing 3cos_C (769/2775)...
# Processing 3ctz_A (770/2775)...
# Processing 3cxp_A (771/2775)...
# Processing 3d0e_B (772/2775)...
# Processing 3d24_C (773/2775)...
# Processing 3d2f_D (774/2775)...
# Processing 3d34_B (775/2775)...
# Processing 3d3l_B (776/2775)...
# Processing 3d3w_B (777/2775)...
# Processing 3d5o_B (778/2775)...
# Processing 3d87_B (779/2775)...
# Processing 3d8b_A (780/2775)...
# Processing 3d8e_C (781/2775)...
# Processing 3ddu_A (782/2775)...
# Processing 3dem_B (783/2775)...
# Processing 3dk9_A (784/2775)...
# Processing 3dko_A (785/2775)...
# Processing 3dlj_B (786/2775)...
# Processing 3dls_C (787/2775)...
# Processing 3dwb_A (788/2775)...
# Processing 3dyd_B (789/2775)...
# Processing 3dz4_B (790/2775)...
# Processing 3e1y_B (791/2775)...
# Processing 3e3r_B (792/2775)...
# Processing 3e4c_B (793/2775)...
# Processing 3e6i_B (794/2775)...
# Processing 3eb5_A (795/2775)...
# Processing 3edy_A (796/2775)...
# Processing 3eh1_A (797/2775)...
# Processing 3eh2_B (798/2775)...
# Processing 3elb_A (799/2775)...
# Processing 3epy_B (800/2775)...
# Processing 3epz_A (801/2775)...
# Processing 3eta_A (802/2775)...
# Processing 3eue_A (803/2775)...
# Processing 3exi_B (804/2775)...
# Processing 3eyh_A (805/2775)...
# Processing 3f1r_B (806/2775)...
# Processing 3f3y_A (807/2775)...
# Processing 3f5o_E (808/2775)...
# Processing 3f70_B (809/2775)...
# Processing 3f7u_C (810/2775)...
# Processing 3f9p_A (811/2775)...
# Processing 3fcx_B (812/2775)...
# Processing 3fd6_B (813/2775)...
# Processing 3fe2_B (814/2775)...
# Processing 3fe3_A (815/2775)...
# Processing 3fe4_A (816/2775)...
# Processing 3fec_A (817/2775)...
# Processing 3ff6_D (818/2775)...
# Processing 3ffk_A (819/2775)...
# Processing 3fg6_F (820/2775)...
# Processing 3fl2_A (821/2775)...
# Processing 3flv_B (822/2775)...
# Processing 3fvy_A (823/2775)...
# Processing 3fy1_A (824/2775)...
# Processing 3g4h_A (825/2775)...
# Processing 3g73_A (826/2775)...
# Processing 3g9y_A (827/2775)...
# Processing 3gbj_A (828/2775)...
# Processing 3gc9_B (829/2775)...
# Processing 3gdh_B (830/2775)...
# Processing 3gdq_A (831/2775)...
# Processing 3gep_B (832/2775)...
# Processing 3ggf_B (833/2775)...
# Processing 3ghg_C (834/2775)...
# Processing 3gis_Z (835/2775)...
# Processing 3gjx_E (836/2775)...
# Processing 3gkh_A (837/2775)...
# Processing 3gpd_G (838/2775)...
# Processing 3gqc_D (839/2775)...
# Processing 3gta_A (840/2775)...
# Processing 3gxb_A (841/2775)...
# Processing 3gzd_A (842/2775)...
# Processing 3h2u_B (843/2775)...
# Processing 3h53_B (844/2775)...
# Processing 3hco_B (845/2775)...
# Processing 3hf1_A (846/2775)...
# Processing 3hn3_B (847/2775)...
# Processing 3ho4_A (848/2775)...
# Processing 3hr4_G (849/2775)...
# Processing 3hud_B (850/2775)...
# Processing 3hxt_A (851/2775)...
# Processing 3hy8_A (852/2775)...
# Processing 3ia8_A (853/2775)...
# Processing 3iei_H (854/2775)...
# Processing 3ihp_B (855/2775)...
# Processing 3ik7_B (856/2775)...
# Processing 3io2_A (857/2775)...
# Processing 3isq_A (858/2775)...
# Processing 3iu6_A (859/2775)...
# Processing 3iuf_A (860/2775)...
# Processing 3iuy_A (861/2775)...
# Processing 3iwl_A (862/2775)...
# Processing 3ixe_B (863/2775)...
# Processing 3ixs_K (864/2775)...
# Processing 3j0a_A (865/2775)...
# Processing 3j2s_B (866/2775)...
# Processing 3jrx_A (867/2775)...
# Processing 3jub_A (868/2775)...
# Processing 3jue_A (869/2775)...
# Processing 3jyh_A (870/2775)...
# Processing 3k2s_B (871/2775)...
# Processing 3k51_B (872/2775)...
# Processing 3k5t_A (873/2775)...
# Processing 3k7v_A (874/2775)...
# Processing 3k9j_A (875/2775)...
# Processing 3k9o_A (876/2775)...
# Processing 3kcg_I (877/2775)...
# Processing 3kn1_A (878/2775)...
# Processing 3kq0_A (879/2775)...
# Processing 3kq4_B (880/2775)...
# Processing 3kqg_A (881/2775)...
# Processing 3kuc_A (882/2775)...
# Processing 3kv5_A (883/2775)...
# Processing 3kvo_A (884/2775)...
# Processing 3kyd_A (885/2775)...
# Processing 3l43_B (886/2775)...
# Processing 3lea_B (887/2775)...
# Processing 3lf5_B (888/2775)...
# Processing 3lgd_B (889/2775)...
# Processing 3ljw_A (890/2775)...
# Processing 3lkj_C (891/2775)...
# Processing 3llk_A (892/2775)...
# Processing 3lqc_A (893/2775)...
# Processing 3lqh_A (894/2775)...
# Processing 3lrq_C (895/2775)...
# Processing 3lru_B (896/2775)...
# Processing 3ltl_B (897/2775)...
# Processing 3luc_A (898/2775)...
# Processing 3lxj_A (899/2775)...
# Processing 3lxx_A (900/2775)...
# Processing 3ly5_A (901/2775)...
# Processing 3lyr_A (902/2775)...
# Processing 3m1d_B (903/2775)...
# Processing 3m52_A (904/2775)...
# Processing 3mb3_A (905/2775)...
# Processing 3mb4_B (906/2775)...
# Processing 3mbg_C (907/2775)...
# Processing 3mdi_A (908/2775)...
# Processing 3mdy_C (909/2775)...
# Processing 3mdz_A (910/2775)...
# Processing 3mgm_A (911/2775)...
# Processing 3mjh_B (912/2775)...
# Processing 3mp5_B (913/2775)...
# Processing 3mq7_L (914/2775)...
# Processing 3mqi_C (915/2775)...
# Processing 3mtg_B (916/2775)...
# Processing 3mtn_A (917/2775)...
# Processing 3my0_J (918/2775)...
# Processing 3mzg_B (919/2775)...
# Processing 3n1g_A (920/2775)...
# Processing 3n1m_B (921/2775)...
# Processing 3n5n_Y (922/2775)...
# Processing 3n7o_A (923/2775)...
# Processing 3na1_A (924/2775)...
# Processing 3ncu_A (925/2775)...
# Processing 3ner_B (926/2775)...
# Processing 3nks_A (927/2775)...
# Processing 3nmq_A (928/2775)...
# Processing 3nmz_B (929/2775)...
# Processing 3nv1_A (930/2775)...
# Processing 3nvq_B (931/2775)...
# Processing 3nwn_A (932/2775)...
# Processing 3nxb_A (933/2775)...
# Processing 3nyn_B (934/2775)...
# Processing 3o0g_A (935/2775)...
# Processing 3o4r_B (936/2775)...
# Processing 3o4s_A (937/2775)...
# Processing 3o7a_A (938/2775)...
# Processing 3oag_A (939/2775)...
# Processing 3oes_A (940/2775)...
# Processing 3oj3_J (941/2775)...
# Processing 3ojy_B (942/2775)...
# Processing 3orh_B (943/2775)...
# Processing 3otc_B (944/2775)...
# Processing 3ovp_B (945/2775)...
# Processing 3p0f_A (946/2775)...
# Processing 3p57_A (947/2775)...
# Processing 3pb4_X (948/2775)...
# Processing 3pe0_A (949/2775)...
# Processing 3pja_K (950/2775)...
# Processing 3pls_A (951/2775)...
# Processing 3pm0_A (952/2775)...
# Processing 3poo_A (953/2775)...
# Processing 3pse_B (954/2775)...
# Processing 3q13_A (955/2775)...
# Processing 3q19_A (956/2775)...
# Processing 3q1d_A (957/2775)...
# Processing 3q2u_A (958/2775)...
# Processing 3q3j_B (959/2775)...
# Processing 3q6z_A (960/2775)...
# Processing 3qcj_A (961/2775)...
# Processing 3qfb_B (962/2775)...
# Processing 3qj4_A (963/2775)...
# Processing 3qj5_B (964/2775)...
# Processing 3qmh_A (965/2775)...
# Processing 3qni_A (966/2775)...
# Processing 3qpu_A (967/2775)...
# Processing 3qrf_F (968/2775)...
# Processing 3qxy_B (969/2775)...
# Processing 3r6b_A (970/2775)...
# Processing 3rap_S (971/2775)...
# Processing 3ray_A (972/2775)...
# Processing 3rbl_B (973/2775)...
# Processing 3rc3_A (974/2775)...
# Processing 3rgk_A (975/2775)...
# Processing 3rk2_G (976/2775)...
# Processing 3rq4_A (977/2775)...
# Processing 3rz3_C (978/2775)...
# Processing 3rzv_A (979/2775)...
# Processing 3s4y_A (980/2775)...
# Processing 3sbz_A (981/2775)...
# Processing 3sh5_A (982/2775)...
# Processing 3sjv_F (983/2775)...
# Processing 3sn5_B (984/2775)...
# Processing 3szb_B (985/2775)...
# Processing 3t6a_A (986/2775)...
# Processing 3t7l_A (987/2775)...
# Processing 3t9i_A (988/2775)...
# Processing 3tac_A (989/2775)...
# Processing 3thd_D (990/2775)...
# Processing 3tkl_A (991/2775)...
# Processing 3top_A (992/2775)...
# Processing 3tvl_A (993/2775)...
# Processing 3twj_B (994/2775)...
# Processing 3u5n_A (995/2775)...
# Processing 3u8u_A (996/2775)...
# Processing 3ucw_A (997/2775)...
# Processing 3uh4_B (998/2775)...
# Processing 3uk3_C (999/2775)...
# Processing 3ukm_C (1000/2775)...
# Processing 3uyq_A (1001/2775)...
# Processing 3uzx_B (1002/2775)...
# Processing 3v3l_A (1003/2775)...
# Processing 3v4v_B (1004/2775)...
# Processing 3v4v_C (1005/2775)...
# Processing 3v70_A (1006/2775)...
# Processing 3v7t_A (1007/2775)...
# Processing 3v8x_B (1008/2775)...
# Processing 3vcm_B (1009/2775)...
# Processing 3vf0_A (1010/2775)...
# Processing 3vfq_A (1011/2775)...
# Processing 3vi3_A (1012/2775)...
# Processing 4cmn_A (1091/2775)...
# Processing 4cql_G (1092/2775)...
# Processing 4cql_P (1093/2775)...
# Processing 4crs_A (1094/2775)...
# Processing 4ct4_D (1095/2775)...
# Processing 4cvh_A (1096/2775)...
# Processing 4cvo_A (1097/2775)...
# Processing 4cz2_B (1098/2775)...
# Processing 4d08_D (1099/2775)...
# Processing 4d0g_A (1100/2775)...
# Processing 4d1p_B (1101/2775)...
# Processing 4d2n_D (1102/2775)...
# Processing 4d50_A (1103/2775)...
# Processing 4d8k_A (1104/2775)...
# Processing 4d90_B (1105/2775)...
# Processing 4da1_A (1106/2775)...
# Processing 4dg6_A (1107/2775)...
# Processing 4dgl_A (1108/2775)...
# Processing 4dgl_C (1109/2775)...
# Processing 4din_B (1110/2775)...
# Processing 4diq_A (1111/2775)...
# Processing 4dir_A (1112/2775)...
# Processing 4drb_F (1113/2775)...
# Processing 4duq_B (1114/2775)...
# Processing 4dur_A (1115/2775)...
# Processing 4dxa_B (1116/2775)...
# Processing 4dy7_C (1117/2775)...
# Processing 4e3c_D (1118/2775)...
# Processing 4e4m_B (1119/2775)...
# Processing 4e93_A (1120/2775)...
# Processing 4e9e_A (1121/2775)...
# Processing 4egc_B (1122/2775)...
# Processing 4epu_A (1123/2775)...
# Processing 4erc_A (1124/2775)...
# Processing 4ezf_A (1125/2775)...
# Processing 4f14_A (1126/2775)...
# Processing 4f5b_A (1127/2775)...
# Processing 4f80_A (1128/2775)...
# Processing 4f9c_B (1129/2775)...
# Processing 4fao_B (1130/2775)...
# Processing 4fc7_C (1131/2775)...
# Processing 4fdi_A (1132/2775)...
# Processing 4fgb_A (1133/2775)...
# Processing 4fgu_B (1134/2775)...
# Processing 4fl6_B (1135/2775)...
# Processing 4fmw_B (1136/2775)...
# Processing 4fom_A (1137/2775)...
# Processing 4fqf_A (1138/2775)...
# Processing 4fr4_F (1139/2775)...
# Processing 4fu4_C (1140/2775)...
# Processing 4fvl_A (1141/2775)...
# Processing 4fwj_A (1142/2775)...
# Processing 4g8a_B (1143/2775)...
# Processing 4gei_A (1144/2775)...
# Processing 4gk0_F (1145/2775)...
# Processing 4gmj_B (1146/2775)...
# Processing 4gnf_A (1147/2775)...
# Processing 4gnk_D (1148/2775)...
# Processing 4gos_A (1149/2775)...
# Processing 4gqq_A (1150/2775)...
# Processing 4gup_C (1151/2775)...
# Processing 4h2d_B (1152/2775)...
# Processing 4h5r_B (1153/2775)...
# Processing 4h7w_A (1154/2775)...
# Processing 4hai_A (1155/2775)...
# Processing 4haz_A (1156/2775)...
# Processing 4hc7_A (1157/2775)...
# Processing 4hlq_A (1158/2775)...
# Processing 4hni_B (1159/2775)...
# Processing 4hon_A (1160/2775)...
# Processing 4hvy_A (1161/2775)...
# Processing 4i5j_A (1162/2775)...
# Processing 4i6b_A (1163/2775)...
# Processing 4ic2_A (1164/2775)...
# Processing 4ic7_D (1165/2775)...
# Processing 4iej_A (1166/2775)...
# Processing 4ig8_A (1167/2775)...
# Processing 4ii1_B (1168/2775)...
# Processing 4iqm_A (1169/2775)...
# Processing 4iqy_B (1170/2775)...
# Processing 4iy0_A (1171/2775)...
# Processing 4j14_A (1172/2775)...
# Processing 4j1y_B (1173/2775)...
# Processing 4j4p_B (1174/2775)...
# Processing 4jvn_A (1175/2775)...
# Processing 4jxf_A (1176/2775)...
# Processing 4jzj_C (1177/2775)...
# Processing 4k7i_C (1178/2775)...
# Processing 4k85_C (1179/2775)...
# Processing 4kfz_B (1180/2775)...
# Processing 4ki5_M (1181/2775)...
# Processing 4kki_A (1182/2775)...
# Processing 4klz_A (1183/2775)...
# Processing 4kq8_A (1184/2775)...
# Processing 4kxc_A (1185/2775)...
# Processing 4kyi_H (1186/2775)...
# Processing 4l1j_B (1187/2775)...
# Processing 4l58_A (1188/2775)...
# Processing 4l7n_A (1189/2775)...
# Processing 4l9m_A (1190/2775)...
# Processing 4lay_A (1191/2775)...
# Processing 4lec_B (1192/2775)...
# Processing 4lhx_B (1193/2775)...
# Processing 4liq_E (1194/2775)...
# Processing 4lot_A (1195/2775)...
# Processing 4lqy_A (1196/2775)...
# Processing 4lt6_A (1197/2775)...
# Processing 4m6r_D (1198/2775)...
# Processing 4mew_A (1199/2775)...
# Processing 4mf3_A (1200/2775)...
# Processing 4mhv_B (1201/2775)...
# Processing 4mqw_X (1202/2775)...
# Processing 4msp_A (1203/2775)...
# Processing 4mvt_C (1204/2775)...
# Processing 4mwi_A (1205/2775)...
# Processing 4myg_A (1206/2775)...
# Processing 4n2c_A (1207/2775)...
# Processing 4n4a_A (1208/2775)...
# Processing 4neh_A (1209/2775)...
# Processing 4ngg_A (1210/2775)...
# Processing 4nn2_B (1211/2775)...
# Processing 4nnr_B (1212/2775)...
# Processing 4npv_A (1213/2775)...
# Processing 4nqa_I (1214/2775)...
# Processing 4ns5_A (1215/2775)...
# Processing 4nsq_C (1216/2775)...
# Processing 4nt5_A (1217/2775)...
# Processing 4nxs_B (1218/2775)...
# Processing 4o0c_B (1219/2775)...
# Processing 4o2w_B (1220/2775)...
# Processing 4o68_A (1221/2775)...
# Processing 4oav_B (1222/2775)...
# Processing 4oem_B (1223/2775)...
# Processing 4oj2_X (1224/2775)...
# Processing 4ojk_A (1225/2775)...
# Processing 4omc_E (1226/2775)...
# Processing 4oni_A (1227/2775)...
# Processing 4onn_B (1228/2775)...
# Processing 4or9_A (1229/2775)...
# Processing 4orw_A (1230/2775)...
# Processing 4otg_A (1231/2775)...
# Processing 4p0p_A (1232/2775)...
# Processing 4p13_C (1233/2775)...
# Processing 4p5w_A (1234/2775)...
# Processing 4p60_A (1235/2775)...
# Processing 4pcu_A (1236/2775)...
# Processing 4pcw_B (1237/2775)...
# Processing 4px2_A (1238/2775)...
# Processing 4pzi_A (1239/2775)...
# Processing 4q4b_A (1240/2775)...
# Processing 4q4d_A (1241/2775)...
# Processing 4q6f_A (1242/2775)...
# Processing 4q7y_A (1243/2775)...
# Processing 4q93_A (1244/2775)...
# Processing 4q9u_E (1245/2775)...
# Processing 4qbm_A (1246/2775)...
# Processing 4qc3_A (1247/2775)...
# Processing 4qil_A (1248/2775)...
# Processing 4qmx_A (1249/2775)...
# Processing 4qn9_A (1250/2775)...
# Processing 4qpn_A (1251/2775)...
# Processing 4qu6_A (1252/2775)...
# Processing 4r1f_A (1253/2775)...
# Processing 4r2d_A (1254/2775)...
# Processing 4r6u_A (1255/2775)...
# Processing 4r7a_B (1256/2775)...
# Processing 4r7p_B (1257/2775)...
# Processing 4r8p_K (1258/2775)...
# Processing 4rau_L (1259/2775)...
# Processing 4rda_A (1260/2775)...
# Processing 4re1_A (1261/2775)...
# Processing 4re8_B (1262/2775)...
# Processing 4rec_A (1263/2775)...
# Processing 4rer_A (1264/2775)...
# Processing 4rfq_A (1265/2775)...
# Processing 4rg1_A (1266/2775)...
# Processing 4rkk_A (1267/2775)...
# Processing 4rn0_A (1268/2775)...
# Processing 4rr2_A (1269/2775)...
# Processing 4rsu_F (1270/2775)...
# Processing 4ruh_B (1271/2775)...
# Processing 4s15_A (1272/2775)...
# Processing 4s3o_B (1273/2775)...
# Processing 4s3o_C (1274/2775)...
# Processing 4tlg_A (1275/2775)...
# Processing 4tnt_A (1276/2775)...
# Processing 4ttv_A (1277/2775)...
# Processing 4twe_B (1278/2775)...
# Processing 4u5t_A (1279/2775)...
# Processing 4u8d_A (1280/2775)...
# Processing 4ueg_A (1281/2775)...
# Processing 4uem_A (1282/2775)...
# Processing 4ug2_A (1283/2775)...
# Processing 4uhz_A (1284/2775)...
# Processing 4ui9_S (1285/2775)...
# Processing 4um8_D (1286/2775)...
# Processing 4usf_B (1287/2775)...
# Processing 4ust_A (1288/2775)...
# Processing 4uu6_A (1289/2775)...
# Processing 4uuu_A (1290/2775)...
# Processing 4uy2_B (1291/2775)...
# Processing 4uy9_A (1292/2775)...
# Processing 4uya_A (1293/2775)...
# Processing 4uye_B (1294/2775)...
# Processing 4v0h_D (1295/2775)...
# Processing 4v3k_F (1296/2775)...
# Processing 4v6x_Aa (1297/2775)...
# Processing 4v6x_Af (1298/2775)...
# Processing 4wgk_A (1299/2775)...
# Processing 4whv_I (1300/2775)...
# Processing 4wle_D (1301/2775)...
# Processing 4wmq_A (1302/2775)...
# Processing 4wqn_B (1303/2775)...
# Processing 4wzx_A (1304/2775)...
# Processing 4x0q_B (1305/2775)...
# Processing 4x30_A (1306/2775)...
# Processing 4x7q_B (1307/2775)...
# Processing 4x93_B (1308/2775)...
# Processing 4xcx_A (1309/2775)...
# Processing 4xdp_A (1310/2775)...
# Processing 4xft_A (1311/2775)...
# Processing 4xhz_A (1312/2775)...
# Processing 4xp7_A (1313/2775)...
# Processing 4xwh_A (1314/2775)...
# Processing 4xyj_H (1315/2775)...
# Processing 4xzp_A (1316/2775)...
# Processing 4y05_A (1317/2775)...
# Processing 4y7b_A (1318/2775)...
# Processing 4y86_A (1319/2775)...
# Processing 4y88_A (1320/2775)...
# Processing 4y8w_A (1321/2775)...
# Processing 4y97_H (1322/2775)...
# Processing 4yhj_B (1323/2775)...
# Processing 4yiq_D (1324/2775)...
# Processing 4yj0_A (1325/2775)...
# Processing 4yls_A (1326/2775)...
# Processing 4ylz_B (1327/2775)...
# Processing 4ymd_B (1328/2775)...
# Processing 4ymj_A (1329/2775)...
# Processing 4ynd_A (1330/2775)...
# Processing 4yoc_C (1331/2775)...
# Processing 4yvp_A (1332/2775)...
# Processing 4ywt_D (1333/2775)...
# Processing 4z0o_A (1334/2775)...
# Processing 4z2b_A (1335/2775)...
# Processing 4z9m_D (1336/2775)...
# Processing 4zaj_A (1337/2775)...
# Processing 4zc4_B (1338/2775)...
# Processing 4zcv_A (1339/2775)...
# Processing 4zdp_A (1340/2775)...
# Processing 4zel_A (1341/2775)...
# Processing 4zes_B (1342/2775)...
# Processing 4zfg_A (1343/2775)...
# Processing 4zg4_B (1344/2775)...
# Processing 4zg9_B (1345/2775)...
# Processing 4zht_B (1346/2775)...
# Processing 4zji_C (1347/2775)...
# Processing 4zlp_A (1348/2775)...
# Processing 4zma_L (1349/2775)...
# Processing 4zrp_B (1350/2775)...
# Processing 4zso_F (1351/2775)...
# Processing 4zvj_A (1352/2775)...
# Processing 4zvw_D (1353/2775)...
# Processing 4zya_A (1354/2775)...
# Processing 4zyo_A (1355/2775)...
# Processing 5a0e_A (1356/2775)...
# Processing 5a15_I (1357/2775)...
# Processing 5a46_A (1358/2775)...
# Processing 5a4k_B (1359/2775)...
# Processing 5a9j_D (1360/2775)...
# Processing 5aaq_A (1361/2775)...
# Processing 5aaz_A (1362/2775)...
# Processing 5ay8_E (1363/2775)...
# Processing 5b0h_B (1364/2775)...
# Processing 5b1x_B (1365/2775)...
# Processing 5b4x_D (1366/2775)...
# Processing 5b4y_B (1367/2775)...
# Processing 5bq8_B (1368/2775)...
# Processing 5bqd_B (1369/2775)...
# Processing 5bqe_C (1370/2775)...
# Processing 5brk_A (1371/2775)...
# Processing 5bwl_A (1372/2775)...
# Processing 5bx1_A (1373/2775)...
# Processing 5c11_A (1374/2775)...
# Processing 5c16_D (1375/2775)...
# Processing 5c41_B (1376/2775)...
# Processing 5c4v_F (1377/2775)...
# Processing 5c5c_A (1378/2775)...
# Processing 5c7j_B (1379/2775)...
# Processing 5c8w_C (1380/2775)...
# Processing 5cc0_B (1381/2775)...
# Processing 5ccb_A (1382/2775)...
# Processing 5ceq_A (1383/2775)...
# Processing 5cjf_A (1384/2775)...
# Processing 5cjp_E (1385/2775)...
# Processing 5cr5_B (1386/2775)...
# Processing 5cuf_A (1387/2775)...
# Processing 5cum_A (1388/2775)...
# Processing 5cvn_B (1389/2775)...
# Processing 5cxy_A (1390/2775)...
# Processing 5d0i_A (1391/2775)...
# Processing 5d1l_B (1392/2775)...
# Processing 5d6y_C (1393/2775)...
# Processing 5d9l_A (1394/2775)...
# Processing 5dah_B (1395/2775)...
# Processing 5dg1_B (1396/2775)...
# Processing 5din_A (1397/2775)...
# Processing 5dka_B (1398/2775)...
# Processing 5do7_B (1399/2775)...
# Processing 5dou_C (1400/2775)...
# Processing 5dv2_A (1401/2775)...
# Processing 5dvx_A (1402/2775)...
# Processing 5e26_B (1403/2775)...
# Processing 5e4l_B (1404/2775)...
# Processing 5e8i_G (1405/2775)...
# Processing 5e8j_A (1406/2775)...
# Processing 5ea1_A (1407/2775)...
# Processing 5ebe_A (1408/2775)...
# Processing 5edv_A (1409/2775)...
# Processing 5efq_C (1410/2775)...
# Processing 5egg_A (1411/2775)...
# Processing 5eh1_A (1412/2775)...
# Processing 5eh2_E (1413/2775)...
# Processing 5ekd_A (1414/2775)...
# Processing 5emc_B (1415/2775)...
# Processing 5emn_B (1416/2775)...
# Processing 5eqx_A (1417/2775)...
# Processing 5erc_A (1418/2775)...
# Processing 5es1_A (1419/2775)...
# Processing 5exr_C (1420/2775)...
# Processing 5eya_F (1421/2775)...
# Processing 5ezv_E (1422/2775)...
# Processing 5f0q_A (1423/2775)...
# Processing 5fd3_A (1424/2775)...
# Processing 5fe4_B (1425/2775)...
# Processing 5fey_A (1426/2775)...
# Processing 5fhh_B (1427/2775)...
# Processing 5fjv_C (1428/2775)...
# Processing 5fn5_C (1429/2775)...
# Processing 5for_A (1430/2775)...
# Processing 5fqd_C (1431/2775)...
# Processing 5fql_A (1432/2775)...
# Processing 5fws_A (1433/2775)...
# Processing 5g1p_A (1434/2775)...
# Processing 5g3m_B (1435/2775)...
# Processing 5g55_A (1436/2775)...
# Processing 5gl7_A (1437/2775)...
# Processing 5gmv_A (1438/2775)...
# Processing 5gox_A (1439/2775)...
# Processing 5grh_B (1440/2775)...
# Processing 5grq_D (1441/2775)...
# Processing 5gt0_G (1442/2775)...
# Processing 5gt3_G (1443/2775)...
# Processing 5gt8_D (1444/2775)...
# Processing 5gtj_D (1445/2775)...
# Processing 5gvs_B (1446/2775)...
# Processing 5gyn_A (1447/2775)...
# Processing 5h3n_A (1448/2775)...
# Processing 5h7r_D (1449/2775)...
# Processing 5h9m_A (1450/2775)...
# Processing 5hda_A (1451/2775)...
# Processing 5hdn_C (1452/2775)...
# Processing 5hdt_B (1453/2775)...
# Processing 5hh0_A (1454/2775)...
# Processing 5hk1_A (1455/2775)...
# Processing 5hlo_C (1456/2775)...
# Processing 5hm7_B (1457/2775)...
# Processing 5hms_A (1458/2775)...
# Processing 5hp5_B (1459/2775)...
# Processing 5hpy_D (1460/2775)...
# Processing 5hq3_B (1461/2775)...
# Processing 5htk_A (1462/2775)...
# Processing 5hvh_A (1463/2775)...
# Processing 5i0i_B (1464/2775)...
# Processing 5i2l_A (1465/2775)...
# Processing 5i3r_B (1466/2775)...
# Processing 5i73_A (1467/2775)...
# Processing 5i81_A (1468/2775)...
# Processing 5i8n_B (1469/2775)...
# Processing 5iko_A (1470/2775)...
# Processing 5ino_B (1471/2775)...
# Processing 5iry_A (1472/2775)...
# Processing 5iyd_A (1473/2775)...
# Processing 5iyd_I (1474/2775)...
# Processing 5izq_H (1475/2775)...
# Processing 5j18_A (1476/2775)...
# Processing 5j1s_A (1477/2775)...
# Processing 5j1s_B (1478/2775)...
# Processing 5j67_B (1479/2775)...
# Processing 5j9s_A (1480/2775)...
# Processing 7zr6_P (2595/2775)...
# Processing 7zrr_A (2596/2775)...
# Processing 7zsc_C (2597/2775)...
# Processing 7zyg_A (2598/2775)...
# Processing 7zyh_J (2599/2775)...
# Processing 7zyu_A (2600/2775)...
# Processing 7zzp_A (2601/2775)...
# Processing 8a0v_A (2602/2775)...
# Processing 8a38_C (2603/2775)...
# Processing 8a40_U (2604/2775)...
# Processing 8a4c_D (2605/2775)...
# Processing 8a4k_B (2606/2775)...
# Processing 8a6l_B (2607/2775)...
# Processing 8a8m_A (2608/2775)...
# Processing 8ajo_A (2609/2775)...
# Processing 8ari_W (2610/2775)...
# Processing 8as4_B (2611/2775)...
# Processing 8ayf_A (2612/2775)...
# Processing 8aza_A (2613/2775)...
# Processing 8b0a_K (2614/2775)...
# Processing 8b0f_C (2615/2775)...
# Processing 8b0f_F (2616/2775)...
# Processing 8b0g_J (2617/2775)...
# Processing 8b0h_E (2618/2775)...
# Processing 8b10_A (2619/2775)...
# Processing 8b5r_P (2620/2775)...
# Processing 8b6l_L (2621/2775)...
# Processing 8b6l_N (2622/2775)...
# Processing 8b6l_O (2623/2775)...
# Processing 8b9e_A (2624/2775)...
# Processing 8bah_B (2625/2775)...
# Processing 8bbg_C (2626/2775)...
# Processing 8bbs_A (2627/2775)...
# Processing 8bc9_J (2628/2775)...
# Processing 8blp_C (2629/2775)...
# Processing 8bot_U (2630/2775)...
# Processing 8bot_X (2631/2775)...
# Processing 8bub_B (2632/2775)...
# Processing 8bya_B (2633/2775)...
# Processing 8byl_B (2634/2775)...
# Processing 8bzy_A (2635/2775)...
# Processing 8c3u_A (2636/2775)...
# Processing 8c6j_7 (2637/2775)...
# Processing 8ca0_B (2638/2775)...
# Processing 8ch6_y (2639/2775)...
# Processing 8cqb_A (2640/2775)...
# Processing 8cr1_B (2641/2775)...
# Processing 8css_8 (2642/2775)...
# Processing 8cua_C (2643/2775)...
# Processing 8cuc_F (2644/2775)...
# Processing 8cv5_A (2645/2775)...
# Processing 8cx0_A (2646/2775)...
# Processing 8d1e_D (2647/2775)...
# Processing 8d1l_C (2648/2775)...
# Processing 8d30_A (2649/2775)...
# Processing 8d3c_E (2650/2775)...
# Processing 8d3v_A (2651/2775)...
# Processing 8d6e_A (2652/2775)...
# Processing 8d7z_C (2653/2775)...
# Processing 8d8i_A (2654/2775)...
# Processing 8daf_A (2655/2775)...
# Processing 8dbk_B (2656/2775)...
# Processing 8dey_F (2657/2775)...
# Processing 8dkm_P (2658/2775)...
# Processing 8dmk_G (2659/2775)...
# Processing 8dnu_D (2660/2775)...
# Processing 8dph_A (2661/2775)...
# Processing 8dyd_A (2662/2775)...
# Processing 8dyl_B (2663/2775)...
# Processing 8e0c_A (2664/2775)...
# Processing 8e0f_B (2665/2775)...
# Processing 8e1a_A (2666/2775)...
# Processing 8e3y_R (2667/2775)...
# Processing 8e4y_A (2668/2775)...
# Processing 8e8v_A (2669/2775)...
# Processing 8e93_B (2670/2775)...
# Processing 8e98_C (2671/2775)...
# Processing 8e9z_A (2672/2775)...
# Processing 8ede_B (2673/2775)...
# Processing 8ef7_A (2674/2775)...
# Processing 8efg_A (2675/2775)...
# Processing 8efq_R (2676/2775)...
# Processing 8eg3_A (2677/2775)...
# Processing 8egx_B (2678/2775)...
# Processing 8eih_A (2679/2775)...
# Processing 8eiq_A (2680/2775)...
# Processing 8ejm_A (2681/2775)...
# Processing 8emr_B (2682/2775)...
# Processing 8eok_G (2683/2775)...
# Processing 8eop_A (2684/2775)...
# Processing 8eor_B (2685/2775)...
# Processing 8epl_A (2686/2775)...
# Processing 8esv_A (2687/2775)...
# Processing 8eyk_F (2688/2775)...
# Processing 8eyo_A (2689/2775)...
# Processing 8f7s_R (2690/2775)...
# Processing 8fb2_B (2691/2775)...
# Processing 8fc7_B (2692/2775)...
# Processing 8ffv_A (2693/2775)...
# Processing 8ffw_D (2694/2775)...
# Processing 8fgw_C (2695/2775)...
# Processing 8fjx_A (2696/2775)...
# Processing 8fmu_B (2697/2775)...
# Processing 8fnb_B (2698/2775)...
# Processing 8foa_A (2699/2775)...
# Processing 8fp1_A (2700/2775)...
# Processing 8fw5_B (2701/2775)...
# Processing 8fyh_I (2702/2775)...
# Processing 8g0l_A (2703/2775)...
# Processing 8g46_B (2704/2775)...
# Processing 8g7n_A (2705/2775)...
# Processing 8g9p_D (2706/2775)...
# Processing 8gju_D (2707/2775)...
# Processing 8gk3_H (2708/2775)...
# Processing 8gnn_A (2709/2775)...
# Processing 8gui_K (2710/2775)...
# Processing 8gx3_A (2711/2775)...
# Processing 8gye_A (2712/2775)...
# Processing 8gyx_B (2713/2775)...
# Processing 8gz2_B (2714/2775)...
# Processing 8h65_C (2715/2775)...
# Processing 8h8j_C (2716/2775)...
# Processing 8hbe_B (2717/2775)...
# Processing 8hdp_R (2718/2775)...
# Processing 8hy5_B (2719/2775)...
# Processing 8i1o_A (2720/2775)...
# Processing 8i5y_A (2721/2775)...
# Processing 8i5y_B (2722/2775)...
# Processing 8i9u_J (2723/2775)...
# Processing 8i9u_O (2724/2775)...
# Processing 8ifo_A (2725/2775)...
# Processing 8il3_C (2726/2775)...
# Processing 8iqn_A (2727/2775)...
# Processing 8irr_R (2728/2775)...
# Processing 8iuh_3 (2729/2775)...
# Processing 8iwu_A (2730/2775)...
# Processing 8iys_R (2731/2775)...
# Processing 8jbn_B (2732/2775)...
# Processing 8jdl_AP (2733/2775)...
# Processing 8jhf_A (2734/2775)...
# Processing 8jii_A (2735/2775)...
# Processing 8jyg_B (2736/2775)...
# Processing 8kb5_G (2737/2775)...
# Processing 8odo_A (2738/2775)...
# Processing 8oew_O (2739/2775)...
# Processing 8oi8_A (2740/2775)...
# Processing 8oma_A (2741/2775)...
# Processing 8omr_A (2742/2775)...
# Processing 8oxy_A (2743/2775)...
# Processing 8p50_B (2744/2775)...
# Processing 8p8x_A (2745/2775)...
# Processing 8p94_A (2746/2775)...
# Processing 8pqh_A (2747/2775)...
# Processing 8q7n_K (2748/2775)...
# Processing 8qk3_E (2749/2775)...
# Processing 8qy4_D (2750/2775)...
# Processing 8rbx_W (2751/2775)...
# Processing 8sg5_H (2752/2775)...
# Processing 8sgo_C (2753/2775)...
# Processing 8syp_C (2754/2775)...
# Processing 8t6j_A (2755/2775)...
# Processing 8t9h_K (2756/2775)...
# Processing 8tar_N (2757/2775)...
# Processing 8tgd_A (2758/2775)...
# Processing 8tnq_B (2759/2775)...
# Processing 8tzo_C (2760/2775)...
# Processing 8tzs_A (2761/2775)...
# Processing 8u26_R (2762/2775)...
# Processing 8u37_A (2763/2775)...
# Processing 8ucd_C (2764/2775)...
# Processing 8uhd_Y (2765/2775)...
# Processing 8v4y_W (2766/2775)...
# Processing 8v8u_B (2767/2775)...
# Processing 8wej_B (2768/2775)...
# Processing 8x15_W (2769/2775)...
# Processing 8x72_A (2770/2775)...
# Processing 8xov_A (2771/2775)...
# Processing 8xpn_A (2772/2775)...
# Processing 8y14_A (2773/2775)...
# Processing 8y6b_F (2774/2775)...
# Processing 8y6o_H (2775/2775)...

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

number_of_pockets = sum([len(i) for i in binding_residues.values()])

mean_br = np.mean(best_residue_overlaps)
median_br = np.median(best_residue_overlaps)
print(f'best_residue_overlap mean={mean_br:.4f}, median={median_br:.4f}')

print(np.sum(np.array(DCCs) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N_plus_K) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N_plus_K) < 4) / number_of_pockets})')
print(np.sum(np.array(DCCs_N) < 12) / number_of_pockets, f'({np.sum(np.array(DCCs_N) < 4) / number_of_pockets})')


print('\nSmall binding pockets (less than 10 residues):')
small_pockets_DCCs = [DCCs[i] for i in range(len(DCCs)) if is_small_pocket_DCC[i]]
print(f'Overall DCC < 12: {np.sum(np.array(small_pockets_DCCs) < 12) / len(small_pockets_DCCs):.4f} ({np.sum(np.array(small_pockets_DCCs) < 4) / len(small_pockets_DCCs):.4f})')
small_pockets_DCCs_N_plus_K = [DCCs_N_plus_K[i] for i in range(len(DCCs_N_plus_K)) if is_small_pocket_DCC_N_plus_K[i]]
print(f'N+K DCC < 12: {np.sum(np.array(small_pockets_DCCs_N_plus_K) < 12) / len(small_pockets_DCCs_N_plus_K):.4f} ({np.sum(np.array(small_pockets_DCCs_N_plus_K) < 4) / len(small_pockets_DCCs_N_plus_K):.4f})')
small_pockets_DCCs_N = [DCCs_N[i] for i in range(len(DCCs_N)) if is_small_pocket_DCC_N[i]]
print(f'N DCC < 12: {np.sum(np.array(small_pockets_DCCs_N) < 12) / len(small_pockets_DCCs_N):.4f} ({np.sum(np.array(small_pockets_DCCs_N) < 4) / len(small_pockets_DCCs_N):.4f})')

print('\nLarge binding pockets (10 or more residues):')
large_pockets_DCCs = [DCCs[i] for i in range(len(DCCs)) if not is_small_pocket_DCC[i]]
print(f'Overall DCC < 12: {np.sum(np.array(large_pockets_DCCs) < 12) / len(large_pockets_DCCs):.4f} ({np.sum(np.array(large_pockets_DCCs) < 4) / len(large_pockets_DCCs):.4f})')
large_pockets_DCCs_N_plus_K = [DCCs_N_plus_K[i] for i in range(len(DCCs_N_plus_K)) if not is_small_pocket_DCC_N_plus_K[i]]
print(f'N+K DCC < 12: {np.sum(np.array(large_pockets_DCCs_N_plus_K) < 12) / len(large_pockets_DCCs_N_plus_K):.4f} ({np.sum(np.array(large_pockets_DCCs_N_plus_K) < 4) / len(large_pockets_DCCs_N_plus_K):.4f})')
large_pockets_DCCs_N = [DCCs_N[i] for i in range(len(DCCs_N)) if not is_small_pocket_DCC_N[i]]
print(f'N DCC < 12: {np.sum(np.array(large_pockets_DCCs_N) < 12) / len(large_pockets_DCCs_N):.4f} ({np.sum(np.array(large_pockets_DCCs_N) < 4) / len(large_pockets_DCCs_N):.4f})')  


fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros = [i for i in number_of_overlapping_actual_sites_on_predicted_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Predicted Pockets Covering True Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_actual_sites_on_predicted_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Predicted Pockets Covering True Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()

fig, ax = plt.subplots(figsize=(7, 4))

# Remove zeros
number_of_overlapping_predictions_on_actual_pocket_without_zeros = [i for i in number_of_overlapping_predictions_on_actual_pocket if i != 0]
bins = np.arange(-0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 1.5, 1)
ax.clear()
ax.hist(number_of_overlapping_predictions_on_actual_pocket_without_zeros, bins=bins, color='C0', edgecolor='k', alpha=0.75)
mean_cov = np.mean(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
median_cov = np.median(number_of_overlapping_predictions_on_actual_pocket_without_zeros)
ax.axvline(mean_cov, color='red', linestyle='--', label=f"mean={mean_cov:.2f}")
ax.axvline(median_cov, color='orange', linestyle=':', label=f"median={median_cov:.2f}")
ax.set_title("Histogram of number of Actual Pockets Covering Predicted Pockets")
ax.set_xlim(0.5, max(number_of_overlapping_predictions_on_actual_pocket_without_zeros) + 0.5)
ax.set_xlabel("Number of Actual Pockets Covering Predicted Pockets")
ax.set_ylabel("Count")
ax.legend()
ax.grid(alpha=0.3)
plt.show()
# Out:
# best_residue_overlap mean=0.4042, median=0.4000
# 0.558994478349317 (0.1839581517000872)
# 0.552019761697181 (0.18047079337401917)
# 0.5201976169718106 (0.16724789305434468)
#
# Small binding pockets (less than 10 residues):
# Overall DCC < 12: 0.4903 (0.1341)
# N+K DCC < 12: 0.4810 (0.1303)
# N DCC < 12: 0.4438 (0.1134)
#
# Large binding pockets (10 or more residues):
# Overall DCC < 12: 0.7660 (0.2805)
# N+K DCC < 12: 0.7597 (0.2765)
# N DCC < 12: 0.7259 (0.2639)
# Exception ignored in: <function ResourceTracker.__del__ at 0x14a8b7ba0a40>
# Traceback (most recent call last):
#   File "/work/skrhakv/miniconda3/envs/cryptic-nn/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/work/skrhakv/miniconda3/envs/cryptic-nn/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/work/skrhakv/miniconda3/envs/cryptic-nn/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x15490ff90a40>
# Traceback (most recent call last):
#   File "/work/skrhakv/miniconda3/envs/cryptic-nn/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/work/skrhakv/miniconda3/envs/cryptic-nn/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/work/skrhakv/miniconda3/envs/cryptic-nn/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
