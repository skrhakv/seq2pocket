# %% [markdown]
# # Intro
# Code copied from the `cryptic-finetuning` repository history to replicate the results that were calculated previously.

# %%
import torch
from transformers import AutoTokenizer, EsmModel
import numpy as np
import torch.nn as nn
import sklearn.metrics as metrics
import functools
import sys
sys.path.append('/home/skrhakv/cryptoshow-analysis/src/utils')
sys.path.append('/home/skrhakv/cryptic-nn/src') 
import eval_utils
import finetuning_utils # download from https://github.com/skrhakv/cryptic-finetuning/blob/master/src/finetuning_utils.py
import baseline_utils

torch.manual_seed(420)
MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/model-enhanced-scPDB.pt'
ESM_MODEL_NAME = 'facebook/esm2_t36_3B_UR50D'
MAX_LENGTH = 1024
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DECISION_THRESHOLD = 0.7
loaded_model = torch.load(MODEL_PATH, weights_only=False).to(DEVICE)
tokenizer = AutoTokenizer.from_pretrained(ESM_MODEL_NAME)
partial_collate_fn = functools.partial(finetuning_utils.collate_fn, tokenizer=tokenizer)

# %%
import csv
RESIDUE_LEVEL_ANNOTATIONS = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis_for_residue_level_evaluation.csv'
sequences = {}
annotations = {}
with open('/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis_for_pocket_level_evaluation.csv', 'r') as f:
    reader = csv.reader(f, delimiter=';')
    for row in reader:
        sequences[row[0]] = row[4]
        if row[0] not in annotations:
            annotations[row[0]] = row[3]
        else:
            annotations[row[0]] += ' ' + row[3]
with open(RESIDUE_LEVEL_ANNOTATIONS, 'w') as f:
    for protein_id in sequences:
        f.write(f"{protein_id[:4]};{protein_id[4:]};UNKNOWN;{annotations[protein_id]};{sequences[protein_id]}\n")
val_dataset = finetuning_utils.process_sequence_dataset(
    RESIDUE_LEVEL_ANNOTATIONS, 
    tokenizer,
    load_ids=True,
    )

# %%
SMOOTHING_MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/C-optimize-smoother/smoother.pt'

SMOOTHING_DECISION_THRESHOLD = 0.4 # see src/C-optimize-smoother/classifier-for-cryptoshow.ipynb
DROPOUT = 0.5
LAYER_WIDTH = 2048
ESM2_DIM = 2560
INPUT_DIM  = ESM2_DIM * 2

class CryptoBenchClassifier(nn.Module):
    def __init__(self, dim=LAYER_WIDTH, dropout=DROPOUT):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=INPUT_DIM, out_features=dim)
        self.dropout1 = nn.Dropout(dropout)

        self.layer_2 = nn.Linear(in_features=dim, out_features=dim)
        self.dropout2 = nn.Dropout(dropout)

        self.layer_3 = nn.Linear(in_features=dim, out_features=1)

        self.relu = nn.ReLU()

    def forward(self, x):
      # Intersperse the ReLU activation function between layers
       return self.layer_3(self.dropout2(self.relu(self.layer_2(self.dropout1(self.relu(self.layer_1(x)))))))


smoothing_model = torch.load(SMOOTHING_MODEL_PATH, weights_only=False).to(DEVICE)
smoothing_model.eval()
# Out:
# CryptoBenchClassifier(
#   (layer_1): Linear(in_features=5120, out_features=2048, bias=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (layer_2): Linear(in_features=2048, out_features=2048, bias=True)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (layer_3): Linear(in_features=2048, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %% [markdown]
# ## Run model with smoothing

# %%
sys.path.append('/home/skrhakv/cryptoshow-analysis/src/utils')
sys.path.append('/home/skrhakv/cryptic-nn/src')
import eval_utils

# ESM_EMBEDDINGS_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/embeddings-enhanced-scPDB'
ESM_EMBEDDINGS_PATH = '/home/skrhakv/esm2/embeddings/sc-PDB-debugging'
COORDINATES_DIR = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis-coordinates'
POSITIVE_DISTANCE_THRESHOLD = 10

with torch.no_grad():
    all_test_logits = []
    all_test_pred = []
    all_y_test = []
    this_test_losses = []

    for batch in val_dataset:
        
        protein_id = batch['ids'][0]
        del batch['ids']
        batch = finetuning_utils.collate_fn([batch], tokenizer=tokenizer)
        output1 = loaded_model(batch)

        labels = batch['labels'].to(DEVICE)
        flattened_labels = labels.flatten()
        y_test = flattened_labels[flattened_labels != -100]
        logits = output1.flatten()[flattened_labels != -100]

        test_pred = (torch.sigmoid(logits)>DECISION_THRESHOLD).float()
        test_pred_copy = test_pred.clone().detach().cpu().numpy()

        # let's use the smoothing model here:
        # first, get the distance matrix
        coordinates = np.load(f'{COORDINATES_DIR}/{protein_id}.npy')
        distance_matrix = eval_utils.compute_distance_matrix(coordinates)

        assert distance_matrix.shape[0] == distance_matrix.shape[1]
        assert distance_matrix.shape[0] == test_pred_copy.shape[0]
        
        X_test = np.load(f'{ESM_EMBEDDINGS_PATH}/{protein_id}.npy')
        assert X_test.shape[0] == distance_matrix.shape[0]

        # loop over the residues that are not binding and are potential candidates for smoothing
        for residue_idx in torch.where(test_pred == 0.0)[0]:
            # get the embedding of the residue
            current_residue_embedding = X_test[residue_idx]

            # get the close binding residues
            close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
            close_binding_residues_indices = np.intersect1d(close_residues_indices, torch.where(test_pred == 1.0)[0].cpu().numpy())

            # create embedding 
            if len(close_binding_residues_indices) == 0:
                # no close binding residues - skip this residue
                continue
            elif len(close_binding_residues_indices) == 1:
                surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
            else:
                # get the mean of the close binding residues
                surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

            concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(DEVICE)
            
            # get the prediction
            test_logits = smoothing_model(concatenated_embedding).squeeze()
            result = (torch.sigmoid(test_logits)>SMOOTHING_DECISION_THRESHOLD).float()
            # print(result)
            if result == 1:
                # set the residue as binding
                print(f"Smoothing changed residue {residue_idx} in protein {protein_id} to binding")
                test_pred_copy[residue_idx] = 1
        
        all_test_logits.append(logits.cpu().detach().numpy())
        all_y_test.append(y_test.cpu().detach().numpy())
        all_test_pred.append(test_pred_copy)
        assert len(y_test) == len(test_pred_copy)        
    test_logits = torch.tensor(np.concatenate(all_test_logits, axis=0), dtype=torch.float32).to(DEVICE)
    test_pred = torch.tensor(np.concatenate(all_test_pred, axis=0), dtype=torch.float32).to(DEVICE)
    y_test = torch.tensor(np.concatenate(all_y_test, axis=0), dtype=torch.float32).to(DEVICE)

    test_acc = baseline_utils.accuracy_fn(y_true=y_test,
                            y_pred=test_pred)

    mcc = metrics.matthews_corrcoef(y_test.cpu().numpy(), test_pred.cpu().numpy())

    f1 = metrics.f1_score(y_test.cpu().numpy(), test_pred.cpu().numpy(), average='weighted')

print(f"Accuracy: {test_acc:.2f}% |  MCC: {mcc:.4f}, F1: {f1:.4f}")
# Out:
# Smoothing changed residue 23 in protein 1a52A to binding
# Smoothing changed residue 33 in protein 1a52A to binding
# Smoothing changed residue 49 in protein 1a52A to binding
# Smoothing changed residue 96 in protein 1a52A to binding
# Smoothing changed residue 109 in protein 1a52A to binding
# Smoothing changed residue 111 in protein 1a52A to binding
# Smoothing changed residue 113 in protein 1a52A to binding
# Smoothing changed residue 116 in protein 1a52A to binding
# Smoothing changed residue 206 in protein 1a52A to binding
# Smoothing changed residue 221 in protein 1a52A to binding
# Smoothing changed residue 223 in protein 1a52A to binding
# Smoothing changed residue 227 in protein 1a52A to binding
# Smoothing changed residue 30 in protein 1a9wE to binding
# Smoothing changed residue 109 in protein 1a9wE to binding
# Smoothing changed residue 99 in protein 1aiiA to binding
# Smoothing changed residue 109 in protein 1aiiA to binding
# Smoothing changed residue 270 in protein 1aiiA to binding
# Smoothing changed residue 302 in protein 1aiiA to binding
# Smoothing changed residue 0 in protein 1aueB to binding
# Smoothing changed residue 2 in protein 1aueB to binding
# Smoothing changed residue 36 in protein 1aueB to binding
# Smoothing changed residue 40 in protein 1aueB to binding
# Smoothing changed residue 41 in protein 1aueB to binding
# Smoothing changed residue 49 in protein 1aueB to binding
# Smoothing changed residue 53 in protein 1aueB to binding
# Smoothing changed residue 80 in protein 1aueB to binding
# Smoothing changed residue 90 in protein 1aueB to binding
# Smoothing changed residue 110 in protein 1b1cA to binding
# Smoothing changed residue 140 in protein 1b1cA to binding
# Smoothing changed residue 142 in protein 1b1cA to binding
# Smoothing changed residue 143 in protein 1b1cA to binding
# Smoothing changed residue 146 in protein 1b1cA to binding
# Smoothing changed residue 8 in protein 1b50B to binding
# Smoothing changed residue 23 in protein 1b50B to binding
# Smoothing changed residue 31 in protein 1b50B to binding
# Smoothing changed residue 40 in protein 1b50B to binding
# Smoothing changed residue 43 in protein 1b50B to binding
# Smoothing changed residue 11 in protein 1b55B to binding
# Smoothing changed residue 16 in protein 1b55B to binding
# Smoothing changed residue 19 in protein 1b55B to binding
# Smoothing changed residue 20 in protein 1b55B to binding
# Smoothing changed residue 22 in protein 1b55B to binding
# Smoothing changed residue 79 in protein 1b6cF to binding
# Smoothing changed residue 89 in protein 1b6cF to binding
# Smoothing changed residue 108 in protein 1b9oA to binding
# Smoothing changed residue 21 in protein 1bboA to binding
# Smoothing changed residue 25 in protein 1bciA to binding
# Smoothing changed residue 78 in protein 1bciA to binding
# Smoothing changed residue 1 in protein 1bf9A to binding
# Smoothing changed residue 18 in protein 1bf9A to binding
# Smoothing changed residue 17 in protein 1bhiA to binding
# Smoothing changed residue 105 in protein 1bldA to binding
# Smoothing changed residue 91 in protein 1blxA to binding
# Smoothing changed residue 181 in protein 1bmoA to binding
# Smoothing changed residue 206 in protein 1bmoA to binding
# Smoothing changed residue 215 in protein 1bmoA to binding
# Smoothing changed residue 17 in protein 1bnlA to binding
# Smoothing changed residue 284 in protein 1cm8A to binding
# Smoothing changed residue 57 in protein 1cwsA to binding
# Smoothing changed residue 112 in protein 1cwsA to binding
# Smoothing changed residue 443 in protein 1cx8C to binding
# Smoothing changed residue 454 in protein 1cx8C to binding
# Smoothing changed residue 70 in protein 1czaN to binding
# Smoothing changed residue 72 in protein 1czaN to binding
# Smoothing changed residue 86 in protein 1czaN to binding
# Smoothing changed residue 158 in protein 1czaN to binding
# Smoothing changed residue 159 in protein 1czaN to binding
# Smoothing changed residue 195 in protein 1czaN to binding
# Smoothing changed residue 207 in protein 1czaN to binding
# Smoothing changed residue 210 in protein 1czaN to binding
# Smoothing changed residue 215 in protein 1czaN to binding
# Smoothing changed residue 377 in protein 1czaN to binding
# Smoothing changed residue 381 in protein 1czaN to binding
# Smoothing changed residue 400 in protein 1czaN to binding
# Smoothing changed residue 425 in protein 1czaN to binding
# Smoothing changed residue 427 in protein 1czaN to binding
# Smoothing changed residue 431 in protein 1czaN to binding
# Smoothing changed residue 433 in protein 1czaN to binding
# Smoothing changed residue 450 in protein 1czaN to binding
# Smoothing changed residue 516 in protein 1czaN to binding
# Smoothing changed residue 518 in protein 1czaN to binding
# Smoothing changed residue 519 in protein 1czaN to binding
# Smoothing changed residue 520 in protein 1czaN to binding
# Smoothing changed residue 530 in protein 1czaN to binding
# Smoothing changed residue 598 in protein 1czaN to binding
# Smoothing changed residue 603 in protein 1czaN to binding
# Smoothing changed residue 606 in protein 1czaN to binding
# Smoothing changed residue 607 in protein 1czaN to binding
# Smoothing changed residue 643 in protein 1czaN to binding
# Smoothing changed residue 663 in protein 1czaN to binding
# Smoothing changed residue 694 in protein 1czaN to binding
# Smoothing changed residue 829 in protein 1czaN to binding
# Smoothing changed residue 848 in protein 1czaN to binding
# Smoothing changed residue 881 in protein 1czaN to binding
# Smoothing changed residue 95 in protein 1d1sA to binding
# Smoothing changed residue 113 in protein 1d1sA to binding
# Smoothing changed residue 114 in protein 1d1sA to binding
# Smoothing changed residue 115 in protein 1d1sA to binding
# Smoothing changed residue 74 in protein 1d4uA to binding
# Smoothing changed residue 24 in protein 1d5gA to binding
# Smoothing changed residue 0 in protein 1drfA to binding
# Smoothing changed residue 1 in protein 1drfA to binding
# Smoothing changed residue 25 in protein 1drfA to binding
# Smoothing changed residue 41 in protein 1drfA to binding
# Smoothing changed residue 47 in protein 1drfA to binding
# Smoothing changed residue 79 in protein 1drfA to binding
# Smoothing changed residue 95 in protein 1drfA to binding
# Smoothing changed residue 171 in protein 1drfA to binding
# Smoothing changed residue 36 in protein 1ds6A to binding
# Smoothing changed residue 62 in protein 1ds6A to binding
# Smoothing changed residue 66 in protein 1ds6A to binding
# Smoothing changed residue 67 in protein 1ds6A to binding
# Smoothing changed residue 84 in protein 1ds6A to binding
# Smoothing changed residue 123 in protein 1ds6A to binding
# Smoothing changed residue 124 in protein 1ds6A to binding
# Smoothing changed residue 125 in protein 1ds6A to binding
# Smoothing changed residue 127 in protein 1ds6A to binding
# Smoothing changed residue 131 in protein 1ds6A to binding
# Smoothing changed residue 132 in protein 1ds6A to binding
# Smoothing changed residue 130 in protein 1nuuB to binding
# Smoothing changed residue 145 in protein 1nuuB to binding
# Smoothing changed residue 172 in protein 1nuuB to binding
# Smoothing changed residue 174 in protein 1nuuB to binding
# Smoothing changed residue 18 in protein 1nypA to binding
# Smoothing changed residue 37 in protein 1nypA to binding
# Smoothing changed residue 125 in protein 1ohcA to binding
# Smoothing changed residue 126 in protein 1ohcA to binding
# Smoothing changed residue 127 in protein 1ohcA to binding
# Smoothing changed residue 129 in protein 1ohcA to binding
# Smoothing changed residue 131 in protein 1ohcA to binding
# Smoothing changed residue 249 in protein 1ohcA to binding
# Smoothing changed residue 112 in protein 1oj6D to binding
# Smoothing changed residue 92 in protein 1oplA to binding
# Smoothing changed residue 184 in protein 1oplA to binding
# Smoothing changed residue 185 in protein 1oplA to binding
# Smoothing changed residue 192 in protein 1oplA to binding
# Smoothing changed residue 225 in protein 1oplA to binding
# Smoothing changed residue 231 in protein 1oplA to binding
# Smoothing changed residue 262 in protein 1oplA to binding
# Smoothing changed residue 266 in protein 1oplA to binding
# Smoothing changed residue 267 in protein 1oplA to binding
# Smoothing changed residue 269 in protein 1oplA to binding
# Smoothing changed residue 273 in protein 1oplA to binding
# Smoothing changed residue 297 in protein 1oplA to binding
# Smoothing changed residue 368 in protein 1oplA to binding
# Smoothing changed residue 376 in protein 1oplA to binding
# Smoothing changed residue 397 in protein 1oplA to binding
# Smoothing changed residue 441 in protein 1oplA to binding
# Smoothing changed residue 445 in protein 1oplA to binding
# Smoothing changed residue 449 in protein 1oplA to binding
# Smoothing changed residue 450 in protein 1oplA to binding
# Smoothing changed residue 7 in protein 1oqjB to binding
# Smoothing changed residue 16 in protein 1oqjB to binding
# Smoothing changed residue 51 in protein 1oqjB to binding
# Smoothing changed residue 61 in protein 1oqjB to binding
# Smoothing changed residue 87 in protein 1oqjB to binding
# Smoothing changed residue 16 in protein 1ozoA to binding
# Smoothing changed residue 17 in protein 1ozoA to binding
# Smoothing changed residue 20 in protein 1ozoA to binding
# Smoothing changed residue 25 in protein 1ozoA to binding
# Smoothing changed residue 32 in protein 1ozoA to binding
# Smoothing changed residue 36 in protein 1ozoA to binding
# Smoothing changed residue 54 in protein 1ozoA to binding
# Smoothing changed residue 66 in protein 1ozoA to binding
# Smoothing changed residue 70 in protein 1ozoA to binding
# Smoothing changed residue 73 in protein 1ozoA to binding
# Smoothing changed residue 74 in protein 1ozoA to binding
# Smoothing changed residue 77 in protein 1ozoA to binding
# Smoothing changed residue 87 in protein 1ozoA to binding
# Smoothing changed residue 12 in protein 1ozsA to binding
# Smoothing changed residue 14 in protein 1ozsA to binding
# Smoothing changed residue 17 in protein 1ozsA to binding
# Smoothing changed residue 180 in protein 1p4oA to binding
# Smoothing changed residue 15 in protein 1p4qB to binding
# Smoothing changed residue 21 in protein 1p4qB to binding
# Smoothing changed residue 27 in protein 1p4qB to binding
# Smoothing changed residue 48 in protein 1p4qB to binding
# Smoothing changed residue 53 in protein 1p4qB to binding
# Smoothing changed residue 94 in protein 1p4qB to binding
# Smoothing changed residue 33 in protein 1pb5A to binding
# Smoothing changed residue 97 in protein 8hdpR to binding
# Smoothing changed residue 105 in protein 8hdpR to binding
# Smoothing changed residue 109 in protein 8hdpR to binding
# Smoothing changed residue 116 in protein 8hdpR to binding
# Smoothing changed residue 146 in protein 8hdpR to binding
# Smoothing changed residue 147 in protein 8hdpR to binding
# Smoothing changed residue 150 in protein 8hdpR to binding
# Smoothing changed residue 151 in protein 8hdpR to binding
# Smoothing changed residue 152 in protein 8hdpR to binding
# Smoothing changed residue 180 in protein 8hdpR to binding
# Smoothing changed residue 198 in protein 8hdpR to binding
# Smoothing changed residue 199 in protein 8hdpR to binding
# Smoothing changed residue 204 in protein 8hdpR to binding
# Smoothing changed residue 205 in protein 8hdpR to binding
# Smoothing changed residue 210 in protein 8hdpR to binding
# Smoothing changed residue 214 in protein 8hdpR to binding
# Smoothing changed residue 228 in protein 8hdpR to binding
# Smoothing changed residue 259 in protein 8hdpR to binding
# Smoothing changed residue 262 in protein 8hdpR to binding
# Smoothing changed residue 267 in protein 8hdpR to binding
# Smoothing changed residue 166 in protein 8hy5B to binding
# Smoothing changed residue 238 in protein 8hy5B to binding
# Smoothing changed residue 168 in protein 8i1oA to binding
# Smoothing changed residue 22 in protein 8i9uJ to binding
# Smoothing changed residue 26 in protein 8i9uJ to binding
# Smoothing changed residue 27 in protein 8i9uJ to binding
# Smoothing changed residue 72 in protein 8i9uJ to binding
# Smoothing changed residue 81 in protein 8i9uJ to binding
# Smoothing changed residue 148 in protein 8i9uJ to binding
# Smoothing changed residue 365 in protein 8i9uJ to binding
# Smoothing changed residue 368 in protein 8i9uJ to binding
# Smoothing changed residue 441 in protein 8i9uJ to binding
# Smoothing changed residue 453 in protein 8i9uJ to binding
# Smoothing changed residue 461 in protein 8i9uJ to binding
# Smoothing changed residue 472 in protein 8i9uJ to binding
# Smoothing changed residue 25 in protein 8i9uO to binding
# Smoothing changed residue 32 in protein 8i9uO to binding
# Smoothing changed residue 34 in protein 8i9uO to binding
# Smoothing changed residue 77 in protein 8i9uO to binding
# Smoothing changed residue 374 in protein 8i9uO to binding
# Smoothing changed residue 375 in protein 8i9uO to binding
# Smoothing changed residue 382 in protein 8i9uO to binding
# Smoothing changed residue 440 in protein 8i9uO to binding
# Smoothing changed residue 447 in protein 8i9uO to binding
# Smoothing changed residue 463 in protein 8i9uO to binding
# Smoothing changed residue 482 in protein 8i9uO to binding
# Smoothing changed residue 10 in protein 8ifoA to binding
# Smoothing changed residue 17 in protein 8ifoA to binding
# Smoothing changed residue 50 in protein 8ifoA to binding
# Smoothing changed residue 74 in protein 8ifoA to binding
# Smoothing changed residue 100 in protein 8il3C to binding
# Smoothing changed residue 159 in protein 8il3C to binding
# Smoothing changed residue 160 in protein 8il3C to binding
# Smoothing changed residue 162 in protein 8il3C to binding
# Smoothing changed residue 163 in protein 8il3C to binding
# Smoothing changed residue 164 in protein 8il3C to binding
# Smoothing changed residue 34 in protein 8iqnA to binding
# Smoothing changed residue 36 in protein 8iqnA to binding
# Smoothing changed residue 37 in protein 8iqnA to binding
# Smoothing changed residue 38 in protein 8iqnA to binding
# Smoothing changed residue 39 in protein 8iqnA to binding
# Smoothing changed residue 69 in protein 8iqnA to binding
# Smoothing changed residue 72 in protein 8iqnA to binding
# Smoothing changed residue 117 in protein 8iqnA to binding
# Smoothing changed residue 119 in protein 8iqnA to binding
# Smoothing changed residue 123 in protein 8iqnA to binding
# Smoothing changed residue 127 in protein 8iqnA to binding
# Smoothing changed residue 128 in protein 8iqnA to binding
# Smoothing changed residue 131 in protein 8iqnA to binding
# Smoothing changed residue 232 in protein 8iqnA to binding
# Smoothing changed residue 233 in protein 8iqnA to binding
# Smoothing changed residue 235 in protein 8iqnA to binding
# Smoothing changed residue 237 in protein 8iqnA to binding
# Smoothing changed residue 243 in protein 8iqnA to binding
# Smoothing changed residue 245 in protein 8iqnA to binding
# Smoothing changed residue 251 in protein 8iqnA to binding
# Smoothing changed residue 2 in protein 8irrR to binding
# Smoothing changed residue 5 in protein 8irrR to binding
# Smoothing changed residue 13 in protein 8irrR to binding
# Smoothing changed residue 16 in protein 8irrR to binding
# Smoothing changed residue 49 in protein 8irrR to binding
# Smoothing changed residue 52 in protein 8irrR to binding
# Smoothing changed residue 53 in protein 8irrR to binding
# Smoothing changed residue 58 in protein 8irrR to binding
# Smoothing changed residue 59 in protein 8irrR to binding
# Smoothing changed residue 68 in protein 8irrR to binding
# Smoothing changed residue 263 in protein 8irrR to binding
# Smoothing changed residue 165 in protein 8iwuA to binding
# Smoothing changed residue 167 in protein 8iwuA to binding
# Smoothing changed residue 209 in protein 8iwuA to binding
# Smoothing changed residue 210 in protein 8iwuA to binding
# Smoothing changed residue 437 in protein 8iwuA to binding
# Smoothing changed residue 474 in protein 8iwuA to binding
# Smoothing changed residue 631 in protein 8iwuA to binding
# Smoothing changed residue 65 in protein 8iysR to binding
# Smoothing changed residue 69 in protein 8iysR to binding
# Smoothing changed residue 169 in protein 8iysR to binding
# Smoothing changed residue 39 in protein 8jbnB to binding
# Smoothing changed residue 40 in protein 8jbnB to binding
# Smoothing changed residue 41 in protein 8jbnB to binding
# Smoothing changed residue 81 in protein 8jbnB to binding
# Smoothing changed residue 172 in protein 8jbnB to binding
# Smoothing changed residue 173 in protein 8jbnB to binding
# Smoothing changed residue 7 in protein 8jdlAP to binding
# Smoothing changed residue 24 in protein 8jiiA to binding
# Smoothing changed residue 172 in protein 8jiiA to binding
# Smoothing changed residue 230 in protein 8jiiA to binding
# Smoothing changed residue 29 in protein 8jygB to binding
# Smoothing changed residue 30 in protein 8jygB to binding
# Smoothing changed residue 94 in protein 8odoA to binding
# Smoothing changed residue 151 in protein 8odoA to binding
# Smoothing changed residue 211 in protein 8odoA to binding
# Smoothing changed residue 219 in protein 8odoA to binding
# Smoothing changed residue 220 in protein 8odoA to binding
# Smoothing changed residue 221 in protein 8odoA to binding
# Smoothing changed residue 254 in protein 8odoA to binding
# Smoothing changed residue 257 in protein 8odoA to binding
# Smoothing changed residue 264 in protein 8odoA to binding
# Smoothing changed residue 372 in protein 8odoA to binding
# Smoothing changed residue 454 in protein 8odoA to binding
# Smoothing changed residue 467 in protein 8odoA to binding
# Smoothing changed residue 38 in protein 8oewO to binding
# Smoothing changed residue 93 in protein 8oewO to binding
# Smoothing changed residue 98 in protein 8oewO to binding
# Smoothing changed residue 123 in protein 8oi8A to binding
# Smoothing changed residue 258 in protein 8oi8A to binding
# Smoothing changed residue 344 in protein 8oi8A to binding
# Smoothing changed residue 349 in protein 8oi8A to binding
# Smoothing changed residue 361 in protein 8oi8A to binding
# Smoothing changed residue 484 in protein 8omaA to binding
# Smoothing changed residue 490 in protein 8omaA to binding
# Smoothing changed residue 500 in protein 8omaA to binding
# Smoothing changed residue 542 in protein 8omaA to binding
# Smoothing changed residue 598 in protein 8omaA to binding
# Smoothing changed residue 631 in protein 8omaA to binding
# Smoothing changed residue 668 in protein 8omaA to binding
# Smoothing changed residue 38 in protein 8omrA to binding
# Smoothing changed residue 39 in protein 8omrA to binding
# Smoothing changed residue 43 in protein 8omrA to binding
# Smoothing changed residue 48 in protein 8omrA to binding
# Smoothing changed residue 67 in protein 8omrA to binding
# Smoothing changed residue 98 in protein 8omrA to binding
# Smoothing changed residue 129 in protein 8omrA to binding
# Smoothing changed residue 133 in protein 8omrA to binding
# Smoothing changed residue 136 in protein 8omrA to binding
# Smoothing changed residue 156 in protein 8omrA to binding
# Smoothing changed residue 157 in protein 8omrA to binding
# Smoothing changed residue 164 in protein 8omrA to binding
# Smoothing changed residue 167 in protein 8omrA to binding
# Smoothing changed residue 189 in protein 8omrA to binding
# Smoothing changed residue 190 in protein 8omrA to binding
# Smoothing changed residue 269 in protein 8omrA to binding
# Smoothing changed residue 270 in protein 8omrA to binding
# Smoothing changed residue 271 in protein 8omrA to binding
# Smoothing changed residue 279 in protein 8omrA to binding
# Smoothing changed residue 280 in protein 8omrA to binding
# Smoothing changed residue 287 in protein 8omrA to binding
# Smoothing changed residue 288 in protein 8omrA to binding
# Smoothing changed residue 290 in protein 8omrA to binding
# Smoothing changed residue 329 in protein 8omrA to binding
# Smoothing changed residue 336 in protein 8omrA to binding
# Smoothing changed residue 31 in protein 8oxyA to binding
# Smoothing changed residue 324 in protein 8oxyA to binding
# Smoothing changed residue 391 in protein 8oxyA to binding
# Smoothing changed residue 393 in protein 8oxyA to binding
# Smoothing changed residue 416 in protein 8oxyA to binding
# Smoothing changed residue 5 in protein 8p50B to binding
# Smoothing changed residue 68 in protein 8p50B to binding
# Smoothing changed residue 110 in protein 8p50B to binding
# Smoothing changed residue 147 in protein 8p50B to binding
# Smoothing changed residue 78 in protein 8p8xA to binding
# Smoothing changed residue 84 in protein 8p8xA to binding
# Smoothing changed residue 87 in protein 8p8xA to binding
# Smoothing changed residue 89 in protein 8p8xA to binding
# Smoothing changed residue 128 in protein 8p8xA to binding
# Smoothing changed residue 129 in protein 8p8xA to binding
# Smoothing changed residue 132 in protein 8p8xA to binding
# Smoothing changed residue 281 in protein 8p8xA to binding
# Smoothing changed residue 142 in protein 8p94A to binding
# Smoothing changed residue 328 in protein 8p94A to binding
# Smoothing changed residue 330 in protein 8p94A to binding
# Smoothing changed residue 370 in protein 8p94A to binding
# Smoothing changed residue 406 in protein 8p94A to binding
# Smoothing changed residue 49 in protein 8pqhA to binding
# Smoothing changed residue 101 in protein 8pqhA to binding
# Smoothing changed residue 13 in protein 8sg5H to binding
# Smoothing changed residue 19 in protein 8sg5H to binding
# Smoothing changed residue 20 in protein 8sg5H to binding
# Smoothing changed residue 21 in protein 8sg5H to binding
# Smoothing changed residue 39 in protein 8sg5H to binding
# Smoothing changed residue 44 in protein 8sg5H to binding
# Smoothing changed residue 46 in protein 8sg5H to binding
# Smoothing changed residue 51 in protein 8sg5H to binding
# Smoothing changed residue 52 in protein 8sg5H to binding
# Smoothing changed residue 157 in protein 8sg5H to binding
# Smoothing changed residue 186 in protein 8sg5H to binding
# Smoothing changed residue 199 in protein 8sg5H to binding
# Smoothing changed residue 380 in protein 8sg5H to binding
# Smoothing changed residue 387 in protein 8sg5H to binding
# Smoothing changed residue 399 in protein 8sg5H to binding
# Smoothing changed residue 426 in protein 8sg5H to binding
# Smoothing changed residue 91 in protein 8sgoC to binding
# Smoothing changed residue 35 in protein 8t6jA to binding
# Smoothing changed residue 580 in protein 8t6jA to binding
# Smoothing changed residue 607 in protein 8t6jA to binding
# Smoothing changed residue 727 in protein 8t6jA to binding
# Smoothing changed residue 728 in protein 8t6jA to binding
# Smoothing changed residue 24 in protein 8t9hK to binding
# Smoothing changed residue 25 in protein 8t9hK to binding
# Smoothing changed residue 99 in protein 8t9hK to binding
# Smoothing changed residue 158 in protein 8tarN to binding
# Smoothing changed residue 59 in protein 8tnqB to binding
# Smoothing changed residue 70 in protein 8tnqB to binding
# Smoothing changed residue 73 in protein 8tnqB to binding
# Smoothing changed residue 332 in protein 8tnqB to binding
# Smoothing changed residue 348 in protein 8tnqB to binding
# Smoothing changed residue 87 in protein 8tzoC to binding
# Smoothing changed residue 88 in protein 8tzoC to binding
# Smoothing changed residue 90 in protein 8tzoC to binding
# Smoothing changed residue 301 in protein 8tzsA to binding
# Smoothing changed residue 58 in protein 8u26R to binding
# Smoothing changed residue 220 in protein 8u26R to binding
# Smoothing changed residue 38 in protein 8u37A to binding
# Smoothing changed residue 19 in protein 8uhdY to binding
# Smoothing changed residue 30 in protein 8uhdY to binding
# Smoothing changed residue 81 in protein 8uhdY to binding
# Smoothing changed residue 64 in protein 8v4yW to binding
# Smoothing changed residue 69 in protein 8v4yW to binding
# Smoothing changed residue 70 in protein 8v4yW to binding
# Smoothing changed residue 112 in protein 8v4yW to binding
# Smoothing changed residue 168 in protein 8v4yW to binding
# Smoothing changed residue 375 in protein 8v4yW to binding
# Smoothing changed residue 376 in protein 8v4yW to binding
# Smoothing changed residue 49 in protein 8v8uB to binding
# Smoothing changed residue 50 in protein 8v8uB to binding
# Smoothing changed residue 57 in protein 8v8uB to binding
# Smoothing changed residue 64 in protein 8v8uB to binding
# Smoothing changed residue 65 in protein 8v8uB to binding
# Smoothing changed residue 68 in protein 8v8uB to binding
# Smoothing changed residue 75 in protein 8v8uB to binding
# Smoothing changed residue 76 in protein 8v8uB to binding
# Smoothing changed residue 99 in protein 8v8uB to binding
# Smoothing changed residue 93 in protein 8wejB to binding
# Smoothing changed residue 324 in protein 8wejB to binding
# Smoothing changed residue 388 in protein 8wejB to binding
# Smoothing changed residue 389 in protein 8wejB to binding
# Smoothing changed residue 391 in protein 8wejB to binding
# Smoothing changed residue 509 in protein 8wejB to binding
# Smoothing changed residue 510 in protein 8wejB to binding
# Smoothing changed residue 13 in protein 8x15W to binding
# Smoothing changed residue 18 in protein 8x72A to binding
# Smoothing changed residue 106 in protein 8x72A to binding
# Smoothing changed residue 108 in protein 8x72A to binding
# Smoothing changed residue 36 in protein 8xpnA to binding
# Smoothing changed residue 108 in protein 8xpnA to binding
# Smoothing changed residue 172 in protein 8xpnA to binding
# Smoothing changed residue 223 in protein 8xpnA to binding
# Smoothing changed residue 228 in protein 8xpnA to binding
# Smoothing changed residue 246 in protein 8xpnA to binding
# Smoothing changed residue 252 in protein 8xpnA to binding
# Smoothing changed residue 253 in protein 8xpnA to binding
# Smoothing changed residue 254 in protein 8xpnA to binding
# Smoothing changed residue 277 in protein 8y14A to binding
# Smoothing changed residue 281 in protein 8y14A to binding
# Smoothing changed residue 317 in protein 8y14A to binding
# Accuracy: 90.53% |  MCC: 0.5008, F1: 0.9079

# %% [markdown]
# ## Model with smoothing without ions
# Run the model that was trained on the original scPDB without enhancement.

# %%
MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/model-non-enhanced-scPDB.pt'

loaded_model = torch.load(MODEL_PATH, weights_only=False).to(DEVICE)

with torch.no_grad():
    all_test_logits = []
    all_test_pred = []
    all_y_test = []
    this_test_losses = []

    for batch in val_dataset:
        
        protein_id = batch['ids'][0]
        del batch['ids']
        batch = finetuning_utils.collate_fn([batch], tokenizer=tokenizer)
        output1 = loaded_model(batch)

        labels = batch['labels'].to(DEVICE)
        flattened_labels = labels.flatten()
        y_test = flattened_labels[flattened_labels != -100]
        logits = output1.flatten()[flattened_labels != -100]

        test_pred = (torch.sigmoid(logits)>DECISION_THRESHOLD).float()
        test_pred_copy = test_pred.clone().detach().cpu().numpy()

        # let's use the smoothing model here:
        # first, get the distance matrix
        coordinates = np.load(f'{COORDINATES_DIR}/{protein_id}.npy')
        distance_matrix = eval_utils.compute_distance_matrix(coordinates)

        assert distance_matrix.shape[0] == distance_matrix.shape[1]
        assert distance_matrix.shape[0] == test_pred_copy.shape[0]
        
        X_test = np.load(f'{ESM_EMBEDDINGS_PATH}/{protein_id}.npy')
        assert X_test.shape[0] == distance_matrix.shape[0]

        # loop over the residues that are not binding and are potential candidates for smoothing
        for residue_idx in torch.where(test_pred == 0.0)[0]:
            # get the embedding of the residue
            current_residue_embedding = X_test[residue_idx]

            # get the close binding residues
            close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
            close_binding_residues_indices = np.intersect1d(close_residues_indices, torch.where(test_pred == 1.0)[0].cpu().numpy())

            # create embedding 
            if len(close_binding_residues_indices) == 0:
                # no close binding residues - skip this residue
                continue
            elif len(close_binding_residues_indices) == 1:
                surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
            else:
                # get the mean of the close binding residues
                surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

            concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(DEVICE)
            
            # get the prediction
            test_logits = smoothing_model(concatenated_embedding).squeeze()
            result = (torch.sigmoid(test_logits)>SMOOTHING_DECISION_THRESHOLD).float()
            if result == 1:
                # set the residue as binding
                test_pred_copy[residue_idx] = 1
        
        all_test_logits.append(logits.cpu().detach().numpy())
        all_y_test.append(y_test.cpu().detach().numpy())
        all_test_pred.append(test_pred_copy)
        assert len(y_test) == len(test_pred_copy)        
    test_logits = torch.tensor(np.concatenate(all_test_logits, axis=0), dtype=torch.float32).to(DEVICE)
    test_pred = torch.tensor(np.concatenate(all_test_pred, axis=0), dtype=torch.float32).to(DEVICE)
    y_test = torch.tensor(np.concatenate(all_y_test, axis=0), dtype=torch.float32).to(DEVICE)

    test_acc = baseline_utils.accuracy_fn(y_true=y_test,
                            y_pred=test_pred)

    mcc = metrics.matthews_corrcoef(y_test.cpu().numpy(), test_pred.cpu().numpy())

    f1 = metrics.f1_score(y_test.cpu().numpy(), test_pred.cpu().numpy(), average='weighted')
    
    fpr, tpr, thresholds = metrics.roc_curve(y_test.cpu().float().numpy(), torch.sigmoid(test_logits).cpu().float().numpy())
    roc_auc = metrics.auc(fpr, tpr)
    precision, recall, thresholds = metrics.precision_recall_curve(y_test.cpu().float().numpy(), torch.sigmoid(test_logits).cpu().float().numpy())
    auprc = metrics.auc(recall, precision)

print(f"Accuracy: {test_acc:.2f}% | AUC: {roc_auc:.4f}, MCC: {mcc:.4f}, F1: {f1:.4f}, AUPRC: {auprc:.4f}")
# Out:
# Accuracy: 90.42% | AUC: 0.8217, MCC: 0.4312, F1: 0.9012, AUPRC: 0.4958

# %% [markdown]
# ## Compare it with model without smoothing

# %%
from torch.utils.data import DataLoader
MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/model-enhanced-scPDB.pt'

loaded_model = torch.load(MODEL_PATH, weights_only=False).to(DEVICE)

partial_collate_fn = functools.partial(finetuning_utils.collate_fn, tokenizer=tokenizer)
val_dataset = finetuning_utils.process_sequence_dataset(RESIDUE_LEVEL_ANNOTATIONS, tokenizer)
val_dataloader = DataLoader(val_dataset, batch_size=val_dataset.num_rows // 20, collate_fn=partial_collate_fn)

all_test_logits = []
all_test_pred = []
all_y_test = []

with torch.no_grad():
    for batch in val_dataloader:
        output1 = loaded_model(batch)

        labels = batch['labels'].to(DEVICE)

        flattened_labels = labels.flatten()

        logits = output1.flatten()[flattened_labels != -100]
        valid_flattened_labels = labels.flatten()[flattened_labels != -100]

        predictions = (torch.sigmoid(logits)>DECISION_THRESHOLD).float()

        all_test_logits.append(logits.cpu().detach().numpy())
        all_y_test.append(valid_flattened_labels.cpu().detach().numpy())
        all_test_pred.append(predictions.cpu().detach().numpy())
        assert len(valid_flattened_labels) == len(predictions)        
    
    cbs_logits = torch.tensor(np.concatenate(all_test_logits, axis=0), dtype=torch.float32).to(DEVICE)
    predictions = torch.tensor(np.concatenate(all_test_pred, axis=0), dtype=torch.float32).to(DEVICE)
    valid_flattened_labels = torch.tensor(np.concatenate(all_y_test, axis=0), dtype=torch.float32).to(DEVICE)

    # compute metrics on test dataset
    test_acc = baseline_utils.accuracy_fn(y_true=valid_flattened_labels,
                            y_pred=predictions)
    fpr, tpr, thresholds = metrics.roc_curve(valid_flattened_labels.cpu().float().numpy(), torch.sigmoid(cbs_logits).cpu().float().numpy())
    roc_auc = metrics.auc(fpr, tpr)

    mcc = metrics.matthews_corrcoef(valid_flattened_labels.cpu().float().numpy(), predictions.cpu().float().numpy())

    f1 = metrics.f1_score(valid_flattened_labels.cpu().float().numpy(), predictions.cpu().float().numpy(), average='weighted')

    precision, recall, thresholds = metrics.precision_recall_curve(valid_flattened_labels.cpu().float().numpy(), torch.sigmoid(cbs_logits).cpu().float().numpy())
    auprc = metrics.auc(recall, precision)

print(f"Accuracy: {test_acc:.2f}% | AUC: {roc_auc:.4f}, MCC: {mcc:.4f}, F1: {f1:.4f}, AUPRC: {auprc:.4f}")
# Out:
# Accuracy: 91.50% | AUC: 0.8732, MCC: 0.5204, F1: 0.9147, AUPRC: 0.5949

# %% [markdown]
# ## Model with smoothing without ions, on LIGYSIS_NI
# Run the model that was trained on the original scPDB without enhancement, but on LIGYSIS without ions (LIGYSIS_NI)

# %%
import csv
RESIDUE_LEVEL_ANNOTATIONS = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis_NI_for_residue_level_evaluation.csv'
sequences = {}
annotations = {}
with open('/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis_NI_without_unobserved.csv', 'r') as f:
    reader = csv.reader(f, delimiter=';')
    for row in reader:
        sequences[row[0]] = row[4]
        if row[0] not in annotations:
            annotations[row[0]] = row[3]
        else:
            annotations[row[0]] += ' ' + row[3]
with open(RESIDUE_LEVEL_ANNOTATIONS, 'w') as f:
    for protein_id in sequences:
        f.write(f"{protein_id[:4]};{protein_id[4:]};UNKNOWN;{annotations[protein_id]};{sequences[protein_id]}\n")
val_dataset = finetuning_utils.process_sequence_dataset(
    RESIDUE_LEVEL_ANNOTATIONS, 
    tokenizer,
    load_ids=True,
    )

# %%
MODEL_PATH = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/model-non-enhanced-scPDB.pt'
COORDINATES_DIR = '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis-coordinates'
ESM_EMBEDDINGS_PATH = '/home/skrhakv/esm2/embeddings/sc-PDB-debugging'
POSITIVE_DISTANCE_THRESHOLD = 10

loaded_model = torch.load(MODEL_PATH, weights_only=False).to(DEVICE)

with torch.no_grad():
    all_test_logits = []
    all_test_pred = []
    all_y_test = []
    this_test_losses = []

    for batch in val_dataset:
        
        protein_id = batch['ids'][0]
        del batch['ids']
        batch = finetuning_utils.collate_fn([batch], tokenizer=tokenizer)
        output1 = loaded_model(batch)

        labels = batch['labels'].to(DEVICE)
        flattened_labels = labels.flatten()
        y_test = flattened_labels[flattened_labels != -100]
        logits = output1.flatten()[flattened_labels != -100]

        test_pred = (torch.sigmoid(logits)>DECISION_THRESHOLD).float()
        test_pred_copy = test_pred.clone().detach().cpu().numpy()

        # let's use the smoothing model here:
        # first, get the distance matrix
        coordinates = np.load(f'{COORDINATES_DIR}/{protein_id}.npy')
        distance_matrix = eval_utils.compute_distance_matrix(coordinates)

        assert distance_matrix.shape[0] == distance_matrix.shape[1]
        assert distance_matrix.shape[0] == test_pred_copy.shape[0]
        
        X_test = np.load(f'{ESM_EMBEDDINGS_PATH}/{protein_id}.npy')
        assert X_test.shape[0] == distance_matrix.shape[0]

        # loop over the residues that are not binding and are potential candidates for smoothing
        for residue_idx in torch.where(test_pred == 0.0)[0]:
            # get the embedding of the residue
            current_residue_embedding = X_test[residue_idx]

            # get the close binding residues
            close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
            close_binding_residues_indices = np.intersect1d(close_residues_indices, torch.where(test_pred == 1.0)[0].cpu().numpy())

            # create embedding 
            if len(close_binding_residues_indices) == 0:
                # no close binding residues - skip this residue
                continue
            elif len(close_binding_residues_indices) == 1:
                surrounding_embedding = X_test[close_binding_residues_indices].reshape(-1)
            else:
                # get the mean of the close binding residues
                surrounding_embedding = np.mean(X_test[close_binding_residues_indices], axis=0).reshape(-1)

            concatenated_embedding = torch.tensor(np.concatenate((current_residue_embedding, surrounding_embedding), axis=0), dtype=torch.float32).to(DEVICE)
            
            # get the prediction
            test_logits = smoothing_model(concatenated_embedding).squeeze()
            result = (torch.sigmoid(test_logits)>SMOOTHING_DECISION_THRESHOLD).float()
            if result == 1:
                # set the residue as binding
                test_pred_copy[residue_idx] = 1
        
        all_test_logits.append(logits.cpu().detach().numpy())
        all_y_test.append(y_test.cpu().detach().numpy())
        all_test_pred.append(test_pred_copy)
        assert len(y_test) == len(test_pred_copy)        
    test_logits = torch.tensor(np.concatenate(all_test_logits, axis=0), dtype=torch.float32).to(DEVICE)
    test_pred = torch.tensor(np.concatenate(all_test_pred, axis=0), dtype=torch.float32).to(DEVICE)
    y_test = torch.tensor(np.concatenate(all_y_test, axis=0), dtype=torch.float32).to(DEVICE)

    test_acc = baseline_utils.accuracy_fn(y_true=y_test,
                            y_pred=test_pred)

    mcc = metrics.matthews_corrcoef(y_test.cpu().numpy(), test_pred.cpu().numpy())

    f1 = metrics.f1_score(y_test.cpu().numpy(), test_pred.cpu().numpy(), average='weighted')
    
    fpr, tpr, thresholds = metrics.roc_curve(y_test.cpu().float().numpy(), torch.sigmoid(test_logits).cpu().float().numpy())
    roc_auc = metrics.auc(fpr, tpr)
    precision, recall, thresholds = metrics.precision_recall_curve(y_test.cpu().float().numpy(), torch.sigmoid(test_logits).cpu().float().numpy())
    auprc = metrics.auc(recall, precision)

print(f"Accuracy: {test_acc:.2f}% | AUC: {roc_auc:.4f}, MCC: {mcc:.4f}, F1: {f1:.4f}, AUPRC: {auprc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 30
#      26 test_pred_copy = test_pred.clone().detach().cpu().numpy()
#      28 # let's use the smoothing model here:
#      29 # first, get the distance matrix
# ---> 30 coordinates = np.load(f'{COORDINATES_DIR}/{protein_id}.npy')
#      31 distance_matrix = eval_utils.compute_distance_matrix(coordinates)
#      33 assert distance_matrix.shape[0] == distance_matrix.shape[1]
#
# File ~/cryptic-nn/src/fine-tuning/esmc-venv/lib/python3.12/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/skrhakv/cryptoshow-analysis/data/E-regular-binding-site-predictor/ligysis-coordinates/1a5hB.npy'
